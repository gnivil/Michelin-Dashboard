# %%
#3 Star Restaurants List of Dictionaires 1-857
[{'Restaurant Name': 'Kashiwaya',
  'Price Range': '13,000 - 43,000 JPY',
  'Restauarant Website': 'https://jp-kashiwaya.com/senriyama/'},
 {'Restaurant Name': 'HAJIME',
  'Price Range': '40,000 - 54,000 JPY',
  'Restauarant Website': 'http://www.hajime-artistes.com/'},
 {'Restaurant Name': 'Taian',
  'Price Range': '20,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Isshisoden Nakamura',
  'Price Range': '26,000 - 38,000 JPY',
  'Restauarant Website': 'http://www.kyoryori-nakamura.com/'},
 {'Restaurant Name': 'Kikunoi Honten',
  'Price Range': '17,000 - 64,000 JPY',
  'Restauarant Website': 'https://kikunoi.jp/'},
 {'Restaurant Name': 'Gion Sasaki',
  'Price Range': '8,000 - 37,000 JPY',
  'Restauarant Website': 'http://gionsasaki.com/'},
 {'Restaurant Name': 'Mizai',
  'Price Range': '50,000 JPY',
  'Restauarant Website': 'https://mizai.jp/'},
 {'Restaurant Name': 'Hyotei',
  'Price Range': '26,000 - 64,000 JPY',
  'Restauarant Website': 'http://hyotei.co.jp/'},
 {'Restaurant Name': 'Maeda',
  'Price Range': '49,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'The French Laundry',
  'Price Range': '350 - 450 USD',
  'Restauarant Website': 'https://www.thomaskeller.com/tfl'},
 {'Restaurant Name': 'SingleThread',
  'Price Range': '375 USD',
  'Restauarant Website': 'https://www.singlethreadfarms.com/'},
 {'Restaurant Name': 'Manresa',
  'Price Range': '325 USD',
  'Restauarant Website': 'https://www.manresarestaurant.com/'},
 {'Restaurant Name': 'Atelier Crenn',
  'Price Range': '298 USD',
  'Restauarant Website': 'https://www.ateliercrenn.com/'},
 {'Restaurant Name': 'Benu',
  'Price Range': '350 USD',
  'Restauarant Website': 'https://www.benusf.com/'},
 {'Restaurant Name': 'Quince',
  'Price Range': '195 - 298 USD',
  'Restauarant Website': 'https://www.quincerestaurant.com/'},
 {'Restaurant Name': 'Frantzén',
  'Price Range': '3,800 SEK',
  'Restauarant Website': 'https://www.restaurantfrantzen.com/'},
 {'Restaurant Name': 'Maaemo',
  'Price Range': '3,500 NOK',
  'Restauarant Website': 'www.maaemo.no'},
 {'Restaurant Name': 'Geranium',
  'Price Range': '2,800 DKK',
  'Restauarant Website': 'https://www.geranium.dk/'},
 {'Restaurant Name': 'noma',
  'Price Range': '2,800 DKK',
  'Restauarant Website': 'http://www.noma.dk/'},
 {'Restaurant Name': 'Odette',
  'Price Range': '248 - 358 SGD',
  'Restauarant Website': 'https://www.odetterestaurant.com/'},
 {'Restaurant Name': 'Les Amis',
  'Price Range': '155 - 480 SGD',
  'Restauarant Website': 'https://www.lesamis.com.sg/'},
 {'Restaurant Name': 'Zén',
  'Price Range': '450 SGD',
  'Restauarant Website': 'https://www.restaurantzen.com/'},
 {'Restaurant Name': 'Le Palais',
  'Price Range': '2,000 - 5,000 TWD',
  'Restauarant Website': 'https://www.palaisdechinehotel.com/'},
 {'Restaurant Name': 'Eleven Madison Park',
  'Price Range': '125 - 285 USD',
  'Restauarant Website': 'https://www.elevenmadisonpark.com/'},
 {'Restaurant Name': 'Per Se',
  'Price Range': '355 USD',
  'Restauarant Website': 'http://www.perseny.com/'},
 {'Restaurant Name': 'Masa',
  'Price Range': '595 USD',
  'Restauarant Website': 'https://www.masanyc.com/'},
 {'Restaurant Name': 'Le Bernardin',
  'Price Range': '93 - 228 USD',
  'Restauarant Website': 'https://www.le-bernardin.com/'},
 {'Restaurant Name': "Chef's Table at Brooklyn Fare",
  'Price Range': '395 USD',
  'Restauarant Website': 'http://www.brooklynfare.com/'},
 {'Restaurant Name': 'Alinea',
  'Price Range': '210 - 365 USD',
  'Restauarant Website': 'https://www.alinearestaurant.com/'},
 {'Restaurant Name': 'The Inn at Little Washington',
  'Price Range': '238 USD',
  'Restauarant Website': 'https://www.theinnatlittlewashington.com/'},
 {'Restaurant Name': 'Inter Scaldes',
  'Price Range': '140 - 380 EUR',
  'Restauarant Website': 'https://www.interscaldes.eu/'},
 {'Restaurant Name': 'De Librije',
  'Price Range': '190 - 253 EUR',
  'Restauarant Website': 'https://www.librije.com/'},
 {'Restaurant Name': "Victor's Fine Dining by christian bau",
  'Price Range': '175 - 275 EUR',
  'Restauarant Website': 'https://www.victors-fine-dining.de/'},
 {'Restaurant Name': 'Aqua',
  'Price Range': '225 EUR',
  'Restauarant Website': 'www.restaurant-aqua.com'},
 {'Restaurant Name': 'Restaurant Überfahrt Christian Jürgens',
  'Price Range': '259 - 319 EUR',
  'Restauarant Website': 'www.althoffcollection.com'},
 {'Restaurant Name': 'The Table Kevin Fehling',
  'Price Range': '230 EUR',
  'Restauarant Website': 'http://www.the-table-hamburg.de/'},
 {'Restaurant Name': 'Atelier',
  'Price Range': '195 - 255 EUR',
  'Restauarant Website': 'https://www.bayerischerhof.de/'},
 {'Restaurant Name': 'Waldhotel Sonnora',
  'Price Range': '191 - 249 EUR',
  'Restauarant Website': 'www.hotel-sonnora.de'},
 {'Restaurant Name': 'temporaire - Schwarzwaldstube',
  'Price Range': '150 - 245 EUR',
  'Restauarant Website': 'https://www.traube-tonbach.de/'},
 {'Restaurant Name': 'Rutz',
  'Price Range': '198 - 245 EUR',
  'Restauarant Website': 'https://www.rutz-restaurant.de/'},
 {'Restaurant Name': 'Restaurant Bareiss',
  'Price Range': '150 - 305 EUR',
  'Restauarant Website': 'www.bareiss.com'},
 {'Restaurant Name': 'Vendôme',
  'Price Range': '240 - 285 EUR',
  'Restauarant Website': 'www.schlossbensberg.com'},
 {'Restaurant Name': "Restaurant de l'Hôtel de Ville",
  'Price Range': '185 - 390 CHF',
  'Restauarant Website': 'https://www.restaurantcrissier.com/'},
 {'Restaurant Name': 'Cheval Blanc by Peter Knogl',
  'Price Range': '151 - 270 CHF',
  'Restauarant Website': 'https://www.chevalblancbasel.com/'},
 {'Restaurant Name': 'Schloss Schauenstein',
  'Price Range': '190 - 330 CHF',
  'Restauarant Website': 'https://www.schauenstein.ch/'},
 {'Restaurant Name': 'Jade Dragon',
  'Price Range': '400 - 2,000 MOP',
  'Restauarant Website': 'https://www.cityofdreamsmacau.com/'},
 {'Restaurant Name': 'Robuchon au Dôme',
  'Price Range': '988 - 3,500 MOP',
  'Restauarant Website': 'https://www.grandlisboahotels.com/'},
 {'Restaurant Name': 'The Eight',
  'Price Range': '400 - 3,000 MOP',
  'Restauarant Website': 'https://www.grandlisboahotels.com/'},
 {'Restaurant Name': '8 1/2 Otto e Mezzo - Bombana',
  'Price Range': '700 - 2,080 HKD',
  'Restauarant Website': 'https://www.ottoemezzobombana.com/'},
 {'Restaurant Name': "T'ang Court",
  'Price Range': '400 - 1,700 HKD',
  'Restauarant Website': 'https://www.langhamhotels.com/hongkong'},
 {'Restaurant Name': 'Sushi Shikon',
  'Price Range': '2,000 - 3,500 HKD',
  'Restauarant Website': 'https://www.sushi-shikon.com/'},
 {'Restaurant Name': 'Caprice',
  'Price Range': '745 - 2,600 HKD',
  'Restauarant Website': 'www.fourseasons.com/hongkong'},
 {'Restaurant Name': 'Forum',
  'Price Range': '300 - 2,000 HKD',
  'Restauarant Website': 'www.forumrestaurant1977.com'},
 {'Restaurant Name': 'Lung King Heen',
  'Price Range': '500 - 2,980 HKD',
  'Restauarant Website': 'https://www.fourseasons.com/hongkong'},
 {'Restaurant Name': "L'Atelier de Joël Robuchon",
  'Price Range': '680 - 2,600 HKD',
  'Restauarant Website': 'https://www.robuchon.hk/'},
 {'Restaurant Name': 'Restaurant Gordon Ramsay',
  'Price Range': '110 - 195 GBP',
  'Restauarant Website': 'https://www.gordonramsayrestaurants.com/'},
 {'Restaurant Name': 'Fat Duck',
  'Price Range': '325 GBP',
  'Restauarant Website': 'https://www.thefatduck.co.uk/'},
 {'Restaurant Name': 'Hélène Darroze at The Connaught',
  'Price Range': '85 - 185 GBP',
  'Restauarant Website': 'https://www.the-connaught.co.uk/restaurants-bars/helene-darroze-at-the-connaught/'},
 {'Restaurant Name': 'CORE by Clare Smyth',
  'Price Range': '105 - 165 GBP',
  'Restauarant Website': 'https://www.corebyclaresmyth.com/'},
 {'Restaurant Name': 'Sketch (The Lecture Room & Library)',
  'Price Range': '145 - 165 GBP',
  'Restauarant Website': 'https://www.sketch.london/'},
 {'Restaurant Name': 'Waterside Inn',
  'Price Range': '140 - 188 GBP',
  'Restauarant Website': 'www.waterside-inn.co.uk'},
 {'Restaurant Name': 'Alain Ducasse at The Dorchester',
  'Price Range': '70 - 170 GBP',
  'Restauarant Website': 'https://www.alainducasse-dorchester.com/'},
 {'Restaurant Name': "Le Louis XV - Alain Ducasse à l'Hôtel de Paris",
  'Price Range': '180 - 370 EUR',
  'Restauarant Website': 'https://www.ducasse-paris.com/'},
 {'Restaurant Name': 'Assiette Champenoise',
  'Price Range': '145 - 335 EUR',
  'Restauarant Website': 'https://www.assiettechampenoise.com/'},
 {'Restaurant Name': "Les Prés d'Eugénie - Michel Guérard",
  'Price Range': '265 - 295 EUR',
  'Restauarant Website': 'https://www.lespresdeugenie.com/'},
 {'Restaurant Name': 'Georges Blanc',
  'Price Range': '225 - 310 EUR',
  'Restauarant Website': 'https://www.georgesblanc.com/'},
 {'Restaurant Name': "La Vague d'Or - Cheval Blanc St-Tropez",
  'Price Range': '240 - 375 EUR',
  'Restauarant Website': 'https://www.chevalblanc.com/'},
 {'Restaurant Name': 'Mirazur',
  'Price Range': '320 EUR',
  'Restauarant Website': 'https://www.mirazur.fr/'},
 {'Restaurant Name': 'René et Maxime Meilleur',
  'Price Range': '179 - 345 EUR',
  'Restauarant Website': 'https://www.la-bouitte.com/'},
 {'Restaurant Name': 'Alléno Paris au Pavillon Ledoyen',
  'Price Range': '230 - 395 EUR',
  'Restauarant Website': 'https://www.yannick-alleno.com/'},
 {'Restaurant Name': 'Le 1947',
  'Price Range': '270 - 420 EUR',
  'Restauarant Website': 'https://www.chevalblanc.com/courchevel'},
 {'Restaurant Name': 'AM par Alexandre Mazzia',
  'Price Range': '115 - 265 EUR',
  'Restauarant Website': 'http://www.alexandremazzia.com/'},
 {'Restaurant Name': 'Pic',
  'Price Range': '320 EUR',
  'Restauarant Website': 'https://www.anne-sophie-pic.com/'},
 {'Restaurant Name': 'Troisgros - Le Bois sans Feuilles',
  'Price Range': '120 - 550 EUR',
  'Restauarant Website': 'https://www.troisgros.com/'},
 {'Restaurant Name': 'Pierre Gagnaire',
  'Price Range': '98 - 400 EUR',
  'Restauarant Website': 'https://www.pierregagnaire.com/'},
 {'Restaurant Name': 'Le Pré Catelan',
  'Price Range': '140 - 290 EUR',
  'Restauarant Website': 'http://www.precatelanparis.com/'},
 {'Restaurant Name': "L'Ambroisie",
  'Price Range': '230 - 330 EUR',
  'Restauarant Website': 'https://www.ambroisie-paris.com/'},
 {'Restaurant Name': 'Épicure',
  'Price Range': '185 - 467 EUR',
  'Restauarant Website': 'https://www.oetkercollection.com/fr/hotels/le-bristol-paris/'},
 {'Restaurant Name': 'Christophe Bacquié',
  'Price Range': '205 - 325 EUR',
  'Restauarant Website': 'https://www.hotelducastellet.com/'},
 {'Restaurant Name': 'Maison Lameloise',
  'Price Range': '85 - 260 EUR',
  'Restauarant Website': 'https://www.lameloise.fr/'},
 {'Restaurant Name': 'Enrico Bartolini al Mudec',
  'Price Range': '180 - 250 EUR',
  'Restauarant Website': 'https://www.enricobartolini.net/'},
 {'Restaurant Name': 'Mirazur',
  'Price Range': '320 EUR',
  'Restauarant Website': 'https://www.mirazur.fr/'},
 {'Restaurant Name': 'Restaurant Überfahrt Christian Jürgens',
  'Price Range': '259 - 319 EUR',
  'Restauarant Website': 'www.althoffcollection.com'},
 {'Restaurant Name': 'Da Vittorio',
  'Price Range': '100 - 300 EUR',
  'Restauarant Website': 'https://www.davittorio.com/'},
 {'Restaurant Name': 'Dal Pescatore',
  'Price Range': '120 - 250 EUR',
  'Restauarant Website': 'https://www.dalpescatore.com/'},
 {'Restaurant Name': 'St. Hubertus',
  'Price Range': '280 - 310 EUR',
  'Restauarant Website': 'https://www.st-hubertus.it/'},
 {'Restaurant Name': 'Osteria Francescana',
  'Price Range': '270 - 320 EUR',
  'Restauarant Website': 'https://www.osteriafrancescana.it/'},
 {'Restaurant Name': 'Le Calandre',
  'Price Range': '150 - 225 EUR',
  'Restauarant Website': 'https://www.alajmo.it/'},
 {'Restaurant Name': 'Enoteca Pinchiorri',
  'Price Range': '150 - 345 EUR',
  'Restauarant Website': 'http://www.enotecapinchiorri.com/'},
 {'Restaurant Name': 'Amador',
  'Price Range': '35 - 275 EUR',
  'Restauarant Website': 'http://www.restaurant-amador.com/'},
 {'Restaurant Name': 'Uliassi',
  'Price Range': '150 - 200 EUR',
  'Restauarant Website': 'https://www.uliassi.it/'},
 {'Restaurant Name': 'La Pergola',
  'Price Range': '170 - 290 EUR',
  'Restauarant Website': 'https://www.romecavalieri.com/lapergola'},
 {'Restaurant Name': 'Reale',
  'Price Range': '140 - 200 EUR',
  'Restauarant Website': 'https://www.nikoromito.com/reale/'},
 {'Restaurant Name': 'Kohaku',
  'Price Range': '43,000 JPY',
  'Restauarant Website': 'https://kagurazaka-kohaku.jp/'},
 {'Restaurant Name': 'Kagurazaka Ishikawa',
  'Price Range': '43,000 JPY',
  'Restauarant Website': 'http://www.kagurazaka-ishikawa.co.jp/'},
 {'Restaurant Name': 'RyuGin',
  'Price Range': '49,000 JPY',
  'Restauarant Website': 'https://www.nihonryori-ryugin.com/'},
 {'Restaurant Name': "L'OSIER",
  'Price Range': '13,000 - 44,000 JPY',
  'Restauarant Website': 'https://losier.shiseido.co.jp/'},
 {'Restaurant Name': 'Sushi Yoshitake',
  'Price Range': '38,000 JPY',
  'Restauarant Website': 'http://sushi-yoshitake.com/'},
 {'Restaurant Name': 'Azabu Kadowaki',
  'Price Range': '26,000 - 70,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Kanda',
  'Price Range': '37,000 - 43,000 JPY',
  'Restauarant Website': 'http://www.nihonryori-kanda.com/'},
 {'Restaurant Name': 'Martín Berasategui',
  'Price Range': '191 - 290 EUR',
  'Restauarant Website': 'www.martinberasategui.com'},
 {'Restaurant Name': 'Akelaŕe',
  'Price Range': '240 EUR',
  'Restauarant Website': 'www.akelarre.net'},
 {'Restaurant Name': 'Quique Dacosta',
  'Price Range': '210 EUR',
  'Restauarant Website': 'www.quiquedacosta.es'},
 {'Restaurant Name': 'Cenador de Amós',
  'Price Range': '197 - 235 EUR',
  'Restauarant Website': 'www.cenadordeamos.com'},
 {'Restaurant Name': "L'OSIER",
  'Price Range': '13,000 - 44,000 JPY',
  'Restauarant Website': 'https://losier.shiseido.co.jp/'},
 {'Restaurant Name': 'Sazenka',
  'Price Range': '34,000 - 73,000 JPY',
  'Restauarant Website': 'https://sazenka.com/'},
 {'Restaurant Name': 'Kagurazaka Ishikawa',
  'Price Range': '43,000 JPY',
  'Restauarant Website': 'http://www.kagurazaka-ishikawa.co.jp/'},
 {'Restaurant Name': 'Kanda',
  'Price Range': '37,000 - 43,000 JPY',
  'Restauarant Website': 'http://www.nihonryori-kanda.com/'},
 {'Restaurant Name': "L'Effervescence",
  'Price Range': '34,000 JPY',
  'Restauarant Website': 'http://www.leffervescence.jp/'},
 {'Restaurant Name': 'Quintessence',
  'Price Range': '33,000 JPY',
  'Restauarant Website': 'https://www.quintessence.jp/'},
 {'Restaurant Name': 'Azabu Kadowaki',
  'Price Range': '26,000 - 70,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Joël Robuchon',
  'Price Range': '23,000 - 54,000 JPY',
  'Restauarant Website': 'https://www.robuchon.jp/'},
 {'Restaurant Name': 'RyuGin',
  'Price Range': '49,000 JPY',
  'Restauarant Website': 'https://www.nihonryori-ryugin.com/'},
 {'Restaurant Name': 'Sushi Yoshitake',
  'Price Range': '38,000 JPY',
  'Restauarant Website': 'http://sushi-yoshitake.com/'},
 {'Restaurant Name': 'Kohaku',
  'Price Range': '43,000 JPY',
  'Restauarant Website': 'https://kagurazaka-kohaku.jp/'},
 {'Restaurant Name': 'Makimura',
  'Price Range': '27,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Enoteca Pinchiorri',
  'Price Range': '150 - 345 EUR',
  'Restauarant Website': 'http://www.enotecapinchiorri.com/'},
 {'Restaurant Name': 'Dal Pescatore',
  'Price Range': '120 - 250 EUR',
  'Restauarant Website': 'https://www.dalpescatore.com/'},
 {'Restaurant Name': 'Le Calandre',
  'Price Range': '150 - 225 EUR',
  'Restauarant Website': 'https://www.alajmo.it/'},
 {'Restaurant Name': 'Reale',
  'Price Range': '140 - 200 EUR',
  'Restauarant Website': 'https://www.nikoromito.com/reale/'},
 {'Restaurant Name': 'Piazza Duomo',
  'Price Range': '270 - 300 EUR',
  'Restauarant Website': 'https://www.piazzaduomoalba.it/'},
 {'Restaurant Name': 'Osteria Francescana',
  'Price Range': '270 - 320 EUR',
  'Restauarant Website': 'https://www.osteriafrancescana.it/'},
 {'Restaurant Name': 'Enrico Bartolini al Mudec',
  'Price Range': '180 - 250 EUR',
  'Restauarant Website': 'https://www.enricobartolini.net/'},
 {'Restaurant Name': 'St. Hubertus',
  'Price Range': '280 - 310 EUR',
  'Restauarant Website': 'https://www.st-hubertus.it/'},
 {'Restaurant Name': 'Da Vittorio',
  'Price Range': '100 - 300 EUR',
  'Restauarant Website': 'https://www.davittorio.com/'},
 {'Restaurant Name': 'Uliassi',
  'Price Range': '150 - 200 EUR',
  'Restauarant Website': 'https://www.uliassi.it/'},
 {'Restaurant Name': 'La Pergola',
  'Price Range': '170 - 290 EUR',
  'Restauarant Website': 'https://www.romecavalieri.com/lapergola'},
 {'Restaurant Name': 'Gaon',
  'Price Range': '120,000 - 240,000 KRW',
  'Restauarant Website': 'http://gaonkr.com'},
 {'Restaurant Name': 'La Yeon',
  'Price Range': '109,000 - 280,000 KRW',
  'Restauarant Website': 'https://www.shilla.net/seoul'},
 {'Restaurant Name': 'Xin Rong Ji (Xinyuan South Road)',
  'Price Range': '400 - 2,000 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': "King's Joy",
  'Price Range': '500 - 1,399 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Ultraviolet by Paul Pairet',
  'Price Range': '4,000 - 8,888 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Amador',
  'Price Range': '35 - 275 EUR',
  'Restauarant Website': 'http://www.restaurant-amador.com/'}]

# %%
#2 Star Restaurants List of Dictionaires
[{'Restaurant Name': 'Oriole',
  'Price Range': '215 USD',
  'Restauarant Website': 'https://www.oriolechicago.com/'},
 {'Restaurant Name': 'Ever',
  'Price Range': '285 USD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Smyth',
  'Price Range': '225 - 280 USD',
  'Restauarant Website': 'https://www.smythandtheloyalist.com/'},
 {'Restaurant Name': 'Moody Tongue',
  'Price Range': '200 USD',
  'Restauarant Website': 'https://www.moodytongue.com/'},
 {'Restaurant Name': 'Jônt',
  'Price Range': '50 - 305 USD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'minibar',
  'Price Range': '295 USD',
  'Restauarant Website': 'https://www.minibarbyjoseandres.com/'},
 {'Restaurant Name': 'Pineapple and Pearls',
  'Price Range': '150 - 325 USD',
  'Restauarant Website': 'https://www.pineappleandpearls.com/'},
 {'Restaurant Name': "L'Atelier de Joël Robuchon",
  'Price Range': '103 - 235 USD',
  'Restauarant Website': 'https://latelier-newyork.com/'},
 {'Restaurant Name': 'Jungsik',
  'Price Range': '165 - 235 USD',
  'Restauarant Website': 'https://www.jungsik.com/'},
 {'Restaurant Name': 'Atera',
  'Price Range': '285 USD',
  'Restauarant Website': 'http://www.ateranyc.com/'},
 {'Restaurant Name': 'Jean-Georges',
  'Price Range': '75 - 248 USD',
  'Restauarant Website': 'https://www.jean-georgesrestaurant.com/'},
 {'Restaurant Name': 'Ko',
  'Price Range': '225 USD',
  'Restauarant Website': 'https://www.momofuku.com/'},
 {'Restaurant Name': 'Gabriel Kreuther',
  'Price Range': '90 - 245 USD',
  'Restauarant Website': 'https://www.gknyc.com/'},
 {'Restaurant Name': 'Ichimura at Uchū',
  'Price Range': '300 USD',
  'Restauarant Website': 'https://www.uchu.nyc/'},
 {'Restaurant Name': 'Atomix',
  'Price Range': '205 USD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'The Modern',
  'Price Range': '138 - 188 USD',
  'Restauarant Website': 'https://www.themodernnyc.com/'},
 {'Restaurant Name': 'Aquavit',
  'Price Range': '58 - 155 USD',
  'Restauarant Website': 'https://www.aquavit.org/'},
 {'Restaurant Name': 'Daniel',
  'Price Range': '158 - 250 USD',
  'Restauarant Website': 'https://www.danielnyc.com/'},
 {'Restaurant Name': 'Aska',
  'Price Range': '195 - 295 USD',
  'Restauarant Website': 'https://www.askanyc.com/'},
 {'Restaurant Name': 'Blanca',
  'Price Range': '198 USD',
  'Restauarant Website': 'https://www.blancanyc.com/'},
 {'Restaurant Name': 'Kikunoi Roan',
  'Price Range': '9,000 - 32,000 JPY',
  'Restauarant Website': 'https://kikunoi.jp/'},
 {'Restaurant Name': 'Sumibi Kappo Ifuki',
  'Price Range': '24,000 - 35,000 JPY',
  'Restauarant Website': 'https://gion-ifuki.com/'},
 {'Restaurant Name': 'Shimmonzen Yonemura',
  'Price Range': '10,000 - 21,000 JPY',
  'Restauarant Website': 'https://r-yonemura.jp/'},
 {'Restaurant Name': 'Miyamaso',
  'Price Range': '19,000 - 32,000 JPY',
  'Restauarant Website': 'http://miyamasou.jp/'},
 {'Restaurant Name': 'Sojiki Nakahigashi',
  'Price Range': '9,000 - 26,000 JPY',
  'Restauarant Website': 'https://www.soujiki-nakahigashi.co.jp/'},
 {'Restaurant Name': 'Otagi',
  'Price Range': '22,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Kyotenjin Noguchi',
  'Price Range': '30,000 - 35,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Wagokoro Izumi',
  'Price Range': '7,000 - 29,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Gion Owatari',
  'Price Range': '32,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Oryori Mitsuyasu',
  'Price Range': '20,000 JPY',
  'Restauarant Website': 'http://kyoto-mitsuyasu.com/'},
 {'Restaurant Name': 'Twins Garden',
  'Price Range': '2,500 - 15,000 RUB',
  'Restauarant Website': 'http://twinsgarden.ru/'},
 {'Restaurant Name': "ARTEST - Chef's Table",
  'Price Range': '15,000 - 20,000 RUB',
  'Restauarant Website': 'https://artest.rest/'},
 {'Restaurant Name': 'Harbor House',
  'Price Range': '180 USD',
  'Restauarant Website': 'https://www.theharborhouseinn.com/'},
 {'Restaurant Name': 'Vespertine',
  'Price Range': '295 USD',
  'Restauarant Website': 'www.vespertine.la'},
 {'Restaurant Name': 'Providence',
  'Price Range': '225 - 475 USD',
  'Restauarant Website': 'https://www.providencela.com/'},
 {'Restaurant Name': 'Sushi Ginza Onodera',
  'Price Range': '300 USD',
  'Restauarant Website': 'https://www.onodera-group.com/'},
 {'Restaurant Name': 'Addison',
  'Price Range': '175 - 275 USD',
  'Restauarant Website': 'https://www.addisondelmar.com/'},
 {'Restaurant Name': 'Commis',
  'Price Range': '189 USD',
  'Restauarant Website': 'www.commisrestaurant.com'},
 {'Restaurant Name': 'Mélisse',
  'Price Range': '295 USD',
  'Restauarant Website': 'https://www.citrinandmelisse.com/'},
 {'Restaurant Name': 'Hayato',
  'Price Range': '260 USD',
  'Restauarant Website': 'https://www.hayatorestaurant.com/'},
 {'Restaurant Name': 'Patrick Guilbaud',
  'Price Range': '65 - 205 EUR',
  'Restauarant Website': 'https://www.restaurantpatrickguilbaud.ie/'},
 {'Restaurant Name': 'Andrew Fairlie at Gleneagles',
  'Price Range': '115 - 155 GBP',
  'Restauarant Website': 'https://www.andrewfairlie.co.uk/'},
 {'Restaurant Name': "L'Enclume",
  'Price Range': '79 - 175 GBP',
  'Restauarant Website': 'https://www.lenclume.co.uk/'},
 {'Restaurant Name': 'Moor Hall',
  'Price Range': '95 - 195 GBP',
  'Restauarant Website': 'https://www.moorhall.com/'},
 {'Restaurant Name': 'Raby Hunt',
  'Price Range': '230 - 300 GBP',
  'Restauarant Website': 'https://www.rabyhuntrestaurant.co.uk/'},
 {'Restaurant Name': "Il Gallo d'Oro",
  'Price Range': '130 - 200 EUR',
  'Restauarant Website': 'www.ilgallodoro.com'},
 {'Restaurant Name': 'Restaurant Sat Bains',
  'Price Range': '120 - 155 GBP',
  'Restauarant Website': 'https://www.restaurantsatbains.com/'},
 {'Restaurant Name': 'The Dining Room',
  'Price Range': '145 GBP',
  'Restauarant Website': 'https://www.whatleymanor.com/'},
 {'Restaurant Name': 'Culler de Pau',
  'Price Range': '95 - 150 EUR',
  'Restauarant Website': 'www.cullerdepau.com'},
 {'Restaurant Name': "L'Auberge des Glazicks",
  'Price Range': '70 - 180 EUR',
  'Restauarant Website': 'https://www.aubergedesglazick.com/'},
 {'Restaurant Name': "Le Manoir aux Quat' Saisons, a Belmond Hotel",
  'Price Range': '136 - 194 GBP',
  'Restauarant Website': 'https://www.belmond.com/'},
 {'Restaurant Name': 'RE-NAA',
  'Price Range': '2,400 NOK',
  'Restauarant Website': 'https://www.restaurantrenaa.no/'},
 {'Restaurant Name': 'Hand and Flowers',
  'Price Range': '40 - 115 GBP',
  'Restauarant Website': 'https://www.thehandandflowers.co.uk/'},
 {'Restaurant Name': 'Casa de Chá da Boa Nova',
  'Price Range': '70 - 195 EUR',
  'Restauarant Website': 'www.casadechadaboanova.pt'},
 {'Restaurant Name': 'The Yeatman',
  'Price Range': '180 EUR',
  'Restauarant Website': 'www.the-yeatman-hotel.com'},
 {'Restaurant Name': 'Midsummer House',
  'Price Range': '115 - 230 GBP',
  'Restauarant Website': 'www.midsummerhouse.co.uk/'},
 {'Restaurant Name': 'Le Gavroche',
  'Price Range': '85 - 178 GBP',
  'Restauarant Website': 'https://www.le-gavroche.co.uk/'},
 {'Restaurant Name': 'Claude Bosi at Bibendum',
  'Price Range': '105 - 175 GBP',
  'Restauarant Website': 'https://www.claudebosi.com/'},
 {'Restaurant Name': 'Dinner by Heston Blumenthal',
  'Price Range': '87 - 106 GBP',
  'Restauarant Website': 'https://www.dinnerbyheston.com/'},
 {'Restaurant Name': 'Kitchen Table',
  'Price Range': '150 - 195 GBP',
  'Restauarant Website': 'https://www.kitchentablelondon.co.uk/'},
 {'Restaurant Name': 'a|o|c',
  'Price Range': '2,500 DKK',
  'Restauarant Website': 'https://www.aoc.dk/'},
 {'Restaurant Name': 'Jordnær',
  'Price Range': '2,700 DKK',
  'Restauarant Website': 'www.restaurantjordnaer.dk/'},
 {'Restaurant Name': 'Kong Hans Kælder',
  'Price Range': '1,700 DKK',
  'Restauarant Website': 'https://www.konghans.dk/'},
 {'Restaurant Name': 'Alchemist',
  'Price Range': '3,500 DKK',
  'Restauarant Website': 'https://www.alchemist.dk/'},
 {'Restaurant Name': 'Shoukouwa',
  'Price Range': '320 - 650 SGD',
  'Restauarant Website': 'https://www.shoukouwa.com.sg/'},
 {'Restaurant Name': 'Shisen Hanten',
  'Price Range': '50 - 150 SGD',
  'Restauarant Website': 'https://www.shisenhanten.com.sg/'},
 {'Restaurant Name': 'Saint Pierre',
  'Price Range': '158 - 388 SGD',
  'Restauarant Website': 'https://www.saintpierre.com.sg/'},
 {'Restaurant Name': 'Waku Ghin',
  'Price Range': '550 - 700 SGD',
  'Restauarant Website': 'https://www.marinabaysands.com/'},
 {'Restaurant Name': 'Jaan by Kirk Westaway',
  'Price Range': '118 - 288 SGD',
  'Restauarant Website': 'https://www.jaan.com.sg/'},
 {'Restaurant Name': 'Shoun Ryugin',
  'Price Range': '4,500 - 6,500 TWD',
  'Restauarant Website': 'https://www.nihonryori-ryugin.com.tw/'},
 {'Restaurant Name': 'Logy',
  'Price Range': '3,750 TWD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'JL Studio',
  'Price Range': '3,800 TWD',
  'Restauarant Website': 'https://jlstudiotw.com/'},
 {'Restaurant Name': 'Sushi Amamoto',
  'Price Range': '3,000 - 5,000 TWD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': "L'Atelier de Joël Robuchon",
  'Price Range': '1,580 - 6,880 TWD',
  'Restauarant Website': 'https://www.robuchon.com.tw/'},
 {'Restaurant Name': 'The Guest House',
  'Price Range': '1,200 - 4,280 TWD',
  'Restauarant Website': 'https://www.sheratongrandtaipei.com/'},
 {'Restaurant Name': 'Taïrroir',
  'Price Range': '2,180 - 4,680 TWD',
  'Restauarant Website': 'https://www.tairroir.com/'},
 {'Restaurant Name': 'Raw',
  'Price Range': '1,850 - 3,500 TWD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'The Modern',
  'Price Range': '138 - 188 USD',
  'Restauarant Website': 'https://www.themodernnyc.com/'},
 {'Restaurant Name': 'Blue Hill at Stone Barns',
  'Price Range': '195 - 278 USD',
  'Restauarant Website': 'http://www.bluehillfarm.com/'},
 {'Restaurant Name': 'Ko',
  'Price Range': '225 USD',
  'Restauarant Website': 'https://www.momofuku.com/'},
 {'Restaurant Name': 'Vila Joya',
  'Price Range': '110 - 195 EUR',
  'Restauarant Website': 'www.vilajoya.com/'},
 {'Restaurant Name': 'Boury',
  'Price Range': '80 - 160 EUR',
  'Restauarant Website': 'https://www.restaurantboury.be/'},
 {'Restaurant Name': 'Atrio',
  'Price Range': '185 EUR',
  'Restauarant Website': 'www.restauranteatrio.com'},
 {'Restaurant Name': 'De Kromme Watergang',
  'Price Range': '62 - 225 EUR',
  'Restauarant Website': 'https://www.krommewatergang.nl/'},
 {'Restaurant Name': 'La Durée',
  'Price Range': '65 - 232 EUR',
  'Restauarant Website': 'https://www.laduree.be/'},
 {'Restaurant Name': 'De Bokkedoorns',
  'Price Range': '69 - 147 EUR',
  'Restauarant Website': 'https://www.bokkedoorns.nl/'},
 {'Restaurant Name': 'Castor',
  'Price Range': '45 - 120 EUR',
  'Restauarant Website': 'https://www.cas-tor.be/'},
 {'Restaurant Name': 'Henne Kirkeby Kro',
  'Price Range': '650 - 1,495 DKK',
  'Restauarant Website': 'https://www.hennekirkebykro.dk/'},
 {'Restaurant Name': 'FG - François Geurds',
  'Price Range': '55 - 210 EUR',
  'Restauarant Website': 'https://www.fgrestaurant.nl/'},
 {'Restaurant Name': 'Spectrum',
  'Price Range': '95 - 180 EUR',
  'Restauarant Website': 'https://www.restaurantspectrum.com/'},
 {'Restaurant Name': 'Restaurant 212',
  'Price Range': '74 - 158 EUR',
  'Restauarant Website': 'https://www.restaurant-212.com/'},
 {'Restaurant Name': 'Aan de Poel',
  'Price Range': '48 - 140 EUR',
  'Restauarant Website': 'https://www.aandepoel.nl/'},
 {'Restaurant Name': 'Ciel Bleu',
  'Price Range': '195 - 225 EUR',
  'Restauarant Website': 'https://www.okura.nl/'},
 {'Restaurant Name': 'Parkheuvel',
  'Price Range': '44 - 165 EUR',
  'Restauarant Website': 'https://www.parkheuvel.nl/'},
 {'Restaurant Name': 'Fred',
  'Price Range': '59 - 169 EUR',
  'Restauarant Website': 'https://www.restaurantfred.nl/'},
 {'Restaurant Name': 'Vrijmoed',
  'Price Range': '69 - 198 EUR',
  'Restauarant Website': 'https://www.vrijmoed.be/'},
 {'Restaurant Name': 'Château du Mylord',
  'Price Range': '95 - 270 EUR',
  'Restauarant Website': 'https://www.mylord.be/'},
 {'Restaurant Name': 'The Jane',
  'Price Range': '215 EUR',
  'Restauarant Website': 'https://www.thejaneantwerp.com/'},
 {'Restaurant Name': 'Maison Rostang',
  'Price Range': '90 - 203 EUR',
  'Restauarant Website': 'https://www.maisonrostang.com/'},
 {'Restaurant Name': 'Le Taillevent',
  'Price Range': '90 - 245 EUR',
  'Restauarant Website': 'https://www.letaillevent.com/'},
 {'Restaurant Name': 'La Scène',
  'Price Range': '75 - 250 EUR',
  'Restauarant Website': 'https://www.la-scene.paris/'},
 {'Restaurant Name': 'Le Clarence',
  'Price Range': '90 - 320 EUR',
  'Restauarant Website': 'https://www.le-clarence.paris/'},
 {'Restaurant Name': 'Le Gabriel',
  'Price Range': '75 - 195 EUR',
  'Restauarant Website': 'https://www.lareserve-paris.com/'},
 {'Restaurant Name': 'David Toutain',
  'Price Range': '100 - 250 EUR',
  'Restauarant Website': 'https://www.davidtoutain.com/'},
 {'Restaurant Name': 'Le Grand Restaurant - Jean-François Piège',
  'Price Range': '120 - 290 EUR',
  'Restauarant Website': 'http://www.jeanfrancoispiege.com/'},
 {'Restaurant Name': "L'Abysse au Pavillon Ledoyen",
  'Price Range': '98 - 280 EUR',
  'Restauarant Website': 'https://www.yannick-alleno.com/'},
 {'Restaurant Name': 'Sur Mesure par Thierry Marx',
  'Price Range': '85 - 195 EUR',
  'Restauarant Website': 'https://www.mandarinoriental.fr/paris'},
 {'Restaurant Name': 'Le Meurice Alain Ducasse',
  'Price Range': '250 - 320 EUR',
  'Restauarant Website': 'https://www.alainducasse-meurice.com/fr'},
 {'Restaurant Name': 'Marsan par Hélène Darroze',
  'Price Range': '75 - 225 EUR',
  'Restauarant Website': 'https://www.helenedarroze.com/'},
 {'Restaurant Name': 'Les Hauts de Loire',
  'Price Range': '89 - 175 EUR',
  'Restauarant Website': 'https://www.hautsdeloire.com/'},
 {'Restaurant Name': 'Pastorale',
  'Price Range': '65 - 195 EUR',
  'Restauarant Website': 'https://www.depastorale.be/'},
 {'Restaurant Name': "d'Eugénie à Emilie",
  'Price Range': '85 - 200 EUR',
  'Restauarant Website': 'http://www.fernez.com/deugenie-a-emilie'},
 {'Restaurant Name': "'t Nonnetje",
  'Price Range': '50 - 150 EUR',
  'Restauarant Website': 'https://www.hetnonnetje.nl/'},
 {'Restaurant Name': 'De Lindenhof',
  'Price Range': '85 - 175 EUR',
  'Restauarant Website': 'https://www.restaurantdelindenhof.nl/'},
 {'Restaurant Name': 'Nuance',
  'Price Range': '75 - 215 EUR',
  'Restauarant Website': 'https://www.resto-nuance.be/'},
 {'Restaurant Name': 'Le Skiff Club',
  'Price Range': '140 - 160 EUR',
  'Restauarant Website': 'https://www.haaitza.com/'},
 {'Restaurant Name': "Söl'ring Hof",
  'Price Range': '214 - 284 EUR',
  'Restauarant Website': 'https://www.soelring-hof.de/'},
 {'Restaurant Name': 'La Paix',
  'Price Range': '105 - 235 EUR',
  'Restauarant Website': 'https://www.lapaix.eu/'},
 {'Restaurant Name': 'Comme chez Soi',
  'Price Range': '69 - 355 EUR',
  'Restauarant Website': 'https://www.commechezsoi.be/'},
 {'Restaurant Name': "La Maison d'à Côté",
  'Price Range': '88 - 178 EUR',
  'Restauarant Website': 'https://www.lamaisondacote.fr/'},
 {'Restaurant Name': 'Falco',
  'Price Range': '95 - 262 EUR',
  'Restauarant Website': 'https://www.falco-leipzig.de/'},
 {'Restaurant Name': 'Hirschen',
  'Price Range': '98 - 270 EUR',
  'Restauarant Website': 'https://www.douce-steiner.de/'},
 {'Restaurant Name': 'EssZimmer',
  'Price Range': '180 - 275 EUR',
  'Restauarant Website': 'https://www.feinkost-kaefer.de/esszimmer-muenchen'},
 {'Restaurant Name': 'Gustav',
  'Price Range': '120 - 165 EUR',
  'Restauarant Website': 'www.restaurant-gustav.de'},
 {'Restaurant Name': "Luce d'Oro",
  'Price Range': '189 - 229 EUR',
  'Restauarant Website': 'www.schloss-elmau.de'},
 {'Restaurant Name': 'Courtier',
  'Price Range': '159 - 215 EUR',
  'Restauarant Website': 'https://www.weissenhaus.de/'},
 {'Restaurant Name': 'Steinheuers Restaurant Zur Alten Post',
  'Price Range': '120 - 195 EUR',
  'Restauarant Website': 'https://www.steinheuers.de/'},
 {'Restaurant Name': 'CODA Dessert Dining',
  'Price Range': '93 - 158 EUR',
  'Restauarant Website': 'https://www.coda-berlin.com/'},
 {'Restaurant Name': 'bianc',
  'Price Range': '190 EUR',
  'Restauarant Website': 'http://www.bianc.de/'},
 {'Restaurant Name': 'Le Cerf',
  'Price Range': '75 - 174 EUR',
  'Restauarant Website': 'https://www.schlosshotel-friedrichsruhe.de/'},
 {'Restaurant Name': 'Meierei Dirk Luther',
  'Price Range': '178 - 198 EUR',
  'Restauarant Website': 'www.alter-meierhof.de'},
 {'Restaurant Name': 'Tim Raue',
  'Price Range': '88 - 248 EUR',
  'Restauarant Website': 'https://www.tim-raue.com/'},
 {'Restaurant Name': "Söl'ring Hof",
  'Price Range': '214 - 284 EUR',
  'Restauarant Website': 'https://www.soelring-hof.de/'},
 {'Restaurant Name': 'GästeHaus Klaus Erfort',
  'Price Range': '105 - 225 EUR',
  'Restauarant Website': 'https://www.gaestehaus-erfort.de/'},
 {'Restaurant Name': 'Ophelia',
  'Price Range': '190 - 240 EUR',
  'Restauarant Website': 'https://www.restaurant-ophelia.de/'},
 {'Restaurant Name': "Obendorfer's Eisvogel",
  'Price Range': '142 - 190 EUR',
  'Restauarant Website': 'https://www.landhotel-birkenhof.de/'},
 {'Restaurant Name': 'OPUS V',
  'Price Range': '99 - 195 EUR',
  'Restauarant Website': 'https://www.restaurant-opus-v.de/'},
 {'Restaurant Name': 'ammolite - The Lighthouse Restaurant',
  'Price Range': '119 - 169 EUR',
  'Restauarant Website': 'https://www.ammolite-restaurant.de/'},
 {'Restaurant Name': 'Les Deux',
  'Price Range': '185 EUR',
  'Restauarant Website': 'www.lesdeux-muc.de'},
 {'Restaurant Name': 'AUGUST',
  'Price Range': '179 - 210 EUR',
  'Restauarant Website': 'https://www.restaurantaugust.de/'},
 {'Restaurant Name': 'Meierei Dirk Luther',
  'Price Range': '178 - 198 EUR',
  'Restauarant Website': 'www.alter-meierhof.de'},
 {'Restaurant Name': 'Racine',
  'Price Range': '70 - 195 EUR',
  'Restauarant Website': 'https://www.racine.re/'},
 {'Restaurant Name': 'El Molino de Urdániz',
  'Price Range': '120 - 140 EUR',
  'Restauarant Website': 'www.elmolinourdaniz.com'},
 {'Restaurant Name': 'Le Parc Les Crayères',
  'Price Range': '75 - 295 EUR',
  'Restauarant Website': 'www.lescrayeres.com'},
 {'Restaurant Name': 'Ralf Berendsen',
  'Price Range': '95 - 225 EUR',
  'Restauarant Website': 'https://www.restaurantlasource.be/'},
 {'Restaurant Name': 'Sabero',
  'Price Range': '90 - 139 EUR',
  'Restauarant Website': 'http://www.restaurant-sabero.nl/'},
 {'Restaurant Name': 'Brut172',
  'Price Range': '90 - 185 EUR',
  'Restauarant Website': 'https://www.brut172.com/'},
 {'Restaurant Name': 'La Table de Maxime',
  'Price Range': '50 - 109 EUR',
  'Restauarant Website': 'https://www.maximecollard.be/'},
 {'Restaurant Name': 'La Côte Saint-Jacques',
  'Price Range': '85 - 238 EUR',
  'Restauarant Website': 'https://www.cotesaintjacques.com/'},
 {'Restaurant Name': 'Rosin',
  'Price Range': '99 - 159 EUR',
  'Restauarant Website': 'https://www.frankrosin.de/'},
 {'Restaurant Name': 'Noor',
  'Price Range': '95 - 190 EUR',
  'Restauarant Website': 'www.noorrestaurant.es'},
 {'Restaurant Name': 'Le Moissonnier',
  'Price Range': '90 - 165 EUR',
  'Restauarant Website': 'www.lemoissonnier.de'},
 {'Restaurant Name': 'Ox & Klee',
  'Price Range': '230 EUR',
  'Restauarant Website': 'https://www.oxundklee.de/'},
 {'Restaurant Name': 'Courtier',
  'Price Range': '159 - 215 EUR',
  'Restauarant Website': 'https://www.weissenhaus.de/'},
 {'Restaurant Name': 'Haerlin',
  'Price Range': '190 - 250 EUR',
  'Restauarant Website': 'https://www.restaurant-haerlin.de/'},
 {'Restaurant Name': 'bianc',
  'Price Range': '190 EUR',
  'Restauarant Website': 'http://www.bianc.de/'},
 {'Restaurant Name': 'Jordnær',
  'Price Range': '2,700 DKK',
  'Restauarant Website': 'www.restaurantjordnaer.dk/'},
 {'Restaurant Name': 'Bardal',
  'Price Range': '150 - 170 EUR',
  'Restauarant Website': 'www.restaurantebardal.com'},
 {'Restaurant Name': 'a|o|c',
  'Price Range': '2,500 DKK',
  'Restauarant Website': 'https://www.aoc.dk/'},
 {'Restaurant Name': 'Kong Hans Kælder',
  'Price Range': '1,700 DKK',
  'Restauarant Website': 'https://www.konghans.dk/'},
 {'Restaurant Name': "Cà d'Oro",
  'Price Range': '140 - 190 CHF',
  'Restauarant Website': 'https://www.kempinski.com/stmoritz'},
 {'Restaurant Name': 'Ecco',
  'Price Range': '185 - 240 CHF',
  'Restauarant Website': 'https://www.giardino-ascona.ch/'},
 {'Restaurant Name': 'Anne-Sophie Pic',
  'Price Range': '207 - 395 CHF',
  'Restauarant Website': 'https://www.brp.ch/'},
 {'Restaurant Name': 'Taverne zum Schäfli',
  'Price Range': '89 - 220 CHF',
  'Restauarant Website': 'https://www.schaefli-wigoltingen.ch/'},
 {'Restaurant Name': 'Ecco St. Moritz',
  'Price Range': '215 - 270 CHF',
  'Restauarant Website': 'https://www.giardinohotels.ch/'},
 {'Restaurant Name': 'Einstein Gourmet',
  'Price Range': '165 - 215 CHF',
  'Restauarant Website': 'https://www.einstein.ch/'},
 {'Restaurant Name': '7132 Silver',
  'Price Range': '275 CHF',
  'Restauarant Website': 'https://www.7132silver.com/'},
 {'Restaurant Name': 'Domaine de Châteauvieux',
  'Price Range': '98 - 320 CHF',
  'Restauarant Website': 'https://www.chateauvieux.ch/'},
 {'Restaurant Name': 'The Restaurant',
  'Price Range': '112 - 298 CHF',
  'Restauarant Website': 'https://www.thedoldergrand.com/'},
 {'Restaurant Name': 'Gasthaus Zur Fernsicht - Incantare',
  'Price Range': '169 - 230 CHF',
  'Restauarant Website': 'https://www.fernsicht-heiden.ch/'},
 {'Restaurant Name': 'Magdalena',
  'Price Range': '59 - 135 CHF',
  'Restauarant Website': 'https://www.restaurant-magdalena.ch/'},
 {'Restaurant Name': 'Memories',
  'Price Range': '195 - 330 CHF',
  'Restauarant Website': 'https://www.memories.ch/'},
 {'Restaurant Name': 'IGNIV by Andreas Caminada',
  'Price Range': '195 - 245 CHF',
  'Restauarant Website': 'https://www.badruttspalace.com/'},
 {'Restaurant Name': 'Widder Restaurant',
  'Price Range': '145 - 260 CHF',
  'Restauarant Website': 'https://www.widderhotel.com/'},
 {'Restaurant Name': 'Adelboden',
  'Price Range': '148 - 195 CHF',
  'Restauarant Website': 'https://www.wiget-adelboden.ch/'},
 {'Restaurant Name': 'IGNIV by Andreas Caminada',
  'Price Range': '158 - 248 CHF',
  'Restauarant Website': 'https://www.igniv.com/'},
 {'Restaurant Name': 'Pavillon',
  'Price Range': '162 - 275 CHF',
  'Restauarant Website': 'https://www.aupavillon.ch/'},
 {'Restaurant Name': 'Sens',
  'Price Range': '145 - 195 CHF',
  'Restauarant Website': 'https://www.vitznauerhof.ch/'},
 {'Restaurant Name': "RICO'S",
  'Price Range': '66 - 260 CHF',
  'Restauarant Website': 'https://www.ricozandonella.ch/'},
 {'Restaurant Name': 'Sichuan Moon',
  'Price Range': '1,688 - 3,268 MOP',
  'Restauarant Website': 'www.wynnpalace.com'},
 {'Restaurant Name': 'Serge Vieira',
  'Price Range': '95 - 165 EUR',
  'Restauarant Website': 'https://www.sergevieira.com/'},
 {'Restaurant Name': 'Bras',
  'Price Range': '170 - 245 EUR',
  'Restauarant Website': 'https://www.bras.fr/'},
 {'Restaurant Name': 'Au 14 Février',
  'Price Range': '87 - 125 EUR',
  'Restauarant Website': 'https://www.sa-au14fevrier.com/'},
 {'Restaurant Name': 'Villa René Lalique',
  'Price Range': '80 - 205 EUR',
  'Restauarant Website': 'https://www.villarenelalique.com/'},
 {'Restaurant Name': 'Lafleur',
  'Price Range': '195 - 215 EUR',
  'Restauarant Website': 'https://www.restaurant-lafleur.de/'},
 {'Restaurant Name': 'Gustav',
  'Price Range': '120 - 165 EUR',
  'Restauarant Website': 'www.restaurant-gustav.de'},
 {'Restaurant Name': 'Auberge du Cheval Blanc',
  'Price Range': '82 - 135 EUR',
  'Restauarant Website': 'https://www.au-cheval-blanc.fr/'},
 {'Restaurant Name': 'Maison Jeunet',
  'Price Range': '65 - 155 EUR',
  'Restauarant Website': 'https://www.maison-jeunet.com/'},
 {'Restaurant Name': 'La Merise',
  'Price Range': '55 - 135 EUR',
  'Restauarant Website': 'https://www.lamerise.alsace/'},
 {'Restaurant Name': 'La Table de Franck Putelat',
  'Price Range': '75 - 230 EUR',
  'Restauarant Website': 'https://www.franck-putelat.com/'},
 {'Restaurant Name': 'Paul Bocuse',
  'Price Range': '185 - 285 EUR',
  'Restauarant Website': 'https://www.bocuse.fr/'},
 {'Restaurant Name': 'OPUS V',
  'Price Range': '99 - 195 EUR',
  'Restauarant Website': 'https://www.restaurant-opus-v.de/'},
 {'Restaurant Name': 'Mère Brazier',
  'Price Range': '75 - 190 EUR',
  'Restauarant Website': 'https://www.lamerebrazier.fr/'},
 {'Restaurant Name': 'Takao Takano',
  'Price Range': '50 - 150 EUR',
  'Restauarant Website': 'https://www.takaotakano.com/'},
 {'Restaurant Name': 'Le Neuvième Art',
  'Price Range': '105 - 175 EUR',
  'Restauarant Website': 'https://www.leneuviemeart.com/'},
 {'Restaurant Name': 'La Fourchette des Ducs',
  'Price Range': '140 - 210 EUR',
  'Restauarant Website': 'http://www.lafourchettedesducs.com/'},
 {'Restaurant Name': "La Table d'Olivier Nasti",
  'Price Range': '165 - 240 EUR',
  'Restauarant Website': 'https://www.lechambard.fr/'},
 {'Restaurant Name': 'Maralba',
  'Price Range': '65 - 99 EUR',
  'Restauarant Website': 'www.maralbarestaurante.es'},
 {'Restaurant Name': "Auberge de l'Ill",
  'Price Range': '110 - 260 EUR',
  'Restauarant Website': 'https://www.auberge-de-l-ill.com/'},
 {'Restaurant Name': 'La Pyramide - Patrick Henriroux',
  'Price Range': '79 - 204 EUR',
  'Restauarant Website': 'https://www.lapyramide.com/'},
 {'Restaurant Name': 'The Dining Room',
  'Price Range': '145 GBP',
  'Restauarant Website': 'https://www.whatleymanor.com/'},
 {'Restaurant Name': 'La Dame de Pic',
  'Price Range': '45 - 160 GBP',
  'Restauarant Website': 'https://www.ladamedepiclondon.co.uk/'},
 {'Restaurant Name': "L'Enclume",
  'Price Range': '79 - 175 GBP',
  'Restauarant Website': 'https://www.lenclume.co.uk/'},
 {'Restaurant Name': 'Da Terra',
  'Price Range': '70 - 140 GBP',
  'Restauarant Website': 'https://www.daterra.co.uk/'},
 {'Restaurant Name': 'Restaurant Sat Bains',
  'Price Range': '120 - 155 GBP',
  'Restauarant Website': 'https://www.restaurantsatbains.com/'},
 {'Restaurant Name': 'Raby Hunt',
  'Price Range': '230 - 300 GBP',
  'Restauarant Website': 'https://www.rabyhuntrestaurant.co.uk/'},
 {'Restaurant Name': 'Moor Hall',
  'Price Range': '95 - 195 GBP',
  'Restauarant Website': 'https://www.moorhall.com/'},
 {'Restaurant Name': 'Story',
  'Price Range': '120 - 170 GBP',
  'Restauarant Website': 'https://www.restaurantstory.co.uk/'},
 {'Restaurant Name': 'Andrew Fairlie at Gleneagles',
  'Price Range': '115 - 155 GBP',
  'Restauarant Website': 'https://www.andrewfairlie.co.uk/'},
 {'Restaurant Name': "Le Manoir aux Quat' Saisons, a Belmond Hotel",
  'Price Range': '136 - 194 GBP',
  'Restauarant Website': 'https://www.belmond.com/'},
 {'Restaurant Name': 'Midsummer House',
  'Price Range': '115 - 230 GBP',
  'Restauarant Website': 'www.midsummerhouse.co.uk/'},
 {'Restaurant Name': 'Hand and Flowers',
  'Price Range': '40 - 115 GBP',
  'Restauarant Website': 'https://www.thehandandflowers.co.uk/'},
 {'Restaurant Name': 'Dinner by Heston Blumenthal',
  'Price Range': '87 - 106 GBP',
  'Restauarant Website': 'https://www.dinnerbyheston.com/'},
 {'Restaurant Name': 'A. Wong',
  'Price Range': '48 - 160 GBP',
  'Restauarant Website': 'http://www.awong.co.uk/'},
 {'Restaurant Name': 'Kitchen Table',
  'Price Range': '150 - 195 GBP',
  'Restauarant Website': 'https://www.kitchentablelondon.co.uk/'},
 {'Restaurant Name': 'Claude Bosi at Bibendum',
  'Price Range': '105 - 175 GBP',
  'Restauarant Website': 'https://www.claudebosi.com/'},
 {'Restaurant Name': 'Auberge du Cheval Blanc',
  'Price Range': '82 - 135 EUR',
  'Restauarant Website': 'https://www.au-cheval-blanc.fr/'},
 {'Restaurant Name': "La Table d'Olivier Nasti",
  'Price Range': '165 - 240 EUR',
  'Restauarant Website': 'https://www.lechambard.fr/'},
 {'Restaurant Name': "La Table de l'Alpaga",
  'Price Range': '120 - 180 EUR',
  'Restauarant Website': 'https://www.alpaga.com/'},
 {'Restaurant Name': 'Jean Sulpice',
  'Price Range': '225 - 265 EUR',
  'Restauarant Website': 'https://www.perebise.com/'},
 {'Restaurant Name': 'La Pyramide - Patrick Henriroux',
  'Price Range': '79 - 204 EUR',
  'Restauarant Website': 'https://www.lapyramide.com/'},
 {'Restaurant Name': 'Le Montgomerie',
  'Price Range': '190 - 315 EUR',
  'Restauarant Website': 'https://www.lek2altitude.com/'},
 {'Restaurant Name': 'Serge Vieira',
  'Price Range': '95 - 165 EUR',
  'Restauarant Website': 'https://www.sergevieira.com/'},
 {'Restaurant Name': 'Racine',
  'Price Range': '70 - 195 EUR',
  'Restauarant Website': 'https://www.racine.re/'},
 {'Restaurant Name': 'Sarkara',
  'Price Range': '107 - 135 EUR',
  'Restauarant Website': 'https://www.lek2palace.com/'},
 {'Restaurant Name': 'Au 14 Février',
  'Price Range': '87 - 125 EUR',
  'Restauarant Website': 'https://www.sa-au14fevrier.com/'},
 {'Restaurant Name': "La Côte d'Or",
  'Price Range': '160 - 245 EUR',
  'Restauarant Website': 'https://www.bernard-loiseau.com/'},
 {'Restaurant Name': 'La Maison des Bois - Marc Veyrat',
  'Price Range': '295 - 395 EUR',
  'Restauarant Website': 'https://www.marc-veyrat.fr/'},
 {'Restaurant Name': 'Les Hauts de Loire',
  'Price Range': '89 - 175 EUR',
  'Restauarant Website': 'https://www.hautsdeloire.com/'},
 {'Restaurant Name': 'Alexandre',
  'Price Range': '64 - 215 EUR',
  'Restauarant Website': 'https://www.michelkayser.com/'},
 {'Restaurant Name': 'La Table de Pavie',
  'Price Range': '72 - 215 EUR',
  'Restauarant Website': 'https://www.hostelleriedeplaisance.com/'},
 {'Restaurant Name': 'Le Kintessence',
  'Price Range': '190 - 315 EUR',
  'Restauarant Website': 'https://www.lek2palace.com/'},
 {'Restaurant Name': 'Le Parc Les Crayères',
  'Price Range': '75 - 295 EUR',
  'Restauarant Website': 'www.lescrayeres.com'},
 {'Restaurant Name': 'Maison Rostang',
  'Price Range': '90 - 203 EUR',
  'Restauarant Website': 'https://www.maisonrostang.com/'},
 {'Restaurant Name': 'La Scène',
  'Price Range': '75 - 250 EUR',
  'Restauarant Website': 'https://www.la-scene.paris/'},
 {'Restaurant Name': 'Le Pré - Xavier Beaudiment',
  'Price Range': '39 - 155 EUR',
  'Restauarant Website': 'https://www.restaurant-lepre.com/'},
 {'Restaurant Name': 'La Côte Saint-Jacques',
  'Price Range': '85 - 238 EUR',
  'Restauarant Website': 'https://www.cotesaintjacques.com/'},
 {'Restaurant Name': 'Le Clarence',
  'Price Range': '90 - 320 EUR',
  'Restauarant Website': 'https://www.le-clarence.paris/'},
 {'Restaurant Name': 'La Villa Archange',
  'Price Range': '78 - 350 EUR',
  'Restauarant Website': 'https://www.bruno-oger.com/fr'},
 {'Restaurant Name': 'Paul Bocuse',
  'Price Range': '185 - 285 EUR',
  'Restauarant Website': 'https://www.bocuse.fr/'},
 {'Restaurant Name': 'Le Grand Restaurant - Jean-François Piège',
  'Price Range': '120 - 290 EUR',
  'Restauarant Website': 'http://www.jeanfrancoispiege.com/'},
 {'Restaurant Name': 'Le Neuvième Art',
  'Price Range': '105 - 175 EUR',
  'Restauarant Website': 'https://www.leneuviemeart.com/'},
 {'Restaurant Name': "Le Pressoir d'Argent - Gordon Ramsay",
  'Price Range': '160 - 250 EUR',
  'Restauarant Website': 'https://www.bordeaux.intercontinental.com/'},
 {'Restaurant Name': 'La Marine',
  'Price Range': '130 - 220 EUR',
  'Restauarant Website': 'https://www.alexandrecouillon.com/'},
 {'Restaurant Name': 'Hostellerie Jérôme',
  'Price Range': '110 - 159 EUR',
  'Restauarant Website': 'https://www.hostellerie-jerome.com/'},
 {'Restaurant Name': 'Les Morainières',
  'Price Range': '148 - 220 EUR',
  'Restauarant Website': 'https://www.les-morainieres.com/'},
 {'Restaurant Name': 'Relais de la Poste',
  'Price Range': '60 - 150 EUR',
  'Restauarant Website': 'https://www.relaisposte.com/'},
 {'Restaurant Name': 'Le Taillevent',
  'Price Range': '90 - 245 EUR',
  'Restauarant Website': 'https://www.letaillevent.com/'},
 {'Restaurant Name': "L'Abysse au Pavillon Ledoyen",
  'Price Range': '98 - 280 EUR',
  'Restauarant Website': 'https://www.yannick-alleno.com/'},
 {'Restaurant Name': 'Anne de Bretagne',
  'Price Range': '45 - 165 EUR',
  'Restauarant Website': 'https://www.annedebretagne.com/'},
 {'Restaurant Name': 'David Toutain',
  'Price Range': '100 - 250 EUR',
  'Restauarant Website': 'https://www.davidtoutain.com/'},
 {'Restaurant Name': 'Château de Beaulieu - Christophe Dufossé',
  'Price Range': '90 - 220 EUR',
  'Restauarant Website': 'www.lechateaudebeaulieu.fr'},
 {'Restaurant Name': 'Le Puits St-Jacques',
  'Price Range': '35 - 143 EUR',
  'Restauarant Website': 'https://www.lepuitssaintjacques.fr/'},
 {'Restaurant Name': 'Les Cèdres',
  'Price Range': '110 - 175 EUR',
  'Restauarant Website': 'https://www.restaurantlescedres.fr/'},
 {'Restaurant Name': 'Takao Takano',
  'Price Range': '50 - 150 EUR',
  'Restauarant Website': 'https://www.takaotakano.com/'},
 {'Restaurant Name': 'Villa René Lalique',
  'Price Range': '80 - 205 EUR',
  'Restauarant Website': 'https://www.villarenelalique.com/'},
 {'Restaurant Name': 'Le Meurice Alain Ducasse',
  'Price Range': '250 - 320 EUR',
  'Restauarant Website': 'https://www.alainducasse-meurice.com/fr'},
 {'Restaurant Name': 'Le Chabichou by Stéphane Buron',
  'Price Range': '175 - 320 EUR',
  'Restauarant Website': 'https://www.chabichou-courchevel.com/'},
 {'Restaurant Name': "JY'S",
  'Price Range': '107 - 185 EUR',
  'Restauarant Website': 'https://www.jean-yves-schillinger.com/'},
 {'Restaurant Name': 'La Grenouillère',
  'Price Range': '155 - 215 EUR',
  'Restauarant Website': 'https://www.lagrenouillere.fr/'},
 {'Restaurant Name': 'La Villa Madie',
  'Price Range': '130 - 235 EUR',
  'Restauarant Website': 'https://www.lavillamadie.com/'},
 {'Restaurant Name': 'AUGUST',
  'Price Range': '179 - 210 EUR',
  'Restauarant Website': 'https://www.restaurantaugust.de/'},
 {'Restaurant Name': 'IGNIV by Andreas Caminada',
  'Price Range': '158 - 248 CHF',
  'Restauarant Website': 'https://www.igniv.com/'},
 {'Restaurant Name': 'Memories',
  'Price Range': '195 - 330 CHF',
  'Restauarant Website': 'https://www.memories.ch/'},
 {'Restaurant Name': 'Piccolo Lago',
  'Price Range': '180 EUR',
  'Restauarant Website': 'https://www.piccololago.it/'},
 {'Restaurant Name': '7132 Silver',
  'Price Range': '275 CHF',
  'Restauarant Website': 'https://www.7132silver.com/'},
 {'Restaurant Name': 'Villa Crespi',
  'Price Range': '140 - 190 EUR',
  'Restauarant Website': 'https://www.villacrespi.it/'},
 {'Restaurant Name': 'Ecco',
  'Price Range': '185 - 240 CHF',
  'Restauarant Website': 'https://www.giardino-ascona.ch/'},
 {'Restaurant Name': "Obendorfer's Eisvogel",
  'Price Range': '142 - 190 EUR',
  'Restauarant Website': 'https://www.landhotel-birkenhof.de/'},
 {'Restaurant Name': 'Antica Corona Reale',
  'Price Range': '80 - 130 EUR',
  'Restauarant Website': 'https://www.anticacoronareale.it/'},
 {'Restaurant Name': 'EssZimmer',
  'Price Range': '180 - 275 EUR',
  'Restauarant Website': 'https://www.feinkost-kaefer.de/esszimmer-muenchen'},
 {'Restaurant Name': 'La Madernassa',
  'Price Range': '80 - 300 EUR',
  'Restauarant Website': 'https://www.lamadernassa.it/'},
 {'Restaurant Name': 'Les Deux',
  'Price Range': '185 EUR',
  'Restauarant Website': 'www.lesdeux-muc.de'},
 {'Restaurant Name': 'Alois - Dallmayr Fine Dining',
  'Price Range': '78 - 220 EUR',
  'Restauarant Website': 'https://www.dallmayr.com/alois'},
 {'Restaurant Name': 'Ecco St. Moritz',
  'Price Range': '215 - 270 CHF',
  'Restauarant Website': 'https://www.giardinohotels.ch/'},
 {'Restaurant Name': 'IGNIV by Andreas Caminada',
  'Price Range': '195 - 245 CHF',
  'Restauarant Website': 'https://www.badruttspalace.com/'},
 {'Restaurant Name': 'Da Vittorio',
  'Price Range': '170 - 420 CHF',
  'Restauarant Website': 'https://www.carlton-stmoritz.ch/'},
 {'Restaurant Name': "Cà d'Oro",
  'Price Range': '140 - 190 CHF',
  'Restauarant Website': 'https://www.kempinski.com/stmoritz'},
 {'Restaurant Name': 'La Villa Archange',
  'Price Range': '78 - 350 EUR',
  'Restauarant Website': 'https://www.bruno-oger.com/fr'},
 {'Restaurant Name': 'La Voile - La Réserve Ramatuelle',
  'Price Range': '135 - 210 EUR',
  'Restauarant Website': 'https://www.lareserve-ramatuelle.com/'},
 {'Restaurant Name': "La Palme d'Or",
  'Price Range': '168 - 240 EUR',
  'Restauarant Website': 'www.lapalmedor-restaurant.fr'},
 {'Restaurant Name': "D'O",
  'Price Range': '95 - 165 EUR',
  'Restauarant Website': 'https://www.cucinapop.do/'},
 {'Restaurant Name': 'Flaveur',
  'Price Range': '130 - 200 EUR',
  'Restauarant Website': 'https://www.restaurant-flaveur.com/'},
 {'Restaurant Name': "Luce d'Oro",
  'Price Range': '189 - 229 EUR',
  'Restauarant Website': 'www.schloss-elmau.de'},
 {'Restaurant Name': "La Chèvre d'Or",
  'Price Range': '90 - 260 EUR',
  'Restauarant Website': 'https://www.chevredor.com/'},
 {'Restaurant Name': 'Hostellerie Jérôme',
  'Price Range': '110 - 159 EUR',
  'Restauarant Website': 'https://www.hostellerie-jerome.com/'},
 {'Restaurant Name': 'Il Luogo di Aimo e Nadia',
  'Price Range': '115 - 280 EUR',
  'Restauarant Website': 'https://www.aimoenadia.com/'},
 {'Restaurant Name': 'Seta by Antonio Guida',
  'Price Range': '90 - 230 EUR',
  'Restauarant Website': 'https://www.mandarinoriental.com/'},
 {'Restaurant Name': 'Restaurant Heinz Winkler',
  'Price Range': '96 - 205 EUR',
  'Restauarant Website': 'https://www.residenz-heinz-winkler.de/'},
 {'Restaurant Name': 'Castel finedining',
  'Price Range': '178 - 208 EUR',
  'Restauarant Website': 'https://www.castelfinedining.com'},
 {'Restaurant Name': "Miramonti l'Altro",
  'Price Range': '90 - 150 EUR',
  'Restauarant Website': 'https://www.miramontilaltro.it/'},
 {'Restaurant Name': 'Gourmetstube Einhorn',
  'Price Range': '130 - 165 EUR',
  'Restauarant Website': 'https://www.stafler.com/'},
 {'Restaurant Name': 'Terra',
  'Price Range': '179 EUR',
  'Restauarant Website': 'https://www.terra.place/'},
 {'Restaurant Name': 'Villa Feltrinelli',
  'Price Range': '220 EUR',
  'Restauarant Website': 'https://www.villafeltrinelli.com/'},
 {'Restaurant Name': 'Ikarus',
  'Price Range': '140 - 210 EUR',
  'Restauarant Website': 'https://www.hangar-7.com/'},
 {'Restaurant Name': 'SENNS.Restaurant',
  'Price Range': '85 - 205 EUR',
  'Restauarant Website': 'https://www.senns.restaurant/'},
 {'Restaurant Name': 'Casa Perbellini',
  'Price Range': '65 - 185 EUR',
  'Restauarant Website': 'https://www.casaperbellini.com/'},
 {'Restaurant Name': 'La Peca',
  'Price Range': '95 - 200 EUR',
  'Restauarant Website': 'https://www.lapeca.it/'},
 {'Restaurant Name': 'Il Piccolo Principe',
  'Price Range': '130 - 230 EUR',
  'Restauarant Website': 'https://www.ristoranteilpiccoloprincipe.it/'},
 {'Restaurant Name': 'Antica Osteria Cera',
  'Price Range': '70 - 250 EUR',
  'Restauarant Website': 'https://www.osteriacera.it/'},
 {'Restaurant Name': 'Vrijmoed',
  'Price Range': '69 - 198 EUR',
  'Restauarant Website': 'https://www.vrijmoed.be/'},
 {'Restaurant Name': 'The Jane',
  'Price Range': '215 EUR',
  'Restauarant Website': 'https://www.thejaneantwerp.com/'},
 {'Restaurant Name': 'Ralf Berendsen',
  'Price Range': '95 - 225 EUR',
  'Restauarant Website': 'https://www.restaurantlasource.be/'},
 {'Restaurant Name': 'La Table de Maxime',
  'Price Range': '50 - 109 EUR',
  'Restauarant Website': 'https://www.maximecollard.be/'},
 {'Restaurant Name': 'Comme chez Soi',
  'Price Range': '69 - 355 EUR',
  'Restauarant Website': 'https://www.commechezsoi.be/'},
 {'Restaurant Name': 'Boury',
  'Price Range': '80 - 160 EUR',
  'Restauarant Website': 'https://www.restaurantboury.be/'},
 {'Restaurant Name': 'Slagmolen',
  'Price Range': '60 - 160 EUR',
  'Restauarant Website': 'https://www.slagmolen.be/'},
 {'Restaurant Name': 'Hostellerie St-Nicolas',
  'Price Range': '55 - 155 EUR',
  'Restauarant Website': 'https://www.hostellerie-stnicolas.com/'},
 {'Restaurant Name': 'Castor',
  'Price Range': '45 - 120 EUR',
  'Restauarant Website': 'https://www.cas-tor.be/'},
 {'Restaurant Name': 'Pastorale',
  'Price Range': '65 - 195 EUR',
  'Restauarant Website': 'https://www.depastorale.be/'},
 {'Restaurant Name': 'Château du Mylord',
  'Price Range': '95 - 270 EUR',
  'Restauarant Website': 'https://www.mylord.be/'},
 {'Restaurant Name': 'Cuchara',
  'Price Range': '65 - 205 EUR',
  'Restauarant Website': 'https://www.cuchara.be/'},
 {'Restaurant Name': 'La Paix',
  'Price Range': '105 - 235 EUR',
  'Restauarant Website': 'https://www.lapaix.eu/'},
 {'Restaurant Name': 'Sorn',
  'Price Range': '3,500 THB',
  'Restauarant Website': 'http://www.sornfinesouthern.com/'},
 {'Restaurant Name': "Chef's Table",
  'Price Range': '7,900 THB',
  'Restauarant Website': 'https://www.lebua.com/chefs-table'},
 {'Restaurant Name': 'R-Haan',
  'Price Range': '1,219 - 2,912 THB',
  'Restauarant Website': 'https://www.r-haan.com/'},
 {'Restaurant Name': 'Mezzaluna',
  'Price Range': '6,500 THB',
  'Restauarant Website': 'https://www.lebua.com/mezzaluna'},
 {'Restaurant Name': 'Sühring',
  'Price Range': '3,500 - 5,500 THB',
  'Restauarant Website': 'https://www.restaurantsuhring.com/'},
 {'Restaurant Name': 'Le Normandie',
  'Price Range': '3,200 - 8,200 THB',
  'Restauarant Website': 'https://www.mandarinoriental.com/bangkok'},
 {'Restaurant Name': 'Casa de Chá da Boa Nova',
  'Price Range': '70 - 195 EUR',
  'Restauarant Website': 'www.casadechadaboanova.pt'},
 {'Restaurant Name': 'Ocean',
  'Price Range': '210 EUR',
  'Restauarant Website': 'www.restauranteocean.com'},
 {'Restaurant Name': 'The Yeatman',
  'Price Range': '180 EUR',
  'Restauarant Website': 'www.the-yeatman-hotel.com'},
 {'Restaurant Name': 'Belcanto',
  'Price Range': '125 - 195 EUR',
  'Restauarant Website': 'www.belcanto.pt'},
 {'Restaurant Name': "Il Gallo d'Oro",
  'Price Range': '130 - 200 EUR',
  'Restauarant Website': 'www.ilgallodoro.com'},
 {'Restaurant Name': 'Vila Joya',
  'Price Range': '110 - 195 EUR',
  'Restauarant Website': 'www.vilajoya.com/'},
 {'Restaurant Name': 'Alma',
  'Price Range': '83 - 145 EUR',
  'Restauarant Website': 'www.almalisboa.pt'},
 {'Restaurant Name': 'Disfrutar',
  'Price Range': '165 - 210 EUR',
  'Restauarant Website': 'www.disfrutarbarcelona.com'},
 {'Restaurant Name': 'Ramón Freixa Madrid',
  'Price Range': '90 - 165 EUR',
  'Restauarant Website': 'www.ramonfreixamadrid.com'},
 {'Restaurant Name': 'Cinc Sentits',
  'Price Range': '119 - 139 EUR',
  'Restauarant Website': 'www.cincsentits.com'},
 {'Restaurant Name': 'Noor',
  'Price Range': '95 - 190 EUR',
  'Restauarant Website': 'www.noorrestaurant.es'},
 {'Restaurant Name': 'El Molino de Urdániz',
  'Price Range': '120 - 140 EUR',
  'Restauarant Website': 'www.elmolinourdaniz.com'},
 {'Restaurant Name': 'Cabaña Buenavista',
  'Price Range': '70 - 140 EUR',
  'Restauarant Website': 'www.cabanabuenavista.com'},
 {'Restaurant Name': 'M.B',
  'Price Range': '105 - 165 EUR',
  'Restauarant Website': 'www.ritzcarlton.com'},
 {'Restaurant Name': 'Coque',
  'Price Range': '198 - 230 EUR',
  'Restauarant Website': 'www.restaurantecoque.com'},
 {'Restaurant Name': 'Casa Marcial',
  'Price Range': '70 - 180 EUR',
  'Restauarant Website': 'www.casamarcial.com'},
 {'Restaurant Name': 'Ricard Camarena',
  'Price Range': '135 - 175 EUR',
  'Restauarant Website': 'www.ricardcamarenarestaurant.com'},
 {'Restaurant Name': 'Moments',
  'Price Range': '130 - 189 EUR',
  'Restauarant Website': 'www.mandarinoriental.es'},
 {'Restaurant Name': 'Atrio',
  'Price Range': '185 EUR',
  'Restauarant Website': 'www.restauranteatrio.com'},
 {'Restaurant Name': 'Maralba',
  'Price Range': '65 - 99 EUR',
  'Restauarant Website': 'www.maralbarestaurante.es'},
 {'Restaurant Name': 'BonAmb',
  'Price Range': '90 - 160 EUR',
  'Restauarant Website': 'www.bonamb.com'},
 {'Restaurant Name': 'Les Cols',
  'Price Range': '155 EUR',
  'Restauarant Website': 'www.lescols.com'},
 {'Restaurant Name': 'Miramar',
  'Price Range': '125 - 195 EUR',
  'Restauarant Website': 'www.restaurantmiramar.com'},
 {'Restaurant Name': 'Enoteca Paco Pérez',
  'Price Range': '175 EUR',
  'Restauarant Website': 'www.enotecapacoperez.com'},
 {'Restaurant Name': "L'Escaleta",
  'Price Range': '60 - 135 EUR',
  'Restauarant Website': 'www.lescaleta.com'},
 {'Restaurant Name': 'Mugaritz',
  'Price Range': '231 EUR',
  'Restauarant Website': 'www.mugaritz.com'},
 {'Restaurant Name': 'Skina',
  'Price Range': '165 - 189 EUR',
  'Restauarant Website': 'www.restauranteskina.com'},
 {'Restaurant Name': 'Culler de Pau',
  'Price Range': '95 - 150 EUR',
  'Restauarant Website': 'www.cullerdepau.com'},
 {'Restaurant Name': 'Bo.TiC',
  'Price Range': '95 - 180 EUR',
  'Restauarant Website': 'www.bo-tic.com'},
 {'Restaurant Name': 'Cocina Hermanos Torres',
  'Price Range': '42 - 195 EUR',
  'Restauarant Website': 'www.cocinahermanostorres.com'},
 {'Restaurant Name': 'Bardal',
  'Price Range': '150 - 170 EUR',
  'Restauarant Website': 'www.restaurantebardal.com'},
 {'Restaurant Name': 'El Portal de Echaurren',
  'Price Range': '150 - 165 EUR',
  'Restauarant Website': 'www.echaurren.com'},
 {'Restaurant Name': 'DSTAgE',
  'Price Range': '145 - 170 EUR',
  'Restauarant Website': 'www.dstageconcept.com'},
 {'Restaurant Name': 'Paco Roncero',
  'Price Range': '85 - 148 EUR',
  'Restauarant Website': 'www.pacoroncerorestaurante.com'},
 {'Restaurant Name': 'Angle',
  'Price Range': '145 - 160 EUR',
  'Restauarant Website': 'www.anglebarcelona.com'},
 {'Restaurant Name': 'El Poblet',
  'Price Range': '98 - 135 EUR',
  'Restauarant Website': 'www.elpobletrestaurante.com'},
 {'Restaurant Name': 'BEIGE Alain Ducasse',
  'Price Range': '12,000 - 30,000 JPY',
  'Restauarant Website': 'http://beige-tokyo.com/'},
 {'Restaurant Name': 'Sushi Kanesaka',
  'Price Range': '19,000 - 37,000 JPY',
  'Restauarant Website': 'http://www.sushi-kanesaka.com/'},
 {'Restaurant Name': 'Jingumae Higuchi',
  'Price Range': '31,000 - 37,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Jushu',
  'Price Range': '19,000 - 25,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Daigo',
  'Price Range': '16,000 - 25,000 JPY',
  'Restauarant Website': 'http://www.atago-daigo.jp/'},
 {'Restaurant Name': 'Florilège',
  'Price Range': '9,500 - 19,000 JPY',
  'Restauarant Website': 'https://www.aoyama-florilege.jp/'},
 {'Restaurant Name': 'Jingumae Higuchi',
  'Price Range': '31,000 - 37,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': "L'ATELIER de Joël Robuchon",
  'Price Range': '4,000 - 22,000 JPY',
  'Restauarant Website': 'https://www.robuchon.jp/'},
 {'Restaurant Name': 'Azabu Yukimura',
  'Price Range': '43,000 - 49,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Sukiyabashi Jiro Roppongiten',
  'Price Range': '25,000 - 39,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Jushu',
  'Price Range': '19,000 - 25,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'PRISMA',
  'Price Range': '19,000 - 21,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Usukifugu Yamadaya',
  'Price Range': '29,000 - 41,000 JPY',
  'Restauarant Website': 'https://www.usukifugu-yamadaya.jp/'},
 {'Restaurant Name': 'Seizan',
  'Price Range': '18,000 - 50,000 JPY',
  'Restauarant Website': 'https://seizan-mita.com/'},
 {'Restaurant Name': 'Seisoka',
  'Price Range': '8,500 - 43,000 JPY',
  'Restauarant Website': 'https://seisoka.com/'},
 {'Restaurant Name': 'Tentempura Uchitsu',
  'Price Range': '31,000 JPY',
  'Restauarant Website': 'http://tempura-uchitsu.com/'},
 {'Restaurant Name': 'Tempura Ginya',
  'Price Range': '21,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'LA TABLE de Joël Robuchon',
  'Price Range': '6,500 - 21,000 JPY',
  'Restauarant Website': 'https://www.robuchon.jp/'},
 {'Restaurant Name': 'Sushi Kimura',
  'Price Range': '26,000 - 33,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Miyamaso',
  'Price Range': '19,000 - 32,000 JPY',
  'Restauarant Website': 'http://miyamasou.jp/'},
 {'Restaurant Name': 'Sojiki Nakahigashi',
  'Price Range': '9,000 - 26,000 JPY',
  'Restauarant Website': 'https://www.soujiki-nakahigashi.co.jp/'},
 {'Restaurant Name': 'Kyokaiseki Kichisen',
  'Price Range': '15,000 - 39,000 JPY',
  'Restauarant Website': 'https://www.kichisen-kyoto.com/'},
 {'Restaurant Name': 'Otagi',
  'Price Range': '22,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Yusokuryori Mankamero',
  'Price Range': '13,000 - 38,000 JPY',
  'Restauarant Website': 'http://www.mankamerou.com/'},
 {'Restaurant Name': 'Shimmonzen Yonemura',
  'Price Range': '10,000 - 21,000 JPY',
  'Restauarant Website': 'https://r-yonemura.jp/'},
 {'Restaurant Name': 'Kappo Chihiro',
  'Price Range': '19,000 - 27,000 JPY',
  'Restauarant Website': 'http://www.kyotochihiro.com/'},
 {'Restaurant Name': 'Oryori Mitsuyasu',
  'Price Range': '20,000 JPY',
  'Restauarant Website': 'http://kyoto-mitsuyasu.com/'},
 {'Restaurant Name': 'Kodaiji Wakuden',
  'Price Range': '28,000 - 50,000 JPY',
  'Restauarant Website': 'https://www.wakuden.jp/'},
 {'Restaurant Name': 'Gion Maruyama',
  'Price Range': '11,000 - 64,000 JPY',
  'Restauarant Website': 'https://gionmaruyama.com/'},
 {'Restaurant Name': 'Gion Matayoshi',
  'Price Range': '12,000 - 37,000 JPY',
  'Restauarant Website': 'http://www.gion-matayoshi.com/'},
 {'Restaurant Name': 'Kyotenjin Noguchi',
  'Price Range': '30,000 - 35,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Sumibi Kappo Ifuki',
  'Price Range': '24,000 - 35,000 JPY',
  'Restauarant Website': 'https://gion-ifuki.com/'},
 {'Restaurant Name': 'Gion Owatari',
  'Price Range': '32,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Gion Nishikawa',
  'Price Range': '6,500 - 31,000 JPY',
  'Restauarant Website': 'http://r.goope.jp/gion-nishikawa/'},
 {'Restaurant Name': 'Kikunoi Roan',
  'Price Range': '9,000 - 32,000 JPY',
  'Restauarant Website': 'https://kikunoi.jp/'},
 {'Restaurant Name': 'Kenninji Gion Maruyama',
  'Price Range': '11,000 - 64,000 JPY',
  'Restauarant Website': 'https://gionmaruyama.com/'},
 {'Restaurant Name': 'Ogata',
  'Price Range': '50,000 - 60,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Wagokoro Izumi',
  'Price Range': '7,000 - 29,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Shunsaiten Tsuchiya',
  'Price Range': '8,000 - 24,000 JPY',
  'Restauarant Website': 'http://www.shunsaiten-tsuchiya.com/'},
 {'Restaurant Name': 'Tenjimbashi Aoki',
  'Price Range': '22,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Sushiyoshi',
  'Price Range': '25,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Miyamoto',
  'Price Range': '19,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'KAHALA',
  'Price Range': '31,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Numata',
  'Price Range': '22,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Koryu',
  'Price Range': '33,000 JPY',
  'Restauarant Website': 'https://www.koryu.net/'},
 {'Restaurant Name': 'La Peca',
  'Price Range': '95 - 200 EUR',
  'Restauarant Website': 'https://www.lapeca.it/'},
 {'Restaurant Name': 'Quattro Passi',
  'Price Range': '75 - 200 EUR',
  'Restauarant Website': 'http://www.ristorantequattropassi.com/'},
 {'Restaurant Name': 'La Madia',
  'Price Range': '90 - 170 EUR',
  'Restauarant Website': 'http://www.ristorantelamadia.it'},
 {'Restaurant Name': 'La Trota',
  'Price Range': '90 - 130 EUR',
  'Restauarant Website': 'https://www.latrota.com/'},
 {'Restaurant Name': 'Villa Crespi',
  'Price Range': '140 - 190 EUR',
  'Restauarant Website': 'https://www.villacrespi.it/'},
 {'Restaurant Name': 'Taverna Estia',
  'Price Range': '95 - 180 EUR',
  'Restauarant Website': 'https://www.tavernaestia.it/'},
 {'Restaurant Name': 'Caino',
  'Price Range': '115 - 190 EUR',
  'Restauarant Website': 'http://www.dacaino.it/'},
 {'Restaurant Name': 'Il Piccolo Principe',
  'Price Range': '130 - 230 EUR',
  'Restauarant Website': 'https://www.ristoranteilpiccoloprincipe.it/'},
 {'Restaurant Name': 'Antica Osteria Cera',
  'Price Range': '70 - 250 EUR',
  'Restauarant Website': 'https://www.osteriacera.it/'},
 {'Restaurant Name': 'Duomo',
  'Price Range': '65 - 190 EUR',
  'Restauarant Website': 'https://www.cicciosultano.it/'},
 {'Restaurant Name': "L'Olivo",
  'Price Range': '125 - 210 EUR',
  'Restauarant Website': 'https://www.capripalace.com/'},
 {'Restaurant Name': 'Casa Perbellini',
  'Price Range': '65 - 185 EUR',
  'Restauarant Website': 'https://www.casaperbellini.com/'},
 {'Restaurant Name': 'Don Alfonso 1890',
  'Price Range': '120 - 190 EUR',
  'Restauarant Website': 'https://www.donalfonso.com/'},
 {'Restaurant Name': 'Glam Enrico Bartolini',
  'Price Range': '130 - 230 EUR',
  'Restauarant Website': 'http://www.ristoranteglam.com'},
 {'Restaurant Name': "Harry's Piccolo",
  'Price Range': '100 - 200 EUR',
  'Restauarant Website': 'https://www.harrystrieste.it/'},
 {'Restaurant Name': 'Arnolfo',
  'Price Range': '120 - 160 EUR',
  'Restauarant Website': 'https://www.arnolfo.com/'},
 {'Restaurant Name': 'La Madernassa',
  'Price Range': '80 - 300 EUR',
  'Restauarant Website': 'https://www.lamadernassa.it/'},
 {'Restaurant Name': "Miramonti l'Altro",
  'Price Range': '90 - 150 EUR',
  'Restauarant Website': 'https://www.miramontilaltro.it/'},
 {'Restaurant Name': 'Antica Corona Reale',
  'Price Range': '80 - 130 EUR',
  'Restauarant Website': 'https://www.anticacoronareale.it/'},
 {'Restaurant Name': "D'O",
  'Price Range': '95 - 165 EUR',
  'Restauarant Website': 'https://www.cucinapop.do/'},
 {'Restaurant Name': 'Villa Feltrinelli',
  'Price Range': '220 EUR',
  'Restauarant Website': 'https://www.villafeltrinelli.com/'},
 {'Restaurant Name': 'Bracali',
  'Price Range': '135 - 225 EUR',
  'Restauarant Website': 'https://www.mondobracali.it/'},
 {'Restaurant Name': 'Santa Elisabetta',
  'Price Range': '74 - 199 EUR',
  'Restauarant Website': 'https://www.ristorantesantaelisabetta.it/'},
 {'Restaurant Name': 'Torre del Saracino',
  'Price Range': '105 - 220 EUR',
  'Restauarant Website': 'https://www.torredelsaracino.it/'},
 {'Restaurant Name': 'Magnolia',
  'Price Range': '95 - 140 EUR',
  'Restauarant Website': 'https://www.magnoliaristorante.it/'},
 {'Restaurant Name': 'Piccolo Lago',
  'Price Range': '180 EUR',
  'Restauarant Website': 'https://www.piccololago.it/'},
 {'Restaurant Name': 'Il Luogo di Aimo e Nadia',
  'Price Range': '115 - 280 EUR',
  'Restauarant Website': 'https://www.aimoenadia.com/'},
 {'Restaurant Name': 'Gourmetstube Einhorn',
  'Price Range': '130 - 165 EUR',
  'Restauarant Website': 'https://www.stafler.com/'},
 {'Restaurant Name': 'Il Pagliaccio',
  'Price Range': '85 - 185 EUR',
  'Restauarant Website': 'https://www.ristoranteilpagliaccio.com/'},
 {'Restaurant Name': 'San Domenico',
  'Price Range': '60 - 180 EUR',
  'Restauarant Website': 'https://www.sandomenico.it/'},
 {'Restaurant Name': 'Seta by Antonio Guida',
  'Price Range': '90 - 230 EUR',
  'Restauarant Website': 'https://www.mandarinoriental.com/'},
 {'Restaurant Name': 'Madonnina del Pescatore',
  'Price Range': '65 - 175 EUR',
  'Restauarant Website': 'https://www.morenocedroni.it/'},
 {'Restaurant Name': 'Kojima',
  'Price Range': '200,000 - 380,000 KRW',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': "L'Impression",
  'Price Range': '100,000 - 220,000 KRW',
  'Restauarant Website': 'http://www.limpression.co.kr/'},
 {'Restaurant Name': 'alla Prima',
  'Price Range': '77,000 - 200,000 KRW',
  'Restauarant Website': 'https://www.allaprima.co.kr/'},
 {'Restaurant Name': 'Jungsik',
  'Price Range': '78,000 - 230,000 KRW',
  'Restauarant Website': 'https://www.jungsik.kr/'},
 {'Restaurant Name': 'Mosu',
  'Price Range': '140,000 - 270,000 KRW',
  'Restauarant Website': 'http://mosuseoul.com'},
 {'Restaurant Name': 'Kwonsooksoo',
  'Price Range': '105,000 - 240,000 KRW',
  'Restauarant Website': 'https://www.kwonsooksoo.com/'},
 {'Restaurant Name': 'Mingles',
  'Price Range': '120,000 - 220,000 KRW',
  'Restauarant Website': 'http://www.restaurant-mingles.com/'},
 {'Restaurant Name': 'Shanghai Cuisine',
  'Price Range': '300 - 1,000 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Jingji',
  'Price Range': '300 - 2,000 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Taian Table',
  'Price Range': '1,858 - 2,188 CNY',
  'Restauarant Website': 'https://taian-table.cn/'},
 {'Restaurant Name': 'Ji Pin Court',
  'Price Range': '200 - 1,000 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Da Vittorio',
  'Price Range': '688 - 2,888 CNY',
  'Restauarant Website': 'https://www.davittorio.com/'},
 {'Restaurant Name': "L'Atelier de Joël Robuchon",
  'Price Range': '600 - 1,798 CNY',
  'Restauarant Website': 'http://www.joelrobuchon-china.com/'},
 {'Restaurant Name': '8 ½ Otto e Mezzo Bombana',
  'Price Range': '698 - 2,380 CNY',
  'Restauarant Website': 'https://www.ottoemezzobombana.com/'},
 {'Restaurant Name': 'Imperial Treasure Fine Chinese Cuisine (Huangpu)',
  'Price Range': '200 - 1,000 CNY',
  'Restauarant Website': 'https://www.imperialtreasure.com/'},
 {'Restaurant Name': 'Canton 8 (Runan Street)',
  'Price Range': '100 - 500 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Bao Li Xuan',
  'Price Range': '300 - 1,288 CNY',
  'Restauarant Website': 'https://www.bulgarihotels.com/shanghai'},
 {'Restaurant Name': 'YongFoo Élite',
  'Price Range': '400 - 1,000 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Xin Rong Ji (Nanyang Road)',
  'Price Range': '1,000 - 2,500 CNY',
  'Restauarant Website': 'www.xinrongji.cc'},
 {'Restaurant Name': 'D.O.M.',
  'Price Range': '415 - 700 BRL',
  'Restauarant Website': 'http://www.domrestaurante.com.br/'},
 {'Restaurant Name': 'Ryo Gastronomia',
  'Price Range': '160 - 650 BRL',
  'Restauarant Website': 'https://www.ryogastronomia.com.br/'},
 {'Restaurant Name': 'Oteque',
  'Price Range': '440 BRL',
  'Restauarant Website': 'https://www.oteque.com/'},
 {'Restaurant Name': 'Oro',
  'Price Range': '445 - 555 BRL',
  'Restauarant Website': 'http://www.ororestaurante.com.br/'},
 {'Restaurant Name': 'Spondi',
  'Price Range': '120 - 165 EUR',
  'Restauarant Website': 'https://www.spondi.gr/'},
 {'Restaurant Name': 'Silvio Nickol Gourmet Restaurant',
  'Price Range': '23 - 165 EUR',
  'Restauarant Website': 'https://www.palais-coburg.com/'},
 {'Restaurant Name': 'Steirereck im Stadtpark',
  'Price Range': '74 - 169 EUR',
  'Restauarant Website': 'https://www.steirereck.at/'},
 {'Restaurant Name': 'Mraz & Sohn',
  'Price Range': '145 EUR',
  'Restauarant Website': 'https://www.mrazundsohn.at/'},
 {'Restaurant Name': 'Konstantin Filippou',
  'Price Range': '56 - 189 EUR',
  'Restauarant Website': 'https://www.konstantinfilippou.com/'},
 {'Restaurant Name': 'SENNS.Restaurant',
  'Price Range': '85 - 205 EUR',
  'Restauarant Website': 'https://www.senns.restaurant/'},
 {'Restaurant Name': 'Ikarus',
  'Price Range': '140 - 210 EUR',
  'Restauarant Website': 'https://www.hangar-7.com/'}]

# %%
#1 Star Restaurants List of Dictionaires
[{'Restaurant Name': 'Shoroku',
  'Price Range': '6,000 - 18,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Point',
  'Price Range': '22,000 JPY',
  'Restauarant Website': 'http://point-accueillir.com/'},
 {'Restaurant Name': 'Oryori Yamada',
  'Price Range': '20,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Yoshiko',
  'Price Range': '30,000 - 37,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Kyomachiryori Mitsuya',
  'Price Range': '6,500 - 17,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Ñ',
  'Price Range': '8,500 - 17,000 JPY',
  'Restauarant Website': 'https://www.enye.jp/'},
 {'Restaurant Name': 'Nishishinsaibashi Yuno',
  'Price Range': '17,000 - 25,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Enomoto',
  'Price Range': '22,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'il Centrino',
  'Price Range': '5,000 - 15,000 JPY',
  'Restauarant Website': 'http://www.il-centrino.com/'},
 {'Restaurant Name': 'HATSU',
  'Price Range': '19,000 JPY',
  'Restauarant Website': 'https://hatsu-osaka.jp/'},
 {'Restaurant Name': 'Kitashinchi Fukutatei',
  'Price Range': '19,000 - 25,000 JPY',
  'Restauarant Website': 'http://fukutatei.com/'},
 {'Restaurant Name': 'IDÉAL bistro',
  'Price Range': '3,500 - 15,000 JPY',
  'Restauarant Website': 'http://idealfoodflower.com/'},
 {'Restaurant Name': 'Shinchi Yamamoto',
  'Price Range': '29,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Ono',
  'Price Range': '28,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Choraku',
  'Price Range': '16,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Sui',
  'Price Range': '5,500 - 18,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Hiraishi',
  'Price Range': '17,000 - 19,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Sosakuwasho Nakashima',
  'Price Range': '11,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Konoha',
  'Price Range': '7,000 - 18,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Oimatsu Kitagawa',
  'Price Range': '9,000 - 27,000 JPY',
  'Restauarant Website': 'https://www.oimatsu-kitagawa.com/'},
 {'Restaurant Name': 'Ichiju Nisai Ueno Minoten',
  'Price Range': '11,000 - 34,000 JPY',
  'Restauarant Website': 'https://ichijunisai-ueno.net/'},
 {'Restaurant Name': 'LE PONT DE CIEL',
  'Price Range': '8,000 - 30,000 JPY',
  'Restauarant Website': 'https://pont-de-ciel.co.jp/'},
 {'Restaurant Name': "agnel d'or",
  'Price Range': '6,500 - 16,000 JPY',
  'Restauarant Website': 'http://www.agneldor.com/'},
 {'Restaurant Name': 'Oimatsu Hisano',
  'Price Range': '15,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Torisho Ishii',
  'Price Range': '10,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Utsubohommachi Gaku',
  'Price Range': '12,000 - 24,000 JPY',
  'Restauarant Website': 'https://www.utsubo-gaku.com/'},
 {'Restaurant Name': 'Iwaki',
  'Price Range': '14,000 - 20,000 JPY',
  'Restauarant Website': 'http://k-iwaki.com/'},
 {'Restaurant Name': 'Iroha',
  'Price Range': '15,000 - 20,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Shintaro',
  'Price Range': '3,000 - 12,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Différence',
  'Price Range': '6,000 - 15,000 JPY',
  'Restauarant Website': 'http://difference.upper.jp/'},
 {'Restaurant Name': 'Rakushin',
  'Price Range': '7,000 - 33,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'a canto',
  'Price Range': '11,000 JPY',
  'Restauarant Website': 'https://www.a-canto.com/'},
 {'Restaurant Name': 'Pierre',
  'Price Range': '9,500 - 21,000 JPY',
  'Restauarant Website': 'https://www.icosaka.com/'},
 {'Restaurant Name': 'Higashichaya Nakamura',
  'Price Range': '24,000 - 26,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Man-u',
  'Price Range': '16,000 - 20,000 JPY',
  'Restauarant Website': 'http://www.kagaman.co.jp/'},
 {'Restaurant Name': 'Kaishoku Shimizu',
  'Price Range': '5,500 - 16,500 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Sushi Murakami Jiro',
  'Price Range': '27,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Sushidokoro Amano',
  'Price Range': '16,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Ayamuya',
  'Price Range': '4,000 - 7,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Nishino',
  'Price Range': '18,000 - 20,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'La Lucciola',
  'Price Range': '9,000 - 14,000 JPY',
  'Restauarant Website': 'http://lucciola.net/'},
 {'Restaurant Name': 'Zeshin',
  'Price Range': '9,000 - 16,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'La casa TOM Curiosa',
  'Price Range': '17,000 JPY',
  'Restauarant Website': 'http://www.tom-curiosa.com/'},
 {'Restaurant Name': 'P greco',
  'Price Range': '22,000 - 28,000 JPY',
  'Restauarant Website': 'https://www.pgreco.jp/'},
 {'Restaurant Name': 'Temmabashi Fujikawa',
  'Price Range': '7,000 - 17,000 JPY',
  'Restauarant Website': 'https://www.te-fujikawa.com/'},
 {'Restaurant Name': 'TEMPURA HANAGATAMI',
  'Price Range': '9,500 - 26,000 JPY',
  'Restauarant Website': 'https://hanagatami.ritzcarltonosaka.com/'},
 {'Restaurant Name': 'Ajikitcho Horieten',
  'Price Range': '19,000 - 46,000 JPY',
  'Restauarant Website': 'https://ajikitcho.com/'},
 {'Restaurant Name': 'capi',
  'Price Range': '22,000 - 24,000 JPY',
  'Restauarant Website': 'https://capi-osaka.com/'},
 {'Restaurant Name': 'Sushi Minazuki',
  'Price Range': '21,000 - 27,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'La Bécasse',
  'Price Range': '10,000 - 30,000 JPY',
  'Restauarant Website': 'https://www.labecasse1990.com/'},
 {'Restaurant Name': 'Oryori Horikawa',
  'Price Range': '7,000 - 16,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Teruya',
  'Price Range': '20,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Yakitori Ichimatsu',
  'Price Range': '8,500 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Terada',
  'Price Range': '5,000 - 20,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'La Baie',
  'Price Range': '13,000 - 37,000 JPY',
  'Restauarant Website': 'https://labaie.ritzcarltonosaka.com/'},
 {'Restaurant Name': 'Sushi Yuden',
  'Price Range': '15,000 - 20,000 JPY',
  'Restauarant Website': 'https://www.sushi-yuuden.net/'},
 {'Restaurant Name': 'Kawahara',
  'Price Range': '7,000 - 17,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Ayamedo',
  'Price Range': '1,000 - 4,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Chugokusai S.Sawada',
  'Price Range': '11,000 - 17,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Kagaman',
  'Price Range': '6,500 - 43,000 JPY',
  'Restauarant Website': 'http://www.kagaman.co.jp/'},
 {'Restaurant Name': 'Ajikitcho Bumbuan',
  'Price Range': '4,000 - 25,000 JPY',
  'Restauarant Website': 'https://bunbu-an.jp/'},
 {'Restaurant Name': 'Sumibi Kappo Ishii',
  'Price Range': '20,000 - 33,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Nishitemma Nakamura',
  'Price Range': '15,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Masuda',
  'Price Range': '3,500 - 18,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Yoshino',
  'Price Range': '5,500 - 14,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'YUNiCO',
  'Price Range': '5,000 - 15,000 JPY',
  'Restauarant Website': 'https://y-unico.jp/'},
 {'Restaurant Name': 'Yonemasu',
  'Price Range': '22,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Sushidokoro Hirokawa',
  'Price Range': '15,000 - 17,000 JPY',
  'Restauarant Website': 'https://sushi-hirokawa.jp/'},
 {'Restaurant Name': 'Naniwaryori Yu',
  'Price Range': '10,000 - 15,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'LIAISON',
  'Price Range': '7,500 - 16,000 JPY',
  'Restauarant Website': 'http://liaison-osaka.com/'},
 {'Restaurant Name': 'ad hoc',
  'Price Range': '7,500 - 16,000 JPY',
  'Restauarant Website': 'http://adhoc2014.jp/'},
 {'Restaurant Name': 'Kappo Hashimoto',
  'Price Range': '7,000 - 13,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Yunagibashi Takoyasu',
  'Price Range': '24,000 - 34,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Yugen',
  'Price Range': '7,000 - 21,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Sushiroku',
  'Price Range': '13,000 - 16,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Alarde',
  'Price Range': '14,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Sushi Ohata',
  'Price Range': '24,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Shunsenwaraku Sanai',
  'Price Range': '11,000 - 14,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Maison Tateru Yoshino',
  'Price Range': '7,000 - 25,000 JPY',
  'Restauarant Website': 'https://www.anacrowneplaza-osaka.jp/'},
 {'Restaurant Name': 'Unkaku',
  'Price Range': '5,500 - 37,000 JPY',
  'Restauarant Website': 'http://www.unkaku.jp/'},
 {'Restaurant Name': 'Peter Luger',
  'Price Range': '75 - 150 USD',
  'Restauarant Website': 'https://www.peterluger.com/'},
 {'Restaurant Name': 'Oxomoco',
  'Price Range': '30 - 75 USD',
  'Restauarant Website': 'https://www.oxomoconyc.com/'},
 {'Restaurant Name': 'The Four Horsemen',
  'Price Range': '30 - 85 USD',
  'Restauarant Website': 'https://www.fourhorsemenbk.com/'},
 {'Restaurant Name': 'Oxalis',
  'Price Range': '25 - 105 USD',
  'Restauarant Website': 'https://www.oxalisnyc.com/'},
 {'Restaurant Name': 'Jeune et Jolie',
  'Price Range': '49 - 90 USD',
  'Restauarant Website': 'www.jeune-jolie.com'},
 {'Restaurant Name': 'Soichi',
  'Price Range': '45 - 125 USD',
  'Restauarant Website': 'https://www.soichisushi.com/'},
 {'Restaurant Name': 'Bistro Na’s',
  'Price Range': '25 - 300 USD',
  'Restauarant Website': 'https://www.bistronas.com/'},
 {'Restaurant Name': 'Sushi Tadokoro',
  'Price Range': '30 - 120 USD',
  'Restauarant Website': 'https://www.sushitadokoro.com/'},
 {'Restaurant Name': 'Knife Pleat',
  'Price Range': '22 - 135 USD',
  'Restauarant Website': 'https://www.knifepleat.com/'},
 {'Restaurant Name': 'Hana re',
  'Price Range': '200 USD',
  'Restauarant Website': 'https://www.hanaresushi.com/'},
 {'Restaurant Name': 'Taco María',
  'Price Range': '45 - 84 USD',
  'Restauarant Website': 'https://www.tacomaria.com/'},
 {'Restaurant Name': 'Morihiro',
  'Price Range': '50 - 300 USD',
  'Restauarant Website': 'https://morionodera.com/'},
 {'Restaurant Name': 'Orsa & Winston',
  'Price Range': '125 USD',
  'Restauarant Website': 'https://www.orsaandwinston.com/'},
 {'Restaurant Name': 'Q Sushi',
  'Price Range': '150 - 300 USD',
  'Restauarant Website': 'http://www.qsushila.com/'},
 {'Restaurant Name': 'Shibumi',
  'Price Range': '95 - 195 USD',
  'Restauarant Website': 'https://www.shibumidtla.com/'},
 {'Restaurant Name': 'Phenakite',
  'Price Range': '158 USD',
  'Restauarant Website': 'https://www.porridgeandpuffs.com/phenakite'},
 {'Restaurant Name': 'Le Comptoir',
  'Price Range': '120 USD',
  'Restauarant Website': 'https://www.lecomptoirla.com/'},
 {'Restaurant Name': 'Kali',
  'Price Range': '50 - 75 USD',
  'Restauarant Website': 'https://www.kalirestaurant.com/'},
 {'Restaurant Name': 'Osteria Mozza',
  'Price Range': '50 - 75 USD',
  'Restauarant Website': 'https://www.osteriamozza.com/'},
 {'Restaurant Name': 'Nozawa Bar',
  'Price Range': '195 USD',
  'Restauarant Website': 'https://www.nozawabar.com/'},
 {'Restaurant Name': 'Droit',
  'Price Range': '19,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Oryori Hiwatashi',
  'Price Range': '10,000 - 25,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Gion Okada',
  'Price Range': '9,000 - 19,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Iwasaki',
  'Price Range': '6,000 - 24,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Tozentei',
  'Price Range': '6,000 - 33,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Sushi Rakumi',
  'Price Range': '25,000 - 28,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Oshikoji Okada',
  'Price Range': '5,500 - 11,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'CAINOYA',
  'Price Range': '40,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'naruya',
  'Price Range': '23,000 - 40,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Reine des prés',
  'Price Range': '8,000 - 24,000 JPY',
  'Restauarant Website': 'http://reine-des-pres.com/'},
 {'Restaurant Name': 'La Biographie···',
  'Price Range': '13,000 - 43,000 JPY',
  'Restauarant Website': 'https://la-biographie.info/'},
 {'Restaurant Name': 'MUNI LA TERRASSE',
  'Price Range': '7,000 - 13,000 JPY',
  'Restauarant Website': 'https://muni-kyoto.com/'},
 {'Restaurant Name': 'Gion Nishimura',
  'Price Range': '16,000 - 26,000 JPY',
  'Restauarant Website': 'https://www.gion-nishimura.com/'},
 {'Restaurant Name': 'Kako Okamoto',
  'Price Range': '14,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Kodaiji Jugyuan',
  'Price Range': '19,000 - 64,000 JPY',
  'Restauarant Website': 'https://jugyuan.jp/'},
 {'Restaurant Name': 'Gion Fukushi',
  'Price Range': '19,000 - 37,000 JPY',
  'Restauarant Website': 'http://gion-fukushi.jp/'},
 {'Restaurant Name': 'NAKATSUKA',
  'Price Range': '8,000 - 15,000 JPY',
  'Restauarant Website': 'https://nakatsuka-kyoto.com/'},
 {'Restaurant Name': 'Kokyu',
  'Price Range': '8,500 - 26,000 JPY',
  'Restauarant Website': 'http://www.kokyu-kyoto.com/'},
 {'Restaurant Name': 'Kappo Hassun',
  'Price Range': '11,000 - 22,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Shuhaku',
  'Price Range': '6,000 - 18,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Shimogamo Saryo',
  'Price Range': '8,500 - 31,000 JPY',
  'Restauarant Website': 'https://www.shimogamosaryo.co.jp/'},
 {'Restaurant Name': 'Kanamean Nishitomiya',
  'Price Range': '25,000 JPY',
  'Restauarant Website': 'https://www.kanamean.co.jp/'},
 {'Restaurant Name': 'TAKAYAMA',
  'Price Range': '22,000 JPY',
  'Restauarant Website': 'https://takayama-kyoto.com/'},
 {'Restaurant Name': 'Sokkon Fujimoto',
  'Price Range': '8,000 - 22,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Ryoriya Maekawa',
  'Price Range': '17,000 JPY',
  'Restauarant Website': 'https://ryouriya-maekawa.com/'},
 {'Restaurant Name': 'Okina',
  'Price Range': '5,000 - 15,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Sanso Kyoyamato',
  'Price Range': '16,000 - 57,000 JPY',
  'Restauarant Website': 'https://www.kyoyamato.com/'},
 {'Restaurant Name': 'Mirei',
  'Price Range': '8,000 - 17,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Aoike',
  'Price Range': '6,500 - 22,000 JPY',
  'Restauarant Website': 'http://aoike-kyoto.com/'},
 {'Restaurant Name': 'cenci',
  'Price Range': '7,500 - 16,000 JPY',
  'Restauarant Website': 'https://cenci-kyoto.com/'},
 {'Restaurant Name': 'Tominokoji Yamagishi',
  'Price Range': '44,000 JPY',
  'Restauarant Website': 'http://www.tominokoji-yamagishi.com/'},
 {'Restaurant Name': 'Gokomachi Tagawa',
  'Price Range': '22,000 JPY',
  'Restauarant Website': 'https://www.gokoumachi-tagawa.com/'},
 {'Restaurant Name': 'Oryori Mashita',
  'Price Range': '5,000 - 25,000 JPY',
  'Restauarant Website': 'http://kyoto-mashita.com/'},
 {'Restaurant Name': 'MUNI ALAIN DUCASSE',
  'Price Range': '27,000 - 39,000 JPY',
  'Restauarant Website': 'https://muni-kyoto.com/'},
 {'Restaurant Name': 'Torisaki',
  'Price Range': '8,500 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Honke Tankuma Honten',
  'Price Range': '8,000 - 64,000 JPY',
  'Restauarant Website': 'http://www.tankuma.jp/'},
 {'Restaurant Name': 'Tempura Mizuki',
  'Price Range': '9,000 - 25,000 JPY',
  'Restauarant Website': 'https://www.ritzcarlton.com/jp/hotels/japan/kyoto'},
 {'Restaurant Name': 'Jiki Miyazawa',
  'Price Range': '6,500 - 20,000 JPY',
  'Restauarant Website': 'https://jiki-miyazawa.com/'},
 {'Restaurant Name': 'Gion Kajisho',
  'Price Range': '4,000 - 17,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Nakazen',
  'Price Range': '9,500 - 14,000 JPY',
  'Restauarant Website': 'https://www.ohhara-nakazen.com/'},
 {'Restaurant Name': 'State Bird Provisions',
  'Price Range': '25 - 90 USD',
  'Restauarant Website': 'https://www.statebirdsf.com/'},
 {'Restaurant Name': 'The Progress',
  'Price Range': '41 - 78 USD',
  'Restauarant Website': 'https://www.theprogress-sf.com/'},
 {'Restaurant Name': "Al's Place",
  'Price Range': '58 - 88 USD',
  'Restauarant Website': 'https://www.alsplacesf.com/'},
 {'Restaurant Name': 'Rasa',
  'Price Range': '47 - 88 USD',
  'Restauarant Website': 'https://www.rasaindian.com/'},
 {'Restaurant Name': 'jū-ni',
  'Price Range': '165 USD',
  'Restauarant Website': 'https://www.junisf.com/'},
 {'Restaurant Name': 'Sorrel',
  'Price Range': '110 - 148 USD',
  'Restauarant Website': 'https://www.sorrelrestaurant.com/'},
 {'Restaurant Name': 'Spruce',
  'Price Range': '50 - 75 USD',
  'Restauarant Website': 'https://www.sprucesf.com/'},
 {'Restaurant Name': 'Wakuriya',
  'Price Range': '148 USD',
  'Restauarant Website': 'https://www.wakuriya.com/'},
 {'Restaurant Name': 'Wako',
  'Price Range': '95 - 135 USD',
  'Restauarant Website': 'https://www.sushiwakosf.com/'},
 {'Restaurant Name': 'Madcap',
  'Price Range': '110 USD',
  'Restauarant Website': 'https://www.madcapmarin.com/'},
 {'Restaurant Name': 'Barndiva',
  'Price Range': '35 - 90 USD',
  'Restauarant Website': 'https://www.barndiva.com/'},
 {'Restaurant Name': 'Aubergine',
  'Price Range': '205 USD',
  'Restauarant Website': 'https://www.auberginecarmel.com/'},
 {'Restaurant Name': 'DILL',
  'Price Range': '15,900 ISK',
  'Restauarant Website': 'https://www.dillrestaurant.is/'},
 {'Restaurant Name': 'Loch Bay',
  'Price Range': '110 GBP',
  'Restauarant Website': 'https://www.lochbay-restaurant.co.uk/'},
 {'Restaurant Name': 'Wild Honey Inn',
  'Price Range': '70 - 80 EUR',
  'Restauarant Website': 'https://www.wildhoneyinn.com/'},
 {'Restaurant Name': 'Aniar',
  'Price Range': '110 EUR',
  'Restauarant Website': 'https://www.aniarrestaurant.ie/'},
 {'Restaurant Name': 'Loam',
  'Price Range': '58 - 99 EUR',
  'Restauarant Website': 'https://www.loamgalway.com/'},
 {'Restaurant Name': 'Chestnut',
  'Price Range': '100 EUR',
  'Restauarant Website': 'https://www.restaurantchestnutwestcork.ie/'},
 {'Restaurant Name': 'The Oak Room',
  'Price Range': '100 - 120 EUR',
  'Restauarant Website': 'https://www.adaremanor.com/'},
 {'Restaurant Name': 'dede',
  'Price Range': '95 EUR',
  'Restauarant Website': 'https://customshousebaltimore.com/'},
 {'Restaurant Name': 'Mokube',
  'Price Range': '11,000 - 22,000 JPY',
  'Restauarant Website': 'https://mokubei.jp/'},
 {'Restaurant Name': 'Kamanza Nagashima',
  'Price Range': '13,000 - 17,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Nikunotakumi Miyoshi',
  'Price Range': '48,000 JPY',
  'Restauarant Website': 'https://niku-miyoshi.com/'},
 {'Restaurant Name': 'Ten-you',
  'Price Range': '3,000 - 17,000 JPY',
  'Restauarant Website': 'https://www.ten-you.jp/'},
 {'Restaurant Name': 'Sushi Matsumoto',
  'Price Range': '11,000 - 21,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Selfie',
  'Price Range': '2,500 - 7,000 RUB',
  'Restauarant Website': 'www.selfiemoscow.ru'},
 {'Restaurant Name': 'Savva',
  'Price Range': '2,500 - 6,000 RUB',
  'Restauarant Website': 'www.savvarest.ru'},
 {'Restaurant Name': 'Sakhalin',
  'Price Range': '3,000 - 11,000 RUB',
  'Restauarant Website': 'www.sakhalin-moscow.ru'},
 {'Restaurant Name': 'Biologie',
  'Price Range': '2,100 - 4,000 RUB',
  'Restauarant Website': 'www.biologie.ru'},
 {'Restaurant Name': 'White Rabbit',
  'Price Range': '2,500 - 12,500 RUB',
  'Restauarant Website': 'www.whiterabbitmoscow.ru'},
 {'Restaurant Name': 'Grand Cru',
  'Price Range': '3,000 - 7,000 RUB',
  'Restauarant Website': 'www.grandcru.ru'},
 {'Restaurant Name': 'Beluga',
  'Price Range': '2,500 - 12,000 RUB',
  'Restauarant Website': 'www.belugamoscow.ru'},
 {'Restaurant Name': "Selby's",
  'Price Range': '85 USD',
  'Restauarant Website': 'https://www.selbysrestaurant.com/'},
 {'Restaurant Name': 'Plumed Horse',
  'Price Range': '70 - 195 USD',
  'Restauarant Website': 'https://www.plumedhorse.com/'},
 {'Restaurant Name': 'Rasa',
  'Price Range': '47 - 88 USD',
  'Restauarant Website': 'https://www.rasaindian.com/'},
 {'Restaurant Name': 'The Village Pub',
  'Price Range': '45 - 85 USD',
  'Restauarant Website': 'https://www.thevillagepub.net/'},
 {'Restaurant Name': 'Pasta | Bar',
  'Price Range': '165 USD',
  'Restauarant Website': 'https://www.pastabarencino.com/'},
 {'Restaurant Name': 'Shin Sushi',
  'Price Range': '100 - 120 USD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Adega',
  'Price Range': '199 USD',
  'Restauarant Website': 'https://www.adegarest.com/'},
 {'Restaurant Name': 'Kenzo',
  'Price Range': '185 - 210 USD',
  'Restauarant Website': 'https://www.kenzonapa.com/'},
 {'Restaurant Name': 'Forest Side',
  'Price Range': '45 - 95 GBP',
  'Restauarant Website': 'https://www.theforestside.com/'},
 {'Restaurant Name': 'Old Stamp House',
  'Price Range': '45 - 75 GBP',
  'Restauarant Website': 'https://www.oldstamphouse.com/'},
 {'Restaurant Name': 'Allium at Askham Hall',
  'Price Range': '95 GBP',
  'Restauarant Website': 'https://www.askhamhall.co.uk/'},
 {'Restaurant Name': 'HRiSHi',
  'Price Range': '75 - 95 GBP',
  'Restauarant Website': 'https://www.thegilpin.co.uk/'},
 {'Restaurant Name': 'Rogan & Co',
  'Price Range': '34 - 63 GBP',
  'Restauarant Website': 'https://www.roganandco.co.uk/'},
 {'Restaurant Name': 'Hjem',
  'Price Range': '85 GBP',
  'Restauarant Website': 'https://www.restauranthjem.co.uk/'},
 {'Restaurant Name': 'Ynyshir',
  'Price Range': '200 - 300 GBP',
  'Restauarant Website': 'https://www.ynyshir.co.uk/'},
 {'Restaurant Name': 'Fraiche',
  'Price Range': '58 - 115 GBP',
  'Restauarant Website': 'www.restaurantfraiche.com'},
 {'Restaurant Name': 'House of Tides',
  'Price Range': '85 - 110 GBP',
  'Restauarant Website': 'https://www.houseoftides.co.uk/'},
 {'Restaurant Name': 'Northcote',
  'Price Range': '45 - 95 GBP',
  'Restauarant Website': 'https://www.northcote.com/'},
 {'Restaurant Name': 'Paul Ainsworth at No.6',
  'Price Range': '85 - 95 GBP',
  'Restauarant Website': 'https://www.paul-ainsworth.co.uk/'},
 {'Restaurant Name': 'Beach House',
  'Price Range': '62 - 95 GBP',
  'Restauarant Website': 'https://www.beachhouseoxwich.co.uk/'},
 {'Restaurant Name': "Outlaw's Fish Kitchen",
  'Price Range': '80 GBP',
  'Restauarant Website': 'https://www.outlaws.co.uk/restaurants/fish-kitchen'},
 {'Restaurant Name': "Outlaw's New Road",
  'Price Range': '80 GBP',
  'Restauarant Website': 'https://www.outlaws.co.uk/restaurants/new-road'},
 {'Restaurant Name': 'White Swan',
  'Price Range': '50 GBP',
  'Restauarant Website': 'https://www.whiteswanatfence.co.uk/'},
 {'Restaurant Name': 'The Angel',
  'Price Range': '44 - 80 GBP',
  'Restauarant Website': 'https://www.angelhetton.co.uk/'},
 {'Restaurant Name': 'Thomas Carr 1873',
  'Price Range': '95 GBP',
  'Restauarant Website': 'https://www.thomascarrdining.co.uk/'},
 {'Restaurant Name': 'mana',
  'Price Range': '155 GBP',
  'Restauarant Website': 'https://www.manarestaurant.co.uk/'},
 {'Restaurant Name': 'Shaun Rankin at Grantley Hall',
  'Price Range': '110 GBP',
  'Restauarant Website': 'https://www.grantleyhall.co.uk/dining/shaun-rankin-at-grantley-hall'},
 {'Restaurant Name': 'The Man Behind The Curtain',
  'Price Range': '88 - 132 GBP',
  'Restauarant Website': 'https://www.themanbehindthecurtain.co.uk/'},
 {'Restaurant Name': 'Gucci Osteria da Massimo Bottura',
  'Price Range': '145 - 195 USD',
  'Restauarant Website': 'https://www.gucci.com/us/en/store/osteria-bottura-beverly-hills/'},
 {'Restaurant Name': 'Pasjoli',
  'Price Range': '100 - 200 USD',
  'Restauarant Website': 'https://www.pasjoli.com/'},
 {'Restaurant Name': 'Rustic Canyon',
  'Price Range': '62 - 97 USD',
  'Restauarant Website': 'www.rusticcanyonrestaurant.com'},
 {'Restaurant Name': 'Aubergine',
  'Price Range': '205 USD',
  'Restauarant Website': 'https://www.auberginecarmel.com/'},
 {'Restaurant Name': 'Madera',
  'Price Range': '50 - 150 USD',
  'Restauarant Website': 'https://www.maderasandhill.com/'},
 {'Restaurant Name': 'Orsa & Winston',
  'Price Range': '125 USD',
  'Restauarant Website': 'https://www.orsaandwinston.com/'},
 {'Restaurant Name': 'Q Sushi',
  'Price Range': '150 - 300 USD',
  'Restauarant Website': 'http://www.qsushila.com/'},
 {'Restaurant Name': 'Osteria Mozza',
  'Price Range': '50 - 75 USD',
  'Restauarant Website': 'https://www.osteriamozza.com/'},
 {'Restaurant Name': 'Phenakite',
  'Price Range': '158 USD',
  'Restauarant Website': 'https://www.porridgeandpuffs.com/phenakite'},
 {'Restaurant Name': 'Shibumi',
  'Price Range': '95 - 195 USD',
  'Restauarant Website': 'https://www.shibumidtla.com/'},
 {'Restaurant Name': 'Morihiro',
  'Price Range': '50 - 300 USD',
  'Restauarant Website': 'https://morionodera.com/'},
 {'Restaurant Name': 'Kato',
  'Price Range': '50 - 75 USD',
  'Restauarant Website': 'https://www.katorestaurant.com/'},
 {'Restaurant Name': 'Mori Sushi',
  'Price Range': '75 - 150 USD',
  'Restauarant Website': 'https://www.morisushila.com/'},
 {'Restaurant Name': 'Le Comptoir',
  'Price Range': '120 USD',
  'Restauarant Website': 'https://www.lecomptoirla.com/'},
 {'Restaurant Name': 'State Bird Provisions',
  'Price Range': '25 - 90 USD',
  'Restauarant Website': 'https://www.statebirdsf.com/'},
 {'Restaurant Name': 'The Progress',
  'Price Range': '41 - 78 USD',
  'Restauarant Website': 'https://www.theprogress-sf.com/'},
 {'Restaurant Name': 'Sons & Daughters',
  'Price Range': '225 USD',
  'Restauarant Website': 'https://www.sonsanddaughterssf.com/'},
 {'Restaurant Name': 'Wako',
  'Price Range': '95 - 135 USD',
  'Restauarant Website': 'https://www.sushiwakosf.com/'},
 {'Restaurant Name': 'jū-ni',
  'Price Range': '165 USD',
  'Restauarant Website': 'https://www.junisf.com/'},
 {'Restaurant Name': 'Mister Jiu’s',
  'Price Range': '50 - 75 USD',
  'Restauarant Website': 'https://www.misterjius.com/'},
 {'Restaurant Name': "Al's Place",
  'Price Range': '58 - 88 USD',
  'Restauarant Website': 'https://www.alsplacesf.com/'},
 {'Restaurant Name': 'Sorrel',
  'Price Range': '110 - 148 USD',
  'Restauarant Website': 'https://www.sorrelrestaurant.com/'},
 {'Restaurant Name': 'Omakase',
  'Price Range': '75 - 150 USD',
  'Restauarant Website': 'https://www.omakasesf.com/'},
 {'Restaurant Name': 'Niku Steakhouse',
  'Price Range': '80 - 402 USD',
  'Restauarant Website': 'www.nikusteakhouse.com'},
 {'Restaurant Name': "O' by Claude Le Tohic",
  'Price Range': '175 - 250 USD',
  'Restauarant Website': 'www.one65sf.com'},
 {'Restaurant Name': 'Mourad',
  'Price Range': '43 - 155 USD',
  'Restauarant Website': 'https://www.mouradsf.com/'},
 {'Restaurant Name': 'Angler SF',
  'Price Range': '90 - 600 USD',
  'Restauarant Website': 'https://www.anglerrestaurants.com/'},
 {'Restaurant Name': 'Kin Khao',
  'Price Range': '25 - 70 USD',
  'Restauarant Website': 'https://www.kinkhao.com/'},
 {'Restaurant Name': 'Gary Danko',
  'Price Range': '89 - 139 USD',
  'Restauarant Website': 'https://www.garydanko.com/'},
 {'Restaurant Name': 'SPQR',
  'Price Range': '39 - 120 USD',
  'Restauarant Website': 'https://www.spqrsf.com/'},
 {'Restaurant Name': 'Avery',
  'Price Range': '89 - 189 USD',
  'Restauarant Website': 'https://www.averysf.com/'},
 {'Restaurant Name': 'Bar Crenn',
  'Price Range': '85 - 165 USD',
  'Restauarant Website': 'https://www.barcrenn.com/'},
 {'Restaurant Name': 'The Shota',
  'Price Range': '175 USD',
  'Restauarant Website': 'www.theshotasf.com'},
 {'Restaurant Name': 'Spruce',
  'Price Range': '50 - 75 USD',
  'Restauarant Website': 'https://www.sprucesf.com/'},
 {'Restaurant Name': 'Marlena',
  'Price Range': '65 - 110 USD',
  'Restauarant Website': 'https://www.marlenarestaurant.com'},
 {'Restaurant Name': 'The Kitchen',
  'Price Range': '155 USD',
  'Restauarant Website': 'https://www.thekitchenrestaurant.com/'},
 {'Restaurant Name': 'Taco María',
  'Price Range': '45 - 84 USD',
  'Restauarant Website': 'https://www.tacomaria.com/'},
 {'Restaurant Name': 'Knife Pleat',
  'Price Range': '22 - 135 USD',
  'Restauarant Website': 'https://www.knifepleat.com/'},
 {'Restaurant Name': 'Hana re',
  'Price Range': '200 USD',
  'Restauarant Website': 'https://www.hanaresushi.com/'},
 {'Restaurant Name': 'Protégé',
  'Price Range': '65 - 210 USD',
  'Restauarant Website': 'https://www.protegepaloalto.com/'},
 {'Restaurant Name': 'Hiša Denk',
  'Price Range': '45 - 85 EUR',
  'Restauarant Website': 'https://www.hisadenk.si/'},
 {'Restaurant Name': 'Vila Podvin',
  'Price Range': '24 - 95 EUR',
  'Restauarant Website': 'https://www.vilapodvin.si/'},
 {'Restaurant Name': 'Dam',
  'Price Range': '75 - 116 EUR',
  'Restauarant Website': 'https://www.damhotel.si/'},
 {'Restaurant Name': 'Gostilna Pri Lojzetu',
  'Price Range': '55 - 95 EUR',
  'Restauarant Website': 'https://www.prilojzetu.com/'},
 {'Restaurant Name': 'Gostišče Grič',
  'Price Range': '60 - 110 EUR',
  'Restauarant Website': 'https://www.gric.si/'},
 {'Restaurant Name': 'Restavracija Atelje',
  'Price Range': '24 - 120 EUR',
  'Restauarant Website': 'https://www.restavracijaatelje.com/'},
 {'Restaurant Name': 'Lai Heen',
  'Price Range': '280 - 1,200 CNY',
  'Restauarant Website': 'https://www.ritzcarlton.com/guangzhou'},
 {'Restaurant Name': 'BingSheng Mansion',
  'Price Range': '100 - 800 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Suyab Courtyard・Pickmoon Gourmet',
  'Price Range': '488 - 3,000 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Lei Garden (Yuexiu)',
  'Price Range': '150 - 400 CNY',
  'Restauarant Website': 'https://www.leigarden.com.hk/'},
 {'Restaurant Name': 'Jade River',
  'Price Range': '200 - 1,000 CNY',
  'Restauarant Website': 'https://www.whiteswanhotel.com/'},
 {'Restaurant Name': 'BingSheng Private Kitchen',
  'Price Range': '500 - 1,000 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Wisca (Haizhu)',
  'Price Range': '200 - 500 CNY',
  'Restauarant Website': 'http://www.shnoble.com/wisca'},
 {'Restaurant Name': 'Hongtu Hall',
  'Price Range': '200 - 300 CNY',
  'Restauarant Website': 'https://www.whiteswanhotel.com/'},
 {'Restaurant Name': 'Lingnan House',
  'Price Range': '300 - 800 CNY',
  'Restauarant Website': 'www.rosewoodhotels.com/en/guangzhou/dining/Lingnan-House'},
 {'Restaurant Name': 'Song',
  'Price Range': '200 - 300 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Yu Yue Heen',
  'Price Range': '250 - 1,288 CNY',
  'Restauarant Website': 'https://www.fourseasons.com/guangzhou'},
 {'Restaurant Name': 'Famous Cuisine (Tianhe)',
  'Price Range': '80 - 200 CNY',
  'Restauarant Website': 'http://www.hl-bandao.com/'},
 {'Restaurant Name': 'Rêver',
  'Price Range': '450 - 1,680 CNY',
  'Restauarant Website': 'www.restaurantrever.com'},
 {'Restaurant Name': 'Imperial Treasure Fine Teochew Cuisine',
  'Price Range': '200 - 800 CNY',
  'Restauarant Website': 'https://www.imperialtreasure.com/china/restaurants'},
 {'Restaurant Name': 'PM & Vänner',
  'Price Range': '1,195 - 1,695 SEK',
  'Restauarant Website': 'https://www.pmrestauranger.se/'},
 {'Restaurant Name': 'Hotell Borgholm',
  'Price Range': '700 - 1,250 SEK',
  'Restauarant Website': 'https://www.hotellborgholm.com/'},
 {'Restaurant Name': 'ÄNG',
  'Price Range': '1,300 SEK',
  'Restauarant Website': 'www.restaurangang.se'},
 {'Restaurant Name': 'Agrikultur',
  'Price Range': '825 - 895 SEK',
  'Restauarant Website': 'https://www.agrikultur.se/'},
 {'Restaurant Name': 'Sushi Sho',
  'Price Range': '895 - 1,495 SEK',
  'Restauarant Website': 'https://www.sushisho.se/'},
 {'Restaurant Name': 'Ekstedt',
  'Price Range': '795 - 1,395 SEK',
  'Restauarant Website': 'https://www.ekstedt.nu/'},
 {'Restaurant Name': 'Operakällaren',
  'Price Range': '1,500 - 2,500 SEK',
  'Restauarant Website': 'https://www.operakallaren.se/'},
 {'Restaurant Name': 'Aira',
  'Price Range': '1,250 - 2,750 SEK',
  'Restauarant Website': 'www.aira.se'},
 {'Restaurant Name': 'Etoile',
  'Price Range': '1,900 SEK',
  'Restauarant Website': 'https://www.restaurantetoile.se/'},
 {'Restaurant Name': 'bhoga',
  'Price Range': '650 - 900 SEK',
  'Restauarant Website': 'https://www.bhoga.se/'},
 {'Restaurant Name': '28+',
  'Price Range': '710 - 1,195 SEK',
  'Restauarant Website': 'http://www.28plus.se/'},
 {'Restaurant Name': 'Project',
  'Price Range': '895 SEK',
  'Restauarant Website': 'https://www.projectgbg.com/'},
 {'Restaurant Name': 'Koka',
  'Price Range': '660 - 995 SEK',
  'Restauarant Website': 'https://www.restaurangkoka.se/'},
 {'Restaurant Name': 'SK Mat & Människor',
  'Price Range': '630 - 825 SEK',
  'Restauarant Website': 'https://www.skmat.se/'},
 {'Restaurant Name': 'Under',
  'Price Range': '2,450 NOK',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Sabi Omakase',
  'Price Range': '1,690 NOK',
  'Restauarant Website': 'https://www.omakase.no/'},
 {'Restaurant Name': 'FAGN',
  'Price Range': '800 - 3,200 NOK',
  'Restauarant Website': 'https://www.fagn.no/'},
 {'Restaurant Name': 'Speilsalen',
  'Price Range': '1,295 - 2,250 NOK',
  'Restauarant Website': 'https://www.britannia.no/'},
 {'Restaurant Name': 'Credo',
  'Price Range': '1,800 NOK',
  'Restauarant Website': 'https://www.restaurantcredo.no/'},
 {'Restaurant Name': 'Bare',
  'Price Range': '1,350 - 1,650 NOK',
  'Restauarant Website': 'https://www.barerestaurant.no/'},
 {'Restaurant Name': 'Kontrast',
  'Price Range': '1,450 - 1,950 NOK',
  'Restauarant Website': 'https://www.restaurant-kontrast.no/'},
 {'Restaurant Name': 'Omakase by Vladimir Pak',
  'Price Range': '1,850 NOK',
  'Restauarant Website': 'https://www.omakaseoslo.no/'},
 {'Restaurant Name': 'Statholdergaarden',
  'Price Range': '1,195 - 1,995 NOK',
  'Restauarant Website': 'https://www.statholdergaarden.no/'},
 {'Restaurant Name': 'DILL',
  'Price Range': '15,900 ISK',
  'Restauarant Website': 'https://www.dillrestaurant.is/'},
 {'Restaurant Name': 'Inari',
  'Price Range': '100 - 150 EUR',
  'Restauarant Website': 'https://www.restaurantinari.com/'},
 {'Restaurant Name': 'Olo',
  'Price Range': '109 - 159 EUR',
  'Restauarant Website': 'https://www.olo-ravintola.fi/'},
 {'Restaurant Name': 'Palace',
  'Price Range': '180 - 200 EUR',
  'Restauarant Website': 'https://www.palacerestaurant.fi/'},
 {'Restaurant Name': 'Grön',
  'Price Range': '86 - 124 EUR',
  'Restauarant Website': 'https://www.restaurantgron.com/'},
 {'Restaurant Name': 'Ora',
  'Price Range': '94 EUR',
  'Restauarant Website': 'https://www.orarestaurant.fi/'},
 {'Restaurant Name': 'Demo',
  'Price Range': '78 - 105 EUR',
  'Restauarant Website': 'https://www.restaurantdemo.fi/'},
 {'Restaurant Name': 'Finnjävel Salonki',
  'Price Range': '89 - 104 EUR',
  'Restauarant Website': 'http://www.finnjavel.fi'},
 {'Restaurant Name': 'Ti Trin Ned',
  'Price Range': '1,200 DKK',
  'Restauarant Website': 'https://www.titrinned.dk/'},
 {'Restaurant Name': 'Dragsholm Slot Gourmet',
  'Price Range': '1,400 - 1,600 DKK',
  'Restauarant Website': 'https://www.dragsholm-slot.dk/'},
 {'Restaurant Name': 'Me|Mu',
  'Price Range': '950 - 3,300 DKK',
  'Restauarant Website': 'https://www.memu-gourmet.dk/'},
 {'Restaurant Name': 'LYST',
  'Price Range': '2,300 DKK',
  'Restauarant Website': 'www.restaurantlyst.com'},
 {'Restaurant Name': 'Kadeau Bornholm',
  'Price Range': '1,600 - 1,950 DKK',
  'Restauarant Website': 'https://www.kadeau.dk/'},
 {'Restaurant Name': 'Frederiksminde',
  'Price Range': '600 - 1,500 DKK',
  'Restauarant Website': 'www.frederiksminde.com'},
 {'Restaurant Name': 'Syttende',
  'Price Range': '1,795 DKK',
  'Restauarant Website': 'www.syttende.dk'},
 {'Restaurant Name': 'Gastromé',
  'Price Range': '900 - 1,800 DKK',
  'Restauarant Website': 'https://www.gastrome.dk/'},
 {'Restaurant Name': 'Frederikshøj',
  'Price Range': '2,000 DKK',
  'Restauarant Website': 'https://www.frederikshoj.com/'},
 {'Restaurant Name': 'Domestic',
  'Price Range': '645 - 1,500 DKK',
  'Restauarant Website': 'https://www.restaurantdomestic.dk/'},
 {'Restaurant Name': 'Substans',
  'Price Range': '450 - 1,500 DKK',
  'Restauarant Website': 'www.restaurantsubstans.dk'},
 {'Restaurant Name': 'Søllerød Kro',
  'Price Range': '545 - 1,795 DKK',
  'Restauarant Website': 'https://www.soelleroed-kro.dk/'},
 {'Restaurant Name': 'formel B',
  'Price Range': '450 - 995 DKK',
  'Restauarant Website': 'https://www.formelb.dk/'},
 {'Restaurant Name': 'Alouette',
  'Price Range': '995 DKK',
  'Restauarant Website': 'https://www.restaurantalouette.dk/'},
 {'Restaurant Name': 'Marchal',
  'Price Range': '450 - 3,145 DKK',
  'Restauarant Website': 'http://www.marchal.dk/'},
 {'Restaurant Name': 'Kokkeriet',
  'Price Range': '800 - 1,200 DKK',
  'Restauarant Website': 'https://www.kokkeriet.dk/'},
 {'Restaurant Name': 'Kiin Kiin',
  'Price Range': '550 - 1,350 DKK',
  'Restauarant Website': 'https://www.kiin.dk/'},
 {'Restaurant Name': 'The Samuel',
  'Price Range': '1,800 DKK',
  'Restauarant Website': 'www.thesamuel.dk'},
 {'Restaurant Name': 'Boškinac',
  'Price Range': '590 - 890 HRK',
  'Restauarant Website': 'https://www.boskinac.com/'},
 {'Restaurant Name': 'Draga di Lovrana',
  'Price Range': '360 - 590 HRK',
  'Restauarant Website': 'https://www.dragadilovrana.hr/'},
 {'Restaurant Name': 'Nebo',
  'Price Range': '890 - 1,250 HRK',
  'Restauarant Website': 'https://neborijeka.com/'},
 {'Restaurant Name': 'Monte',
  'Price Range': '794 - 1,044 HRK',
  'Restauarant Website': 'https://www.monte.hr/'},
 {'Restaurant Name': 'Pelegrini',
  'Price Range': '760 - 955 HRK',
  'Restauarant Website': 'https://www.pelegrini.hr/'},
 {'Restaurant Name': 'Noel',
  'Price Range': '135 - 950 HRK',
  'Restauarant Website': 'https://www.noel.hr/'},
 {'Restaurant Name': 'Agli Amici Rovinj',
  'Price Range': '830 - 1,050 HRK',
  'Restauarant Website': 'www.maistra.com/grand-park-hotel-rovinj/sub/agli-amici-rovinj'},
 {'Restaurant Name': 'Alfred Keller',
  'Price Range': '320 - 780 HRK',
  'Restauarant Website': 'https://www.losinj-hotels.com/en/dining/restaurant-alfred-keller/'},
 {'Restaurant Name': 'LD Restaurant',
  'Price Range': '450 - 970 HRK',
  'Restauarant Website': 'https://www.ldrestaurant.com/'},
 {'Restaurant Name': 'Restaurant 360',
  'Price Range': '560 - 980 HRK',
  'Restauarant Website': 'https://www.360dubrovnik.com/'},
 {'Restaurant Name': 'Stand',
  'Price Range': '16,500 - 34,500 HUF',
  'Restauarant Website': 'www.standrestaurant.hu'},
 {'Restaurant Name': 'Dining Room at The Goring',
  'Price Range': '52 - 78 GBP',
  'Restauarant Website': 'https://www.thegoring.com/'},
 {'Restaurant Name': 'SO|LA',
  'Price Range': '89 - 139 GBP',
  'Restauarant Website': 'https://www.solasoho.com/'},
 {'Restaurant Name': 'Ikoyi',
  'Price Range': '60 - 150 GBP',
  'Restauarant Website': 'https://www.ikoyilondon.com/'},
 {'Restaurant Name': 'Quilon',
  'Price Range': '41 - 95 GBP',
  'Restauarant Website': 'http://www.quilon.co.uk/'},
 {'Restaurant Name': 'Chez Bruce',
  'Price Range': '50 - 65 GBP',
  'Restauarant Website': 'https://www.chezbruce.co.uk/'},
 {'Restaurant Name': 'St John',
  'Price Range': '32 - 50 GBP',
  'Restauarant Website': 'https://www.stjohnrestaurant.com/'},
 {'Restaurant Name': 'Club Gascon',
  'Price Range': '70 - 95 GBP',
  'Restauarant Website': 'https://www.clubgascon.com/'},
 {'Restaurant Name': 'Trinity',
  'Price Range': '55 - 95 GBP',
  'Restauarant Website': 'https://www.trinityrestaurant.co.uk/'},
 {'Restaurant Name': 'Casa Fofō',
  'Price Range': '45 GBP',
  'Restauarant Website': 'https://www.casafofolondon.co.uk/'},
 {'Restaurant Name': 'Sorrel',
  'Price Range': '50 - 95 GBP',
  'Restauarant Website': 'https://www.sorrelrestaurant.co.uk/'},
 {'Restaurant Name': 'Angler',
  'Price Range': '38 - 100 GBP',
  'Restauarant Website': 'https://www.anglerrestaurant.com/'},
 {'Restaurant Name': 'The Clove Club',
  'Price Range': '65 - 145 GBP',
  'Restauarant Website': 'https://www.thecloveclub.com/'},
 {'Restaurant Name': 'Leroy',
  'Price Range': '25 - 48 GBP',
  'Restauarant Website': 'https://www.leroyshoreditch.com/'},
 {'Restaurant Name': 'Brat',
  'Price Range': '32 - 85 GBP',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'City Social',
  'Price Range': '60 - 78 GBP',
  'Restauarant Website': 'https://www.citysociallondon.com/'},
 {'Restaurant Name': "Lyle's",
  'Price Range': '35 - 79 GBP',
  'Restauarant Website': 'https://www.lyleslondon.com/'},
 {'Restaurant Name': 'Mãos',
  'Price Range': '170 GBP',
  'Restauarant Website': 'https://www.bluemountain.school/maos'},
 {'Restaurant Name': 'Galvin La Chapelle',
  'Price Range': '43 - 89 GBP',
  'Restauarant Website': 'https://www.galvinrestaurants.com/'},
 {'Restaurant Name': 'Behind',
  'Price Range': '42 - 74 GBP',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Le Pily',
  'Price Range': '56 - 72 EUR',
  'Restauarant Website': 'http://www.le-pily.com/'},
 {'Restaurant Name': "Chef Kang's",
  'Price Range': '80 - 120 SGD',
  'Restauarant Website': 'https://www.chef-kang.com/'},
 {'Restaurant Name': 'Oshino',
  'Price Range': '180 - 500 SGD',
  'Restauarant Website': 'www.oshino.sg'},
 {'Restaurant Name': 'Esora',
  'Price Range': '268 - 338 SGD',
  'Restauarant Website': 'https://www.restaurant-esora.com/'},
 {'Restaurant Name': 'Buona Terra',
  'Price Range': '88 - 178 SGD',
  'Restauarant Website': 'https://www.buonaterra.com.sg/'},
 {'Restaurant Name': '28 Wilkie',
  'Price Range': '158 - 198 SGD',
  'Restauarant Website': 'https://www.28wilkie.com/'},
 {'Restaurant Name': 'Labyrinth',
  'Price Range': '98 - 208 SGD',
  'Restauarant Website': 'https://www.labyrinth.com.sg/'},
 {'Restaurant Name': 'Lei Garden',
  'Price Range': '60 - 120 SGD',
  'Restauarant Website': 'https://www.leigarden.hk/'},
 {'Restaurant Name': 'Shang Palace',
  'Price Range': '50 - 328 SGD',
  'Restauarant Website': 'https://www.shangri-la.com/singapore'},
 {'Restaurant Name': 'Meta',
  'Price Range': '175 - 270 SGD',
  'Restauarant Website': 'https://metarestaurant.sg/'},
 {'Restaurant Name': 'Ma Cuisine',
  'Price Range': '108 - 388 SGD',
  'Restauarant Website': 'https://macuisinesg.com/'},
 {'Restaurant Name': 'Art',
  'Price Range': '58 - 208 SGD',
  'Restauarant Website': 'www.artrestaurant.sg'},
 {'Restaurant Name': 'Imperial Treasure Fine Teochew Cuisine (Orchard)',
  'Price Range': '30 - 128 SGD',
  'Restauarant Website': 'https://www.imperialtreasure.com/'},
 {'Restaurant Name': 'Garibaldi',
  'Price Range': '39 - 240 SGD',
  'Restauarant Website': 'https://www.garibaldi.com.sg/'},
 {'Restaurant Name': 'Béni',
  'Price Range': '108 - 268 SGD',
  'Restauarant Website': 'https://www.beni-sg.com/'},
 {'Restaurant Name': 'Shinji (Tanglin Road)',
  'Price Range': '125 - 550 SGD',
  'Restauarant Website': 'https://www.shinjibykanesaka.com/'},
 {'Restaurant Name': 'Basque Kitchen by Aitor',
  'Price Range': '158 - 248 SGD',
  'Restauarant Website': 'www.basquekitchenbyaitor.com'},
 {'Restaurant Name': 'Table65',
  'Price Range': '148 SGD',
  'Restauarant Website': 'https://www.rwsentosa.com/table65'},
 {'Restaurant Name': 'Thevar',
  'Price Range': '198 SGD',
  'Restauarant Website': 'https://thevar.sg/'},
 {'Restaurant Name': 'Jag',
  'Price Range': '175 - 298 SGD',
  'Restauarant Website': 'https://www.restaurantjag.com/'},
 {'Restaurant Name': 'Rhubarb',
  'Price Range': '52 - 168 SGD',
  'Restauarant Website': 'https://www.rhubarb.sg/'},
 {'Restaurant Name': 'Nouri',
  'Price Range': '148 - 250 SGD',
  'Restauarant Website': 'https://www.nouri.com.sg/'},
 {'Restaurant Name': 'Corner House',
  'Price Range': '118 - 248 SGD',
  'Restauarant Website': 'https://www.cornerhouse.com.sg/'},
 {'Restaurant Name': 'Candlenut',
  'Price Range': '50 - 98 SGD',
  'Restauarant Website': 'https://www.comodempsey.sg/'},
 {'Restaurant Name': 'Sushi Ichi',
  'Price Range': '100 - 430 SGD',
  'Restauarant Website': 'http://www.ginza-sushiichi.jp/'},
 {'Restaurant Name': 'Shinji (Bras Basah Road)',
  'Price Range': '90 - 650 SGD',
  'Restauarant Website': 'https://www.shinjibykanesaka.com/'},
 {'Restaurant Name': 'Summer Pavilion',
  'Price Range': '60 - 200 SGD',
  'Restauarant Website': 'http://www.summerpavilion.com.sg/'},
 {'Restaurant Name': 'Terra',
  'Price Range': '58 - 408 SGD',
  'Restauarant Website': 'https://www.terraseita.com/'},
 {'Restaurant Name': 'Molino de Urdániz',
  'Price Range': '2,580 - 3,980 TWD',
  'Restauarant Website': 'https://www.hotelmvsa.com/'},
 {'Restaurant Name': 'T+T',
  'Price Range': '1,850 - 2,600 TWD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'A Cut',
  'Price Range': '1,200 - 7,600 TWD',
  'Restauarant Website': 'https://www.ambassador-hotels.com/'},
 {'Restaurant Name': 'Tien Hsiang Lo',
  'Price Range': '2,000 - 8,800 TWD',
  'Restauarant Website': 'http://taipei.landishotelsresorts.com/'},
 {'Restaurant Name': "Danny's Steakhouse",
  'Price Range': '1,280 - 3,380 TWD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Longtail',
  'Price Range': '1,400 - 2,880 TWD',
  'Restauarant Website': 'https://www.longtail.com.tw/'},
 {'Restaurant Name': 'Sushi Akira',
  'Price Range': '2,500 - 4,500 TWD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Impromptu by Paul Lee',
  'Price Range': '2,800 TWD',
  'Restauarant Website': 'https://www.impromptu.com.tw/'},
 {'Restaurant Name': 'Sushi Nomura',
  'Price Range': '3,000 - 10,000 TWD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Forchetta',
  'Price Range': '1,700 - 4,000 TWD',
  'Restauarant Website': 'https://www.forchetta.com.tw/'},
 {'Restaurant Name': 'Sur-',
  'Price Range': '2,000 TWD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Mudan',
  'Price Range': '3,500 - 6,500 TWD',
  'Restauarant Website': 'https://mudantempura.com/'},
 {'Restaurant Name': 'Fujin Tree Taiwanese Cuisine & Champagne (Songshan)',
  'Price Range': '600 - 1,000 TWD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Oretachi No Nikuya',
  'Price Range': '2,500 - 3,500 TWD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Ken Anhe',
  'Price Range': '4,500 - 6,800 TWD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Fleur de Sel',
  'Price Range': '1,580 - 5,880 TWD',
  'Restauarant Website': 'https://www.fleur-de-sel.com.tw/'},
 {'Restaurant Name': 'De Nuit',
  'Price Range': '3,500 - 4,200 TWD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Golden Formosa',
  'Price Range': '800 - 1,500 TWD',
  'Restauarant Website': 'https://www.goldenformosa.com.tw/'},
 {'Restaurant Name': 'Sushi Ryu',
  'Price Range': '3,000 - 7,000 TWD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Ming Fu',
  'Price Range': '1,500 - 2,000 TWD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Mountain and Sea House',
  'Price Range': '980 - 4,680 TWD',
  'Restauarant Website': 'https://www.mountain-n-seahouse.com/'},
 {'Restaurant Name': 'Mipon',
  'Price Range': '1,800 - 3,800 TWD',
  'Restauarant Website': 'https://www.grandmayfull.com/'},
 {'Restaurant Name': 'Da-Wan',
  'Price Range': '3,000 - 5,000 TWD',
  'Restauarant Website': 'https://www.dawan.com.tw/'},
 {'Restaurant Name': 'Ya Ge',
  'Price Range': '1,200 - 8,800 TWD',
  'Restauarant Website': 'https://www.mandarinoriental.com/taipei'},
 {'Restaurant Name': 'Kitcho',
  'Price Range': '3,500 - 7,000 TWD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'The Four Horsemen',
  'Price Range': '30 - 85 USD',
  'Restauarant Website': 'https://www.fourhorsemenbk.com/'},
 {'Restaurant Name': 'Hirohisa',
  'Price Range': '50 - 160 USD',
  'Restauarant Website': 'https://www.hirohisa.nyc/'},
 {'Restaurant Name': 'Estela',
  'Price Range': '50 - 100 USD',
  'Restauarant Website': 'https://www.estelanyc.com/'},
 {'Restaurant Name': 'Tuome',
  'Price Range': '50 - 75 USD',
  'Restauarant Website': 'https://www.tuomenyc.com/'},
 {'Restaurant Name': 'Sushi Amane',
  'Price Range': '250 USD',
  'Restauarant Website': 'https://www.sushi-amane.com/'},
 {'Restaurant Name': 'Claro',
  'Price Range': '25 - 50 USD',
  'Restauarant Website': 'https://www.clarobk.com/'},
 {'Restaurant Name': 'Tsukimi',
  'Price Range': '195 USD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Vestry',
  'Price Range': '69 - 103 USD',
  'Restauarant Website': 'https://www.vestrynyc.com/'},
 {'Restaurant Name': 'Peter Luger',
  'Price Range': '75 - 150 USD',
  'Restauarant Website': 'https://www.peterluger.com/'},
 {'Restaurant Name': 'Wallsé',
  'Price Range': '75 - 150 USD',
  'Restauarant Website': 'https://www.wallse.com/'},
 {'Restaurant Name': 'Francie',
  'Price Range': '55 - 90 USD',
  'Restauarant Website': 'https://www.franciebrooklyn.com/'},
 {'Restaurant Name': 'Casa Mono',
  'Price Range': '50 - 75 USD',
  'Restauarant Website': 'https://www.casamononyc.com/'},
 {'Restaurant Name': 'Le Jardinier',
  'Price Range': '62 - 115 USD',
  'Restauarant Website': 'https://www.lejardinier-nyc.com/'},
 {'Restaurant Name': 'Sushi Ginza Onodera',
  'Price Range': '100 - 445 USD',
  'Restauarant Website': 'https://www.sushiginzaonoderanewyork.com/'},
 {'Restaurant Name': 'Noda',
  'Price Range': '320 USD',
  'Restauarant Website': 'https://www.noda.nyc/'},
 {'Restaurant Name': 'Kochi',
  'Price Range': '75 USD',
  'Restauarant Website': 'https://kochinyc.com/'},
 {'Restaurant Name': 'Crown Shy',
  'Price Range': '45 - 90 USD',
  'Restauarant Website': 'https://www.crownshy.nyc/'},
 {'Restaurant Name': 'Sushi Noz',
  'Price Range': '175 - 325 USD',
  'Restauarant Website': 'https://www.sushinoz.com/'},
 {'Restaurant Name': 'Blue Hill',
  'Price Range': '95 - 108 USD',
  'Restauarant Website': 'http://www.bluehillfarm.com/'},
 {'Restaurant Name': 'Kajitsu',
  'Price Range': '120 USD',
  'Restauarant Website': 'https://www.kajitsunyc.com/'},
 {'Restaurant Name': 'The Musket Room',
  'Price Range': '40 - 95 USD',
  'Restauarant Website': 'https://www.themusketroom.com/'},
 {'Restaurant Name': 'ZZ’s Clam Bar',
  'Price Range': '75 - 150 USD',
  'Restauarant Website': 'https://www.zzsclambar.com/'},
 {'Restaurant Name': 'Oxalis',
  'Price Range': '25 - 105 USD',
  'Restauarant Website': 'https://www.oxalisnyc.com/'},
 {'Restaurant Name': 'Oxomoco',
  'Price Range': '30 - 75 USD',
  'Restauarant Website': 'https://www.oxomoconyc.com/'},
 {'Restaurant Name': 'Jua',
  'Price Range': '95 - 140 USD',
  'Restauarant Website': 'https://www.juanyc.com/'},
 {'Restaurant Name': 'Meadowsweet',
  'Price Range': '50 - 85 USD',
  'Restauarant Website': 'https://www.meadowsweetnyc.com/'},
 {'Restaurant Name': 'The River Café',
  'Price Range': '54 - 175 USD',
  'Restauarant Website': 'https://www.rivercafe.com/'},
 {'Restaurant Name': 'Marea',
  'Price Range': '63 - 150 USD',
  'Restauarant Website': 'https://www.marea-nyc.com/'},
 {'Restaurant Name': 'odo',
  'Price Range': '200 USD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Le Coucou',
  'Price Range': '45 - 130 USD',
  'Restauarant Website': 'https://www.lecoucou.com/'},
 {'Restaurant Name': 'Kanoyama',
  'Price Range': '50 - 75 USD',
  'Restauarant Website': 'https://www.kanoyama.com/'},
 {'Restaurant Name': 'Cote',
  'Price Range': '50 - 180 USD',
  'Restauarant Website': 'https://www.cotenyc.com/'},
 {'Restaurant Name': 'Ai Fiori',
  'Price Range': '54 - 150 USD',
  'Restauarant Website': 'https://www.aifiorinyc.com/'},
 {'Restaurant Name': 'Rezdôra',
  'Price Range': '50 - 90 USD',
  'Restauarant Website': 'https://www.rezdora.nyc/'},
 {'Restaurant Name': 'Benno',
  'Price Range': '45 - 155 USD',
  'Restauarant Website': 'https://www.bennorestaurant.com/'},
 {'Restaurant Name': 'Bâtard',
  'Price Range': '69 - 94 USD',
  'Restauarant Website': 'https://www.batardtribeca.com/'},
 {'Restaurant Name': 'Caviar Russe',
  'Price Range': '70 - 150 USD',
  'Restauarant Website': 'https://www.caviarrusse.com/'},
 {'Restaurant Name': 'Contra',
  'Price Range': '89 USD',
  'Restauarant Website': 'https://www.contranyc.com/'},
 {'Restaurant Name': 'L’Appart',
  'Price Range': '185 USD',
  'Restauarant Website': 'https://www.lappartnyc.com/'},
 {'Restaurant Name': 'Sushi Yasuda',
  'Price Range': '45 - 400 USD',
  'Restauarant Website': 'https://www.sushiyasuda.com/'},
 {'Restaurant Name': 'Tempura Matsui',
  'Price Range': '40 - 230 USD',
  'Restauarant Website': 'https://www.tempuramatsui.com/'},
 {'Restaurant Name': 'Gramercy Tavern',
  'Price Range': '40 - 189 USD',
  'Restauarant Website': 'https://www.gramercytavern.com/'},
 {'Restaurant Name': 'Casa Enrique',
  'Price Range': '30 - 60 USD',
  'Restauarant Website': 'https://www.henrinyc.com/'},
 {'Restaurant Name': 'Sushi Nakazawa',
  'Price Range': '75 - 150 USD',
  'Restauarant Website': 'https://www.sushinakazawa.com/'},
 {'Restaurant Name': 'Jeju Noodle Bar',
  'Price Range': '25 - 50 USD',
  'Restauarant Website': 'https://www.jejunoodlebar.com/'},
 {'Restaurant Name': 'Don Angie',
  'Price Range': '50 - 75 USD',
  'Restauarant Website': 'https://www.donangie.com/'},
 {'Restaurant Name': 'The Clocktower',
  'Price Range': '50 - 100 USD',
  'Restauarant Website': 'https://www.theclocktowernyc.com/'},
 {'Restaurant Name': 'Kosaka',
  'Price Range': '75 - 155 USD',
  'Restauarant Website': 'http://www.kosakanyc.com/'},
 {'Restaurant Name': 'Carbone',
  'Price Range': '75 - 150 USD',
  'Restauarant Website': 'https://www.carbonenewyork.com/'},
 {'Restaurant Name': 'Next',
  'Price Range': '175 - 225 USD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Porto',
  'Price Range': '55 - 75 USD',
  'Restauarant Website': 'https://www.bonhommegroup.com/'},
 {'Restaurant Name': 'Boka',
  'Price Range': '53 - 165 USD',
  'Restauarant Website': 'https://www.bokachicago.com/'},
 {'Restaurant Name': 'Parachute',
  'Price Range': '50 - 75 USD',
  'Restauarant Website': 'https://www.parachuterestaurant.com/'},
 {'Restaurant Name': 'Omakase Yume',
  'Price Range': '125 - 150 USD',
  'Restauarant Website': 'https://www.omakaseyume.com/'},
 {'Restaurant Name': 'Entente',
  'Price Range': '60 - 130 USD',
  'Restauarant Website': 'http://www.ententechicago.com/'},
 {'Restaurant Name': 'Elizabeth',
  'Price Range': '75 - 150 USD',
  'Restauarant Website': 'https://www.elizabeth-restaurant.com/'},
 {'Restaurant Name': 'Goosefoot',
  'Price Range': '145 - 165 USD',
  'Restauarant Website': 'https://www.goosefoot.net/'},
 {'Restaurant Name': 'Elske',
  'Price Range': '75 - 100 USD',
  'Restauarant Website': 'https://www.elskerestaurant.com/'},
 {'Restaurant Name': 'Topolobampo',
  'Price Range': '100 - 140 USD',
  'Restauarant Website': 'https://www.rickbayless.com/'},
 {'Restaurant Name': 'Mako',
  'Price Range': '175 USD',
  'Restauarant Website': 'https://www.makochicago.com/'},
 {'Restaurant Name': 'Sepia',
  'Price Range': '24 - 75 USD',
  'Restauarant Website': 'https://www.sepiachicago.com/'},
 {'Restaurant Name': 'EL Ideas',
  'Price Range': '75 - 150 USD',
  'Restauarant Website': 'https://www.elideas.com/'},
 {'Restaurant Name': 'Schwa',
  'Price Range': '160 USD',
  'Restauarant Website': 'https://www.schwarestaurant.com/'},
 {'Restaurant Name': 'North Pond',
  'Price Range': '65 - 95 USD',
  'Restauarant Website': 'http://www.northpondrestaurant.com/'},
 {'Restaurant Name': 'Temporis',
  'Price Range': '165 USD',
  'Restauarant Website': 'https://www.temporischicago.com/'},
 {'Restaurant Name': 'Métier',
  'Price Range': '200 - 260 USD',
  'Restauarant Website': 'https://www.metierdc.com/'},
 {'Restaurant Name': 'Sushi Taro',
  'Price Range': '150 - 300 USD',
  'Restauarant Website': 'https://www.sushitaro.com/'},
 {'Restaurant Name': 'Sushi Nakazawa',
  'Price Range': '120 - 150 USD',
  'Restauarant Website': 'https://www.sushinakazawa.com/'},
 {'Restaurant Name': 'The Dabney',
  'Price Range': '25 - 50 USD',
  'Restauarant Website': 'https://www.thedabney.com/'},
 {'Restaurant Name': 'Tail Up Goat',
  'Price Range': '25 - 50 USD',
  'Restauarant Website': 'https://www.tailupgoat.com/'},
 {'Restaurant Name': 'Fiola',
  'Price Range': '75 - 220 USD',
  'Restauarant Website': 'https://www.fioladc.com/'},
 {'Restaurant Name': 'Little Pearl',
  'Price Range': '49 USD',
  'Restauarant Website': 'https://www.littlepearldc.com/'},
 {'Restaurant Name': 'Plume',
  'Price Range': '106 - 120 USD',
  'Restauarant Website': 'http://www.plumedc.com/'},
 {'Restaurant Name': 'Komi',
  'Price Range': '165 USD',
  'Restauarant Website': 'https://www.komirestaurant.com/'},
 {'Restaurant Name': 'Masseria',
  'Price Range': '50 - 150 USD',
  'Restauarant Website': 'https://www.masseria-dc.com/'},
 {'Restaurant Name': 'Maydān',
  'Price Range': '45 - 65 USD',
  'Restauarant Website': 'https://www.maydandc.com/'},
 {'Restaurant Name': 'Rooster & Owl',
  'Price Range': '65 USD',
  'Restauarant Website': 'https://www.roosterowl.com/'},
 {'Restaurant Name': 'Elcielo D.C.',
  'Price Range': '70 - 228 USD',
  'Restauarant Website': 'https://www.elcielorestaurant.com/'},
 {'Restaurant Name': 'Bresca',
  'Price Range': '50 - 110 USD',
  'Restauarant Website': 'https://www.brescadc.com/'},
 {'Restaurant Name': 'Cranes',
  'Price Range': '40 - 100 USD',
  'Restauarant Website': 'https://www.cranes-dc.com/'},
 {'Restaurant Name': 'Rose’s Luxury',
  'Price Range': '44 - 75 USD',
  'Restauarant Website': 'https://www.rosesluxury.com/'},
 {'Restaurant Name': 'Xiquet',
  'Price Range': '60 - 130 USD',
  'Restauarant Website': 'https://www.xiquetdl.com/'},
 {'Restaurant Name': 'Gravitas',
  'Price Range': '50 - 150 USD',
  'Restauarant Website': 'https://www.gravitasdc.com/'},
 {'Restaurant Name': 'Kinship',
  'Price Range': '60 - 95 USD',
  'Restauarant Website': 'https://www.kinshipdc.com/'},
 {'Restaurant Name': 'Noni',
  'Price Range': '54 - 80 EUR',
  'Restauarant Website': 'https://www.noni.com.mt/'},
 {'Restaurant Name': 'ION - The Harbour',
  'Price Range': '55 - 125 EUR',
  'Restauarant Website': 'https://www.iontheharbour.com/'},
 {'Restaurant Name': 'Under Grain',
  'Price Range': '70 - 95 EUR',
  'Restauarant Website': 'https://www.grain.mt/'},
 {'Restaurant Name': 'Bahia',
  'Price Range': '38 - 80 EUR',
  'Restauarant Website': 'https://www.bahia.com.mt/'},
 {'Restaurant Name': 'De Mondion',
  'Price Range': '70 - 96 EUR',
  'Restauarant Website': 'https://www.demondion.com/'},
 {'Restaurant Name': 'Noble',
  'Price Range': '36 - 85 EUR',
  'Restauarant Website': 'https://www.restaurantnoble.nl/'},
 {'Restaurant Name': 'Herberg Onder de Linden',
  'Price Range': '55 - 125 EUR',
  'Restauarant Website': 'https://www.herbergonderdelinden.com/'},
 {'Restaurant Name': 'Zarzo',
  'Price Range': '55 - 160 EUR',
  'Restauarant Website': 'https://www.zarzo.nl/'},
 {'Restaurant Name': 'Katseveer',
  'Price Range': '67 - 109 EUR',
  'Restauarant Website': 'https://www.katseveer.nl/'},
 {'Restaurant Name': 'Valuas',
  'Price Range': '50 - 160 EUR',
  'Restauarant Website': 'https://www.valuas-hr.nl/'},
 {'Restaurant Name': 'RIJKS®',
  'Price Range': '45 - 120 EUR',
  'Restauarant Website': 'https://www.rijksrestaurant.nl/'},
 {'Restaurant Name': 'The Millèn',
  'Price Range': '30 - 99 EUR',
  'Restauarant Website': 'https://www.restaurantthemillen.nl/'},
 {'Restaurant Name': 'Brienen aan de Maas',
  'Price Range': '70 - 108 EUR',
  'Restauarant Website': 'https://www.restaurantbrienenaandemaas.nl/'},
 {'Restaurant Name': 'Olivijn',
  'Price Range': '57 - 104 EUR',
  'Restauarant Website': 'https://www.olivijn.nl/'},
 {'Restaurant Name': 'MOS',
  'Price Range': '45 - 95 EUR',
  'Restauarant Website': 'https://www.mosamsterdam.nl/'},
 {'Restaurant Name': 'Posthoorn',
  'Price Range': '65 - 105 EUR',
  'Restauarant Website': 'https://www.posthoorn.eu/'},
 {'Restaurant Name': "'t Raedthuys",
  'Price Range': '43 - 98 EUR',
  'Restauarant Website': 'https://www.raedthuys-duiven.nl/'},
 {'Restaurant Name': 'De Gieser Wildeman',
  'Price Range': '57 - 122 EUR',
  'Restauarant Website': 'https://www.degieserwildeman.nl/'},
 {'Restaurant Name': 'Basiliek',
  'Price Range': '59 - 102 EUR',
  'Restauarant Website': 'https://www.restaurantbasiliek.nl/'},
 {'Restaurant Name': 'ONE',
  'Price Range': '59 - 115 EUR',
  'Restauarant Website': 'https://www.restaurantone.nl/'},
 {'Restaurant Name': 'Wollerich',
  'Price Range': '55 - 90 EUR',
  'Restauarant Website': 'https://www.wollerich.nl/'},
 {'Restaurant Name': 'Kaatje bij de Sluis',
  'Price Range': '63 - 115 EUR',
  'Restauarant Website': 'https://www.kaatje.nl/'},
 {'Restaurant Name': 'Beluga Loves You',
  'Price Range': '59 - 135 EUR',
  'Restauarant Website': 'https://www.belugalovesyou.com/'},
 {'Restaurant Name': 'Daalder',
  'Price Range': '38 - 135 EUR',
  'Restauarant Website': 'https://www.daalderamsterdam.nl/'},
 {'Restaurant Name': 'Joelia',
  'Price Range': '55 - 175 EUR',
  'Restauarant Website': 'https://www.joelia.eu/'},
 {'Restaurant Name': 'Bolenius',
  'Price Range': '49 - 140 EUR',
  'Restauarant Website': 'https://www.bolenius-restaurant.nl/'},
 {'Restaurant Name': 'FG Food Labs',
  'Price Range': '50 - 129 EUR',
  'Restauarant Website': 'https://www.fgfoodlabs.nl/'},
 {'Restaurant Name': 'Amarone',
  'Price Range': '40 - 150 EUR',
  'Restauarant Website': 'https://www.restaurantamarone.nl/'},
 {'Restaurant Name': "L'Aquarelle",
  'Price Range': '56 - 120 EUR',
  'Restauarant Website': 'https://www.laquarelle.net/'},
 {'Restaurant Name': 'Sinne',
  'Price Range': '45 - 95 EUR',
  'Restauarant Website': 'https://www.restaurantsinne.nl/'},
 {'Restaurant Name': 'Yamazato',
  'Price Range': '150 - 190 EUR',
  'Restauarant Website': 'https://www.okura.nl/'},
 {'Restaurant Name': 'Zeezout',
  'Price Range': '36 - 75 EUR',
  'Restauarant Website': 'https://www.restaurantzeezout.nl/'},
 {'Restaurant Name': 'Fitzgerald',
  'Price Range': '34 - 150 EUR',
  'Restauarant Website': 'https://www.restaurantfitzgerald.nl/'},
 {'Restaurant Name': 'Taller',
  'Price Range': '65 - 120 EUR',
  'Restauarant Website': 'www.tallerarzuaga.com'},
 {'Restaurant Name': 'OAK',
  'Price Range': '74 - 119 EUR',
  'Restauarant Website': 'https://www.oakgent.be/'},
 {'Restaurant Name': 'Posthoorn',
  'Price Range': '65 - 105 EUR',
  'Restauarant Website': 'https://www.posthoorn.eu/'},
 {'Restaurant Name': 'Publiek',
  'Price Range': '38 - 98 EUR',
  'Restauarant Website': 'https://www.publiekgent.be/'},
 {'Restaurant Name': 'Souvenir',
  'Price Range': '48 - 110 EUR',
  'Restauarant Website': 'https://www.souvenir.gent/'},
 {'Restaurant Name': 'Benoit en Bernard Dewitte',
  'Price Range': '57 - 88 EUR',
  'Restauarant Website': 'https://www.benoitdewitte.be/'},
 {'Restaurant Name': 'Horseele',
  'Price Range': '95 - 170 EUR',
  'Restauarant Website': 'https://www.restauranthorseele.be/'},
 {'Restaurant Name': 'Perceel',
  'Price Range': '50 - 120 EUR',
  'Restauarant Website': 'https://www.restaurantperceel.nl/'},
 {'Restaurant Name': 'Zarate',
  'Price Range': '60 - 103 EUR',
  'Restauarant Website': 'www.zarate.restaurant'},
 {'Restaurant Name': 'Nerua Guggenheim Bilbao',
  'Price Range': '45 - 80 EUR',
  'Restauarant Website': 'www.neruaguggenheimbilbao.com'},
 {'Restaurant Name': 'Etxanobe Atelier',
  'Price Range': '125 - 150 EUR',
  'Restauarant Website': 'www.etxanobe.com'},
 {'Restaurant Name': 'The Duchess',
  'Price Range': '50 - 150 EUR',
  'Restauarant Website': 'https://www.the-duchess.com/'},
 {'Restaurant Name': 'Perceel',
  'Price Range': '50 - 120 EUR',
  'Restauarant Website': 'https://www.restaurantperceel.nl/'},
 {'Restaurant Name': 'Merlet',
  'Price Range': '65 - 115 EUR',
  'Restauarant Website': 'https://www.merlet.nl/'},
 {'Restaurant Name': 'Monarh',
  'Price Range': '46 - 128 EUR',
  'Restauarant Website': 'https://www.monarh.nl/'},
 {'Restaurant Name': 'Het Koetshuis',
  'Price Range': '58 - 115 EUR',
  'Restauarant Website': 'https://www.hetkoetshuis.nl/'},
 {'Restaurant Name': "Calla's",
  'Price Range': '43 - 115 EUR',
  'Restauarant Website': 'https://www.restaurantcallas.nl/'},
 {'Restaurant Name': 'De Nederlanden',
  'Price Range': '65 - 150 EUR',
  'Restauarant Website': 'https://www.nederlanden.nl/'},
 {'Restaurant Name': 'Spetters',
  'Price Range': '48 - 130 EUR',
  'Restauarant Website': 'https://www.restaurantspetters.nl/'},
 {'Restaurant Name': 'Da Vinci',
  'Price Range': '40 - 125 EUR',
  'Restauarant Website': 'https://www.restaurantdavinci.nl/'},
 {'Restaurant Name': 'Kasteel Heemstede',
  'Price Range': '65 - 130 EUR',
  'Restauarant Website': 'https://www.restaurant-kasteelheemstede.nl/'},
 {'Restaurant Name': "'t Lansink",
  'Price Range': '50 - 120 EUR',
  'Restauarant Website': 'https://www.hotellansink.com/'},
 {'Restaurant Name': 'Ratatouille Food & Wine',
  'Price Range': '70 - 150 EUR',
  'Restauarant Website': 'https://www.ratatouillefoodandwine.nl/'},
 {'Restaurant Name': 'Rantrée',
  'Price Range': '43 - 110 EUR',
  'Restauarant Website': 'https://www.rantree.nl/'},
 {'Restaurant Name': 'Vista',
  'Price Range': '45 - 150 EUR',
  'Restauarant Website': 'http://www.vistawillemstad.nl/'},
 {'Restaurant Name': 'De Burgemeester',
  'Price Range': '62 - 135 EUR',
  'Restauarant Website': 'https://www.deburgemeester.nl/'},
 {'Restaurant Name': 'De Vlindertuin',
  'Price Range': '70 - 90 EUR',
  'Restauarant Website': 'https://www.restaurant-devlindertuin.nl/'},
 {'Restaurant Name': 'Fitzgerald',
  'Price Range': '34 - 150 EUR',
  'Restauarant Website': 'https://www.restaurantfitzgerald.nl/'},
 {'Restaurant Name': 'Bougainville',
  'Price Range': '90 - 224 EUR',
  'Restauarant Website': 'https://www.restaurantbougainville.com/'},
 {'Restaurant Name': "'t Vlasbloemeken",
  'Price Range': '43 - 121 EUR',
  'Restauarant Website': 'https://www.vlasbloemeken.com/'},
 {'Restaurant Name': "'t Amsterdammertje",
  'Price Range': '46 - 120 EUR',
  'Restauarant Website': 'https://www.restaurantamsterdammertje.nl/'},
 {'Restaurant Name': 'FG Food Labs',
  'Price Range': '50 - 129 EUR',
  'Restauarant Website': 'https://www.fgfoodlabs.nl/'},
 {'Restaurant Name': 'Wiesen',
  'Price Range': '49 - 99 EUR',
  'Restauarant Website': 'https://www.wiesen-restaurant.nl/'},
 {'Restaurant Name': 'La Provence',
  'Price Range': '65 - 107 EUR',
  'Restauarant Website': 'https://www.restaurantlaprovence.nl/'},
 {'Restaurant Name': 'Cheval Blanc',
  'Price Range': '35 - 110 EUR',
  'Restauarant Website': 'https://www.cheval-blanc.nl/'},
 {'Restaurant Name': 'De Bloemenbeek',
  'Price Range': '38 - 130 EUR',
  'Restauarant Website': 'https://www.bloemenbeek.nl/'},
 {'Restaurant Name': 'De Loohoeve',
  'Price Range': '45 - 200 EUR',
  'Restauarant Website': 'https://www.deloohoeve.nl/'},
 {'Restaurant Name': 'Rijnzicht',
  'Price Range': '60 - 110 EUR',
  'Restauarant Website': 'https://www.rijnzicht.nl/'},
 {'Restaurant Name': 'Zout & Citroen',
  'Price Range': '37 - 95 EUR',
  'Restauarant Website': 'https://www.zoutencitroen.nl/'},
 {'Restaurant Name': 'De Leuf',
  'Price Range': '55 - 125 EUR',
  'Restauarant Website': 'https://www.deleuf.nl/'},
 {'Restaurant Name': 'RON Gastrobar',
  'Price Range': '30 - 190 EUR',
  'Restauarant Website': 'https://www.rongastrobar.nl/'},
 {'Restaurant Name': 'Tout à Fait',
  'Price Range': '45 - 130 EUR',
  'Restauarant Website': 'https://www.toutafait.nl/'},
 {'Restaurant Name': 'Apicius',
  'Price Range': '45 - 85 EUR',
  'Restauarant Website': 'https://www.apicius.nl/'},
 {'Restaurant Name': 'AIRrepublic',
  'Price Range': '92 - 152 EUR',
  'Restauarant Website': 'https://www.air-republic.com/'},
 {'Restaurant Name': 'Tilia',
  'Price Range': '40 - 80 EUR',
  'Restauarant Website': 'https://www.restauranttilia.nl/'},
 {'Restaurant Name': 'Meliefste',
  'Price Range': '65 - 130 EUR',
  'Restauarant Website': 'https://www.restaurantmeliefste.nl/'},
 {'Restaurant Name': 'Soigné',
  'Price Range': '61 - 88 EUR',
  'Restauarant Website': 'https://www.restaurantsoigne.nl/'},
 {'Restaurant Name': 'Tante Koosje',
  'Price Range': '57 - 129 EUR',
  'Restauarant Website': 'https://www.tante-koosje.nl/'},
 {'Restaurant Name': 'Vermeer',
  'Price Range': '70 - 100 EUR',
  'Restauarant Website': 'https://www.restaurantvermeer.nl/'},
 {'Restaurant Name': 'Eden',
  'Price Range': '47 - 84 EUR',
  'Restauarant Website': 'https://www.restaurant-eden.nl/'},
 {'Restaurant Name': 'Versaen',
  'Price Range': '45 - 80 EUR',
  'Restauarant Website': 'https://www.restaurantversaen.nl/'},
 {'Restaurant Name': 'Noble Kitchen',
  'Price Range': '35 - 88 EUR',
  'Restauarant Website': 'https://www.noblekitchen.nl/'},
 {'Restaurant Name': 'Bolenius',
  'Price Range': '49 - 140 EUR',
  'Restauarant Website': 'https://www.bolenius-restaurant.nl/'},
 {'Restaurant Name': 'Wils',
  'Price Range': '45 - 90 EUR',
  'Restauarant Website': 'https://www.restaurantwils.nl/'},
 {'Restaurant Name': 'OONIVOO',
  'Price Range': '45 - 89 EUR',
  'Restauarant Website': 'https://www.oonivoo.nl/'},
 {'Restaurant Name': "Bord'Eau",
  'Price Range': '60 - 130 EUR',
  'Restauarant Website': 'https://www.bordeau.nl/'},
 {'Restaurant Name': 'O&O',
  'Price Range': '75 - 145 EUR',
  'Restauarant Website': 'https://www.restaurantoeno.nl/'},
 {'Restaurant Name': 'Joelia',
  'Price Range': '55 - 175 EUR',
  'Restauarant Website': 'https://www.joelia.eu/'},
 {'Restaurant Name': 'Yamazato',
  'Price Range': '150 - 190 EUR',
  'Restauarant Website': 'https://www.okura.nl/'},
 {'Restaurant Name': 'Zeezout',
  'Price Range': '36 - 75 EUR',
  'Restauarant Website': 'https://www.restaurantzeezout.nl/'},
 {'Restaurant Name': 'Marrees',
  'Price Range': '40 - 90 EUR',
  'Restauarant Website': 'https://www.restaurantmarrees.nl/'},
 {'Restaurant Name': 'Bij Jef',
  'Price Range': '125 EUR',
  'Restauarant Website': 'https://www.bijjef.nl/'},
 {'Restaurant Name': 'Latour',
  'Price Range': '60 - 112 EUR',
  'Restauarant Website': 'https://www.restaurantlatour.nl/'},
 {'Restaurant Name': 'Aan de Zweth',
  'Price Range': '52 - 115 EUR',
  'Restauarant Website': 'https://www.aandezweth.nl/'},
 {'Restaurant Name': 'Flicka',
  'Price Range': '43 - 115 EUR',
  'Restauarant Website': 'https://restaurant-flicka.nl/'},
 {'Restaurant Name': 'Kilian Stuba',
  'Price Range': '110 - 140 EUR',
  'Restauarant Website': 'https://www.travelcharme.com/'},
 {'Restaurant Name': 'der Schneider',
  'Price Range': '74 - 120 EUR',
  'Restauarant Website': 'www.derschneider-restaurant.com'},
 {'Restaurant Name': 'Zur Post',
  'Price Range': '49 - 135 EUR',
  'Restauarant Website': 'https://www.zurpost.eu/'},
 {'Restaurant Name': 'Le Flair',
  'Price Range': '95 - 130 EUR',
  'Restauarant Website': 'https://www.restaurant-leflair.de/'},
 {'Restaurant Name': 'Orangerie',
  'Price Range': '84 - 135 EUR',
  'Restauarant Website': 'https://www.orangerie-timmendorfer-strand.de/'},
 {'Restaurant Name': 'Rebers Pflug',
  'Price Range': '47 - 105 EUR',
  'Restauarant Website': 'https://www.rebers-pflug.de/'},
 {'Restaurant Name': 'Gourmetrestaurant "fine dining RS"',
  'Price Range': '108 - 153 EUR',
  'Restauarant Website': 'https://www.burg-staufeneck.de/'},
 {'Restaurant Name': 'Atelier Sanssouci',
  'Price Range': '89 - 129 EUR',
  'Restauarant Website': 'https://www.atelier-sanssouci.de/'},
 {'Restaurant Name': 'Apicius',
  'Price Range': '99 - 165 EUR',
  'Restauarant Website': 'https://www.jagdhaus-eiden.de/'},
 {'Restaurant Name': 'SKYKITCHEN',
  'Price Range': '125 EUR',
  'Restauarant Website': 'https://www.skykitchen.berlin/'},
 {'Restaurant Name': 'maiBeck',
  'Price Range': '43 - 62 EUR',
  'Restauarant Website': 'https://www.maibeck.de/'},
 {'Restaurant Name': 'Traube',
  'Price Range': '89 - 120 EUR',
  'Restauarant Website': 'http://www.traube-blansingen.de/'},
 {'Restaurant Name': "BODENDORF'S",
  'Price Range': '178 - 218 EUR',
  'Restauarant Website': 'https://www.landhaus-stricker.de/'},
 {'Restaurant Name': 'Johanns',
  'Price Range': '29 - 82 EUR',
  'Restauarant Website': 'http://www.restaurant-johanns.de/'},
 {'Restaurant Name': 'JUWEL',
  'Price Range': '130 - 157 EUR',
  'Restauarant Website': 'https://www.bei-schumann.de/'},
 {'Restaurant Name': 'Gourmet Restaurant im Schlosshotel Münchhausen',
  'Price Range': '130 - 190 EUR',
  'Restauarant Website': 'www.schlosshotel-muenchhausen.com'},
 {'Restaurant Name': 'Cheval Blanc',
  'Price Range': '85 - 138 EUR',
  'Restauarant Website': 'www.weisses-ross.de'},
 {'Restaurant Name': 'San Martino - Gourmet',
  'Price Range': '146 - 182 EUR',
  'Restauarant Website': 'www.san-martino.net'},
 {'Restaurant Name': '[KOOK] 36',
  'Price Range': '50 - 95 EUR',
  'Restauarant Website': 'https://www.kook36.de/'},
 {'Restaurant Name': 'Wolfshöhle',
  'Price Range': '39 - 125 EUR',
  'Restauarant Website': 'http://www.wolfshoehle-freiburg.de/'},
 {'Restaurant Name': "Coeur D'Artichaut",
  'Price Range': '80 - 130 EUR',
  'Restauarant Website': 'https://www.coeur-dartichaut.de/'},
 {'Restaurant Name': 'Tian',
  'Price Range': '49 - 123 EUR',
  'Restauarant Website': 'https://www.tian-restaurant.com/'},
 {'Restaurant Name': "Kucher's Gourmet",
  'Price Range': '73 - 119 EUR',
  'Restauarant Website': 'www.kucherslandhotel.de'},
 {'Restaurant Name': 'Weinschänke Schloss Groenesteyn',
  'Price Range': '66 - 145 EUR',
  'Restauarant Website': 'https://www.groenesteyn.net/'},
 {'Restaurant Name': 'Philipp Soldan',
  'Price Range': '54 - 125 EUR',
  'Restauarant Website': 'https://www.sonne-frankenberg.de/'},
 {'Restaurant Name': 'Reuter',
  'Price Range': '93 - 144 EUR',
  'Restauarant Website': 'https://www.hotelreuter.de/'},
 {'Restaurant Name': '5',
  'Price Range': '88 - 176 EUR',
  'Restauarant Website': 'https://www.5.fo/'},
 {'Restaurant Name': 'Zeitwerk',
  'Price Range': '120 - 140 EUR',
  'Restauarant Website': 'https://www.dein-zeitwerk.com/'},
 {'Restaurant Name': 'Mühlenhelle',
  'Price Range': '50 - 139 EUR',
  'Restauarant Website': 'https://www.muehlenhelle.de/'},
 {'Restaurant Name': 'REISERS am Stein',
  'Price Range': '39 - 125 EUR',
  'Restauarant Website': 'https://www.der-reiser.de/'},
 {'Restaurant Name': 'Erbprinz',
  'Price Range': '124 - 170 EUR',
  'Restauarant Website': 'https://www.erbprinz.de/'},
 {'Restaurant Name': 'Leos by Stephan Brandl',
  'Price Range': '66 - 135 EUR',
  'Restauarant Website': 'www.bayerwaldhof.de'},
 {'Restaurant Name': 'Hannappel',
  'Price Range': '60 - 118 EUR',
  'Restauarant Website': 'https://www.restaurant-hannappel.de/'},
 {'Restaurant Name': 'Frühsammers Restaurant',
  'Price Range': '135 EUR',
  'Restauarant Website': 'https://www.fruehsammers.de/'},
 {'Restaurant Name': 'Hugos',
  'Price Range': '110 - 175 EUR',
  'Restauarant Website': 'https://www.hugos-restaurant.de/'},
 {'Restaurant Name': 'Werners Restaurant',
  'Price Range': '78 - 120 EUR',
  'Restauarant Website': 'https://www.schlosseberstein.com/'},
 {'Restaurant Name': 'maximilian lorenz',
  'Price Range': '123 - 152 EUR',
  'Restauarant Website': 'https://www.restaurant-maximilianlorenz.de/'},
 {'Restaurant Name': 'Stadtpfeiffer',
  'Price Range': '58 - 138 EUR',
  'Restauarant Website': 'https://www.stadtpfeiffer.de/'},
 {'Restaurant Name': 'Aska',
  'Price Range': '95 - 120 EUR',
  'Restauarant Website': 'https://www.aska.restaurant/'},
 {'Restaurant Name': 'Alte Schule - Klassenzimmer',
  'Price Range': '110 - 160 EUR',
  'Restauarant Website': 'https://www.hotelalteschule.de/'},
 {'Restaurant Name': 'Piment',
  'Price Range': '82 - 124 EUR',
  'Restauarant Website': 'https://www.restaurant-piment.de/'},
 {'Restaurant Name': 'Raubs Landgasthof',
  'Price Range': '49 - 140 EUR',
  'Restauarant Website': 'https://www.raubs-landgasthof.de/'},
 {'Restaurant Name': 'Gasthaus zum Raben',
  'Price Range': '55 - 122 EUR',
  'Restauarant Website': 'https://www.raben-horben.de/'},
 {'Restaurant Name': "Schiller's Manufaktur",
  'Price Range': '75 - 185 EUR',
  'Restauarant Website': 'http://www.schillers-restaurant.de/'},
 {'Restaurant Name': 'La Bécasse',
  'Price Range': '39 - 118 EUR',
  'Restauarant Website': 'www.labecasse.de'},
 {'Restaurant Name': 'Ahlmanns',
  'Price Range': '99 - 139 EUR',
  'Restauarant Website': 'www.kieler-kaufmann.de'},
 {'Restaurant Name': 'Ostseelounge',
  'Price Range': '124 EUR',
  'Restauarant Website': 'https://www.strandhotel-fischland.de/'},
 {'Restaurant Name': 'temporaire - Köhlerstube',
  'Price Range': '125 - 155 EUR',
  'Restauarant Website': 'https://www.traube-tonbach.de/'},
 {'Restaurant Name': 'le Corange',
  'Price Range': '59 - 104 EUR',
  'Restauarant Website': 'https://www.corange-restaurant.de/'},
 {'Restaurant Name': "Stein's Traube",
  'Price Range': '44 - 105 EUR',
  'Restauarant Website': 'https://www.steins-traube.de/'},
 {'Restaurant Name': 'KAI3',
  'Price Range': '98 - 148 EUR',
  'Restauarant Website': 'www.budersand.de'},
 {'Restaurant Name': 'Schranners Waldhorn',
  'Price Range': '29 - 89 EUR',
  'Restauarant Website': 'https://www.schranners-waldhorn.de/'},
 {'Restaurant Name': 'Roter Hahn',
  'Price Range': '36 - 160 EUR',
  'Restauarant Website': 'https://www.roter-hahn.com'},
 {'Restaurant Name': 'Wirtshaus Meyers Keller',
  'Price Range': '64 - 140 EUR',
  'Restauarant Website': 'https://www.jockl-kaiser.de/'},
 {'Restaurant Name': 'Koch und Kellner',
  'Price Range': '90 - 170 EUR',
  'Restauarant Website': 'https://www.kochundkellner.de/'},
 {'Restaurant Name': 'Huberwirt',
  'Price Range': '30 - 119 EUR',
  'Restauarant Website': 'https://www.huber-wirt.de/'},
 {'Restaurant Name': "Anthony's Kitchen",
  'Price Range': '120 - 185 EUR',
  'Restauarant Website': 'https://www.anthonys.kitchen/'},
 {'Restaurant Name': 'Adler',
  'Price Range': '84 - 179 EUR',
  'Restauarant Website': 'www.adler-lahr.de'},
 {'Restaurant Name': 'Gourmetrestaurant Dirk Maus',
  'Price Range': '95 - 140 EUR',
  'Restauarant Website': 'https://www.dirk-maus.de/'},
 {'Restaurant Name': 'Die Brasserie',
  'Price Range': '36 - 109 EUR',
  'Restauarant Website': 'https://www.diebrasserie-ps.de/'},
 {'Restaurant Name': 'Aubergine',
  'Price Range': '99 - 119 EUR',
  'Restauarant Website': 'https://www.aubergine-starnberg.de/'},
 {'Restaurant Name': 'La Cuisine Rademacher',
  'Price Range': '23 - 100 EUR',
  'Restauarant Website': 'https://www.la-cuisine-koeln.de/'},
 {'Restaurant Name': "Zehner's Stube",
  'Price Range': '87 - 135 EUR',
  'Restauarant Website': 'https://www.zehnersstube.de/'},
 {'Restaurant Name': "s'Äpfle",
  'Price Range': '82 - 159 EUR',
  'Restauarant Website': 'https://www.seehotelvillalinde.de/'},
 {'Restaurant Name': 'Falconera',
  'Price Range': '55 - 115 EUR',
  'Restauarant Website': 'https://www.falconera.de/'},
 {'Restaurant Name': 'faelt',
  'Price Range': '89 EUR',
  'Restauarant Website': 'https://www.faelt.de/'},
 {'Restaurant Name': 'Berens am Kai',
  'Price Range': '55 - 115 EUR',
  'Restauarant Website': 'https://www.berensamkai.de/'},
 {'Restaurant Name': "Agata's",
  'Price Range': '85 - 116 EUR',
  'Restauarant Website': 'http://www.agatas.de/'},
 {'Restaurant Name': 'Keidenzeller Hof',
  'Price Range': '75 - 120 EUR',
  'Restauarant Website': 'www.keidenzeller-hof.de'},
 {'Restaurant Name': 'Anima',
  'Price Range': '94 - 125 EUR',
  'Restauarant Website': 'https://www.restaurant-anima.de/'},
 {'Restaurant Name': 'Kunz',
  'Price Range': '78 - 125 EUR',
  'Restauarant Website': 'https://www.restaurant-kunz.de/'},
 {'Restaurant Name': 'SEO Küchenhandwerk',
  'Price Range': '144 EUR',
  'Restauarant Website': 'http://www.restaurant-seo.de/'},
 {'Restaurant Name': 'Friedrich Franz',
  'Price Range': '130 - 249 EUR',
  'Restauarant Website': 'https://www.grandhotel-heiligendamm.de/'},
 {'Restaurant Name': 'Landhaus Köpp',
  'Price Range': '55 - 77 EUR',
  'Restauarant Website': 'https://www.landhauskoepp.de/'},
 {'Restaurant Name': 'Schlossberg',
  'Price Range': '103 - 172 EUR',
  'Restauarant Website': 'www.hotel-sackmann.de'},
 {'Restaurant Name': 'Die Zirbelstube',
  'Price Range': '97 - 169 EUR',
  'Restauarant Website': 'https://www.hotelschlossgarten.com/'},
 {'Restaurant Name': 'Sartory',
  'Price Range': '159 - 189 EUR',
  'Restauarant Website': 'https://www.sartory-augsburg.de/'},
 {'Restaurant Name': 'mural',
  'Price Range': '125 - 155 EUR',
  'Restauarant Website': 'https://www.mural.restaurant/'},
 {'Restaurant Name': 'Casala',
  'Price Range': '109 - 145 EUR',
  'Restauarant Website': 'https://www.hotel-residenz-meersburg.com/'},
 {'Restaurant Name': 'Wielandshöhe',
  'Price Range': '80 - 150 EUR',
  'Restauarant Website': 'https://www.wielandshoehe.de/'},
 {'Restaurant Name': 'Gutshaus Stolpe',
  'Price Range': '120 - 150 EUR',
  'Restauarant Website': 'https://www.gutshaus-stolpe.de/'},
 {'Restaurant Name': 'Laudensacks Gourmet Restaurant',
  'Price Range': '76 - 138 EUR',
  'Restauarant Website': 'https://www.laudensacks-parkhotel.de/'},
 {'Restaurant Name': "Oettinger's Restaurant",
  'Price Range': '64 - 108 EUR',
  'Restauarant Website': 'https://www.hirsch-fellbach.de/'},
 {'Restaurant Name': 'Wein- und Tafelhaus',
  'Price Range': '125 - 165 EUR',
  'Restauarant Website': 'https://www.wein-tafelhaus.de/'},
 {'Restaurant Name': 'Yunico',
  'Price Range': '79 - 170 EUR',
  'Restauarant Website': 'www.kamehabonn.de'},
 {'Restaurant Name': "Erno's Bistro",
  'Price Range': '55 - 165 EUR',
  'Restauarant Website': 'https://www.ernosbistro.de/'},
 {'Restaurant Name': 'Speisemeisterei',
  'Price Range': '145 - 185 EUR',
  'Restauarant Website': 'https://www.speisemeisterei.de/'},
 {'Restaurant Name': 'Alte Pfarrey',
  'Price Range': '82 - 134 EUR',
  'Restauarant Website': 'http://www.altepfarrey.de/'},
 {'Restaurant Name': 'Balthasar',
  'Price Range': '78 - 155 EUR',
  'Restauarant Website': 'https://www.restaurant-balthasar.de/'},
 {'Restaurant Name': 'Christian & Friends, Tastekitchen',
  'Price Range': '30 - 75 EUR',
  'Restauarant Website': 'https://www.christianandfriends.de/'},
 {'Restaurant Name': 'L.A. Jordan',
  'Price Range': '175 - 205 EUR',
  'Restauarant Website': 'https://www.ketschauer-hof.com/'},
 {'Restaurant Name': 'Gabelspiel',
  'Price Range': '130 - 140 EUR',
  'Restauarant Website': 'http://www.restaurant-gabelspiel.de/'},
 {'Restaurant Name': 'Gut Lärchenhof',
  'Price Range': '110 - 199 EUR',
  'Restauarant Website': 'www.restaurant-gutlaerchenhof.de'},
 {'Restaurant Name': 'Gasthof Krone',
  'Price Range': '59 - 99 EUR',
  'Restauarant Website': 'https://www.krone-waldenbuch.de/'},
 {'Restaurant Name': 'Malathounis',
  'Price Range': '49 - 98 EUR',
  'Restauarant Website': 'https://www.malathounis.de/'},
 {'Restaurant Name': 'Der Zauberlehrling',
  'Price Range': '85 - 140 EUR',
  'Restauarant Website': 'https://www.zauberlehrling.de/'},
 {'Restaurant Name': 'Balthazar',
  'Price Range': '119 - 169 EUR',
  'Restauarant Website': 'https://www.restaurantbalthazar.de/'},
 {'Restaurant Name': 'Nobelhart & Schmutzig',
  'Price Range': '105 - 130 EUR',
  'Restauarant Website': 'https://www.nobelhartundschmutzig.com/'},
 {'Restaurant Name': 'Jan´s Restaurant',
  'Price Range': '49 - 56 EUR',
  'Restauarant Website': 'https://www.detmolder-hof.de/'},
 {'Restaurant Name': 'DiVa',
  'Price Range': '85 - 122 EUR',
  'Restauarant Website': 'www.hotel-belveder.de'},
 {'Restaurant Name': 'GOLVET',
  'Price Range': '60 - 120 EUR',
  'Restauarant Website': 'https://www.golvet.de/'},
 {'Restaurant Name': 'astrein',
  'Price Range': '92 - 129 EUR',
  'Restauarant Website': 'https://www.astrein-restaurant.de/'},
 {'Restaurant Name': 'Clostermanns Le Gourmet',
  'Price Range': '89 - 149 EUR',
  'Restauarant Website': 'www.clostermannshof.de'},
 {'Restaurant Name': "Gregor's Fine Dining",
  'Price Range': '119 - 148 EUR',
  'Restauarant Website': 'www.wutzschleife.com'},
 {'Restaurant Name': 'Restaurant Villa Merton',
  'Price Range': '95 - 145 EUR',
  'Restauarant Website': 'https://www.restaurant-villa-merton.de/'},
 {'Restaurant Name': "L'étable",
  'Price Range': '86 - 126 EUR',
  'Restauarant Website': 'www.zumsternhersfeld.de'},
 {'Restaurant Name': 'Landhaus Feckl',
  'Price Range': '53 - 108 EUR',
  'Restauarant Website': 'https://www.landhausfeckl.de/'},
 {'Restaurant Name': 'ernst',
  'Price Range': '195 EUR',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Da Vinci',
  'Price Range': '129 - 158 EUR',
  'Restauarant Website': 'https://www.davinci-koblenz.de/'},
 {'Restaurant Name': 'Genuss-Apotheke',
  'Price Range': '51 - 149 EUR',
  'Restauarant Website': 'https://www.genuss-apotheke.de/'},
 {'Restaurant Name': 'VILLINO',
  'Price Range': '106 - 158 EUR',
  'Restauarant Website': 'https://www.villino.de/'},
 {'Restaurant Name': 'Zur Krone',
  'Price Range': '120 - 132 EUR',
  'Restauarant Website': 'https://www.zurkroneneupotz.de/'},
 {'Restaurant Name': 'Laurentius',
  'Price Range': '59 - 129 EUR',
  'Restauarant Website': 'www.hotel-laurentius.de'},
 {'Restaurant Name': 'Buchner',
  'Price Range': '56 - 115 EUR',
  'Restauarant Website': 'https://www.buchner-welchenberg.de/'},
 {'Restaurant Name': 'Petit Amour',
  'Price Range': '159 - 185 EUR',
  'Restauarant Website': 'https://www.petitamour-hh.com/'},
 {'Restaurant Name': 'Hupperts',
  'Price Range': '109 - 119 EUR',
  'Restauarant Website': 'https://www.hupperts-restaurant.de/'},
 {'Restaurant Name': 'Le Jardin de France',
  'Price Range': '45 - 115 EUR',
  'Restauarant Website': 'https://www.lejardindefrance.de/'},
 {'Restaurant Name': 'Kulmeck by Tom Wickboldt',
  'Price Range': '99 - 135 EUR',
  'Restauarant Website': 'https://www.kulmeck.de/'},
 {'Restaurant Name': 'Jungborn',
  'Price Range': '121 - 144 EUR',
  'Restauarant Website': 'www.bollants.de'},
 {'Restaurant Name': "halbedel's Gasthaus",
  'Price Range': '85 - 150 EUR',
  'Restauarant Website': 'www.halbedels-gasthaus.de'},
 {'Restaurant Name': 'Landhaus Scherrer',
  'Price Range': '85 - 135 EUR',
  'Restauarant Website': 'https://www.landhausscherrer.de/'},
 {'Restaurant Name': 'Waidwerk',
  'Price Range': '125 - 350 EUR',
  'Restauarant Website': 'https://www.rottner-hotel.de/'},
 {'Restaurant Name': 'La Société',
  'Price Range': '135 EUR',
  'Restauarant Website': 'http://www.restaurant-lasociete.de/'},
 {'Restaurant Name': 'Hofstube',
  'Price Range': '119 - 139 EUR',
  'Restauarant Website': 'https://www.deimann.de/'},
 {'Restaurant Name': 'ESS ATELIER STRAUSS',
  'Price Range': '79 - 180 EUR',
  'Restauarant Website': 'https://www.loewen-strauss.de/'},
 {'Restaurant Name': 'Schwabenstube',
  'Price Range': '62 - 115 EUR',
  'Restauarant Website': 'www.adler-asperg.de'},
 {'Restaurant Name': 'Le Gourmet',
  'Price Range': '106 - 160 EUR',
  'Restauarant Website': 'https://www.hirschgasse.de/'},
 {'Restaurant Name': 'Seestern',
  'Price Range': '69 - 165 EUR',
  'Restauarant Website': 'https://www.lago-ulm.de/'},
 {'Restaurant Name': 'Nagaya',
  'Price Range': '79 - 198 EUR',
  'Restauarant Website': 'https://www.nagaya.de/'},
 {'Restaurant Name': 'prism',
  'Price Range': '89 - 165 EUR',
  'Restauarant Website': 'https://www.prismberlin.de/'},
 {'Restaurant Name': 'Doblers',
  'Price Range': '49 - 98 EUR',
  'Restauarant Website': 'https://www.doblers.de/'},
 {'Restaurant Name': "Schwitzer's am Park",
  'Price Range': '99 - 189 EUR',
  'Restauarant Website': 'https://schwitzers.com/'},
 {'Restaurant Name': 'Carmelo Greco',
  'Price Range': '73 - 97 EUR',
  'Restauarant Website': 'https://www.carmelo-greco.de/'},
 {'Restaurant Name': 'Schwarzreiter',
  'Price Range': '85 - 185 EUR',
  'Restauarant Website': 'www.schwarzreiter-muenchen.de'},
 {'Restaurant Name': 'Ursprung',
  'Price Range': '110 - 145 EUR',
  'Restauarant Website': 'https://www.widmanns-albleben.de/'},
 {'Restaurant Name': 'Lakeside',
  'Price Range': '155 - 175 EUR',
  'Restauarant Website': 'https://www.thefontenay.com/restaurants-bar/lakeside-restaurant/'},
 {'Restaurant Name': 'SoulFood',
  'Price Range': '58 - 79 EUR',
  'Restauarant Website': 'www.restaurant-soulfood.com'},
 {'Restaurant Name': 'SIEDEPUNKT',
  'Price Range': '59 - 135 EUR',
  'Restauarant Website': 'https://www.siedepunkt-restaurant.de/'},
 {'Restaurant Name': 'Gasthof zum Bad',
  'Price Range': '46 - 136 EUR',
  'Restauarant Website': 'http://www.gasthof-zum-bad.de/home/'},
 {'Restaurant Name': 'FAVORITE restaurant',
  'Price Range': '35 - 140 EUR',
  'Restauarant Website': 'https://www.favorite-mainz.de/'},
 {'Restaurant Name': 'Admiral',
  'Price Range': '76 - 130 EUR',
  'Restauarant Website': 'https://www.admiral-weisenheim.de/'},
 {'Restaurant Name': 'Eisenbahn',
  'Price Range': '75 - 148 EUR',
  'Restauarant Website': 'https://www.landhauswolf.eu/'},
 {'Restaurant Name': 'Irma la Douce',
  'Price Range': '51 - 89 EUR',
  'Restauarant Website': 'https://www.irmaladouce.de/'},
 {'Restaurant Name': "Rüssel's Landhaus",
  'Price Range': '72 - 165 EUR',
  'Restauarant Website': 'https://www.ruessels-landhaus.de/'},
 {'Restaurant Name': "Christian's Restaurant - Gasthof Grainer",
  'Price Range': '65 - 125 EUR',
  'Restauarant Website': 'www.christians-restaurant.de'},
 {'Restaurant Name': 'Setzkasten',
  'Price Range': '39 - 129 EUR',
  'Restauarant Website': 'https://www.restaurant-setzkasten.de/'},
 {'Restaurant Name': 'Ente',
  'Price Range': '65 - 180 EUR',
  'Restauarant Website': 'https://www.nassauer-hof.de/'},
 {'Restaurant Name': 'kochZIMMER in der Gaststätte zur Ratswaage',
  'Price Range': '115 - 155 EUR',
  'Restauarant Website': 'https://www.restaurant-kochzimmer.de/'},
 {'Restaurant Name': 'Kaupers Restaurant im Kapellenhof',
  'Price Range': '107 - 125 EUR',
  'Restauarant Website': 'https://www.kaupers-kapellenhof.de/'},
 {'Restaurant Name': 'Yoshi by Nagaya',
  'Price Range': '75 - 148 EUR',
  'Restauarant Website': 'https://www.nagaya.de/'},
 {'Restaurant Name': 'Gourmetrestaurant Dichter',
  'Price Range': '138 - 218 EUR',
  'Restauarant Website': 'www.gourmetrestaurant-dichter.de'},
 {'Restaurant Name': 'taku',
  'Price Range': '21 - 130 EUR',
  'Restauarant Website': 'www.taku.de'},
 {'Restaurant Name': 'Oben',
  'Price Range': '130 EUR',
  'Restauarant Website': 'https://www.restaurant-oben.de/'},
 {'Restaurant Name': 'Weinstock',
  'Price Range': '75 - 132 EUR',
  'Restauarant Website': 'https://www.schwane.de/'},
 {'Restaurant Name': 'Cordo',
  'Price Range': '75 - 120 EUR',
  'Restauarant Website': 'https://www.cordo.berlin/'},
 {'Restaurant Name': '1876 Daniel Dal-Ben',
  'Price Range': '130 - 198 EUR',
  'Restauarant Website': 'https://www.1876.restaurant/'},
 {'Restaurant Name': 'Cookies Cream',
  'Price Range': '79 - 149 EUR',
  'Restauarant Website': 'https://www.cookiescream.com/'},
 {'Restaurant Name': 'Goldener Anker',
  'Price Range': '85 - 127 EUR',
  'Restauarant Website': 'https://www.bjoern-freitag.de/'},
 {'Restaurant Name': 'Burg Nideggen - Brockel Schlimbach',
  'Price Range': '125 - 140 EUR',
  'Restauarant Website': 'https://www.burgrestaurant-nideggen.de/'},
 {'Restaurant Name': 'Haubentaucher',
  'Price Range': '70 - 100 EUR',
  'Restauarant Website': 'https://www.haubentaucher-tegernsee.de/'},
 {'Restaurant Name': 'Frieda',
  'Price Range': '79 - 109 EUR',
  'Restauarant Website': 'https://www.frieda-restaurant.de/'},
 {'Restaurant Name': 'Ich weiß ein Haus am See',
  'Price Range': '110 EUR',
  'Restauarant Website': 'https://www.hausamsee.de/'},
 {'Restaurant Name': 'Haus Stemberg',
  'Price Range': '42 - 105 EUR',
  'Restauarant Website': 'https://www.haus-stemberg.de/'},
 {'Restaurant Name': 'Jean',
  'Price Range': '49 - 125 EUR',
  'Restauarant Website': 'https://www.hotel-frankenbach.de/'},
 {'Restaurant Name': 'Im Schiffchen',
  'Price Range': '65 - 160 EUR',
  'Restauarant Website': 'http://www.im-schiffchen.com/'},
 {'Restaurant Name': 'Gourmet-Restaurant Der Butt',
  'Price Range': '149 - 189 EUR',
  'Restauarant Website': 'https://www.hohe-duene.de/'},
 {'Restaurant Name': 'Français',
  'Price Range': '69 - 205 EUR',
  'Restauarant Website': 'https://www.restaurant-francais.de/'},
 {'Restaurant Name': 'einsunternull',
  'Price Range': '139 EUR',
  'Restauarant Website': 'https://restaurant-einsunternull.de/'},
 {'Restaurant Name': 'YOSO',
  'Price Range': '98 - 112 EUR',
  'Restauarant Website': 'https://www.yoso-restaurant.de/'},
 {'Restaurant Name': 'Restaurant 1797',
  'Price Range': '119 EUR',
  'Restauarant Website': 'https://www.ole-liese.de/'},
 {'Restaurant Name': 'Philipp',
  'Price Range': '65 - 155 EUR',
  'Restauarant Website': 'https://www.restaurant-philipp.de/'},
 {'Restaurant Name': 'Alte Baiz',
  'Price Range': '112 - 152 EUR',
  'Restauarant Website': 'www.gruenerwald.de'},
 {'Restaurant Name': 'Bandol sur mer',
  'Price Range': '85 - 139 EUR',
  'Restauarant Website': 'https://www.bandolsurmer.de/'},
 {'Restaurant Name': "BECKER'S",
  'Price Range': '105 - 125 EUR',
  'Restauarant Website': 'www.beckers-trier.de'},
 {'Restaurant Name': 'Gourmetrestaurant Berlins Krone',
  'Price Range': '105 - 145 EUR',
  'Restauarant Website': 'https://www.kronelamm.de/'},
 {'Restaurant Name': 'ferment',
  'Price Range': '104 - 139 EUR',
  'Restauarant Website': 'www.restaurant-ackermann.de'},
 {'Restaurant Name': 'Ratsstuben',
  'Price Range': '79 - 148 EUR',
  'Restauarant Website': 'https://www.hotel-haltern.de/'},
 {'Restaurant Name': 'Alfredo',
  'Price Range': '65 - 81 EUR',
  'Restauarant Website': 'https://www.ristorante-alfredo.com/'},
 {'Restaurant Name': "Hämmerle's Restaurant - Barrique",
  'Price Range': '88 - 108 EUR',
  'Restauarant Website': 'http://www.haemmerles-restaurant.de/'},
 {'Restaurant Name': 'Silberdistel',
  'Price Range': '99 - 298 EUR',
  'Restauarant Website': 'https://www.sonnenalp.de/'},
 {'Restaurant Name': 'Storstad',
  'Price Range': '45 - 145 EUR',
  'Restauarant Website': 'https://www.storstad.de/'},
 {'Restaurant Name': 'Sparkling Bistro',
  'Price Range': '60 - 155 EUR',
  'Restauarant Website': 'http://www.sparklingbistro.de/'},
 {'Restaurant Name': 'Seesteg',
  'Price Range': '54 - 98 EUR',
  'Restauarant Website': 'www.seesteg-norderney.de'},
 {'Restaurant Name': 'Délice',
  'Price Range': '98 - 112 EUR',
  'Restauarant Website': 'https://www.delice-restaurant.de/'},
 {'Restaurant Name': 'Camers Schlossrestaurant',
  'Price Range': '110 - 130 EUR',
  'Restauarant Website': 'https://www.camers.de/'},
 {'Restaurant Name': 'Genießer Stube',
  'Price Range': '59 - 150 EUR',
  'Restauarant Website': 'https://www.geniesserstube.de/'},
 {'Restaurant Name': 'Schloss Filseck',
  'Price Range': '26 - 160 EUR',
  'Restauarant Website': 'https://www.restaurant-auf-schloss-filseck.de/'},
 {'Restaurant Name': 'Alt Wyk',
  'Price Range': '79 - 110 EUR',
  'Restauarant Website': 'www.alt-wyk.de'},
 {'Restaurant Name': 'La Fontaine',
  'Price Range': '78 - 110 EUR',
  'Restauarant Website': 'https://www.ludwigimpark.de/'},
 {'Restaurant Name': 'Schattbuch',
  'Price Range': '63 - 115 EUR',
  'Restauarant Website': 'www.schattbuch.de'},
 {'Restaurant Name': 'Le temple',
  'Price Range': '130 - 165 EUR',
  'Restauarant Website': 'www.le-temple.de'},
 {'Restaurant Name': 'LOUIS restaurant',
  'Price Range': '89 - 169 EUR',
  'Restauarant Website': 'www.lamaison-hotel.de'},
 {'Restaurant Name': 'Das Marktrestaurant',
  'Price Range': '42 - 105 EUR',
  'Restauarant Website': 'https://www.das-marktrestaurant.de/'},
 {'Restaurant Name': 'Showroom',
  'Price Range': '130 - 160 EUR',
  'Restauarant Website': 'https://www.showroom-restaurant.de/'},
 {'Restaurant Name': "Oswald's Gourmetstube",
  'Price Range': '69 - 145 EUR',
  'Restauarant Website': 'https://www.hotel-oswald.de/'},
 {'Restaurant Name': 'Sankt Benedikt',
  'Price Range': '48 - 155 EUR',
  'Restauarant Website': 'www.stbenedikt.de'},
 {'Restaurant Name': 'Maerz - Das Restaurant',
  'Price Range': '119 - 129 EUR',
  'Restauarant Website': 'www.maerzundmaerz.de'},
 {'Restaurant Name': 'Maître im Landhaus Kuckuck',
  'Price Range': '75 - 159 EUR',
  'Restauarant Website': 'https://www.landhaus-kuckuck.de/'},
 {'Restaurant Name': 'PAVO im Burghotel Falkenstein',
  'Price Range': '135 - 140 EUR',
  'Restauarant Website': 'https://www.burghotel-falkenstein.de/'},
 {'Restaurant Name': "The O'ROOM",
  'Price Range': '150 EUR',
  'Restauarant Website': 'https://www.strandcasino-marc-o-polo.com/'},
 {'Restaurant Name': 'freustil',
  'Price Range': '66 - 99 EUR',
  'Restauarant Website': 'https://www.freustil.de/'},
 {'Restaurant Name': 'Das Maximilians',
  'Price Range': '102 - 139 EUR',
  'Restauarant Website': 'https://www.das-maximilians.de/'},
 {'Restaurant Name': 'Lamm Rosswag',
  'Price Range': '46 - 130 EUR',
  'Restauarant Website': 'https://www.lamm-rosswag.de/'},
 {'Restaurant Name': 'sein',
  'Price Range': '40 - 130 EUR',
  'Restauarant Website': 'https://www.restaurant-sein.de'},
 {'Restaurant Name': 'Elements',
  'Price Range': '52 - 85 EUR',
  'Restauarant Website': 'www.restaurant-elements.de'},
 {'Restaurant Name': "Fritz's Frau Franzi",
  'Price Range': '58 - 119 EUR',
  'Restauarant Website': 'https://www.fritzs-frau-franzi.de/'},
 {'Restaurant Name': 'Acquarello',
  'Price Range': '55 - 185 EUR',
  'Restauarant Website': 'www.acquarello.com'},
 {'Restaurant Name': 'Marly',
  'Price Range': '49 - 129 EUR',
  'Restauarant Website': 'https://www.restaurant-marly.com/'},
 {'Restaurant Name': 'Genuss-Atelier',
  'Price Range': '49 - 94 EUR',
  'Restauarant Website': 'www.genuss-atelier.net'},
 {'Restaurant Name': 'Gasthaus Jakob',
  'Price Range': '59 - 89 EUR',
  'Restauarant Website': 'https://www.genuss-jakob.de/'},
 {'Restaurant Name': 'Eckert',
  'Price Range': '34 - 132 EUR',
  'Restauarant Website': 'https://www.eckert-grenzach.de/'},
 {'Restaurant Name': 'Bembergs Häuschen',
  'Price Range': '105 - 165 EUR',
  'Restauarant Website': 'www.burgflamersheim.de'},
 {'Restaurant Name': 'La Vallée Verte',
  'Price Range': '42 - 194 EUR',
  'Restauarant Website': 'www.hohenhaus.de'},
 {'Restaurant Name': 'Gourmetrestaurant Nico Burkhardt',
  'Price Range': '109 - 150 EUR',
  'Restauarant Website': 'https://www.pfauen-schorndorf.de/'},
 {'Restaurant Name': 'PUR',
  'Price Range': '105 - 185 EUR',
  'Restauarant Website': 'https://www.kempinski.com/berchtesgaden'},
 {'Restaurant Name': 'Zur Tant',
  'Price Range': '71 - 98 EUR',
  'Restauarant Website': 'http://www.zurtant.de/'},
 {'Restaurant Name': 'Schwarzer Adler',
  'Price Range': '84 - 135 EUR',
  'Restauarant Website': 'https://www.franz-keller.de/'},
 {'Restaurant Name': 'Entenstuben',
  'Price Range': '57 - 135 EUR',
  'Restauarant Website': 'https://www.entenstuben.de/'},
 {'Restaurant Name': '360°',
  'Price Range': '36 - 160 EUR',
  'Restauarant Website': 'https://www.restaurant360grad.de/'},
 {'Restaurant Name': 'Historisches Gasthaus Sanct Peter Restaurant Brogsitter',
  'Price Range': '69 - 165 EUR',
  'Restauarant Website': 'https://www.sanct-peter.de/'},
 {'Restaurant Name': 'THE IZAKAYA',
  'Price Range': '75 - 110 EUR',
  'Restauarant Website': 'http://www.the-izakaya.com/'},
 {'Restaurant Name': 'Schwingshackl ESSKULTUR Gourmet',
  'Price Range': '75 - 125 EUR',
  'Restauarant Website': 'www.schwingshackl-esskultur.de'},
 {'Restaurant Name': 'Weinsinn',
  'Price Range': '95 - 125 EUR',
  'Restauarant Website': 'www.weinsinn.de'},
 {'Restaurant Name': 'NeoBiota',
  'Price Range': '85 - 145 EUR',
  'Restauarant Website': 'https://www.restaurant-neobiota.de/'},
 {'Restaurant Name': 'Sterneck',
  'Price Range': '85 - 195 EUR',
  'Restauarant Website': 'https://www.badhotel-sternhagen.de/'},
 {'Restaurant Name': 'Urgestein im Steinhäuser Hof',
  'Price Range': '120 - 140 EUR',
  'Restauarant Website': 'https://www.restaurant-urgestein.de/'},
 {'Restaurant Name': 'Landwerk',
  'Price Range': '79 - 145 EUR',
  'Restauarant Website': 'https://www.land-werk.de/'},
 {'Restaurant Name': 'Richard',
  'Price Range': '74 - 118 EUR',
  'Restauarant Website': 'https://www.restaurant-richard.de/'},
 {'Restaurant Name': 'Bieberbau',
  'Price Range': '64 - 84 EUR',
  'Restauarant Website': 'https://www.bieberbau-berlin.de/'},
 {'Restaurant Name': 'ZweiSinn Meiers | Fine Dining',
  'Price Range': '115 - 140 EUR',
  'Restauarant Website': 'https://www.meierszweisinn.de/'},
 {'Restaurant Name': '100/200 Kitchen',
  'Price Range': '144 EUR',
  'Restauarant Website': 'https://www.100200.kitchen/'},
 {'Restaurant Name': 'DR.KOSCH',
  'Price Range': '82 - 110 EUR',
  'Restauarant Website': 'https://www.dr-kosch.de/'},
 {'Restaurant Name': 'Hirsch',
  'Price Range': '52 - 110 EUR',
  'Restauarant Website': 'https://www.romantikhotel-hirsch.de/'},
 {'Restaurant Name': 'BjörnsOX',
  'Price Range': '129 EUR',
  'Restauarant Website': 'www.rhoener-botschaft.de'},
 {'Restaurant Name': 'Pietsch',
  'Price Range': '120 - 140 EUR',
  'Restauarant Website': 'https://www.restaurantpietsch.de/'},
 {'Restaurant Name': 'Bachofer',
  'Price Range': '34 - 149 EUR',
  'Restauarant Website': 'https://www.bachofer.info/'},
 {'Restaurant Name': 'Wullenwever',
  'Price Range': '85 - 150 EUR',
  'Restauarant Website': 'www.wullenwever.de'},
 {'Restaurant Name': 'Kesselhaus',
  'Price Range': '88 - 128 EUR',
  'Restauarant Website': 'https://www.kesselhaus-os.de/'},
 {'Restaurant Name': 'Schwarz Gourmet',
  'Price Range': '129 - 159 EUR',
  'Restauarant Website': 'https://www.schwarz-restaurant.de/'},
 {'Restaurant Name': 'Grammons Restaurant',
  'Price Range': '65 - 119 EUR',
  'Restauarant Website': 'www.grammons.de'},
 {'Restaurant Name': 'Merkles Restaurant',
  'Price Range': '85 - 129 EUR',
  'Restauarant Website': 'www.merkles-restaurant.de'},
 {'Restaurant Name': 'Schote',
  'Price Range': '122 - 189 EUR',
  'Restauarant Website': 'https://www.restaurant-schote.de/'},
 {'Restaurant Name': 'Storchen',
  'Price Range': '42 - 128 EUR',
  'Restauarant Website': 'https://www.storchen-schmidhofen.de/'},
 {'Restaurant Name': 'Seven Swans',
  'Price Range': '129 EUR',
  'Restauarant Website': 'https://www.sevenswans.de/'},
 {'Restaurant Name': 'zeit|geist',
  'Price Range': '49 - 99 EUR',
  'Restauarant Website': 'https://www.walksches-haus.de/'},
 {'Restaurant Name': 'Kin Dee',
  'Price Range': '65 EUR',
  'Restauarant Website': 'https://www.kindeeberlin.com/'},
 {'Restaurant Name': 'El Invernadero',
  'Price Range': '95 - 150 EUR',
  'Restauarant Website': 'www.elinvernaderorestaurante.com'},
 {'Restaurant Name': 'El Club Allard',
  'Price Range': '60 - 135 EUR',
  'Restauarant Website': 'www.elcluballard.com'},
 {'Restaurant Name': 'Brienen aan de Maas',
  'Price Range': '70 - 108 EUR',
  'Restauarant Website': 'https://www.restaurantbrienenaandemaas.nl/'},
 {'Restaurant Name': 'Corral de la Morería Gastronómico',
  'Price Range': '59 - 75 EUR',
  'Restauarant Website': 'www.moreriagastro.com'},
 {'Restaurant Name': 'Lúa',
  'Price Range': '50 - 78 EUR',
  'Restauarant Website': 'www.restaurantelua.com'},
 {'Restaurant Name': "A'Barra",
  'Price Range': '65 - 120 EUR',
  'Restauarant Website': 'www.restauranteabarra.com'},
 {'Restaurant Name': 'Gaytán',
  'Price Range': '50 - 137 EUR',
  'Restauarant Website': 'www.chefjavieraranda.com'},
 {'Restaurant Name': 'Saddle',
  'Price Range': '85 - 120 EUR',
  'Restauarant Website': 'www.saddle-madrid.com'},
 {'Restaurant Name': 'Cebo',
  'Price Range': '115 - 135 EUR',
  'Restauarant Website': 'www.cebomadrid.com'},
 {'Restaurant Name': 'Gofio',
  'Price Range': '65 - 125 EUR',
  'Restauarant Website': 'www.gofiorestaurant.com'},
 {'Restaurant Name': 'De Kristalijn',
  'Price Range': '55 - 158 EUR',
  'Restauarant Website': 'https://www.dekristalijn.be/'},
 {'Restaurant Name': 'Yugo',
  'Price Range': '135 - 182 EUR',
  'Restauarant Website': 'www.yugothebunker.com'},
 {'Restaurant Name': 'Kabuki Wellington',
  'Price Range': '85 - 130 EUR',
  'Restauarant Website': 'www.restaurantekabuki.com'},
 {'Restaurant Name': 'Claude Darroze',
  'Price Range': '39 - 120 EUR',
  'Restauarant Website': 'https://www.darroze.com/'},
 {'Restaurant Name': 'La Tasquería',
  'Price Range': '40 - 75 EUR',
  'Restauarant Website': 'www.latasqueria.com'},
 {'Restaurant Name': 'Au 14 Février',
  'Price Range': '75 - 98 EUR',
  'Restauarant Website': 'https://www.sv-au14fevrier.com/'},
 {'Restaurant Name': 'Altermezzo',
  'Price Range': '90 - 235 EUR',
  'Restauarant Website': 'https://www.altermezzo.be/'},
 {'Restaurant Name': 'Europa',
  'Price Range': '65 - 89 EUR',
  'Restauarant Website': 'www.hreuropa.com'},
 {'Restaurant Name': 'Magis',
  'Price Range': '51 - 100 EUR',
  'Restauarant Website': 'https://www.restaurantmagis.be/'},
 {'Restaurant Name': 'De Mijlpaal',
  'Price Range': '45 - 122 EUR',
  'Restauarant Website': 'https://www.demijlpaal.org/'},
 {'Restaurant Name': 'Bayview by Michel Roth',
  'Price Range': '60 - 200 CHF',
  'Restauarant Website': 'https://www.restaurantbayview.com/'},
 {'Restaurant Name': 'Alpenblick - Stuba',
  'Price Range': '93 - 135 CHF',
  'Restauarant Website': 'https://www.alpenblick-adelboden.ch/'},
 {'Restaurant Name': 'Galleria Arté al Lago',
  'Price Range': '109 - 135 CHF',
  'Restauarant Website': 'http://www.restaurantarte.com/'},
 {'Restaurant Name': 'Le Berceau des Sens',
  'Price Range': '50 - 125 CHF',
  'Restauarant Website': 'https://www.berceau-des-sens.ch/'},
 {'Restaurant Name': 'Sihlhalde',
  'Price Range': '68 - 156 CHF',
  'Restauarant Website': 'https://www.smoly.ch/'},
 {'Restaurant Name': 'Locanda Orico',
  'Price Range': '50 - 135 CHF',
  'Restauarant Website': 'https://www.locandaorico.ch/'},
 {'Restaurant Name': 'Attisholz - le feu',
  'Price Range': '53 - 145 CHF',
  'Restauarant Website': 'https://www.attisholz.ch/'},
 {'Restaurant Name': 'La Brezza',
  'Price Range': '135 - 180 CHF',
  'Restauarant Website': 'https://www.edenroc.ch/'},
 {'Restaurant Name': 'Rössli - Jägerstübli',
  'Price Range': '195 CHF',
  'Restauarant Website': 'https://www.stefanwiesner.ch/'},
 {'Restaurant Name': 'Wirtshaus Zur Säge',
  'Price Range': '103 - 120 CHF',
  'Restauarant Website': 'https://www.säge-flüh.ch/'},
 {'Restaurant Name': 'Café Berra',
  'Price Range': '85 - 190 CHF',
  'Restauarant Website': 'https://www.cafeberra.ch/'},
 {'Restaurant Name': 'roots',
  'Price Range': '59 - 189 CHF',
  'Restauarant Website': 'https://www.roots-basel.ch/'},
 {'Restaurant Name': 'Die Rose',
  'Price Range': '110 - 190 CHF',
  'Restauarant Website': 'https://www.die-rose.ch/'},
 {'Restaurant Name': 'Regina Montium',
  'Price Range': '125 - 165 CHF',
  'Restauarant Website': 'https://www.kraeuterhotel.ch/'},
 {'Restaurant Name': 'Des Trois Tours',
  'Price Range': '78 - 182 CHF',
  'Restauarant Website': 'https://www.troistours.ch/'},
 {'Restaurant Name': "L'Aparté",
  'Price Range': '54 - 119 CHF',
  'Restauarant Website': 'https://www.hotelroyalgeneva.com/'},
 {'Restaurant Name': 'Neue Blumenau',
  'Price Range': '60 - 175 CHF',
  'Restauarant Website': 'https://www.neueblumenau.ch/'},
  {'Restaurant Name': 'the K by mauro colagreco',
  'Price Range': '133 - 330 CHF',
  'Restauarant Website': 'https://www.kulm.com/'},
 {'Restaurant Name': 'Le Chat-Botté',
  'Price Range': '60 - 220 CHF',
  'Restauarant Website': 'https://www.beau-rivage.ch/'},
 {'Restaurant Name': 'Truube',
  'Price Range': '82 - 145 CHF',
  'Restauarant Website': 'http://www.truube.ch/'},
 {'Restaurant Name': 'Principe Leopoldo',
  'Price Range': '68 - 144 CHF',
  'Restauarant Website': 'https://www.leopoldohotel.com/'},
 {'Restaurant Name': 'Jägerhof',
  'Price Range': '70 - 170 CHF',
  'Restauarant Website': 'https://www.jaegerhof.ch/'},
 {'Restaurant Name': 'Traube',
  'Price Range': '68 - 180 CHF',
  'Restauarant Website': 'https://www.traubetrimbach.ch/'},
 {'Restaurant Name': 'La Rôtisserie',
  'Price Range': '82 - 160 CHF',
  'Restauarant Website': 'https://www.storchen.ch/'},
 {'Restaurant Name': "L'Etoile - Nova",
  'Price Range': '79 - 189 CHF',
  'Restauarant Website': 'http://www.etoile.ch/'},
 {'Restaurant Name': '1904 Designed by Lagonda',
  'Price Range': '175 - 250 CHF',
  'Restauarant Website': 'https://zuerich.r-experience.com/'},
 {'Restaurant Name': 'Panorama - Cayenne',
  'Price Range': '118 - 133 CHF',
  'Restauarant Website': 'https://www.panorama-hartlisberg.ch/'},
 {'Restaurant Name': 'La Riva',
  'Price Range': '46 - 225 CHF',
  'Restauarant Website': 'https://www.lariva.ch/'},
 {'Restaurant Name': 'Tosca',
  'Price Range': '69 - 200 CHF',
  'Restauarant Website': 'https://www.tosca-geneva.ch/'},
 {'Restaurant Name': 'Table de Mary',
  'Price Range': '69 - 135 CHF',
  'Restauarant Website': 'https://www.latabledemary.ch/'},
 {'Restaurant Name': 'Sternen - Badstube',
  'Price Range': '52 - 142 CHF',
  'Restauarant Website': 'https://www.sternenwangen.ch/'},
 {'Restaurant Name': 'La Table du Lausanne Palace',
  'Price Range': '78 - 198 CHF',
  'Restauarant Website': 'www.lausanne-palace.ch/restaurants-bars/la-table-du-lausanne-palace/le-restaurant/'},
 {'Restaurant Name': "L'OURS",
  'Price Range': '65 - 205 CHF',
  'Restauarant Website': 'https://www.pasdelours.ch/'},
 {'Restaurant Name': 'Du Cerf',
  'Price Range': '85 - 185 CHF',
  'Restauarant Website': 'http://www.cerf-sonceboz.ch/'},
 {'Restaurant Name': 'EquiTable',
  'Price Range': '105 - 180 CHF',
  'Restauarant Website': 'https://www.equi-table.ch/'},
 {'Restaurant Name': 'mesa',
  'Price Range': '68 - 190 CHF',
  'Restauarant Website': 'https://www.mesa-restaurant.ch/'},
 {'Restaurant Name': 'Le Flacon',
  'Price Range': '55 - 125 CHF',
  'Restauarant Website': 'www.leflacon.ch'},
 {'Restaurant Name': 'Mammertsberg',
  'Price Range': '100 - 180 CHF',
  'Restauarant Website': 'https://www.mammertsberg.ch/'},
 {'Restaurant Name': 'Le Pérolles',
  'Price Range': '78 - 188 CHF',
  'Restauarant Website': 'https://www.leperolles.ch/'},
 {'Restaurant Name': 'Neue Taverne',
  'Price Range': '59 - 130 CHF',
  'Restauarant Website': 'https://www.neuetaverne.ch/'},
 {'Restaurant Name': 'Steinhalle',
  'Price Range': '97 - 147 CHF',
  'Restauarant Website': 'https://www.steinhalle.ch/'},
 {'Restaurant Name': 'Osteria TRE',
  'Price Range': '128 - 168 CHF',
  'Restauarant Website': 'https://www.badbubendorf.ch/'},
 {'Restaurant Name': 'Le 42',
  'Price Range': '115 - 140 CHF',
  'Restauarant Website': 'https://www.restaurantle42.com/'},
 {'Restaurant Name': "La Table d'Adrien",
  'Price Range': '145 - 205 CHF',
  'Restauarant Website': 'https://www.chalet-adrien.com/'},
 {'Restaurant Name': 'Gasthaus Zum Gupf',
  'Price Range': '70 - 164 CHF',
  'Restauarant Website': 'https://www.gupf.ch/'},
 {'Restaurant Name': 'Chesa Stüva Colani',
  'Price Range': '112 - 170 CHF',
  'Restauarant Website': 'https://www.hotelchesacolani.com/'},
 {'Restaurant Name': 'Sonne',
  'Price Range': '75 - 174 CHF',
  'Restauarant Website': 'https://www.sonne-scheunenberg.ch/'},
 {'Restaurant Name': 'Schlüssel',
  'Price Range': '95 - 160 CHF',
  'Restauarant Website': 'https://www.schluessel-oberwil.ch/'},
 {'Restaurant Name': 'Verve by Sven',
  'Price Range': '65 - 140 CHF',
  'Restauarant Website': 'https://www.resortragaz.ch/'},
 {'Restaurant Name': 'La Chaumière by Serge Labrosse',
  'Price Range': '44 - 165 CHF',
  'Restauarant Website': 'https://www.restaurant-la-chaumiere.ch/'},
 {'Restaurant Name': 'After Seven',
  'Price Range': '159 - 199 CHF',
  'Restauarant Website': 'https://www.backstagehotel.ch/'},
 {'Restaurant Name': 'Le Café Suisse',
  'Price Range': '101 - 170 CHF',
  'Restauarant Website': 'https://www.cafe-suisse.ch/'},
 {'Restaurant Name': 'Le Cigalon',
  'Price Range': '56 - 165 CHF',
  'Restauarant Website': 'https://www.le-cigalon.ch/'},
 {'Restaurant Name': 'Vivanda',
  'Price Range': '190 - 250 CHF',
  'Restauarant Website': 'https://www.inlain.ch/'},
 {'Restaurant Name': 'Ornellaia',
  'Price Range': '64 - 190 CHF',
  'Restauarant Website': 'https://www.ristorante-ornellaia.ch/'},
 {'Restaurant Name': 'Zum Äusseren Stand',
  'Price Range': '62 - 145 CHF',
  'Restauarant Website': 'https://www.aeussererstand.ch/'},
 {'Restaurant Name': 'The Japanese Restaurant',
  'Price Range': '160 - 220 CHF',
  'Restauarant Website': 'https://www.thechediandermatt.com/'},
 {'Restaurant Name': 'The Japanese by The Chedi',
  'Price Range': '95 - 140 CHF',
  'Restauarant Website': 'https://www.thechediandermatt.com/'},
 {'Restaurant Name': 'Zur Gedult',
  'Price Range': '95 - 140 CHF',
  'Restauarant Website': 'https://www.gedult.ch/'},
 {'Restaurant Name': 'Guarda Val',
  'Price Range': '86 - 185 CHF',
  'Restauarant Website': 'https://www.guardaval.ch/'},
 {'Restaurant Name': 'Il Lago',
  'Price Range': '78 - 169 CHF',
  'Restauarant Website': 'https://www.fourseasons.com/geneva'},
 {'Restaurant Name': 'Maison Manesse',
  'Price Range': '40 - 160 CHF',
  'Restauarant Website': 'https://www.maisonmanesse.ch/'},
 {'Restaurant Name': 'Löwen - Apriori',
  'Price Range': '62 - 198 CHF',
  'Restauarant Website': 'https://www.loewenbubikon.ch/'},
 {'Restaurant Name': 'I Due Sud',
  'Price Range': '80 - 198 CHF',
  'Restauarant Website': 'https://www.splendide.ch/'},
 {'Restaurant Name': 'Alpine Gourmet Prato Borni',
  'Price Range': '110 - 170 CHF',
  'Restauarant Website': 'https://www.zermatterhof.ch/'},
 {'Restaurant Name': 'IGNIV Zürich by Andreas Caminada',
  'Price Range': '68 - 198 CHF',
  'Restauarant Website': 'https://www.marktgassehotel.ch/'},
 {'Restaurant Name': 'dasRestaurant',
  'Price Range': '105 - 145 CHF',
  'Restauarant Website': 'https://www.seepark.ch/'},
 {'Restaurant Name': 'Sushi Shin',
  'Price Range': '125 - 299 CHF',
  'Restauarant Website': 'https://www.sushishin.ch/'},
 {'Restaurant Name': 'META',
  'Price Range': '88 - 122 CHF',
  'Restauarant Website': 'https://www.metaworld.ch/'},
 {'Restaurant Name': 'UniQuisine Atelier',
  'Price Range': '150 - 180 CHF',
  'Restauarant Website': 'https://www.uniquisine.ch/'},
 {'Restaurant Name': 'Denis Martin',
  'Price Range': '280 - 360 CHF',
  'Restauarant Website': 'https://www.denismartin.ch/'},
 {'Restaurant Name': "L'Ermitage",
  'Price Range': '85 - 285 CHF',
  'Restauarant Website': 'https://www.ravet.swiss/'},
 {'Restaurant Name': 'Gasthaus zum Kreuz',
  'Price Range': '62 - 148 CHF',
  'Restauarant Website': 'https://www.kreuz-dallenwil.ch/'},
 {'Restaurant Name': 'Segreto',
  'Price Range': '110 - 150 CHF',
  'Restauarant Website': 'https://www.segreto.ch/'},
 {'Restaurant Name': 'Le MontBlanc',
  'Price Range': '55 - 179 CHF',
  'Restauarant Website': 'https://www.lecrans.com/'},
 {'Restaurant Name': 'GÜTSCH by Markus Neff',
  'Price Range': '83 - 165 CHF',
  'Restauarant Website': 'https://www.guetsch.com/'},
 {'Restaurant Name': 'Schlüssel - Nidbergstube',
  'Price Range': '75 - 190 CHF',
  'Restauarant Website': 'https://www.schluesselmels.ch/'},
 {'Restaurant Name': 'Bel Etage',
  'Price Range': '77 - 175 CHF',
  'Restauarant Website': 'https://www.teufelhof.com/'},
 {'Restaurant Name': '8 1/2 Otto e Mezzo - Bombana',
  'Price Range': '1,050 - 2,280 MOP',
  'Restauarant Website': 'https://www.ottoemezzobombana.com/'},
 {'Restaurant Name': 'The Golden Peacock',
  'Price Range': '208 - 700 MOP',
  'Restauarant Website': 'https://www.venetianmacao.com/'},
 {'Restaurant Name': 'Zi Yat Heen',
  'Price Range': '300 - 2,000 MOP',
  'Restauarant Website': 'https://www.fourseasons.com/macau'},
 {'Restaurant Name': 'Wing Lei Palace',
  'Price Range': '400 - 1,680 MOP',
  'Restauarant Website': 'https://www.wynnpalace.com/en'},
 {'Restaurant Name': 'Lai Heen',
  'Price Range': '300 - 2,688 MOP',
  'Restauarant Website': 'https://www.ritzcarlton.com/macau'},
 {'Restaurant Name': 'The Kitchen',
  'Price Range': '430 - 1,800 MOP',
  'Restauarant Website': 'https://www.grandlisboahotels.com/'},
 {'Restaurant Name': 'Pearl Dragon',
  'Price Range': '300 - 1,388 MOP',
  'Restauarant Website': 'https://www.studiocity-macau.com/'},
 {'Restaurant Name': 'Ying',
  'Price Range': '300 - 2,000 MOP',
  'Restauarant Website': 'https://www.altiramacau.com/'},
 {'Restaurant Name': 'Liu Yuan Pavilion',
  'Price Range': '200 - 750 HKD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Vea',
  'Price Range': '1,680 HKD',
  'Restauarant Website': 'https://www.vea.hk/'},
 {'Restaurant Name': 'Épure',
  'Price Range': '498 - 1,888 HKD',
  'Restauarant Website': 'http://www.epure.hk/'},
 {'Restaurant Name': "Pang's Kitchen",
  'Price Range': '98 - 500 HKD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'New Punjab Club',
  'Price Range': '600 - 800 HKD',
  'Restauarant Website': 'https://www.newpunjabclub.com/'},
 {'Restaurant Name': 'Man Wah',
  'Price Range': '500 - 3,288 HKD',
  'Restauarant Website': 'https://www.mandarinoriental.com/hongkong'},
 {'Restaurant Name': 'Rùn',
  'Price Range': '400 - 1,400 HKD',
  'Restauarant Website': 'www.stregishongkong.com'},
 {'Restaurant Name': 'Ming Court (Mong Kok)',
  'Price Range': '350 - 1,400 HKD',
  'Restauarant Website': 'https://www.cordishotels.com/en/hong-kong'},
 {'Restaurant Name': 'Shang Palace',
  'Price Range': '400 - 1,388 HKD',
  'Restauarant Website': 'www.shangri-la.com/kowloon'},
 {'Restaurant Name': 'Summer Palace',
  'Price Range': '300 - 1,500 HKD',
  'Restauarant Website': 'https://www.shangri-la.com/island'},
 {'Restaurant Name': 'Ryota Kappou Modern',
  'Price Range': '580 - 2,380 HKD',
  'Restauarant Website': 'https://www.ryota.hk/'},
 {'Restaurant Name': 'Imperial Treasure Fine Chinese Cuisine (Tsim Sha Tsui)',
  'Price Range': '200 - 1,000 HKD',
  'Restauarant Website': 'https://www.imperialtreasure.com/'},
 {'Restaurant Name': 'Andō',
  'Price Range': '788 - 1,888 HKD',
  'Restauarant Website': 'www.andohk.com'},
 {'Restaurant Name': 'Man Ho (Admiralty)',
  'Price Range': '300 - 1,580 HKD',
  'Restauarant Website': 'https://www.jwmarriotthongkong.com/dining'},
 {'Restaurant Name': 'Louise',
  'Price Range': '750 - 1,588 HKD',
  'Restauarant Website': 'https://www.louise.hk/'},
 {'Restaurant Name': 'Spring Moon',
  'Price Range': '400 - 2,188 HKD',
  'Restauarant Website': 'https://www.peninsula.com/hongkong'},
 {'Restaurant Name': 'Yardbird',
  'Price Range': '350 - 500 HKD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Arcane',
  'Price Range': '458 - 1,200 HKD',
  'Restauarant Website': 'https://www.arcane.hk/'},
 {'Restaurant Name': 'Petrus',
  'Price Range': '588 - 2,188 HKD',
  'Restauarant Website': 'www.shangri-la.com/island'},
 {'Restaurant Name': 'Mandarin Grill + Bar',
  'Price Range': '598 - 1,988 HKD',
  'Restauarant Website': 'https://www.mandarinoriental.com/hongkong'},
 {'Restaurant Name': 'Ah Yat Harbour View',
  'Price Range': '400 - 2,200 HKD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Xin Rong Ji',
  'Price Range': '500 - 1,500 HKD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Octavium',
  'Price Range': '560 - 1,888 HKD',
  'Restauarant Website': 'www.octavium.com.hk'},
 {'Restaurant Name': 'Loaf On',
  'Price Range': '200 - 500 HKD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Roganic',
  'Price Range': '320 - 980 HKD',
  'Restauarant Website': 'https://www.roganic.com.hk/'},
 {'Restaurant Name': "Kam's Roast Goose",
  'Price Range': '65 - 200 HKD',
  'Restauarant Website': 'https://www.krg.com.hk/'},
 {'Restaurant Name': 'Fook Lam Moon (Wan Chai)',
  'Price Range': '400 - 2,000 HKD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Lei Garden (Kwun Tong)',
  'Price Range': '150 - 550 HKD',
  'Restauarant Website': 'www.leigarden.com.hk'},
 {'Restaurant Name': 'Yat Lok',
  'Price Range': '70 - 360 HKD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Takumi by Daisuke Mori',
  'Price Range': '2,080 HKD',
  'Restauarant Website': 'https://www.takumibymori.com/'},
 {'Restaurant Name': 'Yan Toh Heen',
  'Price Range': '400 - 2,000 HKD',
  'Restauarant Website': 'https://hongkong-ic.intercontinental.com/zh-hant/'},
 {'Restaurant Name': 'Beefbar',
  'Price Range': '330 - 1,500 HKD',
  'Restauarant Website': 'http://www.beefbar.hk/'},
 {'Restaurant Name': 'The Chairman',
  'Price Range': '358 - 1,200 HKD',
  'Restauarant Website': 'www.thechairmangroup.com'},
 {'Restaurant Name': 'Jardin de Jade (Wan Chai)',
  'Price Range': '200 - 400 HKD',
  'Restauarant Website': 'http://www.jade388.com/'},
 {'Restaurant Name': 'Tosca di Angelo',
  'Price Range': '638 - 1,888 HKD',
  'Restauarant Website': 'https://www.ritzcarlton.com/hongkong'},
 {'Restaurant Name': 'Yè Shanghai (Tsim Sha Tsui)',
  'Price Range': '200 - 800 HKD',
  'Restauarant Website': 'https://www.elite-concepts.com/'},
 {'Restaurant Name': 'Zest by Konishi',
  'Price Range': '480 - 1,880 HKD',
  'Restauarant Website': 'https://zestbykonishihk.com/'},
 {'Restaurant Name': 'Zhejiang Heen',
  'Price Range': '200 - 800 HKD',
  'Restauarant Website': 'https://www.zhejiangheen.com/'},
 {'Restaurant Name': 'Ho Hung Kee (Causeway Bay)',
  'Price Range': '100 - 200 HKD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Celebrity Cuisine',
  'Price Range': '200 - 1,000 HKD',
  'Restauarant Website': 'www.lankwaifonghotel.com.hk'},
 {'Restaurant Name': 'Fu Ho',
  'Price Range': '300 - 1,500 HKD',
  'Restauarant Website': 'www.fuho.com.hk'},
 {'Restaurant Name': 'Tim Ho Wan (Sham Shui Po)',
  'Price Range': '50 - 100 HKD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Aaharn',
  'Price Range': '348 - 800 HKD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': "Gaddi's",
  'Price Range': '608 - 2,088 HKD',
  'Restauarant Website': 'https://www.peninsula.com/hongkong'},
 {'Restaurant Name': 'The Araki',
  'Price Range': '4,000 HKD',
  'Restauarant Website': 'http://www.house1881.com/'},
 {'Restaurant Name': 'Yat Tung Heen',
  'Price Range': '400 - 1,200 HKD',
  'Restauarant Website': 'https://www.yattungheen.com/'},
 {'Restaurant Name': 'Zuicho',
  'Price Range': '1,800 - 2,500 HKD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': "Duddell's",
  'Price Range': '398 - 1,500 HKD',
  'Restauarant Website': 'www.duddells.co'},
 {'Restaurant Name': 'Chestnut',
  'Price Range': '100 EUR',
  'Restauarant Website': 'https://www.restaurantchestnutwestcork.ie/'},
 {'Restaurant Name': 'Aniar',
  'Price Range': '110 EUR',
  'Restauarant Website': 'https://www.aniarrestaurant.ie/'},
 {'Restaurant Name': 'House',
  'Price Range': '130 EUR',
  'Restauarant Website': 'https://www.cliffhousehotel.ie/'},
 {'Restaurant Name': 'dede',
  'Price Range': '95 EUR',
  'Restauarant Website': 'https://customshousebaltimore.com/'},
 {'Restaurant Name': 'Bastion',
  'Price Range': '100 EUR',
  'Restauarant Website': 'http://www.bastionkinsale.com/'},
 {'Restaurant Name': 'The Oak Room',
  'Price Range': '100 - 120 EUR',
  'Restauarant Website': 'https://www.adaremanor.com/'},
 {'Restaurant Name': 'Liath',
  'Price Range': '55 - 120 EUR',
  'Restauarant Website': 'https://www.liathrestaurant.com/'},
 {'Restaurant Name': 'Campagne',
  'Price Range': '45 - 68 EUR',
  'Restauarant Website': 'https://www.campagne.ie/'},
 {'Restaurant Name': 'Ichigo Ichie',
  'Price Range': '120 - 135 EUR',
  'Restauarant Website': 'https://www.ichigoichie.ie/'},
 {'Restaurant Name': 'Variety Jones',
  'Price Range': '60 EUR',
  'Restauarant Website': 'https://www.varietyjones.ie/'},
 {'Restaurant Name': 'Lady Helen',
  'Price Range': '90 - 130 EUR',
  'Restauarant Website': 'https://www.mountjuliet.ie/'},
 {'Restaurant Name': 'Loam',
  'Price Range': '58 - 99 EUR',
  'Restauarant Website': 'https://www.loamgalway.com/'},
 {'Restaurant Name': 'Wild Honey Inn',
  'Price Range': '70 - 80 EUR',
  'Restauarant Website': 'https://www.wildhoneyinn.com/'},
 {'Restaurant Name': 'Olive Tree',
  'Price Range': '34 - 110 GBP',
  'Restauarant Website': 'https://www.olivetreebath.co.uk/'},
 {'Restaurant Name': 'Brat',
  'Price Range': '32 - 85 GBP',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'The Neptune',
  'Price Range': '65 - 80 GBP',
  'Restauarant Website': 'https://www.theneptune.co.uk/'},
 {'Restaurant Name': 'The Cellar',
  'Price Range': '50 - 80 GBP',
  'Restauarant Website': 'https://www.thecellaranstruther.co.uk/'},
 {'Restaurant Name': 'The Man Behind The Curtain',
  'Price Range': '88 - 132 GBP',
  'Restauarant Website': 'https://www.themanbehindthecurtain.co.uk/'},
 {'Restaurant Name': "L'Ortolan",
  'Price Range': '60 - 89 GBP',
  'Restauarant Website': 'https://www.lortolan.com/'},
 {'Restaurant Name': 'Seven Park Place',
  'Price Range': '35 - 95 GBP',
  'Restauarant Website': 'https://www.stjameshotelandclub.com/'},
 {'Restaurant Name': 'The Cross at Kenilworth',
  'Price Range': '35 - 65 GBP',
  'Restauarant Website': 'https://www.thecrosskenilworth.co.uk/'},
 {'Restaurant Name': 'Muse',
  'Price Range': '50 - 145 GBP',
  'Restauarant Website': 'https://www.musebytomaikens.co.uk/'},
 {'Restaurant Name': 'The Ninth',
  'Price Range': '35 - 59 GBP',
  'Restauarant Website': 'https://www.theninthlondon.com/'},
 {'Restaurant Name': 'Chez Bruce',
  'Price Range': '50 - 65 GBP',
  'Restauarant Website': 'https://www.chezbruce.co.uk/'},
 {'Restaurant Name': 'Sosban & The Old Butchers',
  'Price Range': '59 - 145 GBP',
  'Restauarant Website': 'https://www.sosbanandtheoldbutchers.com/'},
 {'Restaurant Name': 'Clock House',
  'Price Range': '50 - 110 GBP',
  'Restauarant Website': 'https://www.theclockhouserestaurant.co.uk/'},
 {'Restaurant Name': 'Le Champignon Sauvage',
  'Price Range': '40 - 75 GBP',
  'Restauarant Website': 'https://www.lechampignonsauvage.co.uk/'},
 {'Restaurant Name': 'Opheem',
  'Price Range': '45 - 115 GBP',
  'Restauarant Website': 'https://www.opheem.com/'},
 {'Restaurant Name': 'Lympstone Manor',
  'Price Range': '65 - 160 GBP',
  'Restauarant Website': 'https://www.lympstonemanor.co.uk/'},
 {'Restaurant Name': 'The Whitebrook',
  'Price Range': '47 - 95 GBP',
  'Restauarant Website': 'https://www.thewhitebrook.co.uk/'},
 {'Restaurant Name': 'Tony Parkin at The Tudor Room',
  'Price Range': '50 - 120 GBP',
  'Restauarant Website': 'https://www.alexanderhotels.co.uk/'},
 {'Restaurant Name': 'Interlude',
  'Price Range': '145 GBP',
  'Restauarant Website': 'https://www.restaurant-interlude.co.uk/'},
 {'Restaurant Name': 'Restaurant Tristan',
  'Price Range': '50 - 100 GBP',
  'Restauarant Website': 'https://www.restauranttristan.co.uk/'},
 {'Restaurant Name': 'Club Gascon',
  'Price Range': '70 - 95 GBP',
  'Restauarant Website': 'https://www.clubgascon.com/'},
 {'Restaurant Name': 'Harwood Arms',
  'Price Range': '50 GBP',
  'Restauarant Website': 'https://www.harwoodarms.com/'},
 {'Restaurant Name': 'Ikoyi',
  'Price Range': '60 - 150 GBP',
  'Restauarant Website': 'https://www.ikoyilondon.com/'},
 {'Restaurant Name': 'Hjem',
  'Price Range': '85 GBP',
  'Restauarant Website': 'https://www.restauranthjem.co.uk/'},
 {'Restaurant Name': 'Davies and Brook',
  'Price Range': '110 - 145 GBP',
  'Restauarant Website': 'https://www.daviesandbrook.co.uk/'},
 {'Restaurant Name': 'Kitchen W8',
  'Price Range': '30 - 80 GBP',
  'Restauarant Website': 'https://www.kitchenw8.com/'},
 {'Restaurant Name': "Purnell's",
  'Price Range': '45 - 95 GBP',
  'Restauarant Website': 'https://www.purnellsrestaurant.com/'},
 {'Restaurant Name': 'Mãos',
  'Price Range': '170 GBP',
  'Restauarant Website': 'https://www.bluemountain.school/maos'},
 {'Restaurant Name': 'Coworth Park',
  'Price Range': '85 GBP',
  'Restauarant Website': 'http://www.dorchestercollection.com/'},
 {'Restaurant Name': 'Salt',
  'Price Range': '48 - 85 GBP',
  'Restauarant Website': 'https://www.salt-restaurant.co.uk/'},
 {'Restaurant Name': 'Benares',
  'Price Range': '39 - 100 GBP',
  'Restauarant Website': 'https://www.benaresrestaurant.com/'},
 {'Restaurant Name': 'Gymkhana',
  'Price Range': '33 - 85 GBP',
  'Restauarant Website': 'https://www.gymkhanalondon.com/'},
 {'Restaurant Name': 'Condita',
  'Price Range': '110 GBP',
  'Restauarant Website': 'https://www.condita.co.uk/'},
 {'Restaurant Name': 'Lei Garden',
  'Price Range': '60 - 120 SGD',
  'Restauarant Website': 'https://www.leigarden.hk/'},
 {'Restaurant Name': 'Whitegrass',
  'Price Range': '68 - 218 SGD',
  'Restauarant Website': 'www.whitegrass.com.sg'},
 {'Restaurant Name': 'Shinji (Bras Basah Road)',
  'Price Range': '90 - 650 SGD',
  'Restauarant Website': 'https://www.shinjibykanesaka.com/'},
 {'Restaurant Name': 'Candlenut',
  'Price Range': '50 - 98 SGD',
  'Restauarant Website': 'https://www.comodempsey.sg/'},
 {'Restaurant Name': 'Garibaldi',
  'Price Range': '39 - 240 SGD',
  'Restauarant Website': 'https://www.garibaldi.com.sg/'},
 {'Restaurant Name': 'Béni',
  'Price Range': '108 - 268 SGD',
  'Restauarant Website': 'https://www.beni-sg.com/'},
 {'Restaurant Name': 'Summer Palace',
  'Price Range': '56 - 398 SGD',
  'Restauarant Website': 'https://www.regenthotels.com/'},
 {'Restaurant Name': 'Imperial Treasure Fine Teochew Cuisine (Orchard)',
  'Price Range': '30 - 128 SGD',
  'Restauarant Website': 'https://www.imperialtreasure.com/'},
 {'Restaurant Name': 'Shinji (Tanglin Road)',
  'Price Range': '125 - 550 SGD',
  'Restauarant Website': 'https://www.shinjibykanesaka.com/'},
 {'Restaurant Name': 'Sushi Ichi',
  'Price Range': '100 - 430 SGD',
  'Restauarant Website': 'http://www.ginza-sushiichi.jp/'},
 {'Restaurant Name': "Iggy's",
  'Price Range': '105 - 285 SGD',
  'Restauarant Website': 'https://www.iggys.com.sg/'},
 {'Restaurant Name': '28 Wilkie',
  'Price Range': '158 - 198 SGD',
  'Restauarant Website': 'https://www.28wilkie.com/'},
 {'Restaurant Name': 'Sushi Kimura',
  'Price Range': '180 - 400 SGD',
  'Restauarant Website': 'https://www.sushikimura.com.sg/'},
 {'Restaurant Name': "Chef Kang's",
  'Price Range': '80 - 120 SGD',
  'Restauarant Website': 'https://www.chef-kang.com/'},
 {'Restaurant Name': 'Alma',
  'Price Range': '78 - 258 SGD',
  'Restauarant Website': 'https://www.alma.sg/'},
 {'Restaurant Name': 'Shang Palace',
  'Price Range': '50 - 328 SGD',
  'Restauarant Website': 'https://www.shangri-la.com/singapore'},
 {'Restaurant Name': 'Buona Terra',
  'Price Range': '88 - 178 SGD',
  'Restauarant Website': 'https://www.buonaterra.com.sg/'},
 {'Restaurant Name': 'Corner House',
  'Price Range': '118 - 248 SGD',
  'Restauarant Website': 'https://www.cornerhouse.com.sg/'},
 {'Restaurant Name': 'Hill Street Tai Hwa Pork Noodle',
  'Price Range': '6 - 10 SGD',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Oshino',
  'Price Range': '180 - 500 SGD',
  'Restauarant Website': 'www.oshino.sg'},
 {'Restaurant Name': 'Dysart Petersham',
  'Price Range': '45 - 95 GBP',
  'Restauarant Website': 'https://www.thedysartpetersham.co.uk/'},
 {'Restaurant Name': 'Hakkasan Mayfair',
  'Price Range': '38 - 128 GBP',
  'Restauarant Website': 'https://www.hakkasan.com/'},
 {'Restaurant Name': 'Casa Fofō',
  'Price Range': '45 GBP',
  'Restauarant Website': 'https://www.casafofolondon.co.uk/'},
 {'Restaurant Name': 'Hambleton Hall',
  'Price Range': '48 - 83 GBP',
  'Restauarant Website': 'https://www.hambletonhall.com/'},
 {'Restaurant Name': 'Thomas Carr 1873',
  'Price Range': '95 GBP',
  'Restauarant Website': 'https://www.thomascarrdining.co.uk/'},
 {'Restaurant Name': 'Rogan & Co',
  'Price Range': '34 - 63 GBP',
  'Restauarant Website': 'https://www.roganandco.co.uk/'},
 {'Restaurant Name': 'Allium at Askham Hall',
  'Price Range': '95 GBP',
  'Restauarant Website': 'https://www.askhamhall.co.uk/'},
 {'Restaurant Name': 'Amaya',
  'Price Range': '29 - 82 GBP',
  'Restauarant Website': 'https://www.amaya.biz/'},
 {'Restaurant Name': 'The Muddlers Club',
  'Price Range': '65 GBP',
  'Restauarant Website': 'https://www.themuddlersclubbelfast.com/'},
 {'Restaurant Name': 'Dining Room at The Goring',
  'Price Range': '52 - 78 GBP',
  'Restauarant Website': 'https://www.thegoring.com/'},
 {'Restaurant Name': 'The Peat Inn',
  'Price Range': '29 - 78 GBP',
  'Restauarant Website': 'https://www.thepeatinn.co.uk/'},
 {'Restaurant Name': 'Restaurant Hywel Jones by Lucknam Park',
  'Price Range': '110 GBP',
  'Restauarant Website': 'https://www.lucknampark.co.uk/'},
 {'Restaurant Name': 'Céleste',
  'Price Range': '43 - 125 GBP',
  'Restauarant Website': 'https://www.oetkercollection.com/hotels/the-lanesborough/restaurants-bars/restaurants/celeste/'},
 {'Restaurant Name': 'Cail Bruich',
  'Price Range': '60 - 90 GBP',
  'Restauarant Website': 'https://www.cailbruich.co.uk/'},
 {'Restaurant Name': 'mana',
  'Price Range': '155 GBP',
  'Restauarant Website': 'https://www.manarestaurant.co.uk/'},
 {'Restaurant Name': 'Galvin La Chapelle',
  'Price Range': '43 - 89 GBP',
  'Restauarant Website': 'https://www.galvinrestaurants.com/'},
 {'Restaurant Name': 'Paul Ainsworth at No.6',
  'Price Range': '85 - 95 GBP',
  'Restauarant Website': 'https://www.paul-ainsworth.co.uk/'},
 {'Restaurant Name': 'Latymer',
  'Price Range': '85 - 130 GBP',
  'Restauarant Website': 'https://latymerrestaurant.co.uk'},
 {'Restaurant Name': 'Ritz Restaurant',
  'Price Range': '56 - 115 GBP',
  'Restauarant Website': 'https://www.theritzlondon.com/'},
 {'Restaurant Name': 'Behind',
  'Price Range': '42 - 74 GBP',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Isle of Eriska',
  'Price Range': '20 - 80 GBP',
  'Restauarant Website': 'www.eriska-hotel.co.uk'},
 {'Restaurant Name': 'Carters of Moseley',
  'Price Range': '120 GBP',
  'Restauarant Website': 'https://www.cartersofmoseley.co.uk/'},
 {'Restaurant Name': 'Star Inn at Harome',
  'Price Range': '36 - 78 GBP',
  'Restauarant Website': 'https://www.thestaratharome.co.uk/'},
 {'Restaurant Name': 'Veeraswamy',
  'Price Range': '30 - 78 GBP',
  'Restauarant Website': 'https://www.veeraswamy.com/'},
 {'Restaurant Name': 'Bohemia',
  'Price Range': '45 - 99 GBP',
  'Restauarant Website': 'https://www.bohemiajersey.com/'},
 {'Restaurant Name': 'Black Swan',
  'Price Range': '125 - 140 GBP',
  'Restauarant Website': 'https://www.blackswanoldstead.co.uk/'},
 {'Restaurant Name': 'Paco Tapas',
  'Price Range': '25 - 60 GBP',
  'Restauarant Website': 'www.pacotapas.co.uk'},
 {'Restaurant Name': 'The Angel',
  'Price Range': '44 - 80 GBP',
  'Restauarant Website': 'https://www.angelhetton.co.uk/'},
 {'Restaurant Name': 'Pensons',
  'Price Range': '45 - 75 GBP',
  'Restauarant Website': 'www.pensons.co.uk'},
 {'Restaurant Name': 'Fordwich Arms',
  'Price Range': '54 - 190 GBP',
  'Restauarant Website': 'www.fordwicharms.co.uk'},
 {'Restaurant Name': 'hide and fox',
  'Price Range': '58 - 85 GBP',
  'Restauarant Website': 'https://www.hideandfox.co.uk/'},
 {'Restaurant Name': 'City Social',
  'Price Range': '60 - 78 GBP',
  'Restauarant Website': 'https://www.citysociallondon.com/'},
 {'Restaurant Name': 'Pea Porridge',
  'Price Range': '30 - 75 GBP',
  'Restauarant Website': 'www.peaporridge.co.uk'},
 {'Restaurant Name': 'Quilon',
  'Price Range': '41 - 95 GBP',
  'Restauarant Website': 'http://www.quilon.co.uk/'},
 {'Restaurant Name': 'Umu',
  'Price Range': '57 - 200 GBP',
  'Restauarant Website': 'https://www.umurestaurant.com/'},
 {'Restaurant Name': 'Murano',
  'Price Range': '45 - 105 GBP',
  'Restauarant Website': 'https://www.muranolondon.com/'},
 {'Restaurant Name': 'Elephant',
  'Price Range': '28 - 80 GBP',
  'Restauarant Website': 'https://www.elephantrestaurant.co.uk/'},
 {'Restaurant Name': 'Winteringham Fields',
  'Price Range': '65 - 95 GBP',
  'Restauarant Website': 'https://www.winteringhamfields.co.uk/'},
 {'Restaurant Name': 'Pied à Terre',
  'Price Range': '30 - 95 GBP',
  'Restauarant Website': 'https://www.pied-a-terre.co.uk/'},
 {'Restaurant Name': 'Cottage in the Wood',
  'Price Range': '50 - 95 GBP',
  'Restauarant Website': 'https://www.thecottageinthewood.co.uk/'},
 {'Restaurant Name': 'Leroy',
  'Price Range': '25 - 48 GBP',
  'Restauarant Website': 'https://www.leroyshoreditch.com/'},
 {'Restaurant Name': 'Pollen Street Social',
  'Price Range': '56 - 135 GBP',
  'Restauarant Website': 'https://www.pollenstreetsocial.com/'},
 {'Restaurant Name': 'Northcote',
  'Price Range': '45 - 95 GBP',
  'Restauarant Website': 'https://www.northcote.com/'},
 {'Restaurant Name': 'Kai',
  'Price Range': '58 - 120 GBP',
  'Restauarant Website': 'https://www.kaimayfair.co.uk/'},
 {'Restaurant Name': 'St John',
  'Price Range': '32 - 50 GBP',
  'Restauarant Website': 'https://www.stjohnrestaurant.com/'},
 {'Restaurant Name': 'Old Stamp House',
  'Price Range': '45 - 75 GBP',
  'Restauarant Website': 'https://www.oldstamphouse.com/'},
 {'Restaurant Name': 'Portland',
  'Price Range': '39 - 65 GBP',
  'Restauarant Website': 'https://www.portlandrestaurant.co.uk/'},
 {'Restaurant Name': 'The Clove Club',
  'Price Range': '65 - 145 GBP',
  'Restauarant Website': 'https://www.thecloveclub.com/'},
 {'Restaurant Name': 'Stark',
  'Price Range': '65 GBP',
  'Restauarant Website': 'www.starkfood.co.uk'},
 {'Restaurant Name': 'Pétrus by Gordon Ramsay',
  'Price Range': '55 - 120 GBP',
  'Restauarant Website': 'https://www.gordonramsayrestaurants.com/petrus'},
 {'Restaurant Name': 'HRiSHi',
  'Price Range': '75 - 95 GBP',
  'Restauarant Website': 'https://www.thegilpin.co.uk/'},
 {'Restaurant Name': 'Hakkasan Hanway Place',
  'Price Range': '35 - 135 GBP',
  'Restauarant Website': 'https://www.hakkasan.com/'},
 {'Restaurant Name': "Outlaw's Fish Kitchen",
  'Price Range': '80 GBP',
  'Restauarant Website': 'https://www.outlaws.co.uk/restaurants/fish-kitchen'},
 {'Restaurant Name': 'Masons Arms',
  'Price Range': '30 - 55 GBP',
  'Restauarant Website': 'https://www.masonsarmsdevon.co.uk/'},
 {'Restaurant Name': 'Bulrush',
  'Price Range': '60 GBP',
  'Restauarant Website': 'https://www.bulrushrestaurant.co.uk/'},
 {'Restaurant Name': "Outlaw's New Road",
  'Price Range': '80 GBP',
  'Restauarant Website': 'https://www.outlaws.co.uk/restaurants/new-road'},
 {'Restaurant Name': 'Trishna',
  'Price Range': '30 - 75 GBP',
  'Restauarant Website': 'https://www.trishnalondon.com/'},
 {'Restaurant Name': 'Roots',
  'Price Range': '95 - 110 GBP',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Trinity',
  'Price Range': '55 - 95 GBP',
  'Restauarant Website': 'https://www.trinityrestaurant.co.uk/'},
 {'Restaurant Name': 'Walnut Tree',
  'Price Range': '35 - 60 GBP',
  'Restauarant Website': 'https://www.thewalnuttreeinn.com/'},
 {'Restaurant Name': 'Forest Side',
  'Price Range': '45 - 95 GBP',
  'Restauarant Website': 'https://www.theforestside.com/'},
 {'Restaurant Name': 'Five Fields',
  'Price Range': '95 - 120 GBP',
  'Restauarant Website': 'https://www.fivefieldsrestaurant.com/'},
 {'Restaurant Name': 'alchemilla',
  'Price Range': '85 - 110 GBP',
  'Restauarant Website': 'www.alchemillarestaurant.uk'},
 {'Restaurant Name': 'Sabor',
  'Price Range': '35 - 60 GBP',
  'Restauarant Website': 'https://www.saborrestaurants.co.uk/'},
 {'Restaurant Name': 'The Woodspeen',
  'Price Range': '30 - 70 GBP',
  'Restauarant Website': 'https://www.thewoodspeen.com/'},
 {'Restaurant Name': 'Number One',
  'Price Range': '110 GBP',
  'Restauarant Website': 'https://www.roccofortehotels.com/hotels-and-resorts/the-balmoral-hotel/restaurants-and-bars/number-one/'},
 {'Restaurant Name': "Peel's",
  'Price Range': '95 - 125 GBP',
  'Restauarant Website': 'https://www.hamptonmanor.com/'},
 {'Restaurant Name': 'Hinds Head',
  'Price Range': '52 - 83 GBP',
  'Restauarant Website': 'https://www.hindsheadbray.com/'},
 {'Restaurant Name': 'Above at HIDE',
  'Price Range': '48 - 140 GBP',
  'Restauarant Website': 'https://www.hide.co.uk/'},
 {'Restaurant Name': 'The Coach',
  'Price Range': '28 - 50 GBP',
  'Restauarant Website': 'https://www.thecoachmarlow.co.uk/'},
 {'Restaurant Name': 'Marcus',
  'Price Range': '55 - 125 GBP',
  'Restauarant Website': 'https://www.marcusrestaurant.com/'},
 {'Restaurant Name': 'Cornerstone',
  'Price Range': '39 - 58 GBP',
  'Restauarant Website': 'https://www.cornerstonehackney.com/'},
 {'Restaurant Name': 'The Glasshouse',
  'Price Range': '45 - 60 GBP',
  'Restauarant Website': 'https://www.glasshouserestaurant.co.uk/'},
 {'Restaurant Name': "Lyle's",
  'Price Range': '35 - 79 GBP',
  'Restauarant Website': 'https://www.lyleslondon.com/'},
 {'Restaurant Name': 'Eipic',
  'Price Range': '29 - 80 GBP',
  'Restauarant Website': 'https://www.deaneseipic.com/'},
 {'Restaurant Name': 'Artichoke',
  'Price Range': '55 - 85 GBP',
  'Restauarant Website': 'https://www.artichokerestaurant.co.uk/'},
 {'Restaurant Name': 'Martin Wishart',
  'Price Range': '39 - 95 GBP',
  'Restauarant Website': 'https://www.restaurantmartinwishart.co.uk/'},
 {'Restaurant Name': 'SO|LA',
  'Price Range': '89 - 139 GBP',
  'Restauarant Website': 'https://www.solasoho.com/'},
 {'Restaurant Name': 'Gravetye Manor',
  'Price Range': '60 - 95 GBP',
  'Restauarant Website': 'https://www.gravetyemanor.co.uk/'},
 {'Restaurant Name': 'Barrafina',
  'Price Range': '20 - 40 GBP',
  'Restauarant Website': 'https://www.barrafina.co.uk/'},
 {'Restaurant Name': 'Simpsons',
  'Price Range': '55 - 115 GBP',
  'Restauarant Website': 'https://www.simpsonsrestaurant.co.uk/'},
 {'Restaurant Name': 'Beach House',
  'Price Range': '62 - 95 GBP',
  'Restauarant Website': 'https://www.beachhouseoxwich.co.uk/'},
 {'Restaurant Name': 'Elystan Street',
  'Price Range': '35 - 105 GBP',
  'Restauarant Website': 'https://www.elystanstreet.com/'},
 {'Restaurant Name': 'Casamia',
  'Price Range': '180 GBP',
  'Restauarant Website': 'www.casamiarestaurant.co.uk'},
 {'Restaurant Name': 'House of Tides',
  'Price Range': '85 - 110 GBP',
  'Restauarant Website': 'https://www.houseoftides.co.uk/'},
 {'Restaurant Name': 'OX',
  'Price Range': '30 - 65 GBP',
  'Restauarant Website': 'https://www.oxbelfast.com/'},
 {'Restaurant Name': 'Crown',
  'Price Range': '38 - 49 GBP',
  'Restauarant Website': 'https://www.thecrownburchettsgreen.com/'},
 {'Restaurant Name': 'Osip',
  'Price Range': '54 - 110 GBP',
  'Restauarant Website': 'www.osiprestaurant.com'},
 {'Restaurant Name': "La Table d'Antonio Salvatore au Rampoldi",
  'Price Range': '120 - 220 EUR',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Yannick Alléno à l’Hôtel Hermitage Monte-Carlo',
  'Price Range': '68 - 235 EUR',
  'Restauarant Website': 'http://www.montecarloresort.com/'},
 {'Restaurant Name': 'Le Blue Bay',
  'Price Range': '110 - 180 EUR',
  'Restauarant Website': 'https://www.montecarlobay.com/'},
 {'Restaurant Name': 'Yoshi',
  'Price Range': '54 - 240 EUR',
  'Restauarant Website': 'https://www.metropole.com/'},
 {'Restaurant Name': 'Le Grill',
  'Price Range': '68 - 210 EUR',
  'Restauarant Website': 'https://www.hoteldeparismontecarlo.com/'},
 {'Restaurant Name': 'Le Georges',
  'Price Range': '59 - 124 EUR',
  'Restauarant Website': 'http://www.monarque.fr/'},
 {'Restaurant Name': 'Pages',
  'Price Range': '65 - 150 EUR',
  'Restauarant Website': 'https://www.restaurantpages.fr/'},
 {'Restaurant Name': "L'Arcane",
  'Price Range': '55 - 155 EUR',
  'Restauarant Website': 'https://www.restaurantlarcane.com/'},
 {'Restaurant Name': 'Hostellerie de Levernois',
  'Price Range': '75 - 125 EUR',
  'Restauarant Website': 'https://www.levernois.com/'},
 {'Restaurant Name': 'Trente-Trois',
  'Price Range': '68 - 118 EUR',
  'Restauarant Website': 'https://www.restaurant-trente-trois.com/'},
 {'Restaurant Name': "L'Auberge de Bagatelle",
  'Price Range': '45 - 100 EUR',
  'Restauarant Website': 'https://www.aubergedebagatelle.fr/'},
 {'Restaurant Name': 'Mavrommatis',
  'Price Range': '45 - 125 EUR',
  'Restauarant Website': 'https://www.mavrommatis.com/'},
 {'Restaurant Name': "Reflet d'Obione",
  'Price Range': '31 - 82 EUR',
  'Restauarant Website': 'https://www.reflet-obione.com/'},
 {'Restaurant Name': 'Côté Jardin',
  'Price Range': '49 - 85 EUR',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': "L'Ardoise du Marché",
  'Price Range': '28 - 75 EUR',
  'Restauarant Website': 'https://www.ardoise-du-marche.com/'},
 {'Restaurant Name': 'Le Duèze - Château de Mercuès',
  'Price Range': '110 - 160 EUR',
  'Restauarant Website': 'https://www.chateaudemercues.com/'},
 {'Restaurant Name': 'Cyril Attrazic',
  'Price Range': '48 - 118 EUR',
  'Restauarant Website': 'https://www.camillou.com/'},
 {'Restaurant Name': 'Le Saint-Estève',
  'Price Range': '80 - 165 EUR',
  'Restauarant Website': 'https://www.leslodgessaintevictoire.com/'},
 {'Restaurant Name': 'Abri',
  'Price Range': '50 - 70 EUR',
  'Restauarant Website': 'https://www.abrirestaurant.fr/'},
 {'Restaurant Name': 'Le Cénacle',
  'Price Range': '39 - 110 EUR',
  'Restauarant Website': 'www.cite-hotels.com/fr/etablissements/restaurant-la-cenacle.html'},
 {'Restaurant Name': 'Le Vieux Logis',
  'Price Range': '55 - 140 EUR',
  'Restauarant Website': 'https://www.vieux-logis.com/'},
 {'Restaurant Name': "L'Amaryllis",
  'Price Range': '40 - 130 EUR',
  'Restauarant Website': 'https://www.lamaryllis.com/'},
 {'Restaurant Name': 'Yoshinori',
  'Price Range': '50 - 150 EUR',
  'Restauarant Website': 'https://www.yoshinori-paris.com/'},
 {'Restaurant Name': 'À Contre Sens',
  'Price Range': '27 - 70 EUR',
  'Restauarant Website': 'https://www.acontresens.fr/'},
 {'Restaurant Name': 'Intuition',
  'Price Range': '44 - 72 EUR',
  'Restauarant Website': 'http://www.restaurant-intuition.com/'},
 {'Restaurant Name': 'Le Restaurant du Cerisier',
  'Price Range': '55 - 109 EUR',
  'Restauarant Website': 'https://www.lecerisier.com/'},
 {'Restaurant Name': 'The Marcel',
  'Price Range': '38 - 100 EUR',
  'Restauarant Website': 'https://www.the-marcel.fr/'},
 {'Restaurant Name': 'Têtedoie',
  'Price Range': '48 - 130 EUR',
  'Restauarant Website': 'https://www.tetedoie.com/'},
 {'Restaurant Name': 'Au Vieux Couvent',
  'Price Range': '39 - 127 EUR',
  'Restauarant Website': 'https://www.vieuxcouvent.fr/'},
 {'Restaurant Name': 'Holen',
  'Price Range': '35 - 85 EUR',
  'Restauarant Website': 'https://restaurant-holen.fr'},
 {'Restaurant Name': 'Dan B. - La Table de Ventabren',
  'Price Range': '54 - 117 EUR',
  'Restauarant Website': 'https://www.danb.fr/'},
 {'Restaurant Name': 'La Chaumière',
  'Price Range': '34 - 140 EUR',
  'Restauarant Website': 'https://www.lachaumiere-dole.fr/'},
 {'Restaurant Name': 'La Mirande',
  'Price Range': '60 - 160 EUR',
  'Restauarant Website': 'https://www.la-mirande.fr/'},
 {'Restaurant Name': 'Restaurant De Lauzun',
  'Price Range': '36 - 110 EUR',
  'Restauarant Website': 'https://www.restaurant-delauzun.com/'},
 {'Restaurant Name': "L'Épuisette",
  'Price Range': '75 - 145 EUR',
  'Restauarant Website': 'https://www.l-epuisette.fr/'},
 {'Restaurant Name': 'Jacques Faussat',
  'Price Range': '42 - 65 EUR',
  'Restauarant Website': 'https://www.jacquesfaussat.com/'},
 {'Restaurant Name': 'Auberge de la Tour',
  'Price Range': '79 - 109 EUR',
  'Restauarant Website': 'https://www.aubergedela-tour.com/'},
 {'Restaurant Name': 'Shabour',
  'Price Range': '59 - 96 EUR',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'NESO',
  'Price Range': '135 - 180 EUR',
  'Restauarant Website': 'https://www.neso.paris/'},
 {'Restaurant Name': 'Le Chantecler',
  'Price Range': '110 - 190 EUR',
  'Restauarant Website': 'https://www.lenegresco.com/'},
 {'Restaurant Name': 'Le Quincangrogne',
  'Price Range': '40 - 95 EUR',
  'Restauarant Website': 'https://www.hotel-restaurant-lequincangrogne.fr/'},
 {'Restaurant Name': 'Château de la Treyne',
  'Price Range': '50 - 176 EUR',
  'Restauarant Website': 'https://www.chateaudelatreyne.com/'},
 {'Restaurant Name': 'Auberge St-Jean',
  'Price Range': '62 - 88 EUR',
  'Restauarant Website': 'https://www.aubergesaintjean.com/'},
 {'Restaurant Name': 'Umami',
  'Price Range': '63 - 70 EUR',
  'Restauarant Website': 'https://www.restaurant-umami.com/'},
 {'Restaurant Name': 'G.a. au Manoir de Rétival',
  'Price Range': '98 - 199 EUR',
  'Restauarant Website': 'http://restaurant-ga.fr'},
 {'Restaurant Name': 'Brikéténia',
  'Price Range': '38 - 108 EUR',
  'Restauarant Website': 'https://www.briketenia.com/'},
 {'Restaurant Name': 'Jean-Claude Leclerc',
  'Price Range': '36 - 115 EUR',
  'Restauarant Website': 'https://www.restaurant-jcl.com/'},
 {'Restaurant Name': 'Villa Salone',
  'Price Range': '58 - 98 EUR',
  'Restauarant Website': 'https://www.villa-salone.com/'},
 {'Restaurant Name': 'La Meynardie',
  'Price Range': '25 - 83 EUR',
  'Restauarant Website': 'https://www.domainedelameynardie.com/'},
 {'Restaurant Name': 'Aigue Marine',
  'Price Range': '26 - 90 EUR',
  'Restauarant Website': 'https://www.aiguemarine-hotel.com/'},
 {'Restaurant Name': 'Le Bec au Cauchois',
  'Price Range': '36 - 95 EUR',
  'Restauarant Website': 'https://www.lebecaucauchois.com/'},
 {'Restaurant Name': "L'Éveil des Sens",
  'Price Range': '26 - 76 EUR',
  'Restauarant Website': 'https://www.restaurant-leveildessens.fr/'},
 {'Restaurant Name': 'La Table de Chaintré',
  'Price Range': '42 - 65 EUR',
  'Restauarant Website': 'https://www.latabledechaintre.com/'},
 {'Restaurant Name': "L'Innocence",
  'Price Range': '39 - 95 EUR',
  'Restauarant Website': 'https://www.linnocence.fr/'},
 {'Restaurant Name': 'Äponem - Auberge du Presbytère',
  'Price Range': '89 EUR',
  'Restauarant Website': 'https://www.aponem-aubergedupresbytere.fr/'},
 {'Restaurant Name': 'Auberge du Cellier',
  'Price Range': '21 - 82 EUR',
  'Restauarant Website': 'http://www.aubergeducellier.com/'},
 {'Restaurant Name': "L'Escarbille",
  'Price Range': '42 - 83 EUR',
  'Restauarant Website': 'https://www.lescarbille.fr/'},
 {'Restaurant Name': "L'Atelier Yssoirien",
  'Price Range': '38 - 98 EUR',
  'Restauarant Website': 'https://www.atelier-yssoirien.com/'},
 {'Restaurant Name': 'La Table des Frères Ibarboure',
  'Price Range': '55 - 130 EUR',
  'Restauarant Website': 'https://www.freresibarboure.com/'},
 {'Restaurant Name': 'Tomy & Co',
  'Price Range': '62 - 85 EUR',
  'Restauarant Website': 'https://www.tomygousset.com/'},
 {'Restaurant Name': "Tour d'Argent",
  'Price Range': '110 - 356 EUR',
  'Restauarant Website': 'https://www.tourdargent.com/'},
 {'Restaurant Name': 'Jean-Marc Pérochon',
  'Price Range': '28 - 112 EUR',
  'Restauarant Website': 'https://www.lesbrisants.com/'},
 {'Restaurant Name': 'Restaurant H',
  'Price Range': '40 - 90 EUR',
  'Restauarant Website': 'https://www.restauranth.com/'},
 {'Restaurant Name': 'Le Mas Bottero',
  'Price Range': '29 - 93 EUR',
  'Restauarant Website': 'http://www.lemasbottero.com/'},
 {'Restaurant Name': "L'Oiseau Bleu",
  'Price Range': '32 - 80 EUR',
  'Restauarant Website': 'https://www.loiseaubleu.fr/'},
 {'Restaurant Name': 'Kasbür',
  'Price Range': '27 - 99 EUR',
  'Restauarant Website': 'https://www.restaurant-kasbur.fr/'},
 {'Restaurant Name': 'Saisons',
  'Price Range': '60 - 140 EUR',
  'Restauarant Website': 'https://www.saisons-restaurant.fr/'},
 {'Restaurant Name': 'Pastis',
  'Price Range': '38 - 56 EUR',
  'Restauarant Website': 'https://www.pastis-restaurant.com/'},
 {'Restaurant Name': 'Pierre',
  'Price Range': '36 - 102 EUR',
  'Restauarant Website': 'www.restaurant-pierre.com'},
 {'Restaurant Name': 'Aida',
  'Price Range': '280 EUR',
  'Restauarant Website': 'http://www.aida-paris.net/'},
 {'Restaurant Name': "L'Aspérule",
  'Price Range': '38 - 120 EUR',
  'Restauarant Website': 'https://www.restaurant-asperule.fr/'},
 {'Restaurant Name': 'Le Patio',
  'Price Range': '53 - 130 EUR',
  'Restauarant Website': 'http://www.lepatio-thierryrenou.com/'},
 {'Restaurant Name': 'Chugokusai S.Sawada',
  'Price Range': '11,000 - 17,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Oimatsu Kitagawa',
  'Price Range': '9,000 - 27,000 JPY',
  'Restauarant Website': 'https://www.oimatsu-kitagawa.com/'},
 {'Restaurant Name': 'P greco',
  'Price Range': '22,000 - 28,000 JPY',
  'Restauarant Website': 'https://www.pgreco.jp/'},
 {'Restaurant Name': 'Oimatsu Hisano',
  'Price Range': '15,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Nishitemma Nakamura',
  'Price Range': '15,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Chi-Fu',
  'Price Range': '7,000 - 22,000 JPY',
  'Restauarant Website': 'http://chi-fu.jp/'},
 {'Restaurant Name': 'Temmabashi Fujikawa',
  'Price Range': '7,000 - 17,000 JPY',
  'Restauarant Website': 'https://www.te-fujikawa.com/'},
 {'Restaurant Name': 'Oryori Horikawa',
  'Price Range': '7,000 - 16,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Naniwaryori Yu',
  'Price Range': '10,000 - 15,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Pierre',
  'Price Range': '9,500 - 21,000 JPY',
  'Restauarant Website': 'https://www.icosaka.com/'},
 {'Restaurant Name': 'Unkaku',
  'Price Range': '5,500 - 37,000 JPY',
  'Restauarant Website': 'http://www.unkaku.jp/'},
 {'Restaurant Name': 'Kappo Hashimoto',
  'Price Range': '7,000 - 13,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Kawahara',
  'Price Range': '7,000 - 17,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Higashichaya Nakamura',
  'Price Range': '24,000 - 26,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Sushidokoro Hirokawa',
  'Price Range': '15,000 - 17,000 JPY',
  'Restauarant Website': 'https://sushi-hirokawa.jp/'},
 {'Restaurant Name': 'Yoshino',
  'Price Range': '5,500 - 14,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Point',
  'Price Range': '22,000 JPY',
  'Restauarant Website': 'http://point-accueillir.com/'},
 {'Restaurant Name': 'Ichiju Nisai Ueno Minoten',
  'Price Range': '11,000 - 34,000 JPY',
  'Restauarant Website': 'https://ichijunisai-ueno.net/'},
 {'Restaurant Name': 'MUNI LA TERRASSE',
  'Price Range': '7,000 - 13,000 JPY',
  'Restauarant Website': 'https://muni-kyoto.com/'},
 {'Restaurant Name': 'MUNI ALAIN DUCASSE',
  'Price Range': '27,000 - 39,000 JPY',
  'Restauarant Website': 'https://muni-kyoto.com/'},
 {'Restaurant Name': 'Okina',
  'Price Range': '5,000 - 15,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Uozuya',
  'Price Range': '20,000 - 27,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'SEN',
  'Price Range': '13,000 - 25,000 JPY',
  'Restauarant Website': 'https://kyoto-sen.com/'},
 {'Restaurant Name': 'Godan Miyazawa',
  'Price Range': '17,000 - 22,000 JPY',
  'Restauarant Website': 'https://jiki-miyazawa.com/'},
 {'Restaurant Name': 'Higashiyama Yoshihisa',
  'Price Range': '7,000 - 22,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Kinobu',
  'Price Range': '6,500 - 32,000 JPY',
  'Restauarant Website': 'http://www.kinobu.co.jp/'},
 {'Restaurant Name': 'Kako Okamoto',
  'Price Range': '14,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Ayanokoji Karatsu',
  'Price Range': '11,000 - 20,000 JPY',
  'Restauarant Website': 'http://karatu.jp/'},
 {'Restaurant Name': 'Ryoriya Maekawa',
  'Price Range': '17,000 JPY',
  'Restauarant Website': 'https://ryouriya-maekawa.com/'},
 {'Restaurant Name': 'Kentan Horibe',
  'Price Range': '8,000 - 22,000 JPY',
  'Restauarant Website': 'https://www.kyoto-horibe.com/'},
 {'Restaurant Name': 'Honke Tankuma Honten',
  'Price Range': '8,000 - 64,000 JPY',
  'Restauarant Website': 'http://www.tankuma.jp/'},
 {'Restaurant Name': 'Shun-ai Sasaki',
  'Price Range': '6,000 - 16,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Jiki Miyazawa',
  'Price Range': '6,500 - 20,000 JPY',
  'Restauarant Website': 'https://jiki-miyazawa.com/'},
 {'Restaurant Name': 'naruya',
  'Price Range': '23,000 - 40,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'CAINOYA',
  'Price Range': '40,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'VELROSIER',
  'Price Range': '8,500 - 22,000 JPY',
  'Restauarant Website': 'https://www.vel-rosier.com/'},
 {'Restaurant Name': 'TAKAYAMA',
  'Price Range': '22,000 JPY',
  'Restauarant Website': 'https://takayama-kyoto.com/'},
 {'Restaurant Name': 'Shuhaku',
  'Price Range': '6,000 - 18,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Kyoryori Fujimoto',
  'Price Range': '3,500 - 15,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Akai',
  'Price Range': '13,000 - 37,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Le Faham by Kelly Rangama',
  'Price Range': '33 - 79 EUR',
  'Restauarant Website': 'http://www.lefaham.com/'},
 {'Restaurant Name': 'La Gouesnière - Maison Tirel-Guérin',
  'Price Range': '45 - 125 EUR',
  'Restauarant Website': 'www.tirel-guerin.com'},
 {'Restaurant Name': 'Les Sources de Fontbelle',
  'Price Range': '35 - 92 EUR',
  'Restauarant Website': 'http://sourcesdefontbelle.com'},
 {'Restaurant Name': 'Pertinence',
  'Price Range': '45 - 180 EUR',
  'Restauarant Website': 'https://www.restaurantpertinence.com/'},
 {'Restaurant Name': 'Hedone',
  'Price Range': '48 - 110 EUR',
  'Restauarant Website': 'https://www.hedone-restaurant.fr/'},
 {'Restaurant Name': 'La Robe',
  'Price Range': '24 - 75 EUR',
  'Restauarant Website': 'https://www.restaurant-la-robe.com/'},
 {'Restaurant Name': 'La Salle à Manger du Château de Mazan',
  'Price Range': '65 - 95 EUR',
  'Restauarant Website': 'https://www.chateaudemazan.com/'},
 {'Restaurant Name': 'Leclere',
  'Price Range': '35 - 45 EUR',
  'Restauarant Website': 'https://www.restaurantleclere.com/'},
 {'Restaurant Name': "Les Voiles d'Or",
  'Price Range': '35 - 85 EUR',
  'Restauarant Website': 'https://www.lesvoilesdor.fr/'},
 {'Restaurant Name': "L'Orée de la Forêt",
  'Price Range': '65 - 125 EUR',
  'Restauarant Website': 'https://www.loreedelaforet.fr/'},
 {'Restaurant Name': "L'Étang du Moulin",
  'Price Range': '65 - 149 EUR',
  'Restauarant Website': 'http://www.etang-du-moulin.com/'},
 {'Restaurant Name': 'Louis',
  'Price Range': '42 - 110 EUR',
  'Restauarant Website': 'https://stephanepitre.fr/restaurant-gastronomique-louis/'},
 {'Restaurant Name': 'Chez Michèle',
  'Price Range': '27 - 115 EUR',
  'Restauarant Website': 'https://www.chezmichele.fr/'},
 {'Restaurant Name': 'Restaurant de Tourrel',
  'Price Range': '98 - 150 EUR',
  'Restauarant Website': 'http://www.detourrel.com/'},
 {'Restaurant Name': 'La Renaissance',
  'Price Range': '36 - 98 EUR',
  'Restauarant Website': 'https://www.arnaudviel.com/'},
 {'Restaurant Name': 'La Sommelière',
  'Price Range': '72 EUR',
  'Restauarant Website': 'https://www.la-sommeliere.net/'},
 {'Restaurant Name': 'Les Trois Rochers',
  'Price Range': '55 - 115 EUR',
  'Restauarant Website': 'https://www.trimen.fr/'},
 {'Restaurant Name': 'Hostellerie de la Pointe St-Mathieu',
  'Price Range': '49 - 105 EUR',
  'Restauarant Website': 'https://www.pointe-saint-mathieu.com/'},
 {'Restaurant Name': "Le P'tit Polyte",
  'Price Range': '73 - 115 EUR',
  'Restauarant Website': 'https://www.chalet-mounier.com/'},
 {'Restaurant Name': 'Sola',
  'Price Range': '65 - 120 EUR',
  'Restauarant Website': 'https://www.restaurant-sola.com/'},
 {'Restaurant Name': 'Elsa',
  'Price Range': '78 - 158 EUR',
  'Restauarant Website': 'https://www.monte-carlo-beach.com/'},
 {'Restaurant Name': 'Aux Terrasses',
  'Price Range': '35 - 105 EUR',
  'Restauarant Website': 'https://www.aux-terrasses.com/'},
 {'Restaurant Name': 'La Scène Thélème',
  'Price Range': '56 - 135 EUR',
  'Restauarant Website': 'https://www.lascenetheleme.fr/'},
 {'Restaurant Name': "L'Arnsbourg",
  'Price Range': '79 - 139 EUR',
  'Restauarant Website': 'https://www.arnsbourg.com/'},
 {'Restaurant Name': 'Les Pêcheurs',
  'Price Range': '98 - 154 EUR',
  'Restauarant Website': 'https://www.ca-beachhotel.com/'},
 {'Restaurant Name': 'Auberge St-Walfrid',
  'Price Range': '71 - 143 EUR',
  'Restauarant Website': 'http://www.stwalfrid.com/'},
 {'Restaurant Name': 'Le Champ des Lunes',
  'Price Range': '85 - 145 EUR',
  'Restauarant Website': 'https://www.domainedefontenille.com/'},
 {'Restaurant Name': 'Le Foch',
  'Price Range': '37 - 125 EUR',
  'Restauarant Website': 'https://www.lefoch.com/'},
 {'Restaurant Name': 'Auberge du Cep',
  'Price Range': '23 - 84 EUR',
  'Restauarant Website': 'https://www.aubergeducep.com/'},
 {'Restaurant Name': 'Les Terraillers',
  'Price Range': '79 - 168 EUR',
  'Restauarant Website': 'https://www.lesterraillers.com/'},
 {'Restaurant Name': 'Le Sérac',
  'Price Range': '35 - 68 EUR',
  'Restauarant Website': 'https://www.3serac.fr/'},
 {'Restaurant Name': 'Les Bories',
  'Price Range': '70 - 120 EUR',
  'Restauarant Website': 'https://www.hotellesbories.com/'},
 {'Restaurant Name': 'La Réserve Rimbaud',
  'Price Range': '40 - 110 EUR',
  'Restauarant Website': 'https://www.reserve-rimbaud.com/'},
 {'Restaurant Name': 'Girardin - Gastronomique',
  'Price Range': '115 - 135 EUR',
  'Restauarant Website': 'https://www.maisondestetes.com/'},
 {'Restaurant Name': 'Le Raisin',
  'Price Range': '36 - 95 EUR',
  'Restauarant Website': 'https://www.leraisin.com/'},
 {'Restaurant Name': 'Alcyone',
  'Price Range': '99 - 139 EUR',
  'Restauarant Website': 'https://marseille.intercontinental.com/alcyone'},
 {'Restaurant Name': 'Oxte',
  'Price Range': '55 - 95 EUR',
  'Restauarant Website': 'https://www.restaurant-oxte.com/'},
 {'Restaurant Name': 'La Mare aux Oiseaux',
  'Price Range': '55 - 120 EUR',
  'Restauarant Website': 'https://www.mareauxoiseaux.fr/'},
 {'Restaurant Name': 'Maison Chabran - La Grande Table',
  'Price Range': '119 - 139 EUR',
  'Restauarant Website': 'https://www.maisonchabran.com/'},
 {'Restaurant Name': 'Vieux Pont',
  'Price Range': '52 - 97 EUR',
  'Restauarant Website': 'https://www.hotelbelcastel.com/'},
 {'Restaurant Name': 'Accents Table Bourse',
  'Price Range': '39 - 75 EUR',
  'Restauarant Website': 'https://www.accents-restaurant.com/'},
 {'Restaurant Name': 'Lasserre',
  'Price Range': '145 - 275 EUR',
  'Restauarant Website': 'https://www.restaurant-lasserre.com/'},
 {'Restaurant Name': 'La Rotonde des Trésoms',
  'Price Range': '37 - 129 EUR',
  'Restauarant Website': 'https://www.lestresoms.com/'},
 {'Restaurant Name': 'La Flibuste',
  'Price Range': '51 - 145 EUR',
  'Restauarant Website': 'https://www.restaurantlaflibuste.fr/'},
 {'Restaurant Name': 'Prairial',
  'Price Range': '64 - 98 EUR',
  'Restauarant Website': 'http://www.prairial-restaurant.com/'},
 {'Restaurant Name': 'Sushi B',
  'Price Range': '68 - 225 EUR',
  'Restauarant Website': 'http://sushi-b-fr.com'},
 {'Restaurant Name': 'La Table de La Butte',
  'Price Range': '48 - 165 EUR',
  'Restauarant Website': 'https://www.labutte.fr/'},
 {'Restaurant Name': 'Le Moulin de la Gorce',
  'Price Range': '89 - 109 EUR',
  'Restauarant Website': 'https://www.moulindelagorce.com/'},
 {'Restaurant Name': 'Auberge du Pont',
  'Price Range': '32 - 155 EUR',
  'Restauarant Website': 'https://www.auberge-du-pont.com/'},
 {'Restaurant Name': 'Septime',
  'Price Range': '60 - 95 EUR',
  'Restauarant Website': 'https://www.septime-charonne.fr/'},
 {'Restaurant Name': 'Le Chiberta',
  'Price Range': '49 - 120 EUR',
  'Restauarant Website': 'https://www.lechiberta.com/'},
 {'Restaurant Name': 'Les Berceaux',
  'Price Range': '51 - 98 EUR',
  'Restauarant Website': 'https://www.lesberceaux.com/'},
 {'Restaurant Name': 'Anne',
  'Price Range': '39 - 120 EUR',
  'Restauarant Website': 'www.pavillon-de-la-reine.com'},
 {'Restaurant Name': "L'Atlantide 1874 - Maison Guého",
  'Price Range': '45 - 130 EUR',
  'Restauarant Website': 'http://www.atlantide1874.fr/'},
 {'Restaurant Name': 'Jérôme Nutile',
  'Price Range': '45 - 180 EUR',
  'Restauarant Website': 'http://www.jerome-nutile.com/'},
 {'Restaurant Name': 'Le Bénaton',
  'Price Range': '35 - 141 EUR',
  'Restauarant Website': 'http://www.lebenaton.com/'},
 {'Restaurant Name': 'Le Jardin Secret',
  'Price Range': '32 - 68 EUR',
  'Restauarant Website': 'https://www.restaurant-jardinsecret.fr/'},
 {'Restaurant Name': 'La Ville Blanche',
  'Price Range': '53 - 95 EUR',
  'Restauarant Website': 'https://www.la-ville-blanche.com/'},
 {'Restaurant Name': 'Qui Plume la Lune',
  'Price Range': '60 - 120 EUR',
  'Restauarant Website': 'http://www.quiplumelalune.fr/'},
 {'Restaurant Name': 'Maison Tiegezh',
  'Price Range': '39 - 93 EUR',
  'Restauarant Website': 'https://maisontiegezh.fr'},
 {'Restaurant Name': 'MoSuke',
  'Price Range': '55 - 110 EUR',
  'Restauarant Website': 'https://mosuke-restaurant.com'},
 {'Restaurant Name': 'Les Loges',
  'Price Range': '94 - 135 EUR',
  'Restauarant Website': 'https://www.courdesloges.com/'},
 {'Restaurant Name': 'Le Mascaret',
  'Price Range': '24 - 106 EUR',
  'Restauarant Website': 'https://www.lemascaret.fr/'},
 {'Restaurant Name': "L'Odas",
  'Price Range': '36 - 130 EUR',
  'Restauarant Website': 'https://www.lodas.fr/'},
 {'Restaurant Name': 'Moulin de la Tardoire',
  'Price Range': '25 - 69 EUR',
  'Restauarant Website': 'https://www.moulindelatardoire.fr/'},
 {'Restaurant Name': 'Le Fanal',
  'Price Range': '38 - 110 EUR',
  'Restauarant Website': 'https://www.pascal-borrell.com/'},
 {'Restaurant Name': 'Les Fresques',
  'Price Range': '47 - 120 EUR',
  'Restauarant Website': 'https://www.vigiers.com/'},
 {'Restaurant Name': 'Comice',
  'Price Range': '84 - 116 EUR',
  'Restauarant Website': 'https://www.comice.paris/'},
 {'Restaurant Name': 'La Petite Maison de Cucuron',
  'Price Range': '60 - 90 EUR',
  'Restauarant Website': 'https://www.lapetitemaisondecucuron.com/'},
 {'Restaurant Name': 'Assa',
  'Price Range': '62 - 114 EUR',
  'Restauarant Website': 'https://www.assarestaurant.com/'},
 {'Restaurant Name': "L'Or Bleu",
  'Price Range': '90 - 139 EUR',
  'Restauarant Website': 'https://www.tiara-hotels.com/'},
 {'Restaurant Name': 'Au 14 Février',
  'Price Range': '98 - 145 EUR',
  'Restauarant Website': 'https://www.ly-au14fevrier.com/'},
 {'Restaurant Name': 'Likoké',
  'Price Range': '54 - 155 EUR',
  'Restauarant Website': 'https://www.likoke.com/'},
 {'Restaurant Name': 'Lulu Rouget',
  'Price Range': '35 - 95 EUR',
  'Restauarant Website': 'http://www.lulurouget.fr/'},
 {'Restaurant Name': 'Auberge des Templiers',
  'Price Range': '59 - 149 EUR',
  'Restauarant Website': 'https://www.lestempliers.com/'},
 {'Restaurant Name': 'Les Ducs de Lorraine',
  'Price Range': '48 - 155 EUR',
  'Restauarant Website': 'https://www.restaurant-ducsdelorraine.com/'},
 {'Restaurant Name': 'Étude',
  'Price Range': '45 - 98 EUR',
  'Restauarant Website': 'https://www.restaurant-etude.fr/'},
 {'Restaurant Name': 'Le Refuge des Gourmets',
  'Price Range': '69 - 105 EUR',
  'Restauarant Website': 'https://www.refugedesgourmets.com/'},
 {'Restaurant Name': 'Le Grand Cerf',
  'Price Range': '39 - 174 EUR',
  'Restauarant Website': 'https://www.le-grand-cerf.fr/'},
 {'Restaurant Name': 'Le Rigmarole',
  'Price Range': '45 - 75 EUR',
  'Restauarant Website': 'https://www.lerigmarole.com/'},
 {'Restaurant Name': 'Borkonyha Winekitchen',
  'Price Range': '8,650 - 23,000 HUF',
  'Restauarant Website': 'www.borkonyha.hu'},
 {'Restaurant Name': 'essência',
  'Price Range': '5,500 - 41,900 HUF',
  'Restauarant Website': 'www.essenciarestaurant.hu'},
 {'Restaurant Name': 'Costes Downtown',
  'Price Range': '7,900 - 31,500 HUF',
  'Restauarant Website': 'www.costesdowntown.hu'},
 {'Restaurant Name': 'Boškinac',
  'Price Range': '590 - 890 HRK',
  'Restauarant Website': 'https://www.boskinac.com/'},
 {'Restaurant Name': 'Noel',
  'Price Range': '135 - 950 HRK',
  'Restauarant Website': 'https://www.noel.hr/'},
 {'Restaurant Name': 'Alfred Keller',
  'Price Range': '320 - 780 HRK',
  'Restauarant Website': 'https://www.losinj-hotels.com/en/dining/restaurant-alfred-keller/'},
 {'Restaurant Name': 'Nebo',
  'Price Range': '890 - 1,250 HRK',
  'Restauarant Website': 'https://neborijeka.com/'},
 {'Restaurant Name': 'Draga di Lovrana',
  'Price Range': '360 - 590 HRK',
  'Restauarant Website': 'https://www.dragadilovrana.hr/'},
 {'Restaurant Name': 'Hiša Denk',
  'Price Range': '45 - 85 EUR',
  'Restauarant Website': 'https://www.hisadenk.si/'},
 {'Restaurant Name': 'Agli Amici Rovinj',
  'Price Range': '830 - 1,050 HRK',
  'Restauarant Website': 'www.maistra.com/grand-park-hotel-rovinj/sub/agli-amici-rovinj'},
 {'Restaurant Name': 'Monte',
  'Price Range': '794 - 1,044 HRK',
  'Restauarant Website': 'https://www.monte.hr/'},
 {'Restaurant Name': 'Restavracija Atelje',
  'Price Range': '24 - 120 EUR',
  'Restauarant Website': 'https://www.restavracijaatelje.com/'},
 {'Restaurant Name': 'Gostišče Grič',
  'Price Range': '60 - 110 EUR',
  'Restauarant Website': 'https://www.gric.si/'},
 {'Restaurant Name': 'Gostilna Pri Lojzetu',
  'Price Range': '55 - 95 EUR',
  'Restauarant Website': 'https://www.prilojzetu.com/'},
 {'Restaurant Name': 'U Santa Marina',
  'Price Range': '75 - 145 EUR',
  'Restauarant Website': 'https://www.usantamarina.com/'},
 {'Restaurant Name': 'Vila Podvin',
  'Price Range': '24 - 95 EUR',
  'Restauarant Website': 'https://www.vilapodvin.si/'},
 {'Restaurant Name': 'Dam',
  'Price Range': '75 - 116 EUR',
  'Restauarant Website': 'https://www.damhotel.si/'},
 {'Restaurant Name': 'PUR',
  'Price Range': '105 - 185 EUR',
  'Restauarant Website': 'https://www.kempinski.com/berchtesgaden'},
 {'Restaurant Name': 'Johanns',
  'Price Range': '29 - 82 EUR',
  'Restauarant Website': 'http://www.restaurant-johanns.de/'},
 {'Restaurant Name': 'Huberwirt',
  'Price Range': '30 - 119 EUR',
  'Restauarant Website': 'https://www.huber-wirt.de/'},
 {'Restaurant Name': 'Marcore',
  'Price Range': '55 - 95 EUR',
  'Restauarant Website': 'https://www.marcore-paris.com/'},
 {'Restaurant Name': 'Château de Courban',
  'Price Range': '69 - 129 EUR',
  'Restauarant Website': 'https://www.chateaudecourban.com/'},
 {'Restaurant Name': 'Benoit',
  'Price Range': '39 - 114 EUR',
  'Restauarant Website': 'https://www.benoit-paris.com/'},
 {'Restaurant Name': "L'Arôme",
  'Price Range': '65 - 169 EUR',
  'Restauarant Website': 'https://www.larome.fr/'},
 {'Restaurant Name': "L'Esquisse",
  'Price Range': '42 - 95 EUR',
  'Restauarant Website': 'https://www.esquisse-annecy.fr/'},
 {'Restaurant Name': "Le Pavé d'Auge",
  'Price Range': '44 - 84 EUR',
  'Restauarant Website': 'https://www.pavedauge.com/'},
 {'Restaurant Name': 'La Magdeleine - Mathias Dandine',
  'Price Range': '60 - 145 EUR',
  'Restauarant Website': 'https://www.relais-magdeleine.com/'},
 {'Restaurant Name': 'Shang Palace',
  'Price Range': '58 - 168 EUR',
  'Restauarant Website': 'https://www.shangri-la.com/fr/paris/shangrila'},
 {'Restaurant Name': "Val d'Auge",
  'Price Range': '45 - 120 EUR',
  'Restauarant Website': 'https://www.valdauge.com/'},
 {'Restaurant Name': 'Le Petit Hôtel du Grand Large',
  'Price Range': '45 - 100 EUR',
  'Restauarant Website': 'https://www.lepetithoteldugrandlarge.fr/'},
 {'Restaurant Name': "L'Atelier de Joël Robuchon - Étoile",
  'Price Range': '49 - 225 EUR',
  'Restauarant Website': 'https://www.joel-robuchon.com/'},
 {'Restaurant Name': 'Le Kaïku',
  'Price Range': '40 - 90 EUR',
  'Restauarant Website': 'https://www.kaiku.fr/'},
 {'Restaurant Name': 'La Dune du Château de Sable',
  'Price Range': '99 - 169 EUR',
  'Restauarant Website': 'https://www.lechateaudesablehotel.fr/'},
 {'Restaurant Name': 'Le Verbois',
  'Price Range': '45 - 117 EUR',
  'Restauarant Website': 'https://www.leverbois.fr/'},
 {'Restaurant Name': 'Pavyllon',
  'Price Range': '68 - 235 EUR',
  'Restauarant Website': 'https://www.yannick-alleno.com/'},
 {'Restaurant Name': 'La Table des Blot - Auberge du Château',
  'Price Range': '75 - 85 EUR',
  'Restauarant Website': 'https://www.latabledesblot.com/'},
 {'Restaurant Name': 'Gaya par Pierre Gagnaire',
  'Price Range': '49 - 120 EUR',
  'Restauarant Website': 'https://www.pierre-gagnaire.com/'},
 {'Restaurant Name': "L'Atelier de Joël Robuchon - St-Germain",
  'Price Range': '49 - 175 EUR',
  'Restauarant Website': 'https://www.joel-robuchon.com/'},
 {'Restaurant Name': 'Pilgrim',
  'Price Range': '45 - 143 EUR',
  'Restauarant Website': 'https://www.pilgrimparis.com/'},
 {'Restaurant Name': 'Azimut',
  'Price Range': '40 - 108 EUR',
  'Restauarant Website': 'https://www.restaurantazimut.com/'},
 {'Restaurant Name': 'La Table de la Bergerie',
  'Price Range': '29 - 70 EUR',
  'Restauarant Website': 'http://www.latable-bergerie.fr/'},
 {'Restaurant Name': 'Julien Binz',
  'Price Range': '68 - 100 EUR',
  'Restauarant Website': 'https://www.restaurantjulienbinz.com/'},
 {'Restaurant Name': 'Le Royal',
  'Price Range': '135 - 280 EUR',
  'Restauarant Website': 'https://www.royalchampagne.com/'},
 {'Restaurant Name': 'Agapé',
  'Price Range': '54 - 185 EUR',
  'Restauarant Website': 'https://www.agape-paris.fr/'},
 {'Restaurant Name': "L'Émulsion",
  'Price Range': '65 - 90 EUR',
  'Restauarant Website': 'https://www.lemulsion-restaurant.com/'},
 {'Restaurant Name': 'Le Saint-James',
  'Price Range': '52 - 160 EUR',
  'Restauarant Website': 'https://www.saintjames-bouliac.com/'},
 {'Restaurant Name': 'Miraflores',
  'Price Range': '45 - 180 EUR',
  'Restauarant Website': 'https://www.restaurant-miraflores.com/'},
 {'Restaurant Name': 'Skab',
  'Price Range': '45 - 135 EUR',
  'Restauarant Website': 'https://www.restaurant-skab.fr/'},
 {'Restaurant Name': 'Ithurria',
  'Price Range': '48 - 92 EUR',
  'Restauarant Website': 'https://www.ithurria.com/'},
 {'Restaurant Name': 'Auberge St-Laurent',
  'Price Range': '33 - 86 EUR',
  'Restauarant Website': 'https://www.auberge-saintlaurent.fr/'},
 {'Restaurant Name': "L'Archeste",
  'Price Range': '55 - 185 EUR',
  'Restauarant Website': 'https://www.archeste.fr/'},
 {'Restaurant Name': 'Signature',
  'Price Range': '29 - 95 EUR',
  'Restauarant Website': 'https://www.signaturemarseille.com/'},
 {'Restaurant Name': '114, Faubourg',
  'Price Range': '82 - 150 EUR',
  'Restauarant Website': 'https://www.lebristolparis.com/'},
 {'Restaurant Name': "Auberge de l'Abbaye",
  'Price Range': '38 - 100 EUR',
  'Restauarant Website': 'https://www.aubergedelabbaye-ambronay.com/'},
 {'Restaurant Name': 'Le Vivier',
  'Price Range': '36 - 120 EUR',
  'Restauarant Website': 'https://www.levivier-restaurant.com/'},
 {'Restaurant Name': 'La Table de Nans',
  'Price Range': '59 - 110 EUR',
  'Restauarant Website': 'https://www.latabledenans.com/'},
 {'Restaurant Name': "L'Oiseau Blanc",
  'Price Range': '95 - 220 EUR',
  'Restauarant Website': 'https://www.peninsula.com/'},
 {'Restaurant Name': 'Le Hittau',
  'Price Range': '36 - 92 EUR',
  'Restauarant Website': 'http://www.lehittau.fr/'},
 {'Restaurant Name': 'La Tour des Vents',
  'Price Range': '51 - 93 EUR',
  'Restauarant Website': 'https://www.tourdesvents.com/'},
 {'Restaurant Name': 'Le Prieuré',
  'Price Range': '49 - 99 EUR',
  'Restauarant Website': 'https://www.leprieureambierle.fr/'},
 {'Restaurant Name': 'Le Candille',
  'Price Range': '80 - 138 EUR',
  'Restauarant Website': 'https://www.lemascandille.com/'},
 {'Restaurant Name': "La Table d'Hôtes - Le Quatrième Mur",
  'Price Range': '170 EUR',
  'Restauarant Website': 'https://www.quatrieme-mur.com/'},
 {'Restaurant Name': "La Table d'Olivier",
  'Price Range': '51 - 93 EUR',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Pantagruel',
  'Price Range': '35 - 73 EUR',
  'Restauarant Website': 'https://www.restaurant-pantagruel.com/'},
 {'Restaurant Name': 'Ed.Em',
  'Price Range': '40 - 90 EUR',
  'Restauarant Website': 'https://www.restaurant-edem.com/'},
 {'Restaurant Name': 'Ochre',
  'Price Range': '55 - 115 EUR',
  'Restauarant Website': 'https://www.ochre.fr/'},
 {'Restaurant Name': 'La Table de Patrick Raingeard',
  'Price Range': '130 - 190 EUR',
  'Restauarant Website': 'https://www.capestel.com/'},
 {'Restaurant Name': 'La Table de Xavier Mathieu',
  'Price Range': '100 - 230 EUR',
  'Restauarant Website': 'https://www.lephebus.com/'},
 {'Restaurant Name': 'Les Climats',
  'Price Range': '49 - 130 EUR',
  'Restauarant Website': 'https://www.lesclimats.fr/'},
 {'Restaurant Name': 'Auberge de la Charme',
  'Price Range': '50 - 96 EUR',
  'Restauarant Website': 'https://www.aubergedelacharme.com/'},
 {'Restaurant Name': 'JAN',
  'Price Range': '85 - 139 EUR',
  'Restauarant Website': 'https://www.restaurantjan.com/'},
 {'Restaurant Name': 'Les Oliviers',
  'Price Range': '80 - 149 EUR',
  'Restauarant Website': 'http://www.ile-rousse.com/'},
 {'Restaurant Name': 'Le Village',
  'Price Range': '58 - 130 EUR',
  'Restauarant Website': 'https://www.restaurant-levillage.fr/'},
 {'Restaurant Name': 'Le Pavillon',
  'Price Range': '85 - 130 EUR',
  'Restauarant Website': 'https://www.hotelsbarriere.com/'},
 {'Restaurant Name': 'Alan Geaam',
  'Price Range': '58 - 128 EUR',
  'Restauarant Website': 'https://www.alangeaam.fr/'},
 {'Restaurant Name': 'Nicolas Carro - Hôtel de Carantec',
  'Price Range': '33 - 120 EUR',
  'Restauarant Website': 'https://www.hotel-carantec.fr/'},
 {'Restaurant Name': 'Divellec',
  'Price Range': '90 - 150 EUR',
  'Restauarant Website': 'https://www.divellec-paris.fr/'},
 {'Restaurant Name': 'Maison Decoret',
  'Price Range': '45 - 137 EUR',
  'Restauarant Website': 'https://www.maisondecoret.com/'},
 {'Restaurant Name': 'Château du Mont Joly',
  'Price Range': '42 - 115 EUR',
  'Restauarant Website': 'https://www.chateaumontjoly.com/'},
 {'Restaurant Name': '1741',
  'Price Range': '45 - 135 EUR',
  'Restauarant Website': 'https://www.1741.fr/'},
 {'Restaurant Name': 'Au Déjeuner de Sousceyrac',
  'Price Range': '30 - 100 EUR',
  'Restauarant Website': 'https://www.au-dejeuner-de-sousceyrac.com/'},
 {'Restaurant Name': 'La Table Breizh Café',
  'Price Range': '55 - 95 EUR',
  'Restauarant Website': 'https://www.breizhcafe.com/'},
 {'Restaurant Name': 'Toya',
  'Price Range': '52 - 120 EUR',
  'Restauarant Website': 'http://www.toya-restaurant.fr/'},
 {'Restaurant Name': 'Fontevraud Le Restaurant',
  'Price Range': '70 - 101 EUR',
  'Restauarant Website': 'https://www.fontevraud.fr/'},
 {'Restaurant Name': 'Loiseau des Ducs',
  'Price Range': '55 - 120 EUR',
  'Restauarant Website': 'https://www.bernard-loiseau.com/'},
 {'Restaurant Name': 'Rustique',
  'Price Range': '75 EUR',
  'Restauarant Website': 'https://www.rustiquelyon.fr/'},
 {'Restaurant Name': 'Ô Saveurs',
  'Price Range': '30 - 98 EUR',
  'Restauarant Website': 'https://www.o-saveurs.com/'},
 {'Restaurant Name': 'Racines',
  'Price Range': '32 - 70 EUR',
  'Restauarant Website': 'https://www.racines-restaurant.fr/'},
 {'Restaurant Name': 'Les Agitateurs',
  'Price Range': '38 - 119 EUR',
  'Restauarant Website': 'https://www.lesagitateurs.com/'},
 {'Restaurant Name': "Hostellerie de l'Abbaye de la Celle",
  'Price Range': '56 - 110 EUR',
  'Restauarant Website': 'https://www.abbaye-celle.com/'},
 {'Restaurant Name': 'Au Souper Fin',
  'Price Range': '52 - 60 EUR',
  'Restauarant Website': 'https://www.souperfin.fr/'},
 {'Restaurant Name': 'Clovis',
  'Price Range': '54 - 85 EUR',
  'Restauarant Website': 'https://www.clovisgourmand.fr/'},
 {'Restaurant Name': 'Atmosphères',
  'Price Range': '52 - 130 EUR',
  'Restauarant Website': 'https://www.atmospheres-hotel.com/'},
 {'Restaurant Name': 'Tentazioni',
  'Price Range': '35 - 95 EUR',
  'Restauarant Website': 'https://www.tentazioni-bordeaux.fr/'},
 {'Restaurant Name': 'Armani Ristorante',
  'Price Range': '105 - 160 EUR',
  'Restauarant Website': 'https://www.emporioarmanicaffeparis.com/'},
 {'Restaurant Name': 'A Casa di Ma',
  'Price Range': '90 - 175 EUR',
  'Restauarant Website': 'https://www.acasadima.com/'},
 {'Restaurant Name': 'Ima',
  'Price Range': '30 - 95 EUR',
  'Restauarant Website': 'https://www.ima.restaurant/'},
 {'Restaurant Name': 'Maison Kieny',
  'Price Range': '55 - 115 EUR',
  'Restauarant Website': 'http://www.restaurant-kieny.com/'},
 {'Restaurant Name': 'Hostellerie la Montagne',
  'Price Range': '25 - 90 EUR',
  'Restauarant Website': 'https://www.hostellerielamontagne.com/'},
 {'Restaurant Name': 'Les Explorateurs',
  'Price Range': '89 - 150 EUR',
  'Restauarant Website': 'https://www.hotelpashmina.com/'},
 {'Restaurant Name': 'Le Colombier',
  'Price Range': '39 - 87 EUR',
  'Restauarant Website': 'https://www.lecolombieroffranville.fr/'},
 {'Restaurant Name': 'Le Passe Temps',
  'Price Range': '39 - 105 EUR',
  'Restauarant Website': 'https://www.lepassetemps-restaurant.com/'},
 {'Restaurant Name': 'Hervé Busset',
  'Price Range': '40 - 110 EUR',
  'Restauarant Website': 'https://www.moulindecambelong.com/'},
 {'Restaurant Name': "L'Écrin de Yohann Chapuis",
  'Price Range': '75 - 182 EUR',
  'Restauarant Website': 'https://www.restaurant-greuze.fr/'},
 {'Restaurant Name': 'Château de Pray',
  'Price Range': '59 - 140 EUR',
  'Restauarant Website': 'https://www.chateaudepray.fr/'},
 {'Restaurant Name': 'En Pleine Nature',
  'Price Range': '32 - 82 EUR',
  'Restauarant Website': 'https://www.en-pleine-nature.com/'},
 {'Restaurant Name': 'Château de Sully',
  'Price Range': '69 - 119 EUR',
  'Restauarant Website': 'https://www.chateau-de-sully.com/'},
 {'Restaurant Name': "Yam'Tcha",
  'Price Range': '150 EUR',
  'Restauarant Website': 'https://www.yamtcha.com/'},
 {'Restaurant Name': 'Il Cortile',
  'Price Range': '36 - 109 EUR',
  'Restauarant Website': 'https://www.ilcortile-mulhouse.fr/'},
 {'Restaurant Name': 'Le Cap',
  'Price Range': '138 - 184 EUR',
  'Restauarant Website': 'https://www.fourseasons.com/fr/capferrat'},
 {'Restaurant Name': 'Oka',
  'Price Range': '65 - 130 EUR',
  'Restauarant Website': 'https://www.okaparis.fr/'},
 {'Restaurant Name': 'La Table de Philippe Girardon',
  'Price Range': '35 - 135 EUR',
  'Restauarant Website': 'https://www.domaine-de-clairefontaine.fr/'},
 {'Restaurant Name': 'Guy Lassausaie',
  'Price Range': '76 - 120 EUR',
  'Restauarant Website': 'https://www.guy-lassausaie.com/'},
 {'Restaurant Name': 'Flaveurs',
  'Price Range': '38 - 98 EUR',
  'Restauarant Website': 'https://www.flaveurs-restaurant.com/'},
 {'Restaurant Name': "La Pomme d'Api",
  'Price Range': '29 - 119 EUR',
  'Restauarant Website': 'https://www.lapommedapi.com/'},
 {'Restaurant Name': 'Terre-Mer au Domaine de Kerdrain',
  'Price Range': '37 - 95 EUR',
  'Restauarant Website': 'https://www.restaurant-terre-mer.fr/'},
 {'Restaurant Name': 'Helen',
  'Price Range': '48 - 170 EUR',
  'Restauarant Website': 'https://www.helenrestaurant.com/'},
 {'Restaurant Name': "L'O des Vignes",
  'Price Range': '34 - 100 EUR',
  'Restauarant Website': 'www.lodesvignes.fr'},
 {'Restaurant Name': 'Mon Plaisir',
  'Price Range': '49 - 99 EUR',
  'Restauarant Website': 'https://www.restaurant-mon-plaisir.com/'},
 {'Restaurant Name': "Le Pot d'Étain",
  'Price Range': '35 - 121 EUR',
  'Restauarant Website': 'https://www.restaurant-potdetain.fr/'},
 {'Restaurant Name': 'Le Relais des Moines',
  'Price Range': '49 - 118 EUR',
  'Restauarant Website': 'https://www.lerelaisdesmoines.com/'},
 {'Restaurant Name': 'Les Terrasses de Lyon',
  'Price Range': '49 - 120 EUR',
  'Restauarant Website': 'https://www.villaflorentine.com/'},
 {'Restaurant Name': 'Ivan Vautier',
  'Price Range': '39 - 110 EUR',
  'Restauarant Website': 'https://www.ivanvautier.com/'},
 {'Restaurant Name': 'Le Brittany',
  'Price Range': '85 - 150 EUR',
  'Restauarant Website': 'https://www.hotel-brittany.com/'},
 {'Restaurant Name': 'La Dame de Pic',
  'Price Range': '90 - 165 EUR',
  'Restauarant Website': 'https://www.anne-sophie-pic.com/'},
 {'Restaurant Name': 'Le France',
  'Price Range': '24 - 108 EUR',
  'Restauarant Website': 'https://www.hotel-restaurant-lefrance.com/'},
 {'Restaurant Name': 'Le Manoir du Lys',
  'Price Range': '50 - 99 EUR',
  'Restauarant Website': 'https://www.manoir-du-lys.fr/'},
 {'Restaurant Name': 'La Bastide Saint-Antoine',
  'Price Range': '72 - 208 EUR',
  'Restauarant Website': 'https://www.jacques-chibois.com/'},
 {'Restaurant Name': "Moulin d'Alotz",
  'Price Range': '51 - 88 EUR',
  'Restauarant Website': 'https://www.moulindalotz.com/'},
 {'Restaurant Name': 'Les Rosiers',
  'Price Range': '39 - 124 EUR',
  'Restauarant Website': 'https://www.restaurant-lesrosiers.fr/'},
 {'Restaurant Name': 'Le Sergent Recruteur',
  'Price Range': '49 - 151 EUR',
  'Restauarant Website': 'https://www.lesergentrecruteur.fr/'},
 {'Restaurant Name': 'Auberge de la Brie',
  'Price Range': '62 - 95 EUR',
  'Restauarant Website': 'https://www.aubergedelabrie.net/'},
 {'Restaurant Name': 'Automne',
  'Price Range': '35 - 125 EUR',
  'Restauarant Website': 'https://www.automne-akishige.com/'},
 {'Restaurant Name': "L'Orangerie",
  'Price Range': '85 - 165 EUR',
  'Restauarant Website': 'https://www.fourseasons.com/fr/paris/dining/restaurants/l-orangerie'},
 {'Restaurant Name': 'Le Belvédère',
  'Price Range': '45 - 112 EUR',
  'Restauarant Website': 'https://www.belvedere-bozouls.com/'},
 {'Restaurant Name': "La Gourmandière - La Table d'Olivier",
  'Price Range': '62 - 95 EUR',
  'Restauarant Website': 'https://www.la-gourmandiere.fr/'},
 {'Restaurant Name': 'Le Manoir de la Régate',
  'Price Range': '28 - 80 EUR',
  'Restauarant Website': 'https://www.manoirdelaregate.com/'},
 {'Restaurant Name': 'Le Haut-Allier',
  'Price Range': '58 - 110 EUR',
  'Restauarant Website': 'https://www.hotel-lehautallier.com/'},
 {'Restaurant Name': 'Michel Trama',
  'Price Range': '75 - 210 EUR',
  'Restauarant Website': 'https://www.aubergade.com/'},
 {'Restaurant Name': 'La Huchette',
  'Price Range': '68 - 110 EUR',
  'Restauarant Website': 'https://www.la-huchette.fr/'},
 {'Restaurant Name': 'Maximin Hellio',
  'Price Range': '39 - 145 EUR',
  'Restauarant Website': 'https://www.maximinhellio.fr/'},
 {'Restaurant Name': 'Le Millénaire',
  'Price Range': '39 - 160 EUR',
  'Restauarant Website': 'https://www.lemillenaire.com/'},
 {'Restaurant Name': "L'Atelier Alexandre Bousquet",
  'Price Range': '38 - 98 EUR',
  'Restauarant Website': 'http://latelier-alexandrebousquet.com'},
 {'Restaurant Name': 'Le Sénéchal',
  'Price Range': '44 - 135 EUR',
  'Restauarant Website': 'https://www.hotel-senechal.fr/'},
 {'Restaurant Name': 'Ursus',
  'Price Range': '98 - 148 EUR',
  'Restauarant Website': 'https://www.les-suites-du-nevada.com/'},
 {'Restaurant Name': "La Table d'Hôtes - La Rôtisserie du Chambertin",
  'Price Range': '55 - 85 EUR',
  'Restauarant Website': 'https://www.thomascollomb.fr/'},
 {'Restaurant Name': "L'Ours",
  'Price Range': '60 - 120 EUR',
  'Restauarant Website': 'https://www.loursrestaurant.com/'},
 {'Restaurant Name': 'Logis de la Cadène',
  'Price Range': '44 - 105 EUR',
  'Restauarant Website': 'https://www.logisdelacadene.fr/'},
 {'Restaurant Name': 'Le Grand Cap',
  'Price Range': '45 - 115 EUR',
  'Restauarant Website': 'https://www.restaurant-grand-cap.fr/'},
 {'Restaurant Name': 'Jérémy Galvan',
  'Price Range': '40 - 109 EUR',
  'Restauarant Website': 'https://www.jeremygalvanrestaurant.com/'},
 {'Restaurant Name': 'Gordon Ramsay au Trianon',
  'Price Range': '118 - 199 EUR',
  'Restauarant Website': 'https://www.trianonpalace.fr/'},
 {'Restaurant Name': 'SEPT',
  'Price Range': '78 - 120 EUR',
  'Restauarant Website': 'https://www.restaurant-sept.fr/'},
 {'Restaurant Name': 'Nakatani',
  'Price Range': '68 - 165 EUR',
  'Restauarant Website': 'http://www.restaurant-nakatani.com/'},
 {'Restaurant Name': 'ONA',
  'Price Range': '24 - 59 EUR',
  'Restauarant Website': 'https://www.clairevallee.com/'},
 {'Restaurant Name': 'Maison Hache',
  'Price Range': '36 - 135 EUR',
  'Restauarant Website': 'https://www.maisonhache.com/'},
 {'Restaurant Name': 'En Marge',
  'Price Range': '39 - 149 EUR',
  'Restauarant Website': 'https://www.restaurantenmarge.com/'},
 {'Restaurant Name': 'Le Clair de la Plume',
  'Price Range': '115 - 135 EUR',
  'Restauarant Website': 'https://www.clairplume.com/'},
 {'Restaurant Name': 'Jérôme Feck',
  'Price Range': '68 - 87 EUR',
  'Restauarant Website': 'https://www.hotel-dangleterre.fr/'},
 {'Restaurant Name': 'Au Crocodile',
  'Price Range': '74 - 138 EUR',
  'Restauarant Website': 'https://www.au-crocodile.com/'},
 {'Restaurant Name': "L'Auberge de St-Rémy-de-Provence - Fanny Rey & Jonathan Wahid",
  'Price Range': '75 - 170 EUR',
  'Restauarant Website': 'https://www.aubergesaintremy.com/'},
 {'Restaurant Name': 'La Liégeoise',
  'Price Range': '54 - 90 EUR',
  'Restauarant Website': 'https://www.atlantic-delpierre.com/'},
 {'Restaurant Name': "Auberge de l'Île Barbe",
  'Price Range': '65 - 165 EUR',
  'Restauarant Website': 'https://www.aubergedelile.com/'},
 {'Restaurant Name': 'Lucas Carton',
  'Price Range': '75 - 185 EUR',
  'Restauarant Website': 'https://www.lucascarton.com/'},
 {'Restaurant Name': 'Un Parfum de Gourmandise',
  'Price Range': '35 - 80 EUR',
  'Restauarant Website': 'https://www.unparfumdegourmandise.com/'},
 {'Restaurant Name': 'Cibo',
  'Price Range': '32 - 79 EUR',
  'Restauarant Website': 'https://www.cibo.restaurant/'},
 {'Restaurant Name': "L'Ekrin by Laurent Azoulay",
  'Price Range': '95 - 305 EUR',
  'Restauarant Website': 'https://www.lekaila.com/'},
 {'Restaurant Name': 'La Palmeraie - Château de Valmer',
  'Price Range': '80 - 150 EUR',
  'Restauarant Website': 'https://www.chateauvalmer.com/'},
 {'Restaurant Name': 'La Balette',
  'Price Range': '54 - 129 EUR',
  'Restauarant Website': 'https://www.relaisdestroismas.com/'},
 {'Restaurant Name': 'Duende',
  'Price Range': '160 - 205 EUR',
  'Restauarant Website': 'https://www.maison-albar-hotels-l-imperator.com/'},
 {'Restaurant Name': "L'Oustalet",
  'Price Range': '82 - 120 EUR',
  'Restauarant Website': 'https://www.loustalet-gigondas.com/'},
 {'Restaurant Name': 'Le Pily',
  'Price Range': '56 - 72 EUR',
  'Restauarant Website': 'http://www.le-pily.com/'},
 {'Restaurant Name': 'La Nouvelle Auberge',
  'Price Range': '45 - 110 EUR',
  'Restauarant Website': 'https://www.nauberge.com/'},
 {'Restaurant Name': "L'Anthocyane",
  'Price Range': '30 - 80 EUR',
  'Restauarant Website': 'https://www.lanthocyane.com/'},
 {'Restaurant Name': 'La Promenade',
  'Price Range': '30 - 100 EUR',
  'Restauarant Website': 'https://www.restaurant-la-promenade.fr/'},
 {'Restaurant Name': 'Choko Ona',
  'Price Range': '25 - 72 EUR',
  'Restauarant Website': 'https://www.choko-ona.fr/'},
 {'Restaurant Name': 'Le Jardin des Plumes',
  'Price Range': '55 - 115 EUR',
  'Restauarant Website': 'https://www.jardindesplumes.fr/'},
 {'Restaurant Name': 'Palais Royal Restaurant',
  'Price Range': '60 - 168 EUR',
  'Restauarant Website': 'https://www.restaurantdupalaisroyal.com/'},
 {'Restaurant Name': "L'Aupiho - Domaine de Manville",
  'Price Range': '60 - 145 EUR',
  'Restauarant Website': 'https://www.domainedemanville.fr/'},
 {'Restaurant Name': 'La Table de la Mainaz',
  'Price Range': '99 - 139 EUR',
  'Restauarant Website': 'https://www.la-mainaz.com/'},
 {'Restaurant Name': 'Frédéric Molina au Moulin de Léré',
  'Price Range': '60 - 90 EUR',
  'Restauarant Website': 'https://www.moulindelere.com/'},
 {'Restaurant Name': "Le Carré d'Alethius",
  'Price Range': '32 - 110 EUR',
  'Restauarant Website': 'https://www.lecarredalethius.com/'},
 {'Restaurant Name': 'Solstice',
  'Price Range': '75 - 120 EUR',
  'Restauarant Website': 'https://www.solsticeparis.com/'},
 {'Restaurant Name': 'Avel Vor',
  'Price Range': '38 - 118 EUR',
  'Restauarant Website': 'https://www.restaurant-avel-vor.com/'},
 {'Restaurant Name': 'La Rotonde',
  'Price Range': '39 - 139 EUR',
  'Restauarant Website': 'https://www.pavillon-rotonde.com/'},
 {'Restaurant Name': 'Château de Vault de Lugny',
  'Price Range': '59 - 139 EUR',
  'Restauarant Website': 'https://www.lugny.fr/'},
 {'Restaurant Name': 'Pertica',
  'Price Range': '48 - 90 EUR',
  'Restauarant Website': 'http://www.restaurantpertica.com/'},
 {'Restaurant Name': 'Ze Kitchen Galerie',
  'Price Range': '48 - 115 EUR',
  'Restauarant Website': 'https://www.zekitchengalerie.fr/'},
 {'Restaurant Name': 'La Closerie',
  'Price Range': '36 - 75 EUR',
  'Restauarant Website': 'https://www.lacloserieansouis.com/'},
 {'Restaurant Name': 'Frenchie',
  'Price Range': '57 - 95 EUR',
  'Restauarant Website': 'http://www.frenchie-restaurant.com/'},
 {'Restaurant Name': "L'Auberge Basque",
  'Price Range': '75 - 118 EUR',
  'Restauarant Website': 'https://www.aubergebasque.com/'},
 {'Restaurant Name': 'Domaine du Colombier',
  'Price Range': '48 - 92 EUR',
  'Restauarant Website': 'https://www.domaine-colombier.com/'},
 {'Restaurant Name': 'La Condesa',
  'Price Range': '45 - 95 EUR',
  'Restauarant Website': 'http://www.lacondesa-paris.com/'},
 {'Restaurant Name': 'Le Gourmet de Sèze',
  'Price Range': '65 - 120 EUR',
  'Restauarant Website': 'https://www.legourmetdeseze.com/'},
 {'Restaurant Name': 'Le Panoramic',
  'Price Range': '56 - 115 EUR',
  'Restauarant Website': 'www.les-suites-du-nevada.com/le-panoramic-restaurant-tignes'},
 {'Restaurant Name': "Pur' - Jean-François Rouquette",
  'Price Range': '135 - 235 EUR',
  'Restauarant Website': 'https://www.paris-restaurant-pur.fr/'},
 {'Restaurant Name': 'Bruno',
  'Price Range': '78 - 195 EUR',
  'Restauarant Website': 'https://www.restaurantbruno.com/'},
 {'Restaurant Name': 'La Bonne Auberge',
  'Price Range': '85 - 140 EUR',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Vincent Favre Félix',
  'Price Range': '31 - 90 EUR',
  'Restauarant Website': 'https://www.restaurant-vff.com/'},
 {'Restaurant Name': 'Château Blanchard',
  'Price Range': '48 - 115 EUR',
  'Restauarant Website': 'https://www.hotel-chateau-blanchard.com/'},
 {'Restaurant Name': 'Le Puits du Trésor',
  'Price Range': '60 - 120 EUR',
  'Restauarant Website': 'https://www.lepuitsdutresor.com/'},
 {'Restaurant Name': 'Transparence - La Table de Patrick Fréchin',
  'Price Range': '37 - 90 EUR',
  'Restauarant Website': 'https://www.restaurant-transparence.fr/'},
 {'Restaurant Name': "L'Empreinte",
  'Price Range': '35 - 99 EUR',
  'Restauarant Website': 'http://www.lempreinte-restaurant.fr/'},
 {'Restaurant Name': "René'Sens par Jean-François Bérard",
  'Price Range': '39 - 125 EUR',
  'Restauarant Website': 'https://www.hotel-berard.com/'},
 {'Restaurant Name': 'La Ribaudière',
  'Price Range': '54 - 120 EUR',
  'Restauarant Website': 'https://www.laribaudiere.com/'},
 {'Restaurant Name': "L'Essentiel",
  'Price Range': '34 - 75 EUR',
  'Restauarant Website': 'https://www.lessentiel-deauville.com/'},
 {'Restaurant Name': 'Dominique Bouchet',
  'Price Range': '58 - 145 EUR',
  'Restauarant Website': 'https://www.dominique-bouchet.com/'},
 {'Restaurant Name': "L'Observatoire du Gabriel",
  'Price Range': '52 - 160 EUR',
  'Restauarant Website': 'https://www.bordeaux-gabriel.fr/'},
 {'Restaurant Name': 'Le Marcq',
  'Price Range': '34 - 79 EUR',
  'Restauarant Website': 'https://www.lemarcq.fr/'},
 {'Restaurant Name': 'La Table du Gourmet',
  'Price Range': '90 - 130 EUR',
  'Restauarant Website': 'https://www.jlbrendel.com/'},
 {'Restaurant Name': "L'Axel",
  'Price Range': '45 - 160 EUR',
  'Restauarant Website': 'http://www.laxel-restaurant.com/'},
 {'Restaurant Name': "Auberge Grand'Maison",
  'Price Range': '31 - 76 EUR',
  'Restauarant Website': 'https://www.auberge-grand-maison.com/'},
 {'Restaurant Name': 'Lait Thym Sel',
  'Price Range': '70 EUR',
  'Restauarant Website': 'https://www.laitthymsel.fr/'},
 {'Restaurant Name': 'La Grande Cascade',
  'Price Range': '105 - 215 EUR',
  'Restauarant Website': 'https://www.restaurantsparisiens.com/'},
 {'Restaurant Name': 'Haut Bonheur de la Table',
  'Price Range': '46 - 58 EUR',
  'Restauarant Website': 'https://www.hautbonheurdelatable.com/'},
 {'Restaurant Name': 'Le Baudelaire',
  'Price Range': '62 - 150 EUR',
  'Restauarant Website': 'https://www.leburgundy.com/'},
 {'Restaurant Name': 'Les Genêts',
  'Price Range': '28 - 72 EUR',
  'Restauarant Website': 'https://www.restaurant-les-genets.fr/'},
 {'Restaurant Name': 'La Barbacane',
  'Price Range': '45 - 130 EUR',
  'Restauarant Website': 'www.cite-hotels.com/fr/etablissements/restaurant-la-barbacane.html'},
 {'Restaurant Name': 'Colette',
  'Price Range': '70 - 110 EUR',
  'Restauarant Website': 'https://www.colettesainttropez.com/'},
 {'Restaurant Name': 'Le Charlemagne',
  'Price Range': '68 - 98 EUR',
  'Restauarant Website': 'https://www.lecharlemagne.fr/'},
 {'Restaurant Name': "La Table d'Uzès",
  'Price Range': '34 - 120 EUR',
  'Restauarant Website': 'https://www.lamaisonduzes.fr/'},
 {'Restaurant Name': 'Soléna',
  'Price Range': '35 - 98 EUR',
  'Restauarant Website': 'https://www.solena-restaurant.com/'},
 {'Restaurant Name': 'Albert 1er',
  'Price Range': '85 - 176 EUR',
  'Restauarant Website': 'www.hameaualbert.fr'},
 {'Restaurant Name': 'Pollen',
  'Price Range': '30 - 60 EUR',
  'Restauarant Website': 'https://www.pollen-restaurant.fr/'},
 {'Restaurant Name': "L'Hysope",
  'Price Range': '48 - 102 EUR',
  'Restauarant Website': 'https://www.lhysope.fr/'},
 {'Restaurant Name': 'Le Jardin de Berne',
  'Price Range': '105 - 160 EUR',
  'Restauarant Website': 'https://www.chateauberne.com/'},
 {'Restaurant Name': 'La Table - Hôtel Clarance',
  'Price Range': '55 - 115 EUR',
  'Restauarant Website': 'https://www.clarancehotel.com/'},
 {'Restaurant Name': 'La Table des Merville',
  'Price Range': '35 - 110 EUR',
  'Restauarant Website': 'http://www.table-des-merville.fr/'},
 {'Restaurant Name': 'La Table du Connétable - Auberge du Jeu de Paume',
  'Price Range': '54 - 145 EUR',
  'Restauarant Website': 'https://www.aubergedujeudepaumechantilly.fr/'},
 {'Restaurant Name': 'Le Donjon - Domaine Saint-Clair',
  'Price Range': '35 - 105 EUR',
  'Restauarant Website': 'https://www.hoteletretat.com/'},
 {'Restaurant Name': 'Le Corot',
  'Price Range': '95 - 145 EUR',
  'Restauarant Website': 'https://www.etangs-corot.com/'},
 {'Restaurant Name': 'Restaurant Pierre Grein',
  'Price Range': '60 - 130 EUR',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'La Mère Germaine',
  'Price Range': '88 - 118 EUR',
  'Restauarant Website': 'https://www.lameregermaine-chateauneufdupape.fr/'},
 {'Restaurant Name': 'La Table de Castigno',
  'Price Range': '47 - 98 EUR',
  'Restauarant Website': 'https://villagecastigno.com/'},
 {'Restaurant Name': 'La Table de la Ferme',
  'Price Range': '210 EUR',
  'Restauarant Website': 'https://www.murtoli.com/'},
 {'Restaurant Name': 'Le Dallaison',
  'Price Range': '35 - 69 EUR',
  'Restauarant Website': 'https://www.ledallaison.com/'},
 {'Restaurant Name': 'Le Prince Noir - Vivien Durand',
  'Price Range': '60 - 125 EUR',
  'Restauarant Website': 'https://www.leprincenoir-restaurant.fr/'},
 {'Restaurant Name': 'Buerehiesel',
  'Price Range': '46 - 114 EUR',
  'Restauarant Website': 'https://www.buerehiesel.fr/'},
 {'Restaurant Name': "Villa de l'Étang Blanc",
  'Price Range': '35 - 85 EUR',
  'Restauarant Website': 'https://www.villaetangblanc.fr/'},
 {'Restaurant Name': 'Le Gindreau',
  'Price Range': '75 - 135 EUR',
  'Restauarant Website': 'http://www.legindreau.com/'},
 {'Restaurant Name': 'Auberge au Bœuf',
  'Price Range': '38 - 102 EUR',
  'Restauarant Website': 'https://www.auberge-au-boeuf.fr/'},
 {'Restaurant Name': 'Fleur de Pavé',
  'Price Range': '45 - 110 EUR',
  'Restauarant Website': 'http://www.fleurdepave.com/'},
 {'Restaurant Name': 'Auberge de Montfleury',
  'Price Range': '25 - 90 EUR',
  'Restauarant Website': 'https://www.auberge-de-montfleury.fr/'},
 {'Restaurant Name': 'Pierre Reboul',
  'Price Range': '75 - 145 EUR',
  'Restauarant Website': 'https://www.chateaudelapioline.com/'},
 {'Restaurant Name': 'La Bonne Étape',
  'Price Range': '88 - 135 EUR',
  'Restauarant Website': 'https://www.bonneetape.com/'},
 {'Restaurant Name': 'Le George',
  'Price Range': '62 - 140 EUR',
  'Restauarant Website': 'https://www.legeorge.com/'},
 {'Restaurant Name': 'Alliance',
  'Price Range': '59 - 195 EUR',
  'Restauarant Website': 'https://www.restaurant-alliance.fr/'},
 {'Restaurant Name': 'Nomicos',
  'Price Range': '49 - 160 EUR',
  'Restauarant Website': 'https://www.nomicos.fr/'},
 {'Restaurant Name': 'Roscanvec',
  'Price Range': '38 - 105 EUR',
  'Restauarant Website': 'www.roscanvec.com'},
 {'Restaurant Name': "Château d'Adoménil",
  'Price Range': '79 - 160 EUR',
  'Restauarant Website': 'http://www.adomenil.com/'},
 {'Restaurant Name': 'Table - Bruno Verjus',
  'Price Range': '70 - 240 EUR',
  'Restauarant Website': 'https://www.table.paris/'},
 {'Restaurant Name': 'Aspic',
  'Price Range': '85 EUR',
  'Restauarant Website': 'https://www.aspic-restaurant.fr/'},
 {'Restaurant Name': "L'Aquarelle",
  'Price Range': '56 - 120 EUR',
  'Restauarant Website': 'https://www.laquarelle.net/'},
 {'Restaurant Name': 'Les Trois Soleils de Montal',
  'Price Range': '38 - 92 EUR',
  'Restauarant Website': 'www.3soleils.fr'},
 {'Restaurant Name': 'Auberge Le Prieuré',
  'Price Range': '33 - 89 EUR',
  'Restauarant Website': 'https://www.aubergeleprieure.fr/'},
 {'Restaurant Name': 'La Source',
  'Price Range': '35 - 90 EUR',
  'Restauarant Website': 'https://www.lacharpiniere.com/'},
 {'Restaurant Name': 'La Terrasse',
  'Price Range': '128 - 152 EUR',
  'Restauarant Website': 'https://www.hotellesrochesrouges.com/'},
 {'Restaurant Name': 'Le Pousse-Pied',
  'Price Range': '20 - 75 EUR',
  'Restauarant Website': 'https://www.lepoussepied.fr/'},
 {'Restaurant Name': 'Roza',
  'Price Range': '25 - 68 EUR',
  'Restauarant Website': 'https://www.restaurantroza.com/'},
 {'Restaurant Name': 'Origines',
  'Price Range': '60 - 110 EUR',
  'Restauarant Website': 'https://www.restaurant-origines.fr/'},
 {'Restaurant Name': "Les Clefs d'Argent",
  'Price Range': '25 - 100 EUR',
  'Restauarant Website': 'https://www.clefs-dargent.com/'},
 {'Restaurant Name': 'La Promenade',
  'Price Range': '53 - 102 EUR',
  'Restauarant Website': 'https://www.restaurantdallaislapromenade.com/'},
 {'Restaurant Name': 'Le Jules Verne',
  'Price Range': '135 - 230 EUR',
  'Restauarant Website': 'https://www.restaurants-toureiffel.com/fr/restaurant-jules-verne.html'},
 {'Restaurant Name': 'Lamartine',
  'Price Range': '70 - 115 EUR',
  'Restauarant Website': 'https://www.lamartine-marin.com/'},
 {'Restaurant Name': 'Auguste',
  'Price Range': '39 - 120 EUR',
  'Restauarant Website': 'https://www.restaurantauguste.fr/'},
 {'Restaurant Name': 'Apicius',
  'Price Range': '39 - 120 EUR',
  'Restauarant Website': 'https://www.apicius-clermont.com/'},
 {'Restaurant Name': 'Le Lièvre Gourmand',
  'Price Range': '47 - 88 EUR',
  'Restauarant Website': 'http://www.lelievregourmand.com/'},
 {'Restaurant Name': 'Château de Massillan',
  'Price Range': '59 - 99 EUR',
  'Restauarant Website': 'https://www.chateaudemassillan.fr/'},
 {'Restaurant Name': 'La Signoria',
  'Price Range': '92 - 195 EUR',
  'Restauarant Website': 'https://www.hotel-la-signoria.com/'},
 {'Restaurant Name': "L'Aparté",
  'Price Range': '32 - 105 EUR',
  'Restauarant Website': 'https://www.restaurant-laparte.fr/'},
 {'Restaurant Name': 'Numéro 3',
  'Price Range': '70 EUR',
  'Restauarant Website': 'https://www.restaurant-numero3.fr/'},
 {'Restaurant Name': 'Frédéric Doucet',
  'Price Range': '45 - 125 EUR',
  'Restauarant Website': 'https://www.maison-doucet.com/'},
 {'Restaurant Name': '1131',
  'Price Range': '98 - 145 EUR',
  'Restauarant Website': 'https://www.abbayedelabussiere.fr/'},
 {'Restaurant Name': "L'Allée des Vignes",
  'Price Range': '59 - 89 EUR',
  'Restauarant Website': 'https://www.alleedesvignes.com/'},
 {'Restaurant Name': 'ERH',
  'Price Range': '65 - 140 EUR',
  'Restauarant Website': 'https://www.restaurant-erh.com/'},
 {'Restaurant Name': 'La Vieille Tour',
  'Price Range': '37 - 57 EUR',
  'Restauarant Website': 'https://www.restaurant-la-vieille-tour-blois.com/'},
 {'Restaurant Name': 'Nature',
  'Price Range': '28 - 72 EUR',
  'Restauarant Website': 'https://www.restaurant-nature.com/'},
 {'Restaurant Name': 'Lalique',
  'Price Range': '95 - 165 EUR',
  'Restauarant Website': 'https://www.lafauriepeyragueylalique.com/'},
 {'Restaurant Name': 'Le Restaurant des Rois',
  'Price Range': '195 - 240 EUR',
  'Restauarant Website': 'https://www.reservebeaulieu.com/'},
 {'Restaurant Name': 'Le Carmin',
  'Price Range': '38 - 128 EUR',
  'Restauarant Website': 'https://www.restaurant-lecarmin.com/'},
 {'Restaurant Name': 'Moulin de Rosmadec',
  'Price Range': '47 - 117 EUR',
  'Restauarant Website': 'https://www.rosmadec.com/'},
 {'Restaurant Name': "L'Évidence",
  'Price Range': '39 - 108 EUR',
  'Restauarant Website': 'http://www.restaurant-levidence.com/'},
 {'Restaurant Name': 'Ô Flaveurs',
  'Price Range': '75 - 135 EUR',
  'Restauarant Website': 'https://www.oflaveurs.com/'},
 {'Restaurant Name': 'Le Pressoir',
  'Price Range': '36 - 110 EUR',
  'Restauarant Website': 'www.le-pressoir.fr'},
 {'Restaurant Name': 'Radio',
  'Price Range': '32 - 109 EUR',
  'Restauarant Website': 'https://www.hotel-radio.fr/'},
 {'Restaurant Name': 'Claude Darroze',
  'Price Range': '39 - 120 EUR',
  'Restauarant Website': 'https://www.darroze.com/'},
 {'Restaurant Name': 'La Chapelle Saint-Martin',
  'Price Range': '75 - 234 EUR',
  'Restauarant Website': 'https://www.chapellesaintmartin.com/'},
 {'Restaurant Name': 'Les Foudres',
  'Price Range': '95 - 135 EUR',
  'Restauarant Website': 'https://www.chaismonnethotel.com/'},
 {'Restaurant Name': 'ES',
  'Price Range': '80 - 150 EUR',
  'Restauarant Website': 'https://www.es-restaurant.fr/'},
 {'Restaurant Name': 'Le 7ème Continent',
  'Price Range': '83 - 115 EUR',
  'Restauarant Website': 'https://www.le7emecontinent.com/'},
 {'Restaurant Name': 'Auberge des Saints Pères',
  'Price Range': '46 - 85 EUR',
  'Restauarant Website': 'https://www.auberge-des-saints-peres.fr/'},
 {'Restaurant Name': 'La Table du 11',
  'Price Range': '55 - 65 EUR',
  'Restauarant Website': 'https://www.latabledu11.com/'},
 {'Restaurant Name': 'Frédéric Simonin',
  'Price Range': '60 - 162 EUR',
  'Restauarant Website': 'https://www.fredericsimonin.com/'},
 {'Restaurant Name': 'Auberge de la Mine',
  'Price Range': '42 - 77 EUR',
  'Restauarant Website': 'https://www.aubergedelamine.com/'},
 {'Restaurant Name': 'Copenhague',
  'Price Range': '55 - 115 EUR',
  'Restauarant Website': 'https://www.restaurant-copenhague-paris.fr/'},
 {'Restaurant Name': 'Auberge à la Bonne Idée',
  'Price Range': '84 - 155 EUR',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Alchémille',
  'Price Range': '90 - 110 EUR',
  'Restauarant Website': 'https://www.lalchemille.fr/'},
 {'Restaurant Name': 'Le Art',
  'Price Range': '63 - 185 EUR',
  'Restauarant Website': 'https://www.chateaudelagaude.com/'},
 {'Restaurant Name': 'Le Farçon',
  'Price Range': '48 - 146 EUR',
  'Restauarant Website': 'https://www.lefarcon.fr/'},
 {'Restaurant Name': 'Quai des Saveurs',
  'Price Range': '75 - 125 EUR',
  'Restauarant Website': 'https://www.quaidessaveurs.com/'},
 {'Restaurant Name': 'Le Fantin Latour - Stéphane Froidevaux',
  'Price Range': '58 - 90 EUR',
  'Restauarant Website': 'https://www.fantin-latour.fr/'},
 {'Restaurant Name': 'Maximilien',
  'Price Range': '36 - 120 EUR',
  'Restauarant Website': 'https://www.le-maximilien.com/'},
 {'Restaurant Name': 'Le Chiquito',
  'Price Range': '70 - 107 EUR',
  'Restauarant Website': 'https://www.lechiquito.fr/'},
 {'Restaurant Name': 'Manoir de Lan-Kerellec',
  'Price Range': '33 - 120 EUR',
  'Restauarant Website': 'https://www.lankerellec.com/'},
 {'Restaurant Name': 'La Licorne Royale',
  'Price Range': '59 - 120 EUR',
  'Restauarant Website': 'https://www.hotel-licorne.com/'},
 {'Restaurant Name': "Auberge Pom'Poire",
  'Price Range': '36 - 74 EUR',
  'Restauarant Website': 'https://www.aubergepompoire.fr/'},
 {'Restaurant Name': 'Ambroisie',
  'Price Range': '78 - 126 EUR',
  'Restauarant Website': 'https://www.restaurant-ambroisie.fr/'},
 {'Restaurant Name': "Auberge du Pont d'Acigné",
  'Price Range': '28 - 115 EUR',
  'Restauarant Website': 'https://www.auberge-du-pont-dacigne.com/'},
 {'Restaurant Name': 'Le St-Placide',
  'Price Range': '35 - 115 EUR',
  'Restauarant Website': 'https://www.st-placide.com/'},
 {'Restaurant Name': 'Les Hautes Roches',
  'Price Range': '68 - 130 EUR',
  'Restauarant Website': 'https://www.leshautesroches.com/'},
 {'Restaurant Name': 'Le Clocher des Pères',
  'Price Range': '75 - 90 EUR',
  'Restauarant Website': 'http://www.leclocherdesperes.com/'},
 {'Restaurant Name': 'La Galinette',
  'Price Range': '28 - 60 EUR',
  'Restauarant Website': 'https://www.restaurant-galinette.com/'},
 {'Restaurant Name': "Neige d'Été",
  'Price Range': '65 - 180 EUR',
  'Restauarant Website': 'https://www.neigedete.fr/'},
 {'Restaurant Name': 'Pure & V',
  'Price Range': '80 - 120 EUR',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'La Chassagnette',
  'Price Range': '67 - 145 EUR',
  'Restauarant Website': 'https://www.chassagnette.fr/'},
 {'Restaurant Name': 'Virtus',
  'Price Range': '39 - 165 EUR',
  'Restauarant Website': 'https://www.virtus-paris.com/'},
 {'Restaurant Name': 'Auberge Frankenbourg',
  'Price Range': '44 - 98 EUR',
  'Restauarant Website': 'https://www.frankenbourg.com/'},
 {'Restaurant Name': 'Louroc',
  'Price Range': '158 - 240 EUR',
  'Restauarant Website': 'https://www.hotel-du-cap-eden-roc.com/'},
 {'Restaurant Name': 'La Vieille Tour',
  'Price Range': '34 - 85 EUR',
  'Restauarant Website': 'https://www.la-vieille-tour.com/'},
 {'Restaurant Name': 'La Madeleine',
  'Price Range': '50 - 125 EUR',
  'Restauarant Website': 'https://www.restaurant-lamadeleine.fr/'},
 {'Restaurant Name': 'Faventia',
  'Price Range': '85 - 175 EUR',
  'Restauarant Website': 'https://www.terre-blanche.com/'},
 {'Restaurant Name': 'Ken Kawasaki',
  'Price Range': '45 - 95 EUR',
  'Restauarant Website': 'https://www.restaurantkenkawasaki.fr/'},
 {'Restaurant Name': 'La Passagère',
  'Price Range': '135 - 185 EUR',
  'Restauarant Website': 'https://www.bellesrives.com/'},
 {'Restaurant Name': 'Le Pourquoi Pas',
  'Price Range': '39 - 105 EUR',
  'Restauarant Website': 'https://www.castelbrac.com/'},
 {'Restaurant Name': "La Table d'à Côté",
  'Price Range': '60 - 103 EUR',
  'Restauarant Website': 'https://www.latabledacote.fr/'},
 {'Restaurant Name': 'La Cachette',
  'Price Range': '50 - 120 EUR',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Relais Louis XIII',
  'Price Range': '65 - 145 EUR',
  'Restauarant Website': 'http://www.relaislouis13.com/'},
 {'Restaurant Name': 'Les Tables de Gaspard',
  'Price Range': '36 - 74 EUR',
  'Restauarant Website': 'http://www.lestablesdegaspard.com/'},
 {'Restaurant Name': 'Le Saint-Martin',
  'Price Range': '65 - 130 EUR',
  'Restauarant Website': 'https://www.chateau-st-martin.com/'},
 {'Restaurant Name': 'Akrame',
  'Price Range': '75 - 160 EUR',
  'Restauarant Website': 'https://www.akrame.com/'},
 {'Restaurant Name': 'Lea Linster',
  'Price Range': '129 - 189 EUR',
  'Restauarant Website': 'https://www.lealinster.lu/'},
 {'Restaurant Name': 'Mosconi',
  'Price Range': '55 - 150 EUR',
  'Restauarant Website': 'http://www.mosconi.lu/'},
 {'Restaurant Name': 'La Distillerie',
  'Price Range': '120 - 150 EUR',
  'Restauarant Website': 'https://www.bourglinster.lu/'},
 {'Restaurant Name': 'La Cristallerie',
  'Price Range': '58 - 178 EUR',
  'Restauarant Website': 'https://www.la-cristallerie.com/'},
 {'Restaurant Name': 'Fani',
  'Price Range': '50 - 145 EUR',
  'Restauarant Website': 'https://www.fani.lu/'},
 {'Restaurant Name': 'Clairefontaine',
  'Price Range': '57 - 112 EUR',
  'Restauarant Website': 'https://www.restaurantclairefontaine.lu/'},
 {'Restaurant Name': 'Guillou Campagne',
  'Price Range': '34 - 100 EUR',
  'Restauarant Website': 'https://www.guilloucampagne.lu/'},
 {'Restaurant Name': "Les Jardins d'Anaïs",
  'Price Range': '59 - 125 EUR',
  'Restauarant Website': 'https://www.jardinsdanais.lu/'},
 {'Restaurant Name': 'Le Comptoir de Marie',
  'Price Range': '39 - 119 EUR',
  'Restauarant Website': 'https://www.lecomptoirdemarie.be/'},
 {'Restaurant Name': "The Butcher's son",
  'Price Range': '64 - 92 EUR',
  'Restauarant Website': 'https://www.thebutchersson.be/'},
 {'Restaurant Name': "'t Fornuis",
  'Price Range': '75 - 125 EUR',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Le Grand Cap',
  'Price Range': '45 - 115 EUR',
  'Restauarant Website': 'https://www.restaurant-grand-cap.fr/'},
 {'Restaurant Name': "L'Aparté",
  'Price Range': '54 - 119 CHF',
  'Restauarant Website': 'https://www.hotelroyalgeneva.com/'},
 {'Restaurant Name': "Le Carré d'Alethius",
  'Price Range': '32 - 110 EUR',
  'Restauarant Website': 'https://www.lecarredalethius.com/'},
 {'Restaurant Name': 'Table de Mary',
  'Price Range': '69 - 135 CHF',
  'Restauarant Website': 'https://www.latabledemary.ch/'},
 {'Restaurant Name': 'Ambroisie',
  'Price Range': '78 - 126 EUR',
  'Restauarant Website': 'https://www.restaurant-ambroisie.fr/'},
 {'Restaurant Name': 'Tsé Fung',
  'Price Range': '78 - 188 CHF',
  'Restauarant Website': 'https://www.tsefung.ch/'},
 {'Restaurant Name': 'Flaveurs',
  'Price Range': '38 - 98 EUR',
  'Restauarant Website': 'https://www.flaveurs-restaurant.com/'},
 {'Restaurant Name': 'La Cachette',
  'Price Range': '50 - 120 EUR',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Wolfshöhle',
  'Price Range': '39 - 125 EUR',
  'Restauarant Website': 'http://www.wolfshoehle-freiburg.de/'},
 {'Restaurant Name': 'Traube',
  'Price Range': '89 - 120 EUR',
  'Restauarant Website': 'http://www.traube-blansingen.de/'},
 {'Restaurant Name': "Zehner's Stube",
  'Price Range': '87 - 135 EUR',
  'Restauarant Website': 'https://www.zehnersstube.de/'},
 {'Restaurant Name': 'temporaire - Köhlerstube',
  'Price Range': '125 - 155 EUR',
  'Restauarant Website': 'https://www.traube-tonbach.de/'},
 {'Restaurant Name': 'Laudensacks Gourmet Restaurant',
  'Price Range': '76 - 138 EUR',
  'Restauarant Website': 'https://www.laudensacks-parkhotel.de/'},
 {'Restaurant Name': 'Auberge St-Laurent',
  'Price Range': '33 - 86 EUR',
  'Restauarant Website': 'https://www.auberge-saintlaurent.fr/'},
 {'Restaurant Name': 'Storchen',
  'Price Range': '42 - 128 EUR',
  'Restauarant Website': 'https://www.storchen-schmidhofen.de/'},
 {'Restaurant Name': 'Auberge de Montfleury',
  'Price Range': '25 - 90 EUR',
  'Restauarant Website': 'https://www.auberge-de-montfleury.fr/'},
 {'Restaurant Name': 'Maison Chabran - La Grande Table',
  'Price Range': '119 - 139 EUR',
  'Restauarant Website': 'https://www.maisonchabran.com/'},
 {'Restaurant Name': 'Schlossberg',
  'Price Range': '103 - 172 EUR',
  'Restauarant Website': 'www.hotel-sackmann.de'},
 {'Restaurant Name': 'Restaurant De Lauzun',
  'Price Range': '36 - 110 EUR',
  'Restauarant Website': 'https://www.restaurant-delauzun.com/'},
 {'Restaurant Name': 'Alte Schule - Klassenzimmer',
  'Price Range': '110 - 160 EUR',
  'Restauarant Website': 'https://www.hotelalteschule.de/'},
 {'Restaurant Name': 'Le Cor de Chasse',
  'Price Range': '40 - 105 EUR',
  'Restauarant Website': 'https://www.lecordechasse.be/'},
 {'Restaurant Name': "'t Overhamme",
  'Price Range': '47 - 95 EUR',
  'Restauarant Website': 'https://www.toverhamme.be/'},
 {'Restaurant Name': 'Michel',
  'Price Range': '52 - 131 EUR',
  'Restauarant Website': 'https://www.restaurant-michel.be/'},
 {'Restaurant Name': 'Attablez-vous',
  'Price Range': '32 - 75 EUR',
  'Restauarant Website': 'https://www.attablezvous.be/'},
 {'Restaurant Name': 'Eyckerhof',
  'Price Range': '49 - 110 EUR',
  'Restauarant Website': 'https://www.eyckerhof.be/'},
 {'Restaurant Name': "'t Truffeltje",
  'Price Range': '45 - 100 EUR',
  'Restauarant Website': 'https://www.truffeltje.be/'},
 {'Restaurant Name': 'Kommilfoo',
  'Price Range': '42 - 115 EUR',
  'Restauarant Website': 'https://www.restaurantkommilfoo.be/'},
 {'Restaurant Name': 'Zur Post',
  'Price Range': '45 - 100 EUR',
  'Restauarant Website': 'https://www.hotelzurpost.be/'},
 {'Restaurant Name': 'De Pastorie',
  'Price Range': '50 - 130 EUR',
  'Restauarant Website': 'https://www.restaurantdepastorie.be/'},
 {'Restaurant Name': 'Sans Cravate',
  'Price Range': '48 - 114 EUR',
  'Restauarant Website': 'https://www.sanscravate.be/'},
 {'Restaurant Name': 'OAK',
  'Price Range': '74 - 119 EUR',
  'Restauarant Website': 'https://www.oakgent.be/'},
 {'Restaurant Name': 'Le Pilori',
  'Price Range': '36 - 95 EUR',
  'Restauarant Website': 'https://www.pilori.be/'},
 {'Restaurant Name': 'La Belle',
  'Price Range': '54 - 125 EUR',
  'Restauarant Website': 'https://www.la-belle.be/'},
 {'Restaurant Name': 'Innesto',
  'Price Range': '43 - 125 EUR',
  'Restauarant Website': 'https://www.innesto.be/'},
 {'Restaurant Name': 'Bistro Racine',
  'Price Range': '24 - 65 EUR',
  'Restauarant Website': 'https://www.bistroracine.be/'},
 {'Restaurant Name': "Auberge de la Grappe d'Or",
  'Price Range': '72 - 84 EUR',
  'Restauarant Website': 'https://www.lagrappedor.com/'},
 {'Restaurant Name': 'Auberge de Herborist',
  'Price Range': '58 - 98 EUR',
  'Restauarant Website': 'https://www.aubergedeherborist.be/'},
 {'Restaurant Name': 'Boo Raan',
  'Price Range': '39 - 55 EUR',
  'Restauarant Website': 'https://www.booraan.be/'},
 {'Restaurant Name': 'Le Château de Strainchamps',
  'Price Range': '45 - 100 EUR',
  'Restauarant Website': 'https://www.chateaudestrainchamps.com/'},
 {'Restaurant Name': 'Publiek',
  'Price Range': '38 - 98 EUR',
  'Restauarant Website': 'https://www.publiekgent.be/'},
 {'Restaurant Name': 'La Ligne Rouge',
  'Price Range': '38 - 95 EUR',
  'Restauarant Website': 'https://www.lalignerouge.be/'},
 {'Restaurant Name': 'Héliport Brasserie',
  'Price Range': '38 - 92 EUR',
  'Restauarant Website': 'http://www.heliportbrasserie.be/'},
 {'Restaurant Name': 'Da Mimmo',
  'Price Range': '55 - 125 EUR',
  'Restauarant Website': 'https://www.da-mimmo.be/'},
 {'Restaurant Name': 'Au Gré du Vent',
  'Price Range': '45 - 110 EUR',
  'Restauarant Website': 'https://www.resto-augreduvent.be/'},
 {'Restaurant Name': 'Dôme',
  'Price Range': '45 - 130 EUR',
  'Restauarant Website': 'https://www.domeantwerp.be/'},
 {'Restaurant Name': 'Couvert Couvert',
  'Price Range': '50 - 135 EUR',
  'Restauarant Website': 'https://www.couvertcouvert.be/'},
 {'Restaurant Name': 'Goffin',
  'Price Range': '50 - 105 EUR',
  'Restauarant Website': 'https://www.timothygoffin.be/'},
 {'Restaurant Name': 'senzanome',
  'Price Range': '50 - 165 EUR',
  'Restauarant Website': 'https://www.senzanome.be/'},
 {'Restaurant Name': 'Le Pristine',
  'Price Range': '80 - 110 EUR',
  'Restauarant Website': 'https://www.lepristine.be/'},
 {'Restaurant Name': "'t Stoveke",
  'Price Range': '38 - 132 EUR',
  'Restauarant Website': 'https://www.tstoveke.be/'},
 {'Restaurant Name': 'Lettres Gourmandes',
  'Price Range': '24 - 70 EUR',
  'Restauarant Website': 'https://www.lettresgourmandes.be/'},
 {'Restaurant Name': 'Carcasse',
  'Price Range': '35 - 150 EUR',
  'Restauarant Website': 'https://www.carcasse.be/'},
 {'Restaurant Name': 'Bar Bulot',
  'Price Range': '65 - 95 EUR',
  'Restauarant Website': 'https://www.barbulot.be/'},
 {'Restaurant Name': 'Chai Gourmand',
  'Price Range': '45 - 135 EUR',
  'Restauarant Website': 'https://www.chaigourmand.be/'},
 {'Restaurant Name': 'De Kristalijn',
  'Price Range': '55 - 158 EUR',
  'Restauarant Website': 'https://www.dekristalijn.be/'},
 {'Restaurant Name': "La Plage d'Amée",
  'Price Range': '28 - 94 EUR',
  'Restauarant Website': 'http://www.laplagedamee.be/'},
 {'Restaurant Name': 'Het Gebaar',
  'Price Range': '75 - 150 EUR',
  'Restauarant Website': 'https://www.hetgebaar.be/'},
 {'Restaurant Name': 'Melchior',
  'Price Range': '35 - 100 EUR',
  'Restauarant Website': 'https://www.melchi-or.be/'},
 {'Restaurant Name': 'Wine in the City',
  'Price Range': '45 - 100 EUR',
  'Restauarant Website': 'https://www.wineinthecity.be/'},
 {'Restaurant Name': 'Les Pieds dans le Plat',
  'Price Range': '34 - 95 EUR',
  'Restauarant Website': 'https://www.lespiedsdansleplat.be/'},
 {'Restaurant Name': 'Auberge au Bœuf',
  'Price Range': '38 - 102 EUR',
  'Restauarant Website': 'https://www.auberge-au-boeuf.fr/'},
 {'Restaurant Name': 'Les Funambules',
  'Price Range': '29 - 67 EUR',
  'Restauarant Website': 'https://www.restaurantlesfunambules.com/'},
 {'Restaurant Name': '1741',
  'Price Range': '45 - 135 EUR',
  'Restauarant Website': 'https://www.1741.fr/'},
 {'Restaurant Name': 'Au Crocodile',
  'Price Range': '74 - 138 EUR',
  'Restauarant Website': 'https://www.au-crocodile.com/'},
 {'Restaurant Name': 'La Nouvelle Auberge',
  'Price Range': '45 - 110 EUR',
  'Restauarant Website': 'https://www.nauberge.com/'},
 {'Restaurant Name': 'Umami',
  'Price Range': '63 - 70 EUR',
  'Restauarant Website': 'https://www.restaurant-umami.com/'},
 {'Restaurant Name': 'Le Jardin Secret',
  'Price Range': '32 - 68 EUR',
  'Restauarant Website': 'https://www.restaurant-jardinsecret.fr/'},
 {'Restaurant Name': 'Julien Binz',
  'Price Range': '68 - 100 EUR',
  'Restauarant Website': 'https://www.restaurantjulienbinz.com/'},
 {'Restaurant Name': 'Maximilien',
  'Price Range': '36 - 120 EUR',
  'Restauarant Website': 'https://www.le-maximilien.com/'},
 {'Restaurant Name': 'Les Plaisirs Gourmands',
  'Price Range': '32 - 75 EUR',
  'Restauarant Website': 'https://www.les-plaisirs-gourmands.com/'},
 {'Restaurant Name': 'La Table du Gourmet',
  'Price Range': '90 - 130 EUR',
  'Restauarant Website': 'https://www.jlbrendel.com/'},
 {'Restaurant Name': 'Alchémille',
  'Price Range': '90 - 110 EUR',
  'Restauarant Website': 'https://www.lalchemille.fr/'},
 {'Restaurant Name': 'Christian & Friends, Tastekitchen',
  'Price Range': '30 - 75 EUR',
  'Restauarant Website': 'https://www.christianandfriends.de/'},
 {'Restaurant Name': 'Thierry Schwartz - Le Restaurant',
  'Price Range': '59 - 139 EUR',
  'Restauarant Website': 'https://www.thierry-schwartz.fr/'},
 {'Restaurant Name': 'Auberge Frankenbourg',
  'Price Range': '44 - 98 EUR',
  'Restauarant Website': 'https://www.frankenbourg.com/'},
 {'Restaurant Name': 'Miraflores',
  'Price Range': '45 - 180 EUR',
  'Restauarant Website': 'https://www.restaurant-miraflores.com/'},
 {'Restaurant Name': 'Le Gourmet de Sèze',
  'Price Range': '65 - 120 EUR',
  'Restauarant Website': 'https://www.legourmetdeseze.com/'},
 {'Restaurant Name': 'Le Passe Temps',
  'Price Range': '39 - 105 EUR',
  'Restauarant Website': 'https://www.lepassetemps-restaurant.com/'},
 {'Restaurant Name': 'Les Trois Dômes',
  'Price Range': '48 - 174 EUR',
  'Restauarant Website': 'https://www.les-3-domes.com/'},
 {'Restaurant Name': 'Les Apothicaires',
  'Price Range': '37 - 79 EUR',
  'Restauarant Website': 'http://www.lesapothicairesrestaurant.com/'},
 {'Restaurant Name': 'L.E.S.S.',
  'Price Range': '47 - 120 EUR',
  'Restauarant Website': 'https://www.l-e-s-s.be/'},
 {'Restaurant Name': 'Hostellerie Gilain',
  'Price Range': '44 - 115 EUR',
  'Restauarant Website': 'https://www.hostelleriegilain.com/'},
 {'Restaurant Name': 'Ogst',
  'Price Range': '42 - 90 EUR',
  'Restauarant Website': 'https://www.ogst.be/'},
 {'Restaurant Name': 'Hof Ter Hulst',
  'Price Range': '45 - 120 EUR',
  'Restauarant Website': 'https://www.hofterhulst.be/'},
 {'Restaurant Name': 'Souvenir',
  'Price Range': '48 - 110 EUR',
  'Restauarant Website': 'https://www.souvenir.gent/'},
 {'Restaurant Name': 'EssenCiel',
  'Price Range': '30 - 90 EUR',
  'Restauarant Website': 'https://www.essenciel.be/'},
 {'Restaurant Name': "L'impératif",
  'Price Range': '49 - 108 EUR',
  'Restauarant Website': 'https://www.domainedarondeau.com/'},
 {'Restaurant Name': 'Le Pigeon Noir',
  'Price Range': '33 - 74 EUR',
  'Restauarant Website': 'https://www.lepigeonnoir.be/'},
 {'Restaurant Name': 'JER',
  'Price Range': '45 - 105 EUR',
  'Restauarant Website': 'https://www.jer.be/'},
 {'Restaurant Name': 'Altermezzo',
  'Price Range': '90 - 235 EUR',
  'Restauarant Website': 'https://www.altermezzo.be/'},
 {'Restaurant Name': 'Bozar Restaurant',
  'Price Range': '54 - 159 EUR',
  'Restauarant Website': 'https://www.bozarrestaurant.be/'},
 {'Restaurant Name': 'Nathan',
  'Price Range': '32 - 130 EUR',
  'Restauarant Website': 'https://www.restaurant-nathan.be/'},
 {'Restaurant Name': 'Centpourcent',
  'Price Range': '46 - 102 EUR',
  'Restauarant Website': 'https://www.centpourcent.be/'},
 {'Restaurant Name': 'FRANQ',
  'Price Range': '39 - 152 EUR',
  'Restauarant Website': 'https://www.hotelfranq.com/'},
 {'Restaurant Name': 'La Villa in the Sky',
  'Price Range': '90 - 210 EUR',
  'Restauarant Website': 'https://www.lavillainthesky.be/'},
 {'Restaurant Name': 'De Zuidkant',
  'Price Range': '69 - 93 EUR',
  'Restauarant Website': 'https://www.restaurantdezuidkant.be/'},
 {'Restaurant Name': 'Kelderman',
  'Price Range': '60 - 208 EUR',
  'Restauarant Website': 'https://www.visrestaurant-kelderman.be/'},
 {'Restaurant Name': 'Magis',
  'Price Range': '51 - 100 EUR',
  'Restauarant Website': 'https://www.restaurantmagis.be/'},
 {'Restaurant Name': 'Den Gouden Harynck',
  'Price Range': '60 - 160 EUR',
  'Restauarant Website': 'https://www.goudenharynck.be/'},
 {'Restaurant Name': 'Methavalai Sorndaeng',
  'Price Range': '400 - 1,250 THB',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Saawaan',
  'Price Range': '1,980 THB',
  'Restauarant Website': 'https://www.saawaan.com/'},
 {'Restaurant Name': 'Blue by Alain Ducasse',
  'Price Range': '1,950 - 7,350 THB',
  'Restauarant Website': 'https://www.blue-alainducasse.com/'},
 {'Restaurant Name': 'Ginza Sushi Ichi',
  'Price Range': '1,800 - 7,000 THB',
  'Restauarant Website': 'http://www.ginza-sushiichi.jp/'},
 {'Restaurant Name': 'PRU',
  'Price Range': '4,500 - 5,500 THB',
  'Restauarant Website': 'http://www.prurestaurant.com/'},
 {'Restaurant Name': 'Paste',
  'Price Range': '2,100 - 3,500 THB',
  'Restauarant Website': 'https://www.pastebangkok.com/'},
 {'Restaurant Name': 'Suan Thip',
  'Price Range': '550 - 1,500 THB',
  'Restauarant Website': 'https://www.suanthip.com/'},
 {'Restaurant Name': 'Nahm',
  'Price Range': '740 - 3,500 THB',
  'Restauarant Website': 'https://www.comohotels.com/metropolitanbangkok'},
 {'Restaurant Name': 'Sra Bua by Kiin Kiin',
  'Price Range': '1,850 - 3,200 THB',
  'Restauarant Website': 'https://www.kempinski.com/'},
 {'Restaurant Name': 'Saneh Jaan',
  'Price Range': '800 - 3,200 THB',
  'Restauarant Website': 'https://www.sanehjaan.com'},
 {'Restaurant Name': "J'AIME by Jean-Michel Lorain",
  'Price Range': '1,150 - 3,200 THB',
  'Restauarant Website': 'https://www.jaime-bangkok.com/'},
 {'Restaurant Name': 'Khao (Ekkamai)',
  'Price Range': '650 - 9,900 THB',
  'Restauarant Website': 'https://www.khaogroup.com/'},
 {'Restaurant Name': 'Cadence by Dan Bark',
  'Price Range': '4,800 THB',
  'Restauarant Website': 'https://www.cadence-danbark.com/'},
 {'Restaurant Name': 'Le Du',
  'Price Range': '3,000 - 3,590 THB',
  'Restauarant Website': 'https://www.ledubkk.com/'},
 {'Restaurant Name': 'Canvas',
  'Price Range': '4,500 THB',
  'Restauarant Website': 'https://www.canvasbangkok.com/'},
 {'Restaurant Name': 'Chim by Siam Wisdom',
  'Price Range': '450 - 2,900 THB',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': '80/20',
  'Price Range': '2,500 THB',
  'Restauarant Website': 'https://www.8020bkk.com/'},
 {'Restaurant Name': 'Jay Fai',
  'Price Range': '300 - 1,500 THB',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Elements',
  'Price Range': '3,200 - 5,200 THB',
  'Restauarant Website': 'https://www.okurabangkok.com/'},
 {'Restaurant Name': 'Sushi Masato',
  'Price Range': '1,100 - 8,000 THB',
  'Restauarant Website': 'https://www.sushimasato.com/'},
 {'Restaurant Name': 'A Cozinha',
  'Price Range': '55 - 100 EUR',
  'Restauarant Website': 'www.restauranteacozinha.pt'},
 {'Restaurant Name': 'Pietsch',
  'Price Range': '120 - 140 EUR',
  'Restauarant Website': 'https://www.restaurantpietsch.de/'},
 {'Restaurant Name': 'Urgestein im Steinhäuser Hof',
  'Price Range': '120 - 140 EUR',
  'Restauarant Website': 'https://www.restaurant-urgestein.de/'},
 {'Restaurant Name': 'L.A. Jordan',
  'Price Range': '175 - 205 EUR',
  'Restauarant Website': 'https://www.ketschauer-hof.com/'},
 {'Restaurant Name': "L'étable",
  'Price Range': '86 - 126 EUR',
  'Restauarant Website': 'www.zumsternhersfeld.de'},
 {'Restaurant Name': 'Le Puits du Trésor',
  'Price Range': '60 - 120 EUR',
  'Restauarant Website': 'https://www.lepuitsdutresor.com/'},
 {'Restaurant Name': 'THE IZAKAYA',
  'Price Range': '75 - 110 EUR',
  'Restauarant Website': 'http://www.the-izakaya.com/'},
 {'Restaurant Name': 'freustil',
  'Price Range': '66 - 99 EUR',
  'Restauarant Website': 'https://www.freustil.de/'},
 {'Restaurant Name': 'Hotell Borgholm',
  'Price Range': '700 - 1,250 SEK',
  'Restauarant Website': 'https://www.hotellborgholm.com/'},
 {'Restaurant Name': 'Kasbür',
  'Price Range': '27 - 99 EUR',
  'Restauarant Website': 'https://www.restaurant-kasbur.fr/'},
 {'Restaurant Name': 'Château Blanchard',
  'Price Range': '48 - 115 EUR',
  'Restauarant Website': 'https://www.hotel-chateau-blanchard.com/'},
 {'Restaurant Name': 'Schwarz Gourmet',
  'Price Range': '129 - 159 EUR',
  'Restauarant Website': 'https://www.schwarz-restaurant.de/'},
 {'Restaurant Name': 'Admiral',
  'Price Range': '76 - 130 EUR',
  'Restauarant Website': 'https://www.admiral-weisenheim.de/'},
 {'Restaurant Name': 'La Source',
  'Price Range': '35 - 90 EUR',
  'Restauarant Website': 'https://www.lacharpiniere.com/'},
 {'Restaurant Name': 'Le Haut-Allier',
  'Price Range': '58 - 110 EUR',
  'Restauarant Website': 'https://www.hotel-lehautallier.com/'},
 {'Restaurant Name': 'Alte Pfarrey',
  'Price Range': '82 - 134 EUR',
  'Restauarant Website': 'http://www.altepfarrey.de/'},
 {'Restaurant Name': "L'Arnsbourg",
  'Price Range': '79 - 139 EUR',
  'Restauarant Website': 'https://www.arnsbourg.com/'},
 {'Restaurant Name': 'Carmelo Greco',
  'Price Range': '73 - 97 EUR',
  'Restauarant Website': 'https://www.carmelo-greco.de/'},
 {'Restaurant Name': 'Seven Swans',
  'Price Range': '129 EUR',
  'Restauarant Website': 'https://www.sevenswans.de/'},
 {'Restaurant Name': 'Français',
  'Price Range': '69 - 205 EUR',
  'Restauarant Website': 'https://www.restaurant-francais.de/'},
 {'Restaurant Name': 'Weinsinn',
  'Price Range': '95 - 125 EUR',
  'Restauarant Website': 'www.weinsinn.de'},
 {'Restaurant Name': 'Maruja Limón',
  'Price Range': '78 - 98 EUR',
  'Restauarant Website': 'www.marujalimon.es'},
 {'Restaurant Name': 'Les Moles',
  'Price Range': '35 - 110 EUR',
  'Restauarant Website': 'www.lesmoles.com'},
 {'Restaurant Name': 'Rincón de Diego',
  'Price Range': '55 - 105 EUR',
  'Restauarant Website': 'www.rincondediego.com'},
 {'Restaurant Name': 'Estany Clar',
  'Price Range': '50 - 80 EUR',
  'Restauarant Website': 'www.estanyclar.com'},
 {'Restaurant Name': 'Ola Martín Berasategui',
  'Price Range': '66 - 125 EUR',
  'Restauarant Website': 'www.taykohotels.com'},
 {'Restaurant Name': 'Ikaro',
  'Price Range': '50 - 75 EUR',
  'Restauarant Website': 'www.restauranteikaro.com'},
 {'Restaurant Name': 'El Invernadero',
  'Price Range': '95 - 150 EUR',
  'Restauarant Website': 'www.elinvernaderorestaurante.com'},
 {'Restaurant Name': 'La Fonda Xesc',
  'Price Range': '50 - 100 EUR',
  'Restauarant Website': 'https://www.fondaxesc.com/'},
 {'Restaurant Name': "L'Aliança 1919 d'Anglès",
  'Price Range': '65 - 110 EUR',
  'Restauarant Website': 'www.alianca1919.com'},
 {'Restaurant Name': 'Solla',
  'Price Range': '98 - 140 EUR',
  'Restauarant Website': 'www.restaurantesolla.com'},
 {'Restaurant Name': 'La Prensa',
  'Price Range': '70 - 95 EUR',
  'Restauarant Website': 'www.restaurantelaprensa.com'},
 {'Restaurant Name': 'Tresmacarrons',
  'Price Range': '95 - 125 EUR',
  'Restauarant Website': 'www.tresmacarrons.com'},
 {'Restaurant Name': 'Eirado',
  'Price Range': '45 - 72 EUR',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Andra Mari',
  'Price Range': '45 - 80 EUR',
  'Restauarant Website': 'www.andra-mari.com'},
 {'Restaurant Name': 'El Ermitaño',
  'Price Range': '50 - 80 EUR',
  'Restauarant Website': 'www.elermitano.com'},
 {'Restaurant Name': 'Messina',
  'Price Range': '50 - 93 EUR',
  'Restauarant Website': 'www.restaurantemessina.com'},
 {'Restaurant Name': 'Zarate',
  'Price Range': '60 - 103 EUR',
  'Restauarant Website': 'www.zarate.restaurant'},
 {'Restaurant Name': 'Retiro da Costiña',
  'Price Range': '65 - 99 EUR',
  'Restauarant Website': 'www.retirodacostina.com'},
 {'Restaurant Name': 'Espacio N',
  'Price Range': '85 EUR',
  'Restauarant Website': 'www.espacion.es'},
 {'Restaurant Name': 'Amelia by Paulo Airaudo',
  'Price Range': '170 EUR',
  'Restauarant Website': 'www.ameliarestaurant.com'},
 {'Restaurant Name': 'El Corral del Indianu',
  'Price Range': '50 - 99 EUR',
  'Restauarant Website': 'www.elcorraldelindianu.com'},
 {'Restaurant Name': 'Marc Fosh',
  'Price Range': '46 - 120 EUR',
  'Restauarant Website': 'www.marcfosh.com'},
 {'Restaurant Name': 'Mu•na',
  'Price Range': '35 - 85 EUR',
  'Restauarant Website': 'www.restaurantemuna.com'},
 {'Restaurant Name': "Audrey's",
  'Price Range': '85 - 125 EUR',
  'Restauarant Website': 'www.audreys.es'},
 {'Restaurant Name': 'Taller',
  'Price Range': '65 - 120 EUR',
  'Restauarant Website': 'www.tallerarzuaga.com'},
 {'Restaurant Name': 'El Bohío',
  'Price Range': '75 - 180 EUR',
  'Restauarant Website': 'https://www.elbohio.net/'},
 {'Restaurant Name': 'Odiseo Gastronómico',
  'Price Range': '90 - 145 EUR',
  'Restauarant Website': 'www.odiseospain.com'},
 {'Restaurant Name': 'Hospedería El Batán',
  'Price Range': '55 - 80 EUR',
  'Restauarant Website': 'www.elbatan.es'},
 {'Restaurant Name': 'Maca de Castro',
  'Price Range': '132 EUR',
  'Restauarant Website': 'www.macadecastro.com'},
 {'Restaurant Name': 'Cocinandos',
  'Price Range': '63 - 90 EUR',
  'Restauarant Website': 'www.cocinandos.com'},
 {'Restaurant Name': 'Massana',
  'Price Range': '80 - 125 EUR',
  'Restauarant Website': 'https://www.restaurantmassana.com/'},
 {'Restaurant Name': 'La Salita',
  'Price Range': '94 - 125 EUR',
  'Restauarant Website': 'www.lasalitarestaurante.com'},
 {'Restaurant Name': 'La Aquarela',
  'Price Range': '79 - 98 EUR',
  'Restauarant Website': 'www.restaurantelaaquarela.com'},
 {'Restaurant Name': 'Kabuki',
  'Price Range': '70 - 95 EUR',
  'Restauarant Website': 'www.grupokabuki.com'},
 {'Restaurant Name': 'Lillas Pastia',
  'Price Range': '50 - 75 EUR',
  'Restauarant Website': 'https://www.lillaspastia.es/'},
 {'Restaurant Name': 'Lluerna',
  'Price Range': '45 - 88 EUR',
  'Restauarant Website': 'www.lluernarestaurant.com'},
 {'Restaurant Name': 'El Xato',
  'Price Range': '65 - 85 EUR',
  'Restauarant Website': 'www.elxato.com'},
 {'Restaurant Name': 'Oria',
  'Price Range': '50 - 115 EUR',
  'Restauarant Website': 'www.monumenthotel.com'},
 {'Restaurant Name': 'La Finca',
  'Price Range': '73 - 119 EUR',
  'Restauarant Website': 'www.lafinca.es'},
 {'Restaurant Name': 'El Retiro',
  'Price Range': '56 - 95 EUR',
  'Restauarant Website': 'www.elretirollanes.es'},
 {'Restaurant Name': 'Alkimia',
  'Price Range': '168 EUR',
  'Restauarant Website': 'www.alkimia.cat'},
 {'Restaurant Name': 'Abantal',
  'Price Range': '80 - 100 EUR',
  'Restauarant Website': 'www.abantalrestaurante.es'},
 {'Restaurant Name': 'Koy Shunka',
  'Price Range': '98 - 147 EUR',
  'Restauarant Website': 'www.koyshunka.com'},
 {'Restaurant Name': 'Aürt',
  'Price Range': '99 EUR',
  'Restauarant Website': 'www.aurtrestaurant.com'},
 {'Restaurant Name': 'Quatre Molins',
  'Price Range': '55 - 75 EUR',
  'Restauarant Website': 'www.quatremolins.com'},
 {'Restaurant Name': 'Etxebarri',
  'Price Range': '100 - 220 EUR',
  'Restauarant Website': 'www.asadoretxebarri.com'},
 {'Restaurant Name': 'Casa Marcelo',
  'Price Range': '75 EUR',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'La Boscana',
  'Price Range': '70 - 155 EUR',
  'Restauarant Website': 'www.laboscana.net'},
 {'Restaurant Name': 'Mina',
  'Price Range': '100 - 130 EUR',
  'Restauarant Website': 'www.restaurantemina.es'},
 {'Restaurant Name': 'Boroa',
  'Price Range': '50 - 125 EUR',
  'Restauarant Website': 'www.boroa.com'},
 {'Restaurant Name': 'Deliranto',
  'Price Range': '120 - 150 EUR',
  'Restauarant Website': 'www.deliranto.com'},
 {'Restaurant Name': 'Choco',
  'Price Range': '95 - 125 EUR',
  'Restauarant Website': 'www.restaurantechoco.com'},
 {'Restaurant Name': 'Zortziko',
  'Price Range': '70 - 99 EUR',
  'Restauarant Website': 'www.zortziko.es'},
 {'Restaurant Name': "L'Antic Molí",
  'Price Range': '60 - 95 EUR',
  'Restauarant Website': 'www.anticmoli.com'},
 {'Restaurant Name': 'La Tasquería',
  'Price Range': '40 - 75 EUR',
  'Restauarant Website': 'www.latasqueria.com'},
 {'Restaurant Name': 'La Bicicleta',
  'Price Range': '95 - 120 EUR',
  'Restauarant Website': 'www.labicicletahoznayo.com'},
 {'Restaurant Name': 'Auga',
  'Price Range': '55 - 90 EUR',
  'Restauarant Website': 'www.restauranteauga.com'},
  {'Restaurant Name': 'Callizo',
  'Price Range': '80 - 95 EUR',
  'Restauarant Website': 'www.restaurantecallizo.es'},
 {'Restaurant Name': 'Tatau',
  'Price Range': '60 - 120 EUR',
  'Restauarant Website': 'www.tatau.es'},
 {'Restaurant Name': 'Real Balneario',
  'Price Range': '60 - 180 EUR',
  'Restauarant Website': 'www.realbalneario.com'},
 {'Restaurant Name': 'Es Tragón',
  'Price Range': '140 EUR',
  'Restauarant Website': 'www.estragonibiza.com'},
 {'Restaurant Name': 'Caelis',
  'Price Range': '45 - 135 EUR',
  'Restauarant Website': 'www.caelis.com'},
 {'Restaurant Name': 'DINS Santi Taura',
  'Price Range': '85 - 130 EUR',
  'Restauarant Website': 'www.dinssantitaura.com'},
 {'Restaurant Name': 'Casa Pepa',
  'Price Range': '55 - 97 EUR',
  'Restauarant Website': 'www.capepa.es'},
 {'Restaurant Name': 'La Cuina de Can Simón',
  'Price Range': '54 - 98 EUR',
  'Restauarant Website': 'www.cuinacansimon.com'},
 {'Restaurant Name': 'La Biblioteca',
  'Price Range': '150 EUR',
  'Restauarant Website': 'www.almahotels.com'},
 {'Restaurant Name': "L'Ó",
  'Price Range': '65 - 95 EUR',
  'Restauarant Website': 'www.hotelmonstbenet.com'},
 {'Restaurant Name': 'Via Veneto',
  'Price Range': '65 - 150 EUR',
  'Restauarant Website': 'www.viavenetorestaurant.com'},
 {'Restaurant Name': 'El Molino de Alcuneza',
  'Price Range': '68 - 98 EUR',
  'Restauarant Website': 'https://www.molinodealcuneza.com/'},
 {'Restaurant Name': 'Alevante',
  'Price Range': '125 - 145 EUR',
  'Restauarant Website': 'www.alevanteangelleon.com'},
 {'Restaurant Name': 'Kiro Sushi',
  'Price Range': '110 EUR',
  'Restauarant Website': 'www.kirosushi.es'},
 {'Restaurant Name': 'Hisop',
  'Price Range': '60 - 75 EUR',
  'Restauarant Website': 'www.hisop.com'},
 {'Restaurant Name': 'Marqués de Riscal',
  'Price Range': '120 - 145 EUR',
  'Restauarant Website': 'www.hotel-marquesderiscal.com'},
 {'Restaurant Name': 'Europa',
  'Price Range': '65 - 89 EUR',
  'Restauarant Website': 'www.hreuropa.com'},
 {'Restaurant Name': 'Les Magnòlies',
  'Price Range': '34 - 92 EUR',
  'Restauarant Website': 'www.lesmagnolies.com'},
 {'Restaurant Name': 'Venta Moncalvillo',
  'Price Range': '100 - 120 EUR',
  'Restauarant Website': 'www.ventamoncalvillo.com'},
 {'Restaurant Name': 'Sents',
  'Price Range': '68 - 88 EUR',
  'Restauarant Website': 'www.sents.es'},
 {'Restaurant Name': 'Silabario',
  'Price Range': '25 - 88 EUR',
  'Restauarant Website': 'www.silabario.gal'},
 {'Restaurant Name': 'Miguel González',
  'Price Range': '65 - 80 EUR',
  'Restauarant Website': 'www.restaurantemiguelgonzalez.com'},
 {'Restaurant Name': 'Casamar',
  'Price Range': '45 - 86 EUR',
  'Restauarant Website': 'www.hotelcasamar.net'},
 {'Restaurant Name': 'Mirador de Ulía',
  'Price Range': '70 - 120 EUR',
  'Restauarant Website': 'www.miradordeulia.es'},
 {'Restaurant Name': 'Víctor Gutiérrez',
  'Price Range': '72 - 110 EUR',
  'Restauarant Website': 'www.restaurantevictorgutierrez.com'},
 {'Restaurant Name': "Ca l'Enric",
  'Price Range': '81 - 120 EUR',
  'Restauarant Website': 'www.restaurantcalenric.cat'},
 {'Restaurant Name': 'Elkano',
  'Price Range': '110 - 150 EUR',
  'Restauarant Website': 'www.restauranteelkano.com'},
 {'Restaurant Name': 'Yugo',
  'Price Range': '135 - 182 EUR',
  'Restauarant Website': 'www.yugothebunker.com'},
 {'Restaurant Name': "Béns d'Avall",
  'Price Range': '68 - 87 EUR',
  'Restauarant Website': 'www.bensdavall.com'},
 {'Restaurant Name': 'Gaytán',
  'Price Range': '50 - 137 EUR',
  'Restauarant Website': 'www.chefjavieraranda.com'},
 {'Restaurant Name': 'Sollo',
  'Price Range': '130 EUR',
  'Restauarant Website': 'www.sollo.es'},
 {'Restaurant Name': 'En la Parra',
  'Price Range': '48 - 65 EUR',
  'Restauarant Website': 'www.restaurantenlaparra.com'},
 {'Restaurant Name': 'Castell Peralada',
  'Price Range': '71 - 130 EUR',
  'Restauarant Website': 'www.castellperaladarestaurant.com'},
 {'Restaurant Name': 'Nerua Guggenheim Bilbao',
  'Price Range': '45 - 80 EUR',
  'Restauarant Website': 'www.neruaguggenheimbilbao.com'},
 {'Restaurant Name': 'El Doncel',
  'Price Range': '76 - 118 EUR',
  'Restauarant Website': 'www.eldoncel.com'},
 {'Restaurant Name': 'Xerta',
  'Price Range': '42 - 135 EUR',
  'Restauarant Website': 'www.xertarestaurant.com'},
 {'Restaurant Name': 'Dama Juana',
  'Price Range': '65 - 100 EUR',
  'Restauarant Website': 'www.damajuanajaen.com'},
 {'Restaurant Name': 'Dos Palillos',
  'Price Range': '45 - 120 EUR',
  'Restauarant Website': 'www.dospalillos.com'},
 {'Restaurant Name': 'Eneko',
  'Price Range': '77 EUR',
  'Restauarant Website': 'www.eneko.restaurant'},
 {'Restaurant Name': 'Chirón',
  'Price Range': '55 - 99 EUR',
  'Restauarant Website': 'www.restaurantechiron.com'},
 {'Restaurant Name': 'Cal Paradís',
  'Price Range': '45 - 110 EUR',
  'Restauarant Website': 'www.calparadis.es'},
 {'Restaurant Name': 'Riff',
  'Price Range': '45 - 135 EUR',
  'Restauarant Website': 'www.restaurante-riff.com'},
 {'Restaurant Name': 'Emporium',
  'Price Range': '78 - 110 EUR',
  'Restauarant Website': 'www.emporiumhotel.com'},
 {'Restaurant Name': 'As Garzas',
  'Price Range': '70 - 90 EUR',
  'Restauarant Website': 'www.asgarzas.com'},
 {'Restaurant Name': 'Andreu Genestra',
  'Price Range': '90 - 130 EUR',
  'Restauarant Website': 'www.andreugenestra.com'},
 {'Restaurant Name': 'Els Casals',
  'Price Range': '50 - 78 EUR',
  'Restauarant Website': 'www.elscasals.cat'},
 {'Restaurant Name': 'Baeza & Rufete',
  'Price Range': '50 - 85 EUR',
  'Restauarant Website': 'www.baezarufete.com'},
 {'Restaurant Name': 'Refectorio',
  'Price Range': '135 - 175 EUR',
  'Restauarant Website': 'www.ledomaine.es'},
 {'Restaurant Name': 'Baluarte',
  'Price Range': '40 - 72 EUR',
  'Restauarant Website': 'www.baluarte.info'},
 {'Restaurant Name': 'Clos Madrid',
  'Price Range': '60 - 95 EUR',
  'Restauarant Website': 'www.restauranteclosmadrid.es'},
 {'Restaurant Name': 'Magoga',
  'Price Range': '55 - 95 EUR',
  'Restauarant Website': 'www.restaurantemagoga.com'},
 {'Restaurant Name': 'Zuberoa',
  'Price Range': '93 - 160 EUR',
  'Restauarant Website': 'www.zuberoa.com'},
 {'Restaurant Name': 'Rodero',
  'Price Range': '65 - 95 EUR',
  'Restauarant Website': 'www.restauranterodero.com'},
 {'Restaurant Name': 'Mantúa',
  'Price Range': '85 - 105 EUR',
  'Restauarant Website': 'www.restaurantemantua.com'},
 {'Restaurant Name': 'Abama Kabuki',
  'Price Range': '120 - 165 EUR',
  'Restauarant Website': 'www.ritzcarlton.com'},
 {'Restaurant Name': 'Orobianco',
  'Price Range': '85 - 120 EUR',
  'Restauarant Website': 'www.orobianco.es'},
 {'Restaurant Name': 'Raúl Resino',
  'Price Range': '80 - 120 EUR',
  'Restauarant Website': 'www.restauranteraulresino.com'},
 {'Restaurant Name': 'Ambivium',
  'Price Range': '120 EUR',
  'Restauarant Website': 'www.restauranteambivium.com'},
 {'Restaurant Name': 'Alameda',
  'Price Range': '70 - 122 EUR',
  'Restauarant Website': 'https://www.restaurantealameda.net/'},
 {'Restaurant Name': 'Trigo',
  'Price Range': '55 EUR',
  'Restauarant Website': 'www.restaurantetrigo.com'},
 {'Restaurant Name': 'Corral de la Morería Gastronómico',
  'Price Range': '59 - 75 EUR',
  'Restauarant Website': 'www.moreriagastro.com'},
 {'Restaurant Name': "A'Barra",
  'Price Range': '65 - 120 EUR',
  'Restauarant Website': 'www.restauranteabarra.com'},
 {'Restaurant Name': 'Malena',
  'Price Range': '55 - 85 EUR',
  'Restauarant Website': 'https://www.malenagastronomia.com/'},
 {'Restaurant Name': 'El Nuevo Molino',
  'Price Range': '45 - 90 EUR',
  'Restauarant Website': 'www.elnuevomolino.es'},
 {'Restaurant Name': 'Tula',
  'Price Range': '40 - 70 EUR',
  'Restauarant Website': 'www.tularestaurante.com'},
 {'Restaurant Name': "Es Racó d'Es Teix",
  'Price Range': '39 - 120 EUR',
  'Restauarant Website': 'https://www.esracodesteix.es/'},
 {'Restaurant Name': 'Arbidel',
  'Price Range': '50 - 90 EUR',
  'Restauarant Website': 'www.arbidelrestaurante.com'},
 {'Restaurant Name': 'Solana',
  'Price Range': '45 - 90 EUR',
  'Restauarant Website': 'www.restaurantesolana.com'},
 {'Restaurant Name': 'Saddle',
  'Price Range': '85 - 120 EUR',
  'Restauarant Website': 'www.saddle-madrid.com'},
 {'Restaurant Name': 'Árbore da Veira',
  'Price Range': '50 - 80 EUR',
  'Restauarant Website': 'www.arboredaveira.com'},
 {'Restaurant Name': 'Retama',
  'Price Range': '60 - 90 EUR',
  'Restauarant Website': 'www.hotellacaminera.com'},
 {'Restaurant Name': 'Kabuki Wellington',
  'Price Range': '85 - 130 EUR',
  'Restauarant Website': 'www.restaurantekabuki.com'},
 {'Restaurant Name': 'Manuel Alonso Restaurante',
  'Price Range': '90 EUR',
  'Restauarant Website': 'www.restaurantemanolo.com'},
 {'Restaurant Name': 'Voro',
  'Price Range': '110 - 140 EUR',
  'Restauarant Website': 'www.vororestaurant.com'},
 {'Restaurant Name': 'Raíces-Carlos Maldonado',
  'Price Range': '65 - 85 EUR',
  'Restauarant Website': 'www.raicescarlosmaldonado.es'},
 {'Restaurant Name': 'La Lobita',
  'Price Range': '80 EUR',
  'Restauarant Website': 'www.lalobita.es'},
 {'Restaurant Name': 'Beat',
  'Price Range': '50 - 125 EUR',
  'Restauarant Website': 'www.thecookbookhotel.com'},
 {'Restaurant Name': 'Can Jubany',
  'Price Range': '70 - 145 EUR',
  'Restauarant Website': 'www.canjubany.com'},
 {'Restaurant Name': 'La Costa',
  'Price Range': '60 - 98 EUR',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'El Club Allard',
  'Price Range': '60 - 135 EUR',
  'Restauarant Website': 'www.elcluballard.com'},
 {'Restaurant Name': 'Villa Retiro',
  'Price Range': '60 - 125 EUR',
  'Restauarant Website': 'www.hotelvillaretiro.com'},
 {'Restaurant Name': 'José Carlos García',
  'Price Range': '100 - 140 EUR',
  'Restauarant Website': 'www.restaurantejcg.com'},
 {'Restaurant Name': 'Trivio',
  'Price Range': '50 - 70 EUR',
  'Restauarant Website': 'www.restaurantetrivio.com'},
 {'Restaurant Name': 'Sala',
  'Price Range': '50 - 90 EUR',
  'Restauarant Website': 'www.fondasala.com'},
 {'Restaurant Name': 'Cancook',
  'Price Range': '65 - 110 EUR',
  'Restauarant Website': 'www.cancookrestaurant.com'},
 {'Restaurant Name': 'Etxanobe Atelier',
  'Price Range': '125 - 150 EUR',
  'Restauarant Website': 'www.etxanobe.com'},
 {'Restaurant Name': 'Los Guayres',
  'Price Range': '100 - 120 EUR',
  'Restauarant Website': 'www.losguayres.com'},
 {'Restaurant Name': 'Cebo',
  'Price Range': '115 - 135 EUR',
  'Restauarant Website': 'www.cebomadrid.com'},
 {'Restaurant Name': 'Adrián Quetglas',
  'Price Range': '40 - 65 EUR',
  'Restauarant Website': 'www.adrianquetglas.es'},
 {'Restaurant Name': 'Pepe Vieira',
  'Price Range': '87 - 150 EUR',
  'Restauarant Website': 'www.pepevieira.com'},
 {'Restaurant Name': 'La Botica',
  'Price Range': '55 - 85 EUR',
  'Restauarant Website': 'www.laboticadematapozuelos.com'},
 {'Restaurant Name': 'Els Tinars',
  'Price Range': '52 - 90 EUR',
  'Restauarant Website': 'www.elstinars.com'},
 {'Restaurant Name': 'Casa Gerardo',
  'Price Range': '75 - 150 EUR',
  'Restauarant Website': 'www.restaurantecasagerardo.es'},
 {'Restaurant Name': 'A Tafona',
  'Price Range': '85 - 115 EUR',
  'Restauarant Website': 'www.restauranteatafona.com'},
 {'Restaurant Name': 'Gofio',
  'Price Range': '65 - 125 EUR',
  'Restauarant Website': 'www.gofiorestaurant.com'},
 {'Restaurant Name': 'Lúa',
  'Price Range': '50 - 78 EUR',
  'Restauarant Website': 'www.restaurantelua.com'},
 {'Restaurant Name': 'eMe Be Garrote',
  'Price Range': '78 - 150 EUR',
  'Restauarant Website': 'www.emeberestaurante.com'},
 {'Restaurant Name': 'Monastrell',
  'Price Range': '75 - 115 EUR',
  'Restauarant Website': 'www.monastrell.com'},
 {'Restaurant Name': 'Bagá',
  'Price Range': '85 EUR',
  'Restauarant Website': 'www.bagagastronomico.com'},
 {'Restaurant Name': 'Can Bosch',
  'Price Range': '50 - 110 EUR',
  'Restauarant Website': 'www.canbosch.com'},
 {'Restaurant Name': 'Fogony',
  'Price Range': '45 - 80 EUR',
  'Restauarant Website': 'www.fogony.com'},
 {'Restaurant Name': 'LÚ Cocina y Alma',
  'Price Range': '95 - 155 EUR',
  'Restauarant Website': 'www.lucocinayalma.com'},
 {'Restaurant Name': 'Es Fum',
  'Price Range': '135 - 150 EUR',
  'Restauarant Website': 'www.restaurant-esfum.com'},
 {'Restaurant Name': 'Hofmann',
  'Price Range': '49 - 82 EUR',
  'Restauarant Website': 'www.hofmann-bcn.com'},
 {'Restaurant Name': 'Iván Cerdeño',
  'Price Range': '55 - 145 EUR',
  'Restauarant Website': 'www.ivancerdeno.com'},
 {'Restaurant Name': 'Nova',
  'Price Range': '45 - 90 EUR',
  'Restauarant Website': 'www.novarestaurante.com'},
 {'Restaurant Name': 'Alejandro',
  'Price Range': '40 - 85 EUR',
  'Restauarant Website': 'www.restaurantealejandro.es'},
 {'Restaurant Name': 'Yayo Daporta',
  'Price Range': '75 - 100 EUR',
  'Restauarant Website': 'www.yayodaporta.com'},
 {'Restaurant Name': 'Pablo',
  'Price Range': '65 - 85 EUR',
  'Restauarant Website': 'www.restaurantepablo.es'},
 {'Restaurant Name': 'Kokotxa',
  'Price Range': '88 - 125 EUR',
  'Restauarant Website': 'www.restaurantekokotxa.com'},
 {'Restaurant Name': 'El Lago',
  'Price Range': '64 - 90 EUR',
  'Restauarant Website': 'www.restauranteellago.com'},
 {'Restaurant Name': "L'orgueil",
  'Price Range': '15,000 JPY',
  'Restauarant Website': 'http://orgueil.net/'},
 {'Restaurant Name': 'Kaiseki Ohara',
  'Price Range': '8,500 - 19,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Sushi Kuwano',
  'Price Range': '33,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'LUGDUNUM Bouchon Lyonnais',
  'Price Range': '3,500 - 13,000 JPY',
  'Restauarant Website': 'http://lyondelyon.com/'},
 {'Restaurant Name': 'Tenoshima',
  'Price Range': '17,000 JPY',
  'Restauarant Website': 'https://www.tenoshima.com/'},
 {'Restaurant Name': 'Sushidokoro Kiraku',
  'Price Range': '5,500 - 11,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'La Clairière',
  'Price Range': '9,000 - 28,000 JPY',
  'Restauarant Website': 'https://www.la-clairiere.tokyo/'},
 {'Restaurant Name': 'Sosakumenkobo NAKIRYU',
  'Price Range': '1,000 - 1,500 JPY',
  'Restauarant Website': 'http://www12.plala.or.jp/nakiryu/'},
 {'Restaurant Name': 'Tempura Maehira',
  'Price Range': '22,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Sushi Hashimoto',
  'Price Range': '28,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Makiyaki Ginza Onodera',
  'Price Range': '8,000 - 37,000 JPY',
  'Restauarant Website': 'https://onodera-group.com/makiyaki/'},
 {'Restaurant Name': 'Hirosaku',
  'Price Range': '4,000 - 55,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'SANT PAU',
  'Price Range': '8,500 - 39,000 JPY',
  'Restauarant Website': 'https://www.santpau.jp/'},
 {'Restaurant Name': "L'AFFINAGE",
  'Price Range': '9,000 - 22,000 JPY',
  'Restauarant Website': 'https://laffinage.jp/'},
 {'Restaurant Name': 'Nanakusa',
  'Price Range': '8,000 JPY',
  'Restauarant Website': 'https://www.nana-kusa.net/'},
 {'Restaurant Name': 'FUSHIKINO',
  'Price Range': '19,000 - 22,000 JPY',
  'Restauarant Website': 'https://fushikino.com/'},
 {'Restaurant Name': 'Jukuseizushi Yorozu',
  'Price Range': '28,000 JPY',
  'Restauarant Website': 'https://www.yorozu-sushi.com/'},
 {'Restaurant Name': 'Jyukou',
  'Price Range': '8,000 - 43,000 JPY',
  'Restauarant Website': 'https://jyu-kou.jp/'},
 {'Restaurant Name': 'ASAHINA Gastronome',
  'Price Range': '15,000 - 28,000 JPY',
  'Restauarant Website': 'https://asahinagastronome.com/'},
 {'Restaurant Name': 'Reikasai Ginza',
  'Price Range': '3,000 - 40,000 JPY',
  'Restauarant Website': 'https://www.reikasai.jp/'},
 {'Restaurant Name': 'Series',
  'Price Range': '9,000 - 14,000 JPY',
  'Restauarant Website': 'https://series-restaurant.com/'},
 {'Restaurant Name': 'Kyobashi Tempura Fukamachi',
  'Price Range': '9,500 - 23,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Hato',
  'Price Range': '34,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Kurosaki',
  'Price Range': '35,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Aroma Fresca',
  'Price Range': '13,000 - 25,000 JPY',
  'Restauarant Website': 'http://www.aromafresca-afsa.com/'},
 {'Restaurant Name': 'ShinoiS',
  'Price Range': '37,000 JPY',
  'Restauarant Website': 'https://shinois.com/'},
 {'Restaurant Name': 'Simplicité',
  'Price Range': '9,000 - 20,000 JPY',
  'Restauarant Website': 'http://www.simplicite123.com/'},
 {'Restaurant Name': 'LATURE',
  'Price Range': '6,000 - 18,000 JPY',
  'Restauarant Website': 'https://www.lature.jp/'},
 {'Restaurant Name': 'Azabu Rokkaku',
  'Price Range': '15,000 - 20,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Shimbashi Sasada',
  'Price Range': '22,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Chez Olivier',
  'Price Range': '5,500 - 16,000 JPY',
  'Restauarant Website': 'http://www.chezolivier.co.jp/'},
 {'Restaurant Name': 'Sushiya Shota',
  'Price Range': '16,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Maison Paul Bocuse',
  'Price Range': '5,500 - 31,000 JPY',
  'Restauarant Website': 'https://www.hiramatsurestaurant.jp/'},
 {'Restaurant Name': 'Dominique Bouchet',
  'Price Range': '13,000 - 23,000 JPY',
  'Restauarant Website': 'https://www.dominique-bouchet.jp/'},
 {'Restaurant Name': 'Ren Mishina',
  'Price Range': '30,000 JPY',
  'Restauarant Website': 'https://ginza-ren.jp/'},
 {'Restaurant Name': 'Shokuzen Abe',
  'Price Range': '24,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Sushi Fukumoto',
  'Price Range': '13,000 - 19,000 JPY',
  'Restauarant Website': 'http://sushifukumoto.jp/index.html'},
 {'Restaurant Name': 'Sushi Isshin',
  'Price Range': '7,000 - 17,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Nogizaka Shin',
  'Price Range': '13,000 - 37,000 JPY',
  'Restauarant Website': 'https://www.nogi-s.com/'},
 {'Restaurant Name': 'Waketokuyama',
  'Price Range': '19,000 JPY',
  'Restauarant Website': 'https://waketoku.com/'},
 {'Restaurant Name': 'Yamazaki',
  'Price Range': '37,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Nihombashi-kakigaracho Sugita',
  'Price Range': '37,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Takagakino Sushi',
  'Price Range': '11,000 - 25,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Ogasawara Hakushakutei',
  'Price Range': '8,500 - 22,000 JPY',
  'Restauarant Website': 'https://www.ogasawaratei.com/'},
 {'Restaurant Name': "l'intemporel",
  'Price Range': '7,000 - 14,000 JPY',
  'Restauarant Website': 'http://lintemporel.jp/'},
 {'Restaurant Name': 'Ginza Ishizaki',
  'Price Range': '27,000 - 43,000 JPY',
  'Restauarant Website': 'http://www.ginza-ishizaki.jp/'},
 {'Restaurant Name': 'ESTERRE',
  'Price Range': '10,000 - 34,000 JPY',
  'Restauarant Website': 'https://www.palacehoteltokyo.com/'},
 {'Restaurant Name': 'Oniku Karyu',
  'Price Range': '27,000 JPY',
  'Restauarant Website': 'http://www.karyu-tokyo.com/'},
 {'Restaurant Name': 'Yuan Yamori',
  'Price Range': '10,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Sushi Yu',
  'Price Range': '14,000 - 22,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'recte',
  'Price Range': '5,500 - 19,000 JPY',
  'Restauarant Website': 'http://www.recte.jp/'},
 {'Restaurant Name': 'Takumi',
  'Price Range': '8,000 - 16,000 JPY',
  'Restauarant Website': 'https://restaurant-takumi.com/'},
 {'Restaurant Name': 'Le Bourguignon',
  'Price Range': '5,000 - 13,000 JPY',
  'Restauarant Website': 'https://le-bourguignon.jp/'},
 {'Restaurant Name': 'GINZA OKUDA',
  'Price Range': '17,000 - 30,000 JPY',
  'Restauarant Website': 'https://www.ginzaokuda.com/'},
 {'Restaurant Name': 'La Paix',
  'Price Range': '7,500 - 16,000 JPY',
  'Restauarant Website': 'https://lapaix-m.jp/'},
 {'Restaurant Name': 'CRAFTALE',
  'Price Range': '8,500 - 25,000 JPY',
  'Restauarant Website': 'https://www.craftale-tokyo.com/'},
 {'Restaurant Name': 'Sushi Murayama',
  'Price Range': '31,000 JPY',
  'Restauarant Website': 'https://sushi-murayama.jp/'},
 {'Restaurant Name': 'Towa',
  'Price Range': '31,000 - 37,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'BVLGARI IL RISTORANTE LUCA FANTIN',
  'Price Range': '14,000 - 31,000 JPY',
  'Restauarant Website': 'https://www.bulgarihotels.com/'},
 {'Restaurant Name': 'Imafuku',
  'Price Range': '11,000 - 20,000 JPY',
  'Restauarant Website': 'https://kuroge-wagyu.com/if/top_j.html'},
 {'Restaurant Name': 'Sushi Sugaya',
  'Price Range': '44,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Ginza Adachi Naoto',
  'Price Range': '16,000 - 21,000 JPY',
  'Restauarant Website': 'http://ginza-adachi.jp/'},
 {'Restaurant Name': 'Nanachome',
  'Price Range': '8,500 JPY',
  'Restauarant Website': 'https://7chome.jimdofree.com/'},
 {'Restaurant Name': 'Azure 45',
  'Price Range': '11,000 - 26,000 JPY',
  'Restauarant Website': 'http://www.ritz-carlton.jp/'},
 {'Restaurant Name': 'Ishibashi',
  'Price Range': '6,500 - 22,000 JPY',
  'Restauarant Website': 'http://unagi-ishibashi.com/'},
 {'Restaurant Name': 'FARO',
  'Price Range': '7,500 - 17,000 JPY',
  'Restauarant Website': 'https://faro.shiseido.co.jp/'},
 {'Restaurant Name': 'Mimosa',
  'Price Range': '15,000 JPY',
  'Restauarant Website': 'http://mimosa-aoyama.com/'},
 {'Restaurant Name': 'Chugoku Hanten Fureika',
  'Price Range': '3,000 - 49,000 JPY',
  'Restauarant Website': 'https://www.chuugokuhanten.com/'},
 {'Restaurant Name': 'Seiju',
  'Price Range': '24,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': "L'aube",
  'Price Range': '7,500 - 16,000 JPY',
  'Restauarant Website': 'https://www.restaurant-laube.com/'},
 {'Restaurant Name': 'Shichubo Yung',
  'Price Range': '9,500 JPY',
  'Restauarant Website': 'https://yung-shirokane.com/'},
 {'Restaurant Name': 'Sumibikappo SHIROSAKA',
  'Price Range': '19,000 JPY',
  'Restauarant Website': 'https://shirosaka.jp/'},
 {'Restaurant Name': 'Shunkeian Arakaki',
  'Price Range': '16,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Nishiazabu Taku',
  'Price Range': '22,000 - 33,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Akasaka Izumi',
  'Price Range': '26,000 - 36,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Akasaka Kitafuku',
  'Price Range': '32,000 - 73,000 JPY',
  'Restauarant Website': 'https://kanikitafuku.com/'},
 {'Restaurant Name': 'Ode',
  'Price Range': '10,000 - 20,000 JPY',
  'Restauarant Website': 'https://restaurant-ode.com/'},
 {'Restaurant Name': 'SOBAHOUSE KONJIKI HOTOTOGISU',
  'Price Range': '1,000 - 1,500 JPY',
  'Restauarant Website': 'https://sobahousekonjikihototogisu.com/'},
 {'Restaurant Name': 'Oryori Katsushi',
  'Price Range': '17,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Tamawarai',
  'Price Range': '2,000 - 10,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Kasumicho Yamagami',
  'Price Range': '19,000 - 37,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Yakitori Omino',
  'Price Range': '6,000 - 9,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Les Saisons',
  'Price Range': '9,500 - 48,000 JPY',
  'Restauarant Website': 'https://www.imperialhotel.co.jp/'},
 {'Restaurant Name': 'Shigematsu',
  'Price Range': '25,000 - 33,000 JPY',
  'Restauarant Website': 'http://ginza-shigematsu.jp/'},
 {'Restaurant Name': "TOUR D'ARGENT",
  'Price Range': '11,000 - 37,000 JPY',
  'Restauarant Website': 'https://tourdargent.jp/'},
 {'Restaurant Name': 'Asagaya BIRD LAND',
  'Price Range': '4,500 - 7,500 JPY',
  'Restauarant Website': 'https://www.asagaya-bird-land.com/'},
 {'Restaurant Name': 'Yunke Ginza',
  'Price Range': '20,000 - 29,000 JPY',
  'Restauarant Website': 'https://www.yunke.co.jp/'},
 {'Restaurant Name': 'Onarimon Haru',
  'Price Range': '22,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Nodaiwa Azabu Iikura Honten',
  'Price Range': '3,000 - 18,000 JPY',
  'Restauarant Website': 'http://www.nodaiwa.co.jp/'},
 {'Restaurant Name': 'Tempura Shimomura',
  'Price Range': '2,500 - 17,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Azabu Ichigo',
  'Price Range': '10,000 - 16,000 JPY',
  'Restauarant Website': 'https://www.azabu-ichigo.com/'},
 {'Restaurant Name': 'Arakicho Tatsuya',
  'Price Range': '10,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'REQUINQUER',
  'Price Range': '5,000 - 20,000 JPY',
  'Restauarant Website': 'https://requinquer.jp/'},
 {'Restaurant Name': 'Ichikawa',
  'Price Range': '33,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Piatto Suzuki',
  'Price Range': '3,500 - 15,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Nihombashi Sonoji',
  'Price Range': '21,000 JPY',
  'Restauarant Website': 'http://www.sonoji.info/'},
 {'Restaurant Name': 'Ichita',
  'Price Range': '31,000 JPY',
  'Restauarant Website': 'https://www.tokyoichita.com/'},
 {'Restaurant Name': 'Signature',
  'Price Range': '6,500 - 26,000 JPY',
  'Restauarant Website': 'https://www.mandarinoriental.co.jp/'},
 {'Restaurant Name': 'Akasaka Momonoki',
  'Price Range': '13,000 - 37,000 JPY',
  'Restauarant Website': 'https://momonoki.tokyo/'},
 {'Restaurant Name': 'Ginza Kitafuku',
  'Price Range': '30,000 - 70,000 JPY',
  'Restauarant Website': 'https://kanikitafuku.com/'},
 {'Restaurant Name': 'Principio',
  'Price Range': '8,500 - 13,000 JPY',
  'Restauarant Website': 'https://www.principio.net/'},
 {'Restaurant Name': 'itsuka',
  'Price Range': '13,000 - 37,000 JPY',
  'Restauarant Website': 'https://www.itsuka8.com/'},
 {'Restaurant Name': 'Fudomae Sushi Iwasawa',
  'Price Range': '22,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Genyadana Hamadaya',
  'Price Range': '19,000 - 66,000 JPY',
  'Restauarant Website': 'https://www.hamadaya.info/'},
 {'Restaurant Name': 'Tapas Molecular Bar',
  'Price Range': '30,000 JPY',
  'Restauarant Website': 'https://www.mandarinoriental.co.jp/'},
 {'Restaurant Name': 'Les enfants gâtés',
  'Price Range': '4,000 - 16,000 JPY',
  'Restauarant Website': 'http://terrine-gates.com/'},
 {'Restaurant Name': 'Ginza Toyoda',
  'Price Range': '13,000 - 31,000 JPY',
  'Restauarant Website': 'https://ginza-toyoda.com/'},
 {'Restaurant Name': 'Tagetsu',
  'Price Range': '6,000 - 25,000 JPY',
  'Restauarant Website': 'https://tagetsu.tokyo/'},
 {'Restaurant Name': 'Azabujuban Fukuda',
  'Price Range': '31,000 - 37,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'TACUBO',
  'Price Range': '22,000 JPY',
  'Restauarant Website': 'https://tacubo.com/'},
 {'Restaurant Name': 'Regalo',
  'Price Range': '9,500 - 11,000 JPY',
  'Restauarant Website': 'http://www.regalo-ristorante.com/'},
 {'Restaurant Name': 'Sense',
  'Price Range': '5,500 - 64,000 JPY',
  'Restauarant Website': 'https://www.mandarinoriental.co.jp/'},
 {'Restaurant Name': 'Ishibashi',
  'Price Range': '14,000 - 16,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'BOTTEGA',
  'Price Range': '10,000 - 13,000 JPY',
  'Restauarant Website': 'https://www.bottega-cucina.com/'},
 {'Restaurant Name': 'Akebonobashi Marutomi',
  'Price Range': '19,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'abysse',
  'Price Range': '9,500 - 19,000 JPY',
  'Restauarant Website': 'https://abysse.jp/'},
 {'Restaurant Name': 'Ozashiki Tempura Mitsuta',
  'Price Range': '17,000 - 20,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'LAUBURU',
  'Price Range': '6,000 - 9,000 JPY',
  'Restauarant Website': 'http://lauburu.jp/'},
 {'Restaurant Name': 'BIRD LAND',
  'Price Range': '6,000 - 10,000 JPY',
  'Restauarant Website': 'http://ginza-birdland.sakura.ne.jp/'},
 {'Restaurant Name': 'Tempura Motoyoshi',
  'Price Range': '22,000 JPY',
  'Restauarant Website': 'http://motoyoshi-1120.com/'},
 {'Restaurant Name': 'Nishiazabu Sushi Shin',
  'Price Range': '9,500 - 25,000 JPY',
  'Restauarant Website': 'http://sushi-shin.com/'},
 {'Restaurant Name': 'Le Coq',
  'Price Range': '10,000 - 13,000 JPY',
  'Restauarant Website': 'http://www.lecoq.co.jp/'},
 {'Restaurant Name': 'Edomae Shinsaku',
  'Price Range': '20,000 JPY',
  'Restauarant Website': 'https://www.shinsaku.tokyo/'},
 {'Restaurant Name': 'Jizozushi',
  'Price Range': '26,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Shinjuku Kappo Nakajima',
  'Price Range': '1,000 - 15,000 JPY',
  'Restauarant Website': 'http://www.shinjyuku-nakajima.com/'},
 {'Restaurant Name': 'Seika Kobayashi',
  'Price Range': '22,000 - 39,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Chugoku Hanten Kohakukyu (Amber Palace)',
  'Price Range': '4,500 - 44,000 JPY',
  'Restauarant Website': 'https://www.chuugokuhanten.com/'},
 {'Restaurant Name': "L'ALGORITHME",
  'Price Range': '8,000 - 15,000 JPY',
  'Restauarant Website': 'http://lalgorithme.com/'},
 {'Restaurant Name': 'Akasaka Ogino',
  'Price Range': '28,000 - 33,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'le sputnik',
  'Price Range': '8,000 - 19,000 JPY',
  'Restauarant Website': 'https://le-sputnik.jp/'},
 {'Restaurant Name': 'ALTER EGO',
  'Price Range': '19,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Tanimoto',
  'Price Range': '20,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'sio',
  'Price Range': '8,500 - 17,000 JPY',
  'Restauarant Website': 'http://sio-yoyogiuehara.com/'},
 {'Restaurant Name': 'Yotsuya Uemura',
  'Price Range': '19,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Shunso',
  'Price Range': '10,000 - 12,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'au deco',
  'Price Range': '9,000 - 15,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Azabu Wakei',
  'Price Range': '25,000 JPY',
  'Restauarant Website': 'https://wakei.tokyo/'},
 {'Restaurant Name': 'Sushi Takamitsu',
  'Price Range': '33,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Takumi Sushi Owana',
  'Price Range': '9,000 - 22,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Nagumo',
  'Price Range': '2,500 - 17,000 JPY',
  'Restauarant Website': 'http://mejironagumo.g1.xrea.com/top.html'},
 {'Restaurant Name': 'JO',
  'Price Range': '19,000 - 31,000 JPY',
  'Restauarant Website': 'http://jo-tokyo.jp/'},
 {'Restaurant Name': 'Hananoren Kagura',
  'Price Range': '5,500 - 25,000 JPY',
  'Restauarant Website': 'https://hananoren-kagura.jp/'},
 {'Restaurant Name': "L'ASSE",
  'Price Range': '3,000 - 12,000 JPY',
  'Restauarant Website': 'http://lasse.jp/'},
 {'Restaurant Name': 'Sincère',
  'Price Range': '17,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Sushi Keita',
  'Price Range': '11,000 - 20,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'TEN-MASA',
  'Price Range': '15,000 - 25,000 JPY',
  'Restauarant Website': 'http://ten-masa.info/'},
 {'Restaurant Name': 'Torishiki',
  'Price Range': '8,000 - 10,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Tempura Miyashiro',
  'Price Range': '14,000 - 22,000 JPY',
  'Restauarant Website': 'https://www.miyashiro.tokyo/'},
 {'Restaurant Name': 'Ginza Fujiyama',
  'Price Range': '43,000 - 61,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Ginza Yamanobe Edo Chuka',
  'Price Range': '34,000 - 40,000 JPY',
  'Restauarant Website': 'http://ginza-yamanobe.com/'},
 {'Restaurant Name': 'Akiyama',
  'Price Range': '3,000 - 21,000 JPY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Oryori Tsuji',
  'Price Range': '10,000 - 37,000 JPY',
  'Restauarant Website': 'https://oryouritsuji.jp/'},
 {'Restaurant Name': 'Ristorante HONDA',
  'Price Range': '6,500 - 19,000 JPY',
  'Restauarant Website': 'http://www.ristorantehonda.jp'},
 {'Restaurant Name': 'Righi',
  'Price Range': '42 - 100 EUR',
  'Restauarant Website': 'http://www.ristoranterighi.com'},
 {'Restaurant Name': 'Caracol',
  'Price Range': '110 - 130 EUR',
  'Restauarant Website': 'https://www.caracolgourmet.it/'},
 {'Restaurant Name': 'Villa Naj',
  'Price Range': '56 - 80 EUR',
  'Restauarant Website': 'https://www.najstradella.com/'},
 {'Restaurant Name': 'Umberto De Martino',
  'Price Range': '65 - 105 EUR',
  'Restauarant Website': 'https://www.florianmaison.it/'},
 {'Restaurant Name': "Già Sotto l'Arco",
  'Price Range': '70 - 140 EUR',
  'Restauarant Website': 'https://www.giasottolarco.it/'},
 {'Restaurant Name': 'Arnaldo - Clinica Gastronomica',
  'Price Range': '38 - 75 EUR',
  'Restauarant Website': 'https://www.clinicagastronomica.com/'},
 {'Restaurant Name': 'Il Palagio',
  'Price Range': '80 - 140 EUR',
  'Restauarant Website': 'https://www.ilpalagioristorante.it/'},
 {'Restaurant Name': 'St. George by Heinz Beck',
  'Price Range': '145 - 170 EUR',
  'Restauarant Website': 'https://www.theashbeehotel.com/'},
 {'Restaurant Name': 'Gardenia',
  'Price Range': '20 - 100 EUR',
  'Restauarant Website': 'https://www.gardeniacaluso.com/'},
 {'Restaurant Name': 'Virtuoso Gourmet - Tenuta Le Tre Virtù',
  'Price Range': '115 - 150 EUR',
  'Restauarant Website': 'https://www.virtuosogourmet.it/'},
 {'Restaurant Name': 'Poggio Rosso',
  'Price Range': '100 - 190 EUR',
  'Restauarant Website': 'https://www.borgosanfelice.com/'},
 {'Restaurant Name': 'IT Milano',
  'Price Range': '45 - 89 EUR',
  'Restauarant Website': 'http://www.itrestaurants.com'},
 {'Restaurant Name': 'Colline Ciociare',
  'Price Range': '80 - 120 EUR',
  'Restauarant Website': 'https://www.collineciociare.it'},
 {'Restaurant Name': 'Moma',
  'Price Range': '62 - 105 EUR',
  'Restauarant Website': 'https://www.ristorantemoma.it/'},
 {'Restaurant Name': 'Meo Modo',
  'Price Range': '155 - 195 EUR',
  'Restauarant Website': 'https://www.meomodo.it'},
 {'Restaurant Name': 'Claudio',
  'Price Range': '80 - 140 EUR',
  'Restauarant Website': 'http://www.hotelclaudio.it/'},
 {'Restaurant Name': 'Da Gorini',
  'Price Range': '54 - 105 EUR',
  'Restauarant Website': 'https://www.dagorini.it/'},
 {'Restaurant Name': 'Contraste',
  'Price Range': '160 EUR',
  'Restauarant Website': 'https://www.contrastemilano.it/'},
 {'Restaurant Name': 'D.One Restaurant',
  'Price Range': '64 - 120 EUR',
  'Restauarant Website': 'https://www.donerestaurant.it/'},
 {'Restaurant Name': 'Il Cantuccio',
  'Price Range': '54 - 78 EUR',
  'Restauarant Website': 'https://www.mauroelli.com/'},
 {'Restaurant Name': 'Apostelstube',
  'Price Range': '95 - 115 EUR',
  'Restauarant Website': 'https://www.hotelelephant.com/'},
 {'Restaurant Name': 'Oseleta',
  'Price Range': '66 - 130 EUR',
  'Restauarant Website': 'https://www.ristoranteoseleta.it/'},
 {'Restaurant Name': 'Bistrot 64',
  'Price Range': '50 - 90 EUR',
  'Restauarant Website': 'https://www.bistrot64.it/'},
 {'Restaurant Name': 'Pascucci al Porticciolo',
  'Price Range': '60 - 120 EUR',
  'Restauarant Website': 'https://www.pascuccialporticciolo.com/'},
 {'Restaurant Name': 'Gucci Osteria da Massimo Bottura',
  'Price Range': '75 - 150 EUR',
  'Restauarant Website': 'https://www.gucci.com/'},
 {'Restaurant Name': 'La Bottega del Buon Caffè',
  'Price Range': '68 - 165 EUR',
  'Restauarant Website': 'http://www.borgointhecity.com'},
 {'Restaurant Name': 'Schöneck',
  'Price Range': '70 - 96 EUR',
  'Restauarant Website': 'https://www.schoeneck.it/'},
 {'Restaurant Name': 'Relais Blu',
  'Price Range': '62 - 92 EUR',
  'Restauarant Website': 'https://www.relaisblu.com/'},
 {'Restaurant Name': 'Danilo Ciavattini',
  'Price Range': '50 - 76 EUR',
  'Restauarant Website': 'https://www.danilociavattini.com/'},
 {'Restaurant Name': 'I Salotti',
  'Price Range': '110 - 150 EUR',
  'Restauarant Website': 'https://www.ilpatriarca.it/it/ristoranti'},
 {'Restaurant Name': 'Stube Hermitage',
  'Price Range': '40 - 150 EUR',
  'Restauarant Website': 'http://www.stubehermitage.it'},
 {'Restaurant Name': 'Zash',
  'Price Range': '70 - 160 EUR',
  'Restauarant Website': 'https://www.zash.it/'},
 {'Restaurant Name': 'La Stüa de Michil',
  'Price Range': '105 - 140 EUR',
  'Restauarant Website': 'https://www.hotel-laperla.it/'},
 {'Restaurant Name': 'Lazzaro 1915',
  'Price Range': '60 - 110 EUR',
  'Restauarant Website': 'http://www.lazzaro1915.it'},
 {'Restaurant Name': 'Krèsios',
  'Price Range': '150 EUR',
  'Restauarant Website': 'https://www.kresios.it/'},
 {'Restaurant Name': 'Pashà',
  'Price Range': '65 - 150 EUR',
  'Restauarant Website': 'https://www.ristorantepasha.com/'},
 {'Restaurant Name': 'Lorelei',
  'Price Range': '60 - 150 EUR',
  'Restauarant Website': 'https://www.loreleisorrento.com/'},
 {'Restaurant Name': 'Anna Stuben',
  'Price Range': '106 - 130 EUR',
  'Restauarant Website': 'https://www.annastuben.it/'},
 {'Restaurant Name': 'Il Tino',
  'Price Range': '90 - 130 EUR',
  'Restauarant Website': 'https://www.ristoranteiltino.com/'},
 {'Restaurant Name': 'Casa Sgarra',
  'Price Range': '50 - 85 EUR',
  'Restauarant Website': 'https://www.casasgarra.it/'},
 {'Restaurant Name': 'Re Santi e Leoni',
  'Price Range': '65 - 110 EUR',
  'Restauarant Website': 'https://www.resantieleoni.com/'},
 {'Restaurant Name': 'Vintage 1997',
  'Price Range': '24 - 120 EUR',
  'Restauarant Website': 'https://www.vintage1997.com/'},
 {'Restaurant Name': 'Lux Lucis',
  'Price Range': '100 - 150 EUR',
  'Restauarant Website': 'http://principefortedeimarmi.com/en/'},
 {'Restaurant Name': 'Due Camini',
  'Price Range': '140 - 200 EUR',
  'Restauarant Website': 'https://www.ristoranteduecamini.it/'},
 {'Restaurant Name': 'Silene',
  'Price Range': '65 - 120 EUR',
  'Restauarant Website': 'https://www.ilsilene.it/'},
 {'Restaurant Name': "Ca' Matilde",
  'Price Range': '80 - 110 EUR',
  'Restauarant Website': 'https://www.camatilde.it/'},
 {'Restaurant Name': 'Damini Macelleria & Affini',
  'Price Range': '60 - 135 EUR',
  'Restauarant Website': 'https://www.daminieaffini.com/'},
 {'Restaurant Name': 'Il Parco di Villa Grey',
  'Price Range': '90 - 150 EUR',
  'Restauarant Website': 'https://www.ilparcodivillagrey.com/'},
 {'Restaurant Name': 'Spinechile',
  'Price Range': '80 - 120 EUR',
  'Restauarant Website': 'https://www.spinechileresort.com/'},
 {'Restaurant Name': 'Joia',
  'Price Range': '25 - 125 EUR',
  'Restauarant Website': 'https://www.joia.it/'},
 {'Restaurant Name': 'Essenza',
  'Price Range': '55 - 120 EUR',
  'Restauarant Website': 'https://www.essenza.co/'},
 {'Restaurant Name': 'San Martino',
  'Price Range': '45 - 115 EUR',
  'Restauarant Website': 'http://www.sanmartinotreviglio.it'},
 {'Restaurant Name': 'Il Pellicano',
  'Price Range': '98 - 150 EUR',
  'Restauarant Website': 'https://www.pellicanohotel.com/'},
 {'Restaurant Name': 'La Présef',
  'Price Range': '70 - 125 EUR',
  'Restauarant Website': 'http://www.lapresef.it/'},
 {'Restaurant Name': 'I Pupi',
  'Price Range': '35 - 130 EUR',
  'Restauarant Website': 'https://www.ipupiristorante.it/'},
 {'Restaurant Name': 'Veritas',
  'Price Range': '70 - 100 EUR',
  'Restauarant Website': 'https://www.veritasrestaurant.it/'},
 {'Restaurant Name': 'Casin del Gamba',
  'Price Range': '75 - 110 EUR',
  'Restauarant Website': 'https://www.casindelgamba.it/'},
 {'Restaurant Name': 'Maxi',
  'Price Range': '70 - 150 EUR',
  'Restauarant Website': 'https://www.hotelcapolagala.com/'},
 {'Restaurant Name': 'Lido 84',
  'Price Range': '85 - 126 EUR',
  'Restauarant Website': 'https://www.ristorantelido84.com/'},
 {'Restaurant Name': 'La Serra',
  'Price Range': '100 - 180 EUR',
  'Restauarant Website': 'https://www.agavi.it/'},
 {'Restaurant Name': 'L’Alchimia',
  'Price Range': '60 - 95 EUR',
  'Restauarant Website': 'https://www.ristorantelalchimia.com/'},
 {'Restaurant Name': 'Zia',
  'Price Range': '60 - 90 EUR',
  'Restauarant Website': 'https://www.ziarestaurant.com/'},
 {'Restaurant Name': 'Locanda Margon',
  'Price Range': '100 - 200 EUR',
  'Restauarant Website': 'https://www.locandamargon.it/'},
 {'Restaurant Name': 'Sadler',
  'Price Range': '100 - 160 EUR',
  'Restauarant Website': 'https://www.ristorantesadler.it/'},
 {'Restaurant Name': 'Tilia',
  'Price Range': '75 - 110 EUR',
  'Restauarant Website': 'http://www.tilia.bz/'},
 {'Restaurant Name': 'Osteria Arborina',
  'Price Range': '70 - 110 EUR',
  'Restauarant Website': 'https://www.arborinarelais.it/'},
 {'Restaurant Name': 'Osteria di Passignano',
  'Price Range': '80 - 100 EUR',
  'Restauarant Website': 'http://www.osteriadipassignano.com/'},
 {'Restaurant Name': 'Aqua Crua',
  'Price Range': '65 - 160 EUR',
  'Restauarant Website': 'https://www.aquacrua.it'},
 {'Restaurant Name': 'Glicine',
  'Price Range': '100 - 170 EUR',
  'Restauarant Website': 'https://www.hotelsantacaterina.it/'},
 {'Restaurant Name': 'La Zanzara',
  'Price Range': '70 - 110 EUR',
  'Restauarant Website': 'http://www.ristorantelazanzara.com/'},
 {'Restaurant Name': 'Gambero Rosso',
  'Price Range': '58 - 130 EUR',
  'Restauarant Website': 'https://www.gamberorosso.net/'},
 {'Restaurant Name': 'La Capinera',
  'Price Range': '70 - 105 EUR',
  'Restauarant Website': 'https://www.pietrodagostino.it/'},
 {'Restaurant Name': 'Locanda di Orta',
  'Price Range': '110 - 170 EUR',
  'Restauarant Website': 'https://www.locandaorta.com/'},
 {'Restaurant Name': 'Kuppelrain',
  'Price Range': '39 - 130 EUR',
  'Restauarant Website': 'https://www.kuppelrain.com/'},
 {'Restaurant Name': "L'Asinello",
  'Price Range': '48 - 70 EUR',
  'Restauarant Website': 'https://www.asinelloristorante.it/'},
 {'Restaurant Name': "All'Oro",
  'Price Range': '83 - 150 EUR',
  'Restauarant Website': 'https://www.ristorantealloro.it/'},
 {'Restaurant Name': 'La Capanna di Eraclio',
  'Price Range': '63 - 103 EUR',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Il Ridotto',
  'Price Range': '85 - 135 EUR',
  'Restauarant Website': 'https://www.ilridotto.com/'},
 {'Restaurant Name': 'Zur Rose',
  'Price Range': '64 - 115 EUR',
  'Restauarant Website': 'https://www.zur-rose.com/'},
 {'Restaurant Name': 'Josè Restaurant - Tenuta Villa Guerra',
  'Price Range': '70 - 90 EUR',
  'Restauarant Website': 'https://www.joserestaurant.it/'},
 {'Restaurant Name': 'Dolomieu',
  'Price Range': '65 - 110 EUR',
  'Restauarant Website': 'https://www.dvchalet.it/'},
 {'Restaurant Name': 'Petit Royal',
  'Price Range': '130 - 180 EUR',
  'Restauarant Website': 'https://www.hotelroyalegolf.com/'},
 {'Restaurant Name': 'Il Patio',
  'Price Range': '65 - 95 EUR',
  'Restauarant Website': 'https://www.ristoranteilpatio.it/'},
 {'Restaurant Name': '12 Apostoli',
  'Price Range': '120 - 160 EUR',
  'Restauarant Website': 'https://www.12apostoli.com/'},
 {'Restaurant Name': 'Locanda San Lorenzo',
  'Price Range': '30 - 98 EUR',
  'Restauarant Website': 'https://www.locandasanlorenzo.it/'},
 {'Restaurant Name': 'Qafiz',
  'Price Range': '90 - 120 EUR',
  'Restauarant Website': 'https://www.qafiz.it/'},
 {'Restaurant Name': 'Cannavacciuolo Bistrot',
  'Price Range': '100 - 110 EUR',
  'Restauarant Website': 'https://www.cannavacciuolobistrot.it/'},
 {'Restaurant Name': 'La Tavola',
  'Price Range': '95 - 130 EUR',
  'Restauarant Website': 'https://www.ilporticciolo.com/'},
 {'Restaurant Name': 'Al Metrò',
  'Price Range': '60 - 100 EUR',
  'Restauarant Website': 'https://www.ristorantealmetro.it/'},
 {'Restaurant Name': 'Il Falconiere',
  'Price Range': '90 - 130 EUR',
  'Restauarant Website': 'https://www.ilfalconiere.it/'},
 {'Restaurant Name': 'Il Gallo Cedrone',
  'Price Range': '65 - 195 EUR',
  'Restauarant Website': 'https://www.ilgallocedrone.it/'},
 {'Restaurant Name': 'Antica Osteria Nonna Rosa',
  'Price Range': '60 - 120 EUR',
  'Restauarant Website': 'http://www.osterianonnarosa.it/'},
 {'Restaurant Name': 'Laite',
  'Price Range': '70 - 130 EUR',
  'Restauarant Website': 'https://www.ristorantelaite.com/'},
 {'Restaurant Name': 'La Magnolia',
  'Price Range': '100 - 130 EUR',
  'Restauarant Website': 'https://www.hotelbyron.net/'},
 {'Restaurant Name': 'La Fermata',
  'Price Range': '56 - 84 EUR',
  'Restauarant Website': 'https://www.ristorantelafermata.it/'},
 {'Restaurant Name': 'Innocenti Evasioni',
  'Price Range': '58 - 90 EUR',
  'Restauarant Website': 'https://www.innocentievasioni.com/'},
 {'Restaurant Name': 'Mistral',
  'Price Range': '120 - 250 EUR',
  'Restauarant Website': 'https://www.villaserbelloni.com/'},
 {'Restaurant Name': 'Lorenzo',
  'Price Range': '60 - 140 EUR',
  'Restauarant Website': 'https://www.ristorantelorenzo.com/'},
 {'Restaurant Name': "All'Enoteca",
  'Price Range': '90 - 130 EUR',
  'Restauarant Website': 'https://www.davidepalluda.it/'},
 {'Restaurant Name': 'Prezioso',
  'Price Range': '130 EUR',
  'Restauarant Website': 'https://www.fragsburg.com/'},
 {'Restaurant Name': 'Taverna del Capitano',
  'Price Range': '70 - 150 EUR',
  'Restauarant Website': 'http://www.tavernadelcapitano.it/'},
 {'Restaurant Name': 'Le Colonne',
  'Price Range': '70 - 110 EUR',
  'Restauarant Website': 'https://www.lecolonnemarziale.it/'},
 {'Restaurant Name': 'Berton al Lago',
  'Price Range': '105 - 175 EUR',
  'Restauarant Website': 'http://www.serenohotels.com/'},
 {'Restaurant Name': 'Malga Panna',
  'Price Range': '60 - 105 EUR',
  'Restauarant Website': 'https://www.malgapanna.it/'},
 {'Restaurant Name': 'Piazzetta Milù',
  'Price Range': '110 - 130 EUR',
  'Restauarant Website': 'https://www.piazzettamilu.it/'},
 {'Restaurant Name': 'Iacobucci',
  'Price Range': '66 - 110 EUR',
  'Restauarant Website': 'https://www.agostinoiacobucci.it/'},
 {'Restaurant Name': 'Gellius',
  'Price Range': '60 - 110 EUR',
  'Restauarant Website': 'https://www.ristorantegellius.it/'},
 {'Restaurant Name': 'Antonella Ricci-Vinod Sookar',
  'Price Range': '60 - 120 EUR',
  'Restauarant Website': 'https://www.antonellariccivinodsookar.it'},
 {'Restaurant Name': 'Il Bavaglino',
  'Price Range': '60 - 95 EUR',
  'Restauarant Website': 'https://www.giuseppecosta.com/'},
 {'Restaurant Name': 'Viva Viviana Varese',
  'Price Range': '73 - 170 EUR',
  'Restauarant Website': 'https://www.vivavivianavarese.it/'},
 {'Restaurant Name': 'Oasis - Sapori Antichi',
  'Price Range': '25 - 77 EUR',
  'Restauarant Website': 'https://www.oasis-saporiantichi.it/'},
 {'Restaurant Name': 'Franco Mare',
  'Price Range': '62 - 120 EUR',
  'Restauarant Website': 'https://www.ristorantefrancomare.com/'},
 {'Restaurant Name': 'Giglio',
  'Price Range': '58 - 100 EUR',
  'Restauarant Website': 'https://www.ristorantegiglio.com/'},
 {'Restaurant Name': 'LoRo',
  'Price Range': '60 - 125 EUR',
  'Restauarant Website': 'https://www.loroandco.com/'},
 {'Restaurant Name': 'Cannavacciuolo Cafè & Bistrot',
  'Price Range': '76 - 140 EUR',
  'Restauarant Website': 'https://www.cannavacciuolobistrot.it/'},
 {'Restaurant Name': 'I Portici',
  'Price Range': '87 - 140 EUR',
  'Restauarant Website': 'https://www.iporticihotel.com/'},
 {'Restaurant Name': 'Peter Brunel Ristorante Gourmet',
  'Price Range': '28 - 140 EUR',
  'Restauarant Website': 'http://www.peterbrunel.com'},
 {'Restaurant Name': 'Osteria Altran',
  'Price Range': '70 - 96 EUR',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Idylio by Apreda',
  'Price Range': '100 - 140 EUR',
  'Restauarant Website': 'https://www.thepantheonhotel.com/'},
 {'Restaurant Name': 'Nido del Picchio',
  'Price Range': '60 - 96 EUR',
  'Restauarant Website': 'https://www.ristorantenidodelpicchio.it/'},
 {'Restaurant Name': 'Il Refettorio',
  'Price Range': '80 - 125 EUR',
  'Restauarant Website': 'https://www.monasterosantarosa.com/'},
 {'Restaurant Name': "Tano Passami l'Olio",
  'Price Range': '35 - 145 EUR',
  'Restauarant Website': 'https://www.tanopassamilolio.it/'},
 {'Restaurant Name': 'Il Comandante',
  'Price Range': '95 - 175 EUR',
  'Restauarant Website': 'https://www.romeohotel.it/'},
 {'Restaurant Name': 'Abocar Due Cucine',
  'Price Range': '49 - 90 EUR',
  'Restauarant Website': 'https://www.abocarduecucine.it/'},
 {'Restaurant Name': 'Vecchia Malcesine',
  'Price Range': '90 - 140 EUR',
  'Restauarant Website': 'https://www.vecchiamalcesine.com/'},
 {'Restaurant Name': 'La Locanda del Borgo',
  'Price Range': '90 - 120 EUR',
  'Restauarant Website': 'https://www.aquapetra.com/'},
 {'Restaurant Name': 'Atelier',
  'Price Range': '60 - 80 EUR',
  'Restauarant Website': 'https://www.eurossola.com/'},
 {'Restaurant Name': 'Rossellinis',
  'Price Range': '110 - 180 EUR',
  'Restauarant Website': 'https://www.palazzoavino.com/'},
 {'Restaurant Name': 'Antonello Colonna Labico',
  'Price Range': '100 - 120 EUR',
  'Restauarant Website': 'https://www.antonellocolonna.it/'},
 {'Restaurant Name': 'Cielo',
  'Price Range': '70 - 160 EUR',
  'Restauarant Website': 'https://www.lasommita.it/'},
 {'Restaurant Name': 'Gabbiano 3.0',
  'Price Range': '85 - 180 EUR',
  'Restauarant Website': 'https://www.ilgabbianotrepuntozero.it/'},
 {'Restaurant Name': 'Quintessenza',
  'Price Range': '60 - 102 EUR',
  'Restauarant Website': 'https://www.quintessenzaristorante.it/'},
 {'Restaurant Name': "Ca' Vittoria",
  'Price Range': '70 - 115 EUR',
  'Restauarant Website': 'http://www.ristorantevittoria.it'},
 {'Restaurant Name': 'Il Buco',
  'Price Range': '90 - 120 EUR',
  'Restauarant Website': 'https://www.ilbucoristorante.it/'},
 {'Restaurant Name': 'La Buca',
  'Price Range': '65 - 95 EUR',
  'Restauarant Website': 'https://www.labucaristorante.it/'},
 {'Restaurant Name': 'Osteria da Fiore',
  'Price Range': '70 - 130 EUR',
  'Restauarant Website': 'https://www.ristorantedafiore.com/'},
 {'Restaurant Name': 'Casa Vicina-Eataly Lingotto',
  'Price Range': '50 - 130 EUR',
  'Restauarant Website': 'https://www.casavicina.com/'},
 {'Restaurant Name': 'Esplanade',
  'Price Range': '90 - 130 EUR',
  'Restauarant Website': 'https://www.ristorante-esplanade.com/'},
 {'Restaurant Name': 'AALTO',
  'Price Range': '85 - 150 EUR',
  'Restauarant Website': 'https://www.aalto-restaurant.com/'},
 {'Restaurant Name': 'Kitchen',
  'Price Range': '57 - 90 EUR',
  'Restauarant Website': 'https://www.kitchencomo.com/'},
 {'Restaurant Name': 'Trattoria da Amerigo',
  'Price Range': '33 - 65 EUR',
  'Restauarant Website': 'http://www.amerigo1934.it/'},
 {'Restaurant Name': 'Linfa',
  'Price Range': '80 - 125 EUR',
  'Restauarant Website': 'https://www.linfa.restaurant/'},
 {'Restaurant Name': 'Lanterna Verde',
  'Price Range': '52 - 100 EUR',
  'Restauarant Website': 'https://www.lanternaverde.com/'},
 {'Restaurant Name': 'Antica Corte Pallavicina',
  'Price Range': '85 - 180 EUR',
  'Restauarant Website': 'http://www.acpallavicina.com/'},
 {'Restaurant Name': 'Spazio7',
  'Price Range': '50 - 100 EUR',
  'Restauarant Website': 'https://www.ristorantespazio7.it/'},
 {'Restaurant Name': 'La Veranda del Color',
  'Price Range': '76 - 150 EUR',
  'Restauarant Website': 'https://www.laverandadelcolor.it/'},
 {'Restaurant Name': 'Le Trabe',
  'Price Range': '70 - 104 EUR',
  'Restauarant Website': 'https://www.letrabe.it/'},
 {'Restaurant Name': 'Borgo San Jacopo',
  'Price Range': '84 - 150 EUR',
  'Restauarant Website': 'https://www.lungarnocollection.com/'},
 {'Restaurant Name': 'George Restaurant',
  'Price Range': '90 - 150 EUR',
  'Restauarant Website': 'https://www.grandhotelparkers.it/'},
 {'Restaurant Name': 'Tordomatto',
  'Price Range': '50 - 90 EUR',
  'Restauarant Website': 'https://www.tordomattoroma.com/'},
 {'Restaurant Name': 'Acquolina',
  'Price Range': '90 - 150 EUR',
  'Restauarant Website': 'https://www.acquolinaristorante.it/'},
 {'Restaurant Name': 'President',
  'Price Range': '55 - 110 EUR',
  'Restauarant Website': 'https://www.ristorantepresident.it/'},
 {'Restaurant Name': 'Sissi',
  'Price Range': '70 - 95 EUR',
  'Restauarant Website': 'https://www.sissi.andreafenoglio.com/'},
 {'Restaurant Name': 'La Ciau del Tornavento',
  'Price Range': '68 - 115 EUR',
  'Restauarant Website': 'https://www.laciaudeltornavento.it/'},
 {'Restaurant Name': 'Iyo',
  'Price Range': '70 - 130 EUR',
  'Restauarant Website': 'https://www.iyo.it/'},
 {'Restaurant Name': 'Signum',
  'Price Range': '75 - 160 EUR',
  'Restauarant Website': 'https://www.hotelsignum.it/'},
 {'Restaurant Name': 'Dolce Stil Novo alla Reggia',
  'Price Range': '38 - 145 EUR',
  'Restauarant Website': 'https://www.alfredorusso.com/'},
 {'Restaurant Name': 'Quadri',
  'Price Range': '150 - 215 EUR',
  'Restauarant Website': 'https://www.alajmo.it/'},
 {'Restaurant Name': 'Johannesstube',
  'Price Range': '88 - 155 EUR',
  'Restauarant Website': 'https://www.johannesstube.com/'},
 {'Restaurant Name': 'SanBrite',
  'Price Range': '100 - 130 EUR',
  'Restauarant Website': 'https://www.sanbrite.it/'},
 {'Restaurant Name': 'Guido',
  'Price Range': '80 - 120 EUR',
  'Restauarant Website': 'http://www.guidoristorante.it/'},
 {'Restaurant Name': 'La Fenice',
  'Price Range': '65 - 130 EUR',
  'Restauarant Website': 'https://www.lafeniceristorante.com/'},
 {'Restaurant Name': 'Del Cambio',
  'Price Range': '105 - 210 EUR',
  'Restauarant Website': 'https://www.delcambio.it/'},
 {'Restaurant Name': 'Locanda Don Serafino',
  'Price Range': '55 - 165 EUR',
  'Restauarant Website': 'https://www.locandadonserafino.it/'},
 {'Restaurant Name': 'Il Convivio Troiani',
  'Price Range': '80 - 140 EUR',
  'Restauarant Website': 'https://www.ilconviviotroiani.com/'},
 {'Restaurant Name': "Il Faro di Capo d'Orso",
  'Price Range': '70 - 150 EUR',
  'Restauarant Website': 'https://www.ilfarodicapodorso.it/'},
 {'Restaurant Name': 'Nostrano',
  'Price Range': '70 - 100 EUR',
  'Restauarant Website': 'https://www.nostranoristorante.it/'},
 {'Restaurant Name': 'Il Desco',
  'Price Range': '85 - 150 EUR',
  'Restauarant Website': 'https://www.ildesco.com/'},
 {'Restaurant Name': "Leon d'Oro",
  'Price Range': '50 - 120 EUR',
  'Restauarant Website': 'http://www.locandaleondoro.it/'},
 {'Restaurant Name': 'Il Pievano',
  'Price Range': '72 - 130 EUR',
  'Restauarant Website': 'https://www.spaltenna.it/'},
 {'Restaurant Name': "L'Erba del Re",
  'Price Range': '75 - 110 EUR',
  'Restauarant Website': 'https://www.lerbadelre.it/'},
 {'Restaurant Name': 'Da Candida',
  'Price Range': '70 - 110 EUR',
  'Restauarant Website': 'https://www.dacandida.ch/'},
 {'Restaurant Name': 'La Rucola 2.0',
  'Price Range': '90 - 110 EUR',
  'Restauarant Website': 'https://www.ristorantelarucola.it/'},
 {'Restaurant Name': 'Il Papavero',
  'Price Range': '40 - 62 EUR',
  'Restauarant Website': 'https://www.ristoranteilpapavero.it/'},
 {'Restaurant Name': 'La Leggenda dei Frati',
  'Price Range': '90 - 170 EUR',
  'Restauarant Website': 'https://www.laleggendadeifrati.it/'},
 {'Restaurant Name': 'La Tana Gourmet',
  'Price Range': '180 EUR',
  'Restauarant Website': 'https://www.latanagourmet.it/'},
 {'Restaurant Name': 'Il Flauto di Pan',
  'Price Range': '90 - 190 EUR',
  'Restauarant Website': 'https://www.hotelvillacimbrone.it/'},
 {'Restaurant Name': 'Massimo Camia',
  'Price Range': '63 - 90 EUR',
  'Restauarant Website': 'https://www.massimocamia.it/'},
 {'Restaurant Name': 'Cinzia da Christian e Manuel',
  'Price Range': '60 - 140 EUR',
  'Restauarant Website': 'http://www.christianemanuel.it/'},
 {'Restaurant Name': 'Paolo e Barbara',
  'Price Range': '63 - 98 EUR',
  'Restauarant Website': 'https://www.paolobarbara.it/'},
 {'Restaurant Name': 'Tivoli',
  'Price Range': '82 - 140 EUR',
  'Restauarant Website': 'https://www.ristorantetivolicortina.it/'},
 {'Restaurant Name': 'Matteo Grandi',
  'Price Range': '90 - 130 EUR',
  'Restauarant Website': 'https://www.ristorantematteograndi.it/degusto/'},
 {'Restaurant Name': "Bros'",
  'Price Range': '130 - 200 EUR',
  'Restauarant Website': 'https://www.brosrestaurant.it/'},
 {'Restaurant Name': 'La Pineta',
  'Price Range': '57 - 85 EUR',
  'Restauarant Website': 'https://www.lapinetadizazzeri.it/'},
 {'Restaurant Name': 'La Parolina',
  'Price Range': '60 - 110 EUR',
  'Restauarant Website': 'https://www.laparolina.it/'},
 {'Restaurant Name': 'La Credenza',
  'Price Range': '70 - 170 EUR',
  'Restauarant Website': 'https://credenzagroup.it/locali/ristorante-la-credenza/'},
 {'Restaurant Name': 'Magorabin',
  'Price Range': '80 - 160 EUR',
  'Restauarant Website': 'https://www.magorabin.com/'},
 {'Restaurant Name': 'Condividere',
  'Price Range': '70 - 100 EUR',
  'Restauarant Website': 'https://www.condividere.com/'},
 {'Restaurant Name': 'Due Colombe',
  'Price Range': '66 - 100 EUR',
  'Restauarant Website': 'https://www.duecolombe.com/'},
 {'Restaurant Name': 'Pietramare Natural Food',
  'Price Range': '50 - 120 EUR',
  'Restauarant Website': 'https://www.praiaartresort.com/'},
 {'Restaurant Name': 'L˜ARIA',
  'Price Range': '95 - 140 EUR',
  'Restauarant Website': 'http://www.mandarinoriental.com/lake-como'},
 {'Restaurant Name': 'Il Portale',
  'Price Range': '65 - 210 EUR',
  'Restauarant Website': 'https://www.ristoranteilportale.it/'},
 {'Restaurant Name': 'Locanda Vecchia Pavia "Al Mulino"',
  'Price Range': '45 - 90 EUR',
  'Restauarant Website': 'http://www.vecchiapaviaalmulino.it/'},
 {'Restaurant Name': 'Villa Giulia',
  'Price Range': '85 - 130 EUR',
  'Restauarant Website': 'https://www.villagiulia.it/'},
 {'Restaurant Name': 'Il Cappero',
  'Price Range': '140 - 160 EUR',
  'Restauarant Website': 'https://www.therasiaresort.it/'},
 {'Restaurant Name': 'Aroma',
  'Price Range': '100 - 170 EUR',
  'Restauarant Website': 'https://www.aromarestaurant.it/'},
 {'Restaurant Name': 'Frosio',
  'Price Range': '70 - 80 EUR',
  'Restauarant Website': 'http://www.frosioristoranti.it/'},
 {'Restaurant Name': 'Andreina',
  'Price Range': '60 - 115 EUR',
  'Restauarant Website': 'https://www.ristoranteandreina.it/'},
 {'Restaurant Name': 'Senso Alfio Ghezzi Mart',
  'Price Range': '80 - 100 EUR',
  'Restauarant Website': 'https://alfioghezzi.com/'},
 {'Restaurant Name': 'I Castagni',
  'Price Range': '55 - 90 EUR',
  'Restauarant Website': 'https://www.ristoranteicastagni.com/'},
 {'Restaurant Name': 'Vitantonio Lombardo',
  'Price Range': '90 - 150 EUR',
  'Restauarant Website': 'https://www.vlristorante.it/'},
 {'Restaurant Name': 'Nove',
  'Price Range': '70 - 118 EUR',
  'Restauarant Website': 'http://www.noveristorante.it'},
 {'Restaurant Name': 'Il Centro',
  'Price Range': '50 - 90 EUR',
  'Restauarant Website': 'https://www.ristoranteilcentro.com/'},
 {'Restaurant Name': 'La Taverna',
  'Price Range': '55 - 80 EUR',
  'Restauarant Website': 'https://www.ristorantelataverna.it/'},
 {'Restaurant Name': 'Zass',
  'Price Range': '130 - 180 EUR',
  'Restauarant Website': 'https://www.ilsanpietro.it/'},
 {'Restaurant Name': 'Pipero Roma',
  'Price Range': '120 - 160 EUR',
  'Restauarant Website': 'https://www.piperoroma.it/'},
 {'Restaurant Name': "Locanda Sant'Uffizio Enrico Bartolini",
  'Price Range': '80 - 140 EUR',
  'Restauarant Website': 'https://www.relaissantuffizio.com/'},
 {'Restaurant Name': 'Inkiostro',
  'Price Range': '80 - 135 EUR',
  'Restauarant Website': 'https://www.ristoranteinkiostro.it/'},
 {'Restaurant Name': 'Locanda del Pilone',
  'Price Range': '78 - 140 EUR',
  'Restauarant Website': 'https://www.locandadelpilone.com/'},
 {'Restaurant Name': 'The Cook',
  'Price Range': '55 - 110 EUR',
  'Restauarant Website': 'https://www.thecookrestaurant.com/'},
 {'Restaurant Name': 'Glass Hostaria',
  'Price Range': '75 - 105 EUR',
  'Restauarant Website': 'https://www.glasshostaria.it/'},
 {'Restaurant Name': 'Piano 35',
  'Price Range': '14 - 120 EUR',
  'Restauarant Website': 'http://www.piano35.com/'},
 {'Restaurant Name': 'Zum Löwen',
  'Price Range': '75 - 100 EUR',
  'Restauarant Website': 'https://www.zumloewen.it/'},
 {'Restaurant Name': 'Sedicesimo Secolo',
  'Price Range': '60 - 92 EUR',
  'Restauarant Website': 'https://www.ristorantesedicesimosecolo.it/'},
 {'Restaurant Name': 'Re Maurì',
  'Price Range': '71 - 110 EUR',
  'Restauarant Website': 'https://www.remauri.it/'},
 {'Restaurant Name': 'Feva',
  'Price Range': '25 - 90 EUR',
  'Restauarant Website': 'https://www.fevaristorante.it/'},
 {'Restaurant Name': '21.9',
  'Price Range': '70 - 150 EUR',
  'Restauarant Website': 'https://www.ristorante21punto9.it/'},
 {'Restaurant Name': 'Villa Maiella',
  'Price Range': '60 - 95 EUR',
  'Restauarant Website': 'https://www.villamaiella.it/'},
 {'Restaurant Name': 'Trattoria al Cacciatore - La Subida',
  'Price Range': '60 - 100 EUR',
  'Restauarant Website': 'https://www.lasubida.it/'},
 {'Restaurant Name': 'Angelo Sabatelli',
  'Price Range': '75 - 160 EUR',
  'Restauarant Website': 'https://www.angelosabatelliristorante.com/'},
 {'Restaurant Name': 'Materia',
  'Price Range': '19 - 135 EUR',
  'Restauarant Website': 'https://www.ristorantemateria.it/'},
 {'Restaurant Name': 'La Terrazza',
  'Price Range': '130 - 200 EUR',
  'Restauarant Website': 'http://www.dorchestercollection.com/'},
 {'Restaurant Name': "Impronta d'Acqua",
  'Price Range': '52 - 120 EUR',
  'Restauarant Website': 'http://www.improntadacqua.com'},
 {'Restaurant Name': 'Otto Geleng',
  'Price Range': '120 - 150 EUR',
  'Restauarant Website': 'https://www.belmond.com/grandhoteltimeo'},
 {'Restaurant Name': 'Ristorante Castello di Fighine',
  'Price Range': '90 - 120 EUR',
  'Restauarant Website': 'https://www.fighine.it/'},
 {'Restaurant Name': 'Il Cantinone e Sport Hotel Alpina',
  'Price Range': '59 - 139 EUR',
  'Restauarant Website': 'https://www.ristorantecantinone.com/'},
 {'Restaurant Name': 'Capriccio',
  'Price Range': '55 - 130 EUR',
  'Restauarant Website': 'https://www.ristorantecapriccio.it/'},
 {'Restaurant Name': 'Osteria del Povero Diavolo',
  'Price Range': '42 - 68 EUR',
  'Restauarant Website': 'https://www.osteriapoverodiavolo.it/'},
 {'Restaurant Name': 'Casa Iozzìa',
  'Price Range': '75 - 110 EUR',
  'Restauarant Website': 'https://www.casaiozzia.it/'},
 {'Restaurant Name': 'Oro Restaurant',
  'Price Range': '220 EUR',
  'Restauarant Website': 'https://www.belmond.com/'},
 {'Restaurant Name': 'Coria',
  'Price Range': '45 - 100 EUR',
  'Restauarant Website': 'https://www.ristorantecoria.it/'},
 {'Restaurant Name': 'Shalai',
  'Price Range': '52 - 130 EUR',
  'Restauarant Website': 'https://www.shalai.it/'},
 {'Restaurant Name': 'Vecchio Ristoro',
  'Price Range': '70 - 100 EUR',
  'Restauarant Website': 'https://www.ristorantevecchioristoro.it/'},
 {'Restaurant Name': 'La Tortuga',
  'Price Range': '100 - 120 EUR',
  'Restauarant Website': 'https://www.ristorantelatortuga.it/'},
 {'Restaurant Name': 'Al Gambero',
  'Price Range': '40 - 105 EUR',
  'Restauarant Website': 'https://www.algamberoristorante.it/'},
 {'Restaurant Name': 'Impronte',
  'Price Range': '75 - 130 EUR',
  'Restauarant Website': 'https://www.impronteristorante.com/'},
 {'Restaurant Name': 'Dal Corsaro',
  'Price Range': '110 - 145 EUR',
  'Restauarant Website': 'https://www.stefanodeidda.it/'},
 {'Restaurant Name': 'Culinaria im Farmerkreuz',
  'Price Range': '45 - 110 EUR',
  'Restauarant Website': 'www.culinaria-im-farmerkreuz.it'},
 {'Restaurant Name': "Borgo Sant'Anna",
  'Price Range': '45 - 70 EUR',
  'Restauarant Website': 'https://www.borgosantanna.it/'},
 {'Restaurant Name': "Storie d'Amore",
  'Price Range': '25 - 100 EUR',
  'Restauarant Website': 'http://www.storiedamorerestaurant.it'},
 {'Restaurant Name': 'Alpenroyal Gourmet',
  'Price Range': '115 - 148 EUR',
  'Restauarant Website': 'https://www.alpenroyal.com/'},
 {'Restaurant Name': 'Sarri',
  'Price Range': '74 - 90 EUR',
  'Restauarant Website': 'https://www.ristorantesarri.it/'},
 {'Restaurant Name': 'Enoteca La Torre',
  'Price Range': '85 - 140 EUR',
  'Restauarant Website': 'https://www.enotecalatorreroma.com/'},
 {'Restaurant Name': 'Al Sorriso',
  'Price Range': '80 - 150 EUR',
  'Restauarant Website': 'https://www.alsorriso.com/'},
 {'Restaurant Name': 'Sala dei Grappoli',
  'Price Range': '90 - 160 EUR',
  'Restauarant Website': 'http://www.castellobanfiilborgo.it'},
 {'Restaurant Name': 'Terrazza Bosquet',
  'Price Range': '100 - 150 EUR',
  'Restauarant Website': 'https://www.excelsiorvittoria.com/'},
 {'Restaurant Name': 'San Martino',
  'Price Range': '38 - 90 EUR',
  'Restauarant Website': 'https://www.ristorantesanmartino.info/'},
 {'Restaurant Name': 'La Caravella dal 1959',
  'Price Range': '60 - 180 EUR',
  'Restauarant Website': 'http://www.ristorantelacaravella.it/'},
 {'Restaurant Name': 'Dattilo',
  'Price Range': '75 - 120 EUR',
  'Restauarant Website': 'https://www.dattilo.it/'},
 {'Restaurant Name': 'El Molin',
  'Price Range': '110 - 150 EUR',
  'Restauarant Website': 'https://www.alessandrogilmozzi.it/'},
 {'Restaurant Name': 'Astra',
  'Price Range': '77 - 110 EUR',
  'Restauarant Website': 'https://www.restaurant-astra.com/'},
 {'Restaurant Name': 'Pierino Penati',
  'Price Range': '40 - 110 EUR',
  'Restauarant Website': 'https://www.pierinopenati.it/'},
 {'Restaurant Name': 'Il Cascinalenuovo',
  'Price Range': '40 - 80 EUR',
  'Restauarant Website': 'https://www.walterferretto.com/'},
 {'Restaurant Name': 'La Bandiera',
  'Price Range': '35 - 87 EUR',
  'Restauarant Website': 'https://www.labandiera.it/'},
 {'Restaurant Name': 'Osteria della Brughiera',
  'Price Range': '85 - 121 EUR',
  'Restauarant Website': 'https://www.osteriadellabrughiera.it/'},
 {'Restaurant Name': 'Ma.Ri.Na.',
  'Price Range': '80 - 180 EUR',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'La Trattoria Enrico Bartolini',
  'Price Range': '80 - 180 EUR',
  'Restauarant Website': 'https://www.enricobartolini.net/'},
 {'Restaurant Name': 'Sud',
  'Price Range': '60 - 100 EUR',
  'Restauarant Website': 'https://www.sudristorante.it/'},
 {'Restaurant Name': 'Sapio',
  'Price Range': '78 - 120 EUR',
  'Restauarant Website': 'https://www.sapiorestaurant.it/'},
 {'Restaurant Name': 'Parizzi',
  'Price Range': '52 - 75 EUR',
  'Restauarant Website': 'https://www.ristoranteparizzi.it/'},
 {'Restaurant Name': 'La Torre',
  'Price Range': '100 - 180 EUR',
  'Restauarant Website': 'https://www.comohotels.com/'},
 {'Restaurant Name': 'Carignano',
  'Price Range': '62 - 120 EUR',
  'Restauarant Website': 'https://www.ristorantecarignano.it/'},
 {'Restaurant Name': 'Bistrot',
  'Price Range': '80 - 140 EUR',
  'Restauarant Website': 'http://www.bistrotforte.it'},
 {'Restaurant Name': 'Le Monzù',
  'Price Range': '90 - 200 EUR',
  'Restauarant Website': 'https://www.hoteltragara.com/'},
 {'Restaurant Name': "'L Chimpl",
  'Price Range': '45 - 90 EUR',
  'Restauarant Website': 'https://www.lchimpl.it/'},
 {'Restaurant Name': 'Da Francesco',
  'Price Range': '60 - 90 EUR',
  'Restauarant Website': 'http://www.ristorantedafrancesco.com'},
 {'Restaurant Name': 'Don Geppi',
  'Price Range': '72 - 140 EUR',
  'Restauarant Website': 'http://ww7.dongeppirestaurant.com/'},
 {'Restaurant Name': 'Le Petit Bellevue',
  'Price Range': '75 - 110 EUR',
  'Restauarant Website': 'http://www.hotelbellevue.it'},
 {'Restaurant Name': 'ConFusion',
  'Price Range': '80 - 190 EUR',
  'Restauarant Website': 'http://www.confusionlounge.it/'},
 {'Restaurant Name': 'Il Piastrino',
  'Price Range': '55 - 95 EUR',
  'Restauarant Website': 'https://www.piastrino.it/'},
 {'Restaurant Name': 'In Viaggio - Claudio Melis',
  'Price Range': '90 - 130 EUR',
  'Restauarant Website': 'https://www.inviaggioristorante.com/'},
 {'Restaurant Name': 'Amistà',
  'Price Range': '80 - 120 EUR',
  'Restauarant Website': 'https://www.ristoranteamista.it/'},
 {'Restaurant Name': 'Lunasia',
  'Price Range': '70 - 150 EUR',
  'Restauarant Website': 'https://www.plazaederussie.com/'},
 {'Restaurant Name': 'Venissa',
  'Price Range': '110 - 170 EUR',
  'Restauarant Website': 'https://www.venissa.it/'},
 {'Restaurant Name': 'Mammà',
  'Price Range': '80 - 150 EUR',
  'Restauarant Website': 'https://www.ristorantemamma.com/'},
 {'Restaurant Name': 'I Caffi',
  'Price Range': '50 - 95 EUR',
  'Restauarant Website': 'https://www.icaffi.it/'},
 {'Restaurant Name': 'La Bottega del 30',
  'Price Range': '61 - 110 EUR',
  'Restauarant Website': 'https://www.labottegadel30.it/'},
 {'Restaurant Name': 'I Tigli in Theoria',
  'Price Range': '95 - 150 EUR',
  'Restauarant Website': 'https://www.theoriagallery.it/'},
 {'Restaurant Name': 'Il Saraceno',
  'Price Range': '30 - 120 EUR',
  'Restauarant Website': 'https://www.ristorante-ilsaraceno.it/'},
 {'Restaurant Name': 'Abbruzzino',
  'Price Range': '75 - 110 EUR',
  'Restauarant Website': 'https://www.abbruzzino.it/'},
 {'Restaurant Name': 'Osteria Arbustico',
  'Price Range': '70 - 95 EUR',
  'Restauarant Website': 'http://www.osteriaarbustico.it'},
 {'Restaurant Name': 'Aminta Resort',
  'Price Range': '70 - 130 EUR',
  'Restauarant Website': 'https://www.amintaresort.it/'},
 {'Restaurant Name': 'Atman a Villa Rospigliosi',
  'Price Range': '82 - 210 EUR',
  'Restauarant Website': 'https://www.atmanavillarospigliosi.it/'},
 {'Restaurant Name': 'Zappatori',
  'Price Range': '25 - 90 EUR',
  'Restauarant Website': 'https://www.trattoriazappatori.it/'},
 {'Restaurant Name': 'La Cru',
  'Price Range': '75 - 120 EUR',
  'Restauarant Website': 'https://www.ristorantelacru.it/'},
 {'Restaurant Name': 'Indaco',
  'Price Range': '90 - 145 EUR',
  'Restauarant Website': 'http://www.reginaisabella.it/'},
 {'Restaurant Name': 'Vespasia',
  'Price Range': '75 - 150 EUR',
  'Restauarant Website': 'https://www.vespasia.com/'},
 {'Restaurant Name': 'Romano',
  'Price Range': '60 - 135 EUR',
  'Restauarant Website': 'https://www.romanoristorante.it/'},
 {'Restaurant Name': 'Berton',
  'Price Range': '45 - 150 EUR',
  'Restauarant Website': 'https://www.ristoranteberton.com/'},
 {'Restaurant Name': 'La Primula',
  'Price Range': '51 - 90 EUR',
  'Restauarant Website': 'https://www.ristorantelaprimula.it/'},
 {'Restaurant Name': 'Casual',
  'Price Range': '90 - 145 EUR',
  'Restauarant Website': 'https://www.enricobartolini.net/'},
 {'Restaurant Name': 'Tantris',
  'Price Range': '70 - 95 EUR',
  'Restauarant Website': 'https://www.ristorantetantris.com/'},
 {'Restaurant Name': "L'Argine a Vencò",
  'Price Range': '70 - 110 EUR',
  'Restauarant Website': 'http://www.largineavenco.it/'},
 {'Restaurant Name': 'La Palta',
  'Price Range': '60 - 85 EUR',
  'Restauarant Website': 'https://www.lapalta.it/'},
 {'Restaurant Name': 'Imàgo',
  'Price Range': '130 - 160 EUR',
  'Restauarant Website': 'http://www.imagorestaurant.com/'},
 {'Restaurant Name': 'Osteria Perillà',
  'Price Range': '75 - 130 EUR',
  'Restauarant Website': 'https://www.osteriaperilla.it/'},
 {'Restaurant Name': 'Dolada',
  'Price Range': '68 - 110 EUR',
  'Restauarant Website': 'https://www.dolada.it/'},
 {'Restaurant Name': 'Cracco',
  'Price Range': '125 - 200 EUR',
  'Restauarant Website': 'https://www.ristorantecracco.it/'},
 {'Restaurant Name': 'Casa Vissani',
  'Price Range': '100 - 250 EUR',
  'Restauarant Website': 'https://www.casavissani.it/'},
 {'Restaurant Name': 'Acquerello',
  'Price Range': '75 - 180 EUR',
  'Restauarant Website': 'https://www.ristoranteacquerello.com/'},
 {'Restaurant Name': 'Marco Martini Restaurant',
  'Price Range': '51 - 150 EUR',
  'Restauarant Website': 'https://www.marcomartinichef.com/'},
 {'Restaurant Name': 'Guido',
  'Price Range': '79 - 100 EUR',
  'Restauarant Website': 'https://www.ristoranteguido.it/'},
 {'Restaurant Name': "Ora d'Aria",
  'Price Range': '90 - 120 EUR',
  'Restauarant Website': 'https://www.oradariaristorante.com/'},
 {'Restaurant Name': 'Don Alfonso 1890 San Barbato',
  'Price Range': '70 - 100 EUR',
  'Restauarant Website': 'https://www.sanbarbatoresort.com/'},
 {'Restaurant Name': 'Casamatta',
  'Price Range': '60 - 110 EUR',
  'Restauarant Website': 'https://www.viniliaresort.com/'},
 {'Restaurant Name': 'Larossa',
  'Price Range': '65 - 150 EUR',
  'Restauarant Website': 'https://www.ristorantelarossa.it/'},
 {'Restaurant Name': 'Palazzo Petrucci',
  'Price Range': '75 - 150 EUR',
  'Restauarant Website': 'https://www.palazzopetrucci.it/'},
 {'Restaurant Name': 'Il Ristorante di Guido da Costigliole',
  'Price Range': '90 - 155 EUR',
  'Restauarant Website': 'http://www.guidosanmaurizio.com'},
 {'Restaurant Name': 'Assaje',
  'Price Range': '80 - 140 EUR',
  'Restauarant Website': 'www.aldrovandi.com'},
 {'Restaurant Name': 'Fre',
  'Price Range': '90 - 150 EUR',
  'Restauarant Website': 'http://www.ristorantefre.it/'},
 {'Restaurant Name': 'Acqua Pazza',
  'Price Range': '69 - 110 EUR',
  'Restauarant Website': 'https://www.acquapazza.com/'},
 {'Restaurant Name': 'Il Vescovado',
  'Price Range': '95 - 160 EUR',
  'Restauarant Website': 'https://www.ricchebuonochef.it/'},
 {'Restaurant Name': 'Per Me Giulio Terrinoni',
  'Price Range': '33 - 140 EUR',
  'Restauarant Website': 'https://www.giulioterrinoni.it'},
 {'Restaurant Name': 'Accursio',
  'Price Range': '95 - 140 EUR',
  'Restauarant Website': 'http://www.accursioristorante.it/'},
 {'Restaurant Name': 'Butterfly',
  'Price Range': '70 - 120 EUR',
  'Restauarant Website': 'https://www.ristorantebutterfly.it/'},
 {'Restaurant Name': 'Stube Gourmet',
  'Price Range': '86 - 116 EUR',
  'Restauarant Website': 'https://www.hoteleuroparesidence.it/'},
 {'Restaurant Name': 'Zero Complex',
  'Price Range': '100,000 - 180,000 KRW',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Table for Four',
  'Price Range': '60,000 - 120,000 KRW',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Muni',
  'Price Range': '180,000 - 250,000 KRW',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Evett',
  'Price Range': '75,000 - 180,000 KRW',
  'Restauarant Website': 'https://www.restaurantevett.com/'},
 {'Restaurant Name': 'Hansikgonggan',
  'Price Range': '80,000 - 150,000 KRW',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Myomi',
  'Price Range': '100,000 - 205,000 KRW',
  'Restauarant Website': 'https://www.myomiseoul.com/'},
 {'Restaurant Name': 'Exquisine',
  'Price Range': '60,000 - 145,000 KRW',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Bicena',
  'Price Range': '77,000 - 190,000 KRW',
  'Restauarant Website': 'https://www.bicena.com/'},
 {'Restaurant Name': 'Auprès',
  'Price Range': '65,000 - 190,000 KRW',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Onjium',
  'Price Range': '110,000 - 176,000 KRW',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Mitou',
  'Price Range': '180,000 - 230,000 KRW',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': "L'Amitié",
  'Price Range': '80,000 - 190,000 KRW',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Soigné',
  'Price Range': '98,000 - 265,000 KRW',
  'Restauarant Website': 'http://www.soignerestaurantgroup.com/'},
 {'Restaurant Name': '7th Door',
  'Price Range': '120,000 - 250,000 KRW',
  'Restauarant Website': 'https://www.7thdoor.kr/'},
 {'Restaurant Name': 'Terreno',
  'Price Range': '70,000 - 150,000 KRW',
  'Restauarant Website': 'http://www.terreno.co.kr/'},
 {'Restaurant Name': 'Votre Maison',
  'Price Range': '65,000 - 150,000 KRW',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Pierre Gagnaire',
  'Price Range': '90,000 - 340,000 KRW',
  'Restauarant Website': 'https://www.pierregagnaire.co.kr/'},
 {'Restaurant Name': 'Muoki',
  'Price Range': '70,000 - 160,000 KRW',
  'Restauarant Website': 'http://www.muoki.kr/'},
 {'Restaurant Name': "L'Amant Secret",
  'Price Range': '110,000 - 245,000 KRW',
  'Restauarant Website': 'https://www.lescapehotel.com/'},
 {'Restaurant Name': 'STAY',
  'Price Range': '73,000 - 248,000 KRW',
  'Restauarant Website': 'https://www.lottehotel.com/seoul-signiel'},
 {'Restaurant Name': 'Yu Yuan',
  'Price Range': '60,000 - 220,000 KRW',
  'Restauarant Website': 'https://www.fourseasons.com/seoul'},
 {'Restaurant Name': 'Joo Ok',
  'Price Range': '90,000 - 200,000 KRW',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Poetry‧Wine (Chaoyanggongyuan Road)',
  'Price Range': '200 - 600 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Da Dong (Dongsi 10th Alley)',
  'Price Range': '300 - 500 CNY',
  'Restauarant Website': 'http://www.dadongdadong.com'},
 {'Restaurant Name': 'Seventh Son',
  'Price Range': '200 - 1,000 CNY',
  'Restauarant Website': 'www.seventhson.hk/'},
 {'Restaurant Name': 'Sheng Yong Xing (Chaoyang)',
  'Price Range': '400 - 1,288 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Zijin Mansion',
  'Price Range': '268 - 888 CNY',
  'Restauarant Website': 'https://www.waldorfastoria.com/beijing'},
 {'Restaurant Name': 'Family Li Imperial Cuisine (Xicheng)',
  'Price Range': '298 - 2,868 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Zhiguan Courtyard',
  'Price Range': '400 - 1,000 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Cai Yi Xuan',
  'Price Range': '288 - 1,388 CNY',
  'Restauarant Website': 'https://www.fourseasons.com/beijing/'},
 {'Restaurant Name': 'Cui Hua Lou (Chongwenmenwai Street)',
  'Price Range': '200 - 500 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Jing',
  'Price Range': '500 - 1,088 CNY',
  'Restauarant Website': 'www.peninsula.com/beijing'},
 {'Restaurant Name': 'Xin Rong Ji (Jinrong Street)',
  'Price Range': '600 - 1,000 CNY',
  'Restauarant Website': 'www.xinrongji.cc'},
 {'Restaurant Name': 'The Georg',
  'Price Range': '500 - 1,888 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Vege Wonder',
  'Price Range': '480 - 1,280 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Poetry‧Wine (Dongsanhuan Middle Road)',
  'Price Range': '200 - 500 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Il Ristorante - Niko Romito',
  'Price Range': '458 - 1,900 CNY',
  'Restauarant Website': 'https://www.bulgarihotels.com/beijing'},
 {'Restaurant Name': 'Mio',
  'Price Range': '298 - 1,688 CNY',
  'Restauarant Website': 'https://www.fourseasons.com/beijing/'},
 {'Restaurant Name': 'Jing Yaa Tang',
  'Price Range': '188 - 600 CNY',
  'Restauarant Website': 'https://www.theoppositehouse.com/'},
 {'Restaurant Name': 'Xin Rong Ji (Jianguomenwai Street)',
  'Price Range': '400 - 600 CNY',
  'Restauarant Website': 'www.xinrongji.cc'},
 {'Restaurant Name': 'Country Kitchen',
  'Price Range': '200 - 700 CNY',
  'Restauarant Website': 'https://www.rosewoodhotels.com/en/beijing'},
 {'Restaurant Name': 'The Tasty House',
  'Price Range': '400 - 1,000 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Huaiyang Fu',
  'Price Range': '200 - 300 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Lei Garden (Jinbao Tower)',
  'Price Range': '200 - 600 CNY',
  'Restauarant Website': 'www.leigarden.hk/'},
 {'Restaurant Name': 'Fu Chun Ju',
  'Price Range': '300 - 1,000 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'In Love (Gongti East Road)',
  'Price Range': '300 - 600 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'The Beijing Kitchen',
  'Price Range': '150 - 500 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Lao Ji Tang (Gongrentiyuchang South Road)',
  'Price Range': '100 - 250 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Maison Lameloise',
  'Price Range': '488 - 2,388 CNY',
  'Restauarant Website': 'http://www.lameloise.com.cn/'},
 {'Restaurant Name': "T'ang Court",
  'Price Range': '400 - 3,188 CNY',
  'Restauarant Website': 'http://www.xintiandi.langhamhotels.com/'},
 {'Restaurant Name': 'Shang-High Cuisine',
  'Price Range': '300 - 1,000 CNY',
  'Restauarant Website': 'https://www.jumeirah.com/'},
 {'Restaurant Name': 'Lao Zheng Xing (Huangpu)',
  'Price Range': '150 - 300 CNY',
  'Restauarant Website': 'http://www.laozhengxing-sh.com'},
 {'Restaurant Name': 'Moose (Changning)',
  'Price Range': '300 - 800 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Yi Long Court',
  'Price Range': '250 - 1,980 CNY',
  'Restauarant Website': 'https://www.peninsula.com/shanghai'},
 {'Restaurant Name': 'Jade Mansion',
  'Price Range': '300 - 600 CNY',
  'Restauarant Website': 'http://www.jade388.com/'},
 {'Restaurant Name': 'Jin Xuan',
  'Price Range': '300 - 1,200 CNY',
  'Restauarant Website': 'https://www.ritzcarlton.cn/shanghaipudong'},
 {'Restaurant Name': 'Yu Zhi Lan',
  'Price Range': '1,288 - 1,888 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Seventh Son',
  'Price Range': '300 - 1,000 CNY',
  'Restauarant Website': 'https://www.seventhson.hk/'},
 {'Restaurant Name': 'Tea Culture (East Beijing Road)',
  'Price Range': '200 - 800 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Moose (Pudong)',
  'Price Range': '300 - 800 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': "Sir Elly's",
  'Price Range': '650 - 1,950 CNY',
  'Restauarant Website': 'https://www.peninsula.com/shanghai'},
 {'Restaurant Name': 'Meet the Bund',
  'Price Range': '200 - 500 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Ming Court',
  'Price Range': '300 - 800 CNY',
  'Restauarant Website': 'https://www.cordishotels.com/shanghai-hongqiao'},
 {'Restaurant Name': 'Phénix',
  'Price Range': '198 - 988 CNY',
  'Restauarant Website': 'https://www.thepuli.com/'},
 {'Restaurant Name': 'Fu He Hui',
  'Price Range': '880 - 1,160 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Ren He Guan (Zhaojiabang Road)',
  'Price Range': '150 - 300 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Yong Yi Ting',
  'Price Range': '300 - 1,200 CNY',
  'Restauarant Website': 'https://www.mandarinoriental.com/shanghai'},
 {'Restaurant Name': 'Cheng Long Hang (Huangpu)',
  'Price Range': '388 - 988 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Da Dong (Xuhui)',
  'Price Range': '300 - 600 CNY',
  'Restauarant Website': 'http://www.dadongdadong.com/'},
 {'Restaurant Name': 'Canton Table',
  'Price Range': '400 - 1,000 CNY',
  'Restauarant Website': 'https://www.threeonthebund.com/'},
 {'Restaurant Name': 'Il Ristorante - Niko Romito',
  'Price Range': '450 - 2,100 CNY',
  'Restauarant Website': 'https://www.bulgarihotels.com/shanghai'},
 {'Restaurant Name': 'Jean Georges',
  'Price Range': '298 - 1,498 CNY',
  'Restauarant Website': 'https://www.threeonthebund.com/'},
 {'Restaurant Name': 'Lei Garden (Xuhui)',
  'Price Range': '150 - 500 CNY',
  'Restauarant Website': 'www.leigarden.hk'},
 {'Restaurant Name': 'Le Comptoir de Pierre Gagnaire',
  'Price Range': '398 - 1,488 CNY',
  'Restauarant Website': 'https://www.capellahotels.com/en/capella-shanghai'},
 {'Restaurant Name': 'Amazing Chinese Cuisine (Changning)',
  'Price Range': '800 - 1,200 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Lei Garden (Pudong)',
  'Price Range': '150 - 550 CNY',
  'Restauarant Website': 'www.leigarden.hk'},
 {'Restaurant Name': 'Da Dong (Jingan)',
  'Price Range': '400 - 1,000 CNY',
  'Restauarant Website': 'www.dadongdadong.com'},
 {'Restaurant Name': 'Yong Fu',
  'Price Range': '500 - 1,000 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Le Patio & La Famille (Huangpu)',
  'Price Range': '250 - 400 CNY',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Xin Rong Ji (West Nanjing Road)',
  'Price Range': '400 - 1,000 CNY',
  'Restauarant Website': 'http://www.xinrongji.cc/'},
 {'Restaurant Name': 'Kinoshita',
  'Price Range': '83 - 383 BRL',
  'Restauarant Website': 'https://www.restaurantekinoshita.com.br/'},
 {'Restaurant Name': 'Evvai',
  'Price Range': '160 - 389 BRL',
  'Restauarant Website': 'https://www.evvai.com.br/'},
 {'Restaurant Name': 'Mee',
  'Price Range': '190 - 520 BRL',
  'Restauarant Website': 'https://www.belmond.com/'},
 {'Restaurant Name': 'Cipriani',
  'Price Range': '180 - 440 BRL',
  'Restauarant Website': 'https://www.belmond.com/'},
 {'Restaurant Name': 'Maní',
  'Price Range': '130 - 470 BRL',
  'Restauarant Website': 'https://www.manimanioca.com.br/'},
 {'Restaurant Name': 'Jun Sakamoto',
  'Price Range': '300 - 395 BRL',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Huto',
  'Price Range': '190 - 315 BRL',
  'Restauarant Website': 'https://www.hutorestaurante.com.br/'},
 {'Restaurant Name': 'Kan Suke',
  'Price Range': '70 - 340 BRL',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'Picchi',
  'Price Range': '170 - 460 BRL',
  'Restauarant Website': 'https://www.restaurantepicchi.com.br/'},
 {'Restaurant Name': 'Lasai',
  'Price Range': '345 - 385 BRL',
  'Restauarant Website': 'https://www.lasai.com.br/'},
 {'Restaurant Name': 'Bottiglieria 1881',
  'Price Range': '200 - 360 PLN',
  'Restauarant Website': 'https://www.1881.com.pl/'},
 {'Restaurant Name': 'Varoulko Seaside',
  'Price Range': '43 - 60 EUR',
  'Restauarant Website': 'https://www.varoulko.gr/'},
 {'Restaurant Name': "Botrini's",
  'Price Range': '90 - 120 EUR',
  'Restauarant Website': 'https://www.botrinis.com/'},
 {'Restaurant Name': 'Hytra',
  'Price Range': '55 - 90 EUR',
  'Restauarant Website': 'https://www.hytra.gr/'},
 {'Restaurant Name': 'Field',
  'Price Range': '650 - 3,200 CZK',
  'Restauarant Website': 'https://www.fieldrestaurant.cz/'},
 {'Restaurant Name': 'La Degustation Bohême Bourgeoise',
  'Price Range': '950 - 2,100 CZK',
  'Restauarant Website': 'https://www.ladegustation.cz/'},
 {'Restaurant Name': 'APRON',
  'Price Range': '99 - 141 EUR',
  'Restauarant Website': 'https://www.restaurant-apron.at/'},
 {'Restaurant Name': 'Walter Bauer',
  'Price Range': '52 - 79 EUR',
  'Restauarant Website': 'N/A'},
 {'Restaurant Name': 'TIAN',
  'Price Range': '120 - 140 EUR',
  'Restauarant Website': 'https://www.tian-restaurant.com/'},
 {'Restaurant Name': 'SHIKI',
  'Price Range': '115 - 145 EUR',
  'Restauarant Website': 'https://www.shiki.at/'},
 {'Restaurant Name': 'Edvard',
  'Price Range': '60 - 158 EUR',
  'Restauarant Website': 'https://www.kempinski.com/vienna'},
 {'Restaurant Name': '[aend]',
  'Price Range': '49 - 149 EUR',
  'Restauarant Website': 'https://www.aend.at/'},
 {'Restaurant Name': 'Esszimmer',
  'Price Range': '45 - 128 EUR',
  'Restauarant Website': 'https://www.esszimmer.com/'},
 {'Restaurant Name': 'The Glass Garden',
  'Price Range': '63 - 163 EUR',
  'Restauarant Website': 'https://www.monchstein.at/'},
 {'Restaurant Name': 'Pfefferschiff',
  'Price Range': '65 - 189 EUR',
  'Restauarant Website': 'https://www.pfefferschiff.at/'},
 {'Restaurant Name': 'Pramerl & the Wolf',
  'Price Range': '110 - 130 EUR',
  'Restauarant Website': 'https://www.pramerlandthewolf.com/'}]
